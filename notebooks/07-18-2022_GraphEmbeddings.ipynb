# %%
import glob
import io
import itertools
import json
import re
import string
from collections import Counter

import matplotlib.pyplot as plt
import nltk
import numpy as np
import pandas as pd
import regex as re
import tensorflow as tf
import torch_geometric
import tqdm
from keras.layers import Embedding, TextVectorization
from nltk import word_tokenize
from nltk.corpus import wordnet as wn
from nltk.stem import WordNetLemmatizer

nltk.download('wordnet')
nltk.download('omw-1.4')

SEED = 42
AUTOTUNE = tf.data.experimental.AUTOTUNE
# %load_ext tensorboard
import io
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# [nltk_data] Error loading wordnet: <urlopen error [SSL:
# [nltk_data]     CERTIFICATE_VERIFY_FAILED] certificate verify failed:
# [nltk_data]     unable to get local issuer certificate (_ssl.c:1129)>
# [nltk_data] Error loading omw-1.4: <urlopen error [SSL:
# [nltk_data]     CERTIFICATE_VERIFY_FAILED] certificate verify failed:
# [nltk_data]     unable to get local issuer certificate (_ssl.c:1129)>

# %% [markdown]
# ## Import Metadata

# %%
path = "/Users/xavierevans/nasa/metadata"
json_files = glob.glob(path + "/*.json")

# %%
json_keys = []
for file in json_files:
    with open(file) as f:
        data = json.load(f)
        json_keys += data.keys()
json_keys = list(set(json_keys))

# %%
json_values = []
for file in json_files:
    with open(file) as f:
        data = json.load(f)
        json_values.append(
            [data[key] if key in data.keys() else None for key in json_keys]
        )

# %%
df = pd.DataFrame(json_values, columns=json_keys)
columns = df.columns

# %% [markdown]
# ## Process Text

# %%
def clean_abstract(abstract):
    return abstract.replace("\n", "").replace("\t", "")

# %%
nltk.download('stopwords')
stop_words = set(nltk.corpus.stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/xavierevans/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
lemmatizer = WordNetLemmatizer()

# %%
def clean_text(text):
    # Remove extra white space
    text = re.sub(r'\s+', ' ', text, flags=re.I)      
    # Remove special characters
    text = re.sub(r'\W', ' ', str(text))
    # Remove single characters
    text = re.sub(r'\s+[a-zA-Z]\s+', ' ', text)

    # Convert to lowercase
    text = text.lower()

    # Tokenize    
    tokens = text.split()
    # Remove stop words
    tokens_no_stop = [word for word in tokens if word not in stop_words]
    # Drop short words
    tokens_no_stop = [word for word in tokens_no_stop if len(word) > 3]

    clean_text = ' '.join(tokens_no_stop)

    return clean_text

# %%
def clean_title(title):
    return re.sub(r"[()]", "", title)

# %%
abstracts_list = df["Abstract"].to_list()
titles_list = df["EntryTitle"].to_list()

clean_abstracts_list = [clean_text(abstract) for abstract in abstracts_list]
clean_titles_list = [clean_text(title) for title in titles_list]

# %%
def create_vocab(tokens):
    vocab = set(tokens)

    token2index = dict(zip(vocab, range(1, len(vocab) + 1)))
    token2index['OOV'] = -1
    token2index['PAD'] = 0

    index2token = {index: token for token, index in token2index.items()}

    return vocab, token2index, index2token

# %%
abstract_tokens = ' '.join(clean_abstracts_list).split()
title_tokens = ' '.join(clean_titles_list).split()

# %%
tokens = list(set(abstract_tokens + title_tokens))
vocab, token2index, index2token = create_vocab(tokens)

# %%
abstract_tokens = [abstract.split() for abstract in clean_abstracts_list]
abstract_sequences = [[token2index[token] for token in abstract] for abstract in abstract_tokens]
title_tokens = [title.split() for title in clean_titles_list]
title_sequences = [[token2index[token] for token in title] for title in title_tokens]

# %%
padded_sequences = tf.keras.utils.pad_sequences(
    abstract_sequences + title_sequences,
    padding='post'
)

# %% [markdown]
# ## Word Embeddings

# %%
from gensim.models.fasttext import FastText

# %%
dimensions = 300
window_size = 5
min_count = 1
 
model = FastText(
    abstract_tokens + title_tokens,
    vector_size=dimensions,
    window=window_size, 
    min_count=min_count
)

# %%
token2embed = {token: model.wv[token].tolist() for token in tokens}
token2embed['OOV'] = np.zeros(dimensions, dtype=int)

# %% [markdown]
# ## Synonyms

# %%
def get_synonyms(word):
    synsets = wn.synsets(word)
    lemma_names = []
    for synset in synsets:
        for lemma in synset.lemma_names():
            spaced_lemma = lemma.replace("_", " ")
            if spaced_lemma != word:
                lemma_names.append(spaced_lemma)
    return list(set(lemma_names))

# %%
token2synon = {token: get_synonyms(token) for token in tokens}

# %%
synons = [item for sublist in list(token2synon.values()) for item in sublist]
tokens_synons = list(set(tokens + synons))

# %%
token2graph = dict(zip(tokens_synons, range(len(tokens_synons))))

# %%
def create_synon_edges(synon_dict):
    synon_edges = []
    for token, synons in synon_dict.items():
        token_id = token2graph[token]
        for synon in synons:
            synon_id = token2graph[synon]
            synon_edges.append((token_id, synon_id, 1.0))
    return synon_edges

# %%
synon_edges = create_synon_edges(token2synon)

# %% [markdown]
# ## Word Similarity

# %%
from itertools import permutations

from numpy.linalg import norm

# %%
token_perms = list(permutations(tokens, 2))

# %%
def cosine_similarity(t1, t2):
    v1, v2 = np.array(model.wv[t1]), np.array(model.wv[t2])
    return np.dot(v1, v2) / (norm(v1)*norm(v2))

# %%
weights = [cosine_similarity(t1, t2) for t1, t2 in token_perms]

# %%
cosine_edges = [(token2graph[t1], token2graph[t2], weight) for (t1, t2), weight in zip(token_perms, weights)]

# %% [markdown]
# ## Graph Creation

# %%
edges = synon_edges + cosine_edges

# %%
with open('/users/xavierevans/nasa/notebooks/07-18-2022_EdgeListWeights.txt', 'w') as fp:
    for edge in edges:
        fp.write(f"{edge}")
    print('Done')

# %%
import networkx as nx

graph = nx.Graph()

for source, target, weight in edges:
    graph.add_edge(source, target, weight=weight)

# %%
import networkx as nx
from node2vec import Node2Vec

node2vec = Node2Vec(graph, dimensions=3, walk_length=2, num_walks=1, workers=10)

# %% [markdown]
# ## tf–idf

# %%
# Create list of combined title and abstract text
title_abstract_list = list(zip(clean_titles_list, clean_abstracts_list))
title_abstract_list = [' '.join(title_abstract) for title_abstract in title_abstract_list]

# %%
# Give each dataset a unique ID
title2index = dict(zip(titles_list, range(len(titles_list))))
index2title = {index: title for title, index in title2index.items()}

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
# Calculate tf–idf for all words
vectorizer = TfidfVectorizer()
vectors = vectorizer.fit_transform(title_abstract_list)
feature_names = vectorizer.get_feature_names()
dense = vectors.todense()
dense_list = dense.tolist()
df_tfidf = pd.DataFrame(dense_list, columns=feature_names)
# Out:
# /Users/xavierevans/nasa/environment/miniforge3/envs/nasa/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# ## Relevance

# %%
query = "measuring precipitation passive microwave sensors"

# %%
index2title
# Out:
# {0: 'Gridded Monthly Time-Mean Observation minus Analysis (oma) Values 0.5 x 0.667 degree V001 (MA_HIRS2_TIROSN_OMA) at GES DISC',
#  1: 'Suomi NPP CrIS Level 1B Full Spectral Resolution V2 (SNPPCrISL1B) at GES DISC',
#  2: 'GPM SSM/I on F13 (GPROF) Climate-based Radiometer Precipitation Profiling L2 1.5 hours 12 km V05 (GPM_2AGPROFF13SSMI_CLIM) at GES DISC',
#  3: 'Sentinel-5P TROPOMI Radiance product band 7 (SWIR detector) L1B 5.5km x 7km V1 (S5P_L1B_RA_BD7_HiR) at GES DISC',
#  4: 'OMI/Aura NO2 Tropospheric, Stratospheric & Total Columns MINDS Daily L2 Global Gridded 0.25 degree x 0.25 degree V1.1 (OMI_MINDS_NO2G) at GES DISC',
#  5: 'MLS/Aura Level 3 Monthly Binned Hydroxyl (OH) Mixing Ratio on Assorted Grids V004 (ML3MBOH) at GES DISC',
#  6: 'Gridded Monthly Time-Mean Observation minus Analysis (oma) Values 0.5 x 0.667 degree V001 (MA_SSU_NOAA07_OMA) at GES DISC',
#  7: 'Suomi NPP CrIS Level 1B Normal Spectral Resolution V1 (SNPPCrISL1BNSR) at GES DISC',
#  8: 'MODIS/Aqua Aerosol 5-Min L2 Swath Subset 10km along MLS V002 (MAM04S0) at GES DISC',
#  9: 'GPM GMI Antenna Temperatures L1BASE 1.5 hours 13 km V05 (GPM_BASEGPMGMI) at GES DISC',
#  10: 'GPM MHS on NOAA-19 (GPROF) Radiometer Precipitation Profiling L2A 1.5 hours 17 km V05 (GPM_2AGPROFNOAA19MHS_CLIM) at GES DISC',
#  11: 'WindSat/Coriolis surface soil moisture (LPRM) L3 1 day 25 km x 25 km nighttime V001 (LPRM_WINDSAT_NT_SOILM3) at GES DISC',
#  12: 'ATMOS L2 Trace Gases on Altitude Grid, Tab Delimited Format V3 (ATMOSL2AT) at GES DISC',
#  13: 'TOVS LMD 5 DAY GRIDS from NOAA-12 V01 (TOVSB5ND) at GES DISC',
#  14: 'TROPESS CrIS-SNPP L2 Ammonia for West Coast Fires, Standard Product V1 (TRPSDL2NH3CRSWCF) at GES DISC',
#  15: 'MLS/Aura Level 2 Diagnostics, Miscellaneous Grid V005 (ML2DGM) at GES DISC',
#  16: 'TOVS GLA 5 DAY GRIDS from NOAA-11 V01 (TOVSA5NH) at GES DISC',
#  17: 'Suomi NPP ATMS Sounder Science Investigator-led Processing System (SIPS) Level 1B Brightness Temperature V3 (SNPPATMSL1B) at GES DISC',
#  18: 'SORCE XPS Level 4 Solar Spectral Irradiance 0.1nm Res 5-Minute V012 (SOR4XPS5) at GES DISC',
#  19: 'Aqua/AIRS L3 Daily Support Product (AIRS-only) 1 degree x 1 degree V7.0 at GES DISC',
#  20: 'AIRS/Aqua L3 8-day Support Multiday Product (AIRS+AMSU) 1 degree x 1 degree V006 (AIRX3SP8) at GES DISC',
#  21: 'MLS/Aura Level 2 Cloud Ice Product V004 (ML2IWC) at GES DISC',
#  22: 'TROPESS AIRS-Aqua L2 Ammonia for Forward Stream, Standard Product V1 (TRPSDL2NH3AIRSFS) at GES DISC',
#  23: 'tavg3_3d_chm_Fe: MERRA Chem 3D IAU, Precip Mass Flux, Time average 3-hourly  1.25 x 1 degree V5.2.0 (MAT3FECHM) at GES DISC',
#  24: 'TSIS SIM Level 3 Solar Spectral Irradiance 24-Hour Means V06 (TSIS_SSI_L3_24HR) at GES DISC',
#  25: 'Gridded Monthly Time-Mean Observation minus Analysis (oma) Values 0.5 x 0.667 degree V001 (MA_SSMI_DMSP10_OMA) at GES DISC',
#  26: 'OCO-3 Level 2 bias-corrected XCO2 and other select fields from the full-physics retrieval aggregated as daily files, Retrospective processing VEarlyR (OCO3_L2_Lite_FP) at GES DISC',
#  27: 'Sounder SIPS: JPSS-1 CrIS Level 3 Specific Quality Control Gridded Daily CLIMCAPS V2 at GES DISC',
#  28: 'MERRA-2 tavgU_3d_cld_Np: 3d,diurnal,Time-Averaged,Pressure-Level,Assimilation,Cloud Diagnostics 0.625 x 0.5 degree V5.12.4 (M2TUNPCLD) at GES DISC',
#  29: 'OCO-2 Level 2 meteorological parameters interpolated from global assimilation model for each sounding V10 (OCO2_L2_Met) at GES DISC',
#  30: 'GPM PR on TRMM Reflectivity, Precipitation Statistics, Histograms, at Surface and Fixed Heights, 1 month 5x5 and 0.25x0.25 degree V06 (GPM_3PR) at GES DISC',
#  31: 'MLS/Aura Level 3 Daily Binned Temperature on Assorted Grids V005 (ML3DBT) at GES DISC',
#  32: 'NLDAS VIC Land Surface Model L4 Monthly 0.125 x 0.125 degree V002 (NLDAS_VIC0125_M) at GES DISC',
#  33: 'TROPESS CrIS-SNPP L2 Methanol for Forward Stream, Standard Product V1 (TRPSDL2CH3OHCRSFS) at GES DISC',
#  34: 'OCO-3 Level 2 geolocated XCO2 retrievals results, physical model VEarlyR (OCO3_L2_Standard) at GES DISC',
#  35: 'GPM TMI on TRMM (GPROF) Climate-based Radiometer Precipitation Profiling L2A 1.5 hours 13 km V05 (GPM_2AGPROFTRMMTMI_CLIM) at GES DISC',
#  36: 'Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_MSU_NOAA14_OBS) at GES DISC',
#  37: 'Carbon Monitoring System Lake Michigan Primary Production Monthly V1 (CMSLakeMichiganPPM) at GES DISC',
#  38: 'Aqua/AIRS L3 Monthly Standard Physical Retrieval (AIRS-only) 1 degree x 1 degree V7.0 at GES DISC',
#  39: 'GPM SAPHIR on MT1 (PRPS) Radiometer Precipitation Profiling L2 1.5 hours 10 km V06 (GPM_2APRPSMT1SAPHIR) at GES DISC',
#  40: 'MERRA-2 inst6_3d_ana_Nv: 3d,6-Hourly,Instantaneous,Model-Level,Analysis,Analyzed Meteorological Fields 0.625 x 0.5 degree V5.12.4 (M2I6NVANA) at GES DISC',
#  41: 'NLDAS Primary Forcing Data L4 Hourly 0.125 x 0.125 degree V2.0 (NLDAS_FORA0125_H) at GES DISC',
#  42: 'GPM VIRS on TRMM Radiance L1B 1.5 hours 2 km V05 (GPM_1BVIRS) at GES DISC',
#  43: 'GPM AMSR-2 on GCOM-W1 (GPROF) Radiometer Precipitation Profiling L3 1 month 0.25 degree x 0.25 degree V05 (GPM_3GPROFGCOMW1AMSR2) at GES DISC',
#  44: 'GPM SSMIS on F19 (GPROF) Climate-based Radiometer Precipitation Profiling L3 1 month 0.25 degree x 0.25 degree V05 (GPM_3GPROFF19SSMIS_CLIM) at GES DISC',
#  45: 'Aqua/AIRS L2 Cloud-Cleared Infrared Radiances (AIRS+AMSU+HSB) V7.0 at GES DISC',
#  46: 'GPCP Precipitation Level 3 Daily 0.5-Degree V3.1 (GPCPDAY) at GES DISC',
#  47: 'Sounder SIPS: Suomi NPP CrIMSS Level 3 Comprehensive Quality Control Gridded Daily CLIMCAPS Normal Spectral Resolution V2 at GES DISC',
#  48: 'ATMOS L2 Trace Gases on Potential Temperature Grid, Tab Delimited Format V3 (ATMOSL2TT) at GES DISC',
#  49: 'GLDAS CLM Land Surface Model L4 3 hourly 1.0 x 1.0 degree Subsetted V001 (GLDAS_CLM10SUBP_3H) at GES DISC',
#  50: 'OCO-3 Level 1B calibrated, geolocated calibration spectra, Retrospective Processing EarlyR (OCO3_L1B_Calibration) at GES DISC',
#  51: 'TOMS Nimbus-7 UV Reflectivity Daily L3 Global 1 deg x 1.25 deg Lat/Lon Grid V008 (TOMSN7L3dref) at GES DISC',
#  52: 'MERRA-2 inst1_2d_int_Nx: 2d,1-Hourly,Instantaneous,Single-Level,Assimilation,Vertically Integrated Diagnostics 0.625 x 0.5 degree V5.12.4 (M2I1NXINT) at GES DISC',
#  53: 'Sentinel-5P TROPOMI Tropospheric Ozone Profile 1-Orbit L2 5.5km x 3.5km V1 (S5P_L2__O3_TPR_HiR) at GES DISC',
#  54: 'SBUV2/NOAA-16 Level 2 Daily Ozone Profile and Total Column from CD-ROM V008 (SBUV2N16O3) at GES DISC',
#  55: 'NLDAS Mosaic Land Surface Model L4 Hourly 0.125 x 0.125 degree V002 (NLDAS_MOS0125_H) at GES DISC',
#  56: 'TROPESS CrIS-SNPP and TROPOMI-S5P L2 Carbon Monoxide for Forward Stream, Standard Product V1 (TRPSDL2COCRSTRPOMIFS) at GES DISC',
#  57: 'OMI/Aura NO2 Tropospheric, Stratospheric & Total Columns MINDS 1-Orbit L2 Swath 13 km x 24 km V1 (OMI_MINDS_NO2) at GES DISC',
#  58: 'MERRA-2 tavgM_2d_glc_Nx: 2d,Monthly mean,Time-Averaged,Single-Level,Assimilation,Land Ice Surface Diagnostics 0.625 x 0.5 degree V5.12.4 (M2TMNXGLC) at GES DISC',
#  59: 'GPM SSMIS on F17 (GPROF) Radiometer Precipitation Profiling L3 1 day 0.25 degree x 0.25 degree V05 (GPM_3GPROFF17SSMIS_DAY) at GES DISC',
#  60: 'Sentinel-5P TROPOMI Carbon Monoxide CO Column 1-Orbit L2 5.5km x 7km V1 (S5P_L2__CO_____HiR) at GES DISC',
#  61: 'GPM PR and TMI on TRMM Combined Convective-Stratiform Latent Heating Profiles L3 1 month 0.25x0.25 degree V06 (GPM_3HCSH_TRMM) at GES DISC',
#  62: 'TRMM Attitude and VIRS Packets and Header Record L1A V7 (TRMM_1A01) at GES DISC',
#  63: 'Sentinel-5P TROPOMI Ozone Profile 1-Orbit L2 30km x 30km V2 (S5P_L2__O3__PR_HiR) at GES DISC',
#  64: 'MLS/Aura Level 3 Monthly Binned Carbon Monoxide (CO) Mixing Ratio on Assorted Grids V005 (ML3MBCO) at GES DISC',
#  65: 'NCEP/DOE Reanalysis II in HDF-EOS5, for GSSTF2c, 1x1 deg Daily grid V2c (GSSTF_NCEP) at GES DISC',
#  66: 'MLS/Aura Level 3 Daily Binned Water Vapor (H2O) Mixing Ratio on Zonal and Similar Grids V005 (ML3DZH2O) at GES DISC',
#  67: 'TROPESS TROPOMI-S5P L2 Ozone for Forward Stream, Standard Product V1 (TRPSDL2O3TRPOMIFS) at GES DISC',
#  68: 'tavgM_2d_chm_Fx: MERRA Chem 2D IAU Diagnostics, Fluxes and Meteorology, Monthly Mean  1.25 x 1 degree V5.2.0 (MATMFXCHM) at GES DISC',
#  69: 'Sentinel-5P TROPOMI Sulphur Dioxide SO2 1-Orbit L2 5.5km x 3.5km V1 (S5P_L2__SO2____HiR) at GES DISC',
#  70: 'HIRDLS-MLS/Aura Level 3 Monthly 10 x 20 deg Ice Water Content V002 (HIRMLS3IWC) at GES DISC',
#  71: 'MLS/Aura Level 3 Daily Binned Geopotential Height (GPH) on Zonal and Similar Grids V005 (ML3DZGPH) at GES DISC',
#  72: 'TRMM Ground Validation Radar Site Rain Rate Map L2 1 hour 2 km V7 (TRMM_2A53) at GES DISC',
#  73: 'MLS/Aura Level 3 Daily Binned Ozone (O3) Mixing Ratio on Zonal and Similar Grids V004 (ML3DZO3) at GES DISC',
#  74: 'AIRS/Aqua L3 Monthly Support Product (AIRS+AMSU) 1 degree x 1 degree V006 (AIRX3SPM) at GES DISC',
#  75: 'Sentinel-5P TROPOMI Irradiance product SWIR module L1B V2 (S5P_L1B_IR_SIR) at GES DISC',
#  76: 'Sentinel-5P TROPOMI Radiance product band 7 (SWIR detector) L1B V2 (S5P_L1B_RA_BD7) at GES DISC',
#  77: 'WindSat/Coriolis surface soil moisture (LPRM) L2 V001 (LPRM_WINDSAT_SOILM2) at GES DISC',
#  78: 'FLDAS Noah Land Surface Model L4 Global Monthly 0.1 x 0.1 degree (GDAS and CHIRPS-PRELIM) V001 (FLDAS_NOAH01_CP_GL_M) at GES DISC',
#  79: 'Carbon Monitoring System Flux for Prior Total Carbon L4 V1 (CMSFluxTotalprior) at GES DISC',
#  80: 'TOMS EP Total Column Ozone Daily and Monthly Zonal Means V008 (TOMSEPL3ztoz) at GES DISC',
#  81: 'Sentinel-5P TROPOMI Carbon Monoxide CO Column 1-Orbit L2 7km x 7km V1 (S5P_L2__CO____) at GES DISC',
#  82: 'GEOS-Carb CASA-GFED Monthly Fire Fuel NPP Rh NEE Fluxes 0.5 degree x 0.5 degree V3 (GEOS_CASAGFED_M_FLUX) at GES DISC',
#  83: 'MERRA-2 tavgU_3d_tdt_Np: 3d,diurnal,Time-Averaged,Pressure-Level,Assimilation,Temperature Tendencies 0.625 x 0.5 degree V5.12.4 (M2TUNPTDT) at GES DISC',
#  84: 'OCO-2 Level 0 spacecraft attitude data V10 (OCO2_Att) at GES DISC',
#  85: 'MERRA-2 tavg3_3d_mst_Np: 3d,3-Hourly,Time-Averaged,Pressure-Level,Assimilation,Moist Processes Diagnostics 0.625 x 0.5 degree V5.12.4 (M2T3NPMST) at GES DISC',
#  86: 'TROPESS CrIS-SNPP L2 Ozone for West Coast Fires, Standard Product V1 (TRPSDL2O3CRSWCF) at GES DISC',
#  87: 'Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_MSU_NOAA06_OBS) at GES DISC',
#  88: 'MRIR/Nimbus-3 Level 1 Meteorological Radiation Data V001 (MRIRN3L1) at GES DISC',
#  89: 'OMI/Aura Level 1B UV Global Geolocated Earthshine Radiances 1-orbit L2 Swath 13x24 km V003 (OML1BRUG) at GES DISC',
#  90: 'GPM PR on TRMM Echo Power L1B 1.5 hours 5 km V05 (GPM_1BPR) at GES DISC',
#  91: 'tavg3_3d_chm_Ne: MERRA Chem 3D IAU C-Grid Edge Mass Flux, Time Average 3-Hourly  0.667 x 0.5 degree V5.2.0 (MAT3NECHM) at GES DISC',
#  92: 'SBUV2/NOAA-19 Ozone (O3) Profile and Total Column Ozone 1 Month Zonal Mean L3 Global 5.0 degree Latitude Zones V1 (SBUV2N19L3zm) at GES DISC',
#  93: 'TIROS-4 Medium-Resolution Scanning Radiometer Level 1 Final Meteorological Radiation Data V001 (TIROS4L1FMRT) at GES DISC',
#  94: 'TROPESS AIRS-Aqua L2 Ozone for Forward Stream, Standard Product V1 (TRPSDL2O3AIRSFS) at GES DISC',
#  95: 'NLDAS Mosaic Land Surface Model L4 Monthly Climatology 0.125 x 0.125 degree V2.0 (NLDAS_MOS0125_MC) at GES DISC',
#  96: 'OMPS-NPP L2 NM Cloud Pressure and Fraction swath orbital V2 (OMPS_NPP_NMCLDRR_L2) at GES DISC',
#  97: 'SBUV2/NOAA-16 Ozone (O3) Nadir Profile and Total Column 1 Day L2 V1 (SBUV2N16L2) at GES DISC',
#  98: 'SAMS/Nimbus-7 Level 3 Zonal Means Composition Data V001 (SAMSN7L3ZMTG) at GES DISC',
#  99: 'SBUV2/NOAA-17 Ozone (O3) Nadir Profile and Total Column 1 Day L2 V1 (SBUV2N17L2) at GES DISC',
#  100: 'CAR Safari South African Biogeophysics and Biogeochemistry L1 V1 (CAR_SAFARI_L1C) at GES DISC',
#  101: 'Sentinel-5P TROPOMI Radiance product band 2 (UV detector) L1B V1 (S5P_L1B_RA_BD2) at GES DISC',
#  102: 'Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_AMSUB_NOAA17_OBS) at GES DISC',
#  103: 'OCO-2 Level 1A collated, parsed, calibration data, Retrospective Processing V10r (OCO2_L1aIn_Pixel) at GES DISC',
#  104: 'GPM SSMI on F15 (GPROF) Climate-based Radiometer Precipitation Profiling L3 1 day 0.25 degree x 0.25 degree V05 (GPM_3GPROFF15SSMI_DAY_CLIM) at GES DISC',
#  105: 'Carbon Monitoring System Lake Michigan Primary Production Yearly V1 (CMSLakeMichiganPPY) at GES DISC',
#  106: 'NLDAS Secondary Forcing Data L4 Monthly 0.125 x 0.125 degree V002 (NLDAS_FORB0125_M) at GES DISC',
#  107: 'MERRA-2 inst3_3d_aer_Nv: 3d,3-Hourly,Instantaneous,Model-Level,Assimilation,Aerosol Mixing Ratio 0.625 x 0.5 degree V5.12.4 (M2I3NVAER) at GES DISC',
#  108: 'Sounder SIPS: AQUA AIRS IR-only Level 3 CLIMCAPS: Comprehensive Quality Control Gridded Monthly V2 at GES DISC',
#  109: 'AIRS/Aqua L3 Daily Standard Physical Retrieval (AIRS+AMSU) 1 degree x 1 degree V006 (AIRX3STD) at GES DISC',
#  110: 'Carbon Monitoring System Carbon Flux for Ocean Prior L4 V2 (CMSFluxOceanPrior) at GES DISC',
#  111: 'MLS/Aura Near-Real-Time L2 Water Vapor (H2O) Mixing Ratio V004 (ML2H2O_NRT) at GES DISC',
#  112: 'Gridded Monthly Time-Mean Observation minus Forecast (omf) Values 0.5 x 0.667 degree V001 (MA_MSU_NOAA08_OMF) at GES DISC',
#  113: 'MLS/Aura Level 3 Monthly Binned Chlorine Monoxide (ClO) Mixing Ratio on Assorted Grids V005 (ML3MBCLO) at GES DISC',
#  114: 'GLDAS Noah Land Surface Model L4 3 hourly 0.25 x 0.25 degree Early Product V2.1 (GLDAS_NOAH025_3H_EP) at GES DISC',
#  115: 'Goddard Satellite-Based Surface Turbulent Fluxes, 1x1 deg Daily Grid, Satellite F14 V2c (GSSTF_F14) at GES DISC',
#  116: 'UARS Cryogenic Limb Array Etalon Spectrometer (CLAES) Level 3AL V009 (UARCL3AL) at GES DISC',
#  117: 'MODIS/Aqua Total Precip Water Vapor 1km and 5km 5-Min L2 Narrow Swath Subset along CloudSat V002 (MAC05S0) at GES DISC',
#  118: 'HIRDLS/Aura Level 3 Chlorine Nitrate (ClONO2) 1deg Lat Zonal Fourier Coefficients V007 (H3ZFCCLONO2) at GES DISC',
#  119: 'OCO-3 Level 2 meteorological parameters interpolated from global assimilation model for each sounding, Retrospective Processing V10r (OCO3_L2_Met) at GES DISC',
#  120: 'MERRA-2 tavgM_3d_qdt_Np: 3d,Monthly mean,Time-Averaged,Pressure-Level,Assimilation,Moist Tendencies 0.625 x 0.5 degree V5.12.4 (M2TMNPQDT) at GES DISC',
#  121: 'MLS/Aura Level 3 Monthly Binned Hypochlorous Acid (HOCl) Mixing Ratio on Assorted Grids V004 (ML3MBHOCL) at GES DISC',
#  122: 'GPM SSMIS on F18 (GPROF) Climate-based Radiometer Precipitation Profiling L3 1 day 0.25 degree x 0.25 degree V05 (GPM_3GPROFF18SSMIS_DAY_CLIM) at GES DISC',
#  123: 'MODIS/Aqua Total Precip Water Vapor 1km and 5km 5-Min L2 Wide Swath Subset along CloudSat V002 (MAC05S1) at GES DISC',
#  124: 'TROPESS AIRS-Aqua L2 Atmospheric Temperature for Forward Stream, Standard Product V1 (TRPSDL2TATMAIRSFS) at GES DISC',
#  125: 'GPM DPR and GMI Combined Convective Stratiform Heating L3 1 month 0.5 degree x 0.5 degree V07 (GPM_3HCSH) at GES DISC',
#  126: 'Multi-Satellite Lambertian Equivalent Reflectivity (Noon Normalized) 10-Day L3 Global 2.0x5.0deg Lat/Lon Grid V1 (MSLERNNL3d10) at GES DISC',
#  127: 'FLDAS Noah Land Surface Model L4 Central Asia Daily 0.01 x 0.01 degree V001 (FLDAS_NOAH001_G_CA_D) at GES DISC',
#  128: 'tavg1_2d_ocn_Nx: MERRA 2D IAU Ocean Surface Diagnostic, Time Average 1-hourly  0.667 x 0.5 degree V5.2.0 (MAT1NXOCN) at GES DISC',
#  129: 'TOMS EP UV Aerosol Index Daily and Monthly Zonal Means V008 (TOMSEPL3zaer) at GES DISC',
#  130: 'THIR/Nimbus-4 Images of Daytime and Nighttime Brightness Temperature at 6.7 microns on 70 mm Film V001 (THIRN4IMCH67) at GES DISC',
#  131: 'Multi-Satellite Merged Ozone (O3) Profile and Total Column 1 Month Zonal Mean L3 Global 5.0 degree Latitude Zones V1 (MSO3L3zm5) at GES DISC',
#  132: 'AMSR2/GCOM-W1 surface soil moisture (LPRM) L3 1 day 25 km x 25 km descending V001 (LPRM_AMSR2_D_SOILM3) at GES DISC',
#  133: 'Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_SSU_NOAA11_OBS) at GES DISC',
#  134: 'GPM PR and TMI on TRMM Combined Gridded Orbital Convective-Stratiform Latent Heating Profiles L3 1.5 hours 0.25x0.25 degree V06 (GPM_3GCSH_TRMM) at GES DISC',
#  135: 'OMPS-NPP L2 NM Nitrogen Dioxide (NO2) Total and Tropospheric Column swath orbital V2 (OMPS_NPP_NMNO2_L2) at GES DISC',
#  136: 'MLS/Aura Level 2 Hydrogen Chloride (HCl) Mixing Ratio V005 (ML2HCL) at GES DISC',
#  137: 'MERRA-2 tavg3_3d_cld_Nv: 3d,3-Hourly,Time-Averaged,Model-Level,Assimilation,Cloud Diagnostics 0.625 x 0.5 degree V5.12.4 (M2T3NVCLD) at GES DISC',
#  138: 'MLS/Aura Level 3 Daily Binned Sulfur Dioxide (SO2) Mixing Ratio on Assorted Grids V004 (ML3DBSO2) at GES DISC',
#  139: 'MLS/Aura Level 3 Daily Binned Hydroxyl (OH) Mixing Ratio on Assorted Grids V004 (ML3DBOH) at GES DISC',
#  140: 'Land/Sea static mask relevant to TMPA precipitation 0.25x0.25 degree V2 (TRMM_TMPA_LandSeaMask) at GES DISC',
#  141: 'Aqua AIRS Level 3 Spectral Outgoing Longwave Radiation (OLR) Monthly',
#  142: 'tavgU_3d_odt_Cp: MERRA 3D IAU Tendency, Ozone, Diurnal  1.25 x 1.25 degree V5.2.0 (MATUCPODT) at GES DISC',
#  143: 'AIRS/Aqua L3 Monthly Quantization in Physical Units (AIRS-only) 5 degrees x 5 degrees V006 (AIRS3QPM) at GES DISC',
#  144: 'Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_AMSUA_NOAA17_OBS) at GES DISC',
#  145: 'Sounder SIPS: Sun Synchronous 13:30 orbit Climate Hyperspectral InfraRed Product (CHIRP): Calibrated Radiances from S-NPP, V2 (SNDR13CHRP1SNCal) at GES DISC',
#  146: 'MLS/Aura Level 3 Daily Binned Relative Humidity With Respect To Ice (RHI) on Assorted Grids V004 (ML3DBRHI) at GES DISC',
#  147: 'Gridded Monthly Time-Mean Observation minus Forecast (omf) Values 0.5 x 0.667 degree V001 (MA_SSMI_DMSP08_OMF) at GES DISC',
#  148: 'GLDAS Noah Land Surface Model L4 monthly 0.25 x 0.25 degree Early Product V2.1 (GLDAS_NOAH025_M_EP) at GES DISC',
#  149: 'TOMS Nimbus-7 UV Reflectivity Monthly L3 Global 1 deg x 1.25 deg Lat/Lon Grid V008 (TOMSN7L3mref) at GES DISC',
#  150: 'MLS/Aura Level 2 Diagnostics, Geophysical Parameter Grid V005 (ML2DGG) at GES DISC',
#  151: 'TRMM Ground Validation Radar Site 3D Rain Map L3 1 month 2 km V7 (TRMM_3A55) at GES DISC',
#  152: 'ACOS GOSAT/TANSO-FTS Level 2 bias-corrected XCO2 and other select fields from the full-physics retrieval aggregated as daily files V9r (ACOS_L2_Lite_FP) at GES DISC',
#  153: 'GPM DPR Ka Environment L2A 1.5 hours 5 km V07 (GPM_2AKaENV) at GES DISC',
#  154: 'BUV/Nimbus-4 Ozone (O3) Profile and Total Column Ozone 1 Month Zonal Mean L3 Global 5.0 degree Latitude Zones V1 (BUVN04L3zm) at GES DISC',
#  155: 'TOVS GLA MONTHLY GRIDS from NOAA-10 V01 (TOVSAMNG) at GES DISC',
#  156: 'instU_2d_int_Nx: MERRA 2D IAU Diagnostic, Vertical Integrals and Budget Terms, Diurnal  0.667 x 0.5 degree V5.2.0 (MAIUNXINT) at GES DISC',
#  157: 'AIRS/Aqua L2 Standard Physical Retrieval (AIRS-only) V006 (AIRS2RET) at GES DISC',
#  158: 'Gridded Monthly Time-Mean Observation minus Forecast (omf) Values 0.5 x 0.667 degree V001 (MA_HIRS2_NOAA14_OMF) at GES DISC',
#  159: 'OCO-3 Level 2 CO2 prior based on CO2 monthly flask record, global meteorology, and age of air, Retrospective Processing V10r (OCO3_L2_CO2Prior) at GES DISC',
#  160: 'GPM AMSR-E on Aqua (GPROF) Climate-based Radiometer Precipitation Profiling L2 1.5 hours 5 km V05 (GPM_2AGPROFAQUAAMSRE_CLIM) at GES DISC',
#  161: 'MUSTARD-EMLS Level 2 Standard Products V1 (MUSEMLSL2DGG) at GES DISC',
#  162: 'GPM TMI on TRMM unpacked data L1A 1.5 hours 13 km V05 (GPM_1ATMI) at GES DISC',
#  163: 'GLDAS VIC Land Surface Model L4 3 hourly 1.0 x 1.0 degree V2.0 (GLDAS_VIC10_3H) at GES DISC',
#  164: 'HRIR/Nimbus-2 Images of Nighttime Brightness Temperature on 70 mm Film V001 (HRIRN2IM) at GES DISC',
#  165: 'GPM AMSUB on NOAA16 (GPROF) Climate-based Radiometer Precipitation Profiling L3 1 month 0.25 degree x 0.25 degree  V05 (GPM_3GPROFNOAA16AMSUB_CLIM) at GES DISC',
#  166: 'tavgM_3d_tdt_Cp: MERRA 3D IAU Tendency, Temperature, Monthly Mean  1.25 x 1.25 degree V5.2.0 (MATMCPTDT) at GES DISC',
#  167: 'GPM AMSR-2 on GCOM-W1 (GPROF) Radiometer Precipitation Profiling L2A 1.5 hours 10 km V05 (GPM_2AGPROFGCOMW1AMSR2) at GES DISC',
#  168: 'MLS/Aura Level 3 Daily Binned Hydrogen Cyanide (HCN) Mixing Ratio on Zonal and Similar Grids V005 (ML3DZHCN) at GES DISC',
#  169: 'MLS/Aura Level 3 Daily Binned Nitrous Oxide (N2O) Mixing Ratio on Assorted Grids V004 (ML3DBN2O) at GES DISC',
#  170: 'GLDAS Catchment Land Surface Model L4 daily 0.25 x 0.25 degree GRACE-DA1 V2.2 (GLDAS_CLSM025_DA1_D_EP) at GES DISC',
#  171: 'GPM AMSR-2 on GCOM-W1 (GPROF) Radiometer Precipitation Profiling L3 1 day 0.25 degree x 0.25 degree V05 (GPM_3GPROFGCOMW1AMSR2_DAY) at GES DISC',
#  172: 'OCO-3 Level 1B calibrated, geolocated science spectra, Retrospective Processing EarlyR (OCO3_L1B_Science) at GES DISC',
#  173: 'TMI/TRMM surface soil moisture (LPRM) L3 1 day 25 km x 25 km daytime V001 (LPRM_TMI_DY_SOILM3) at GES DISC',
#  174: 'GPM MHS on METOP-B (GPROF) Climate-based Radiometer Precipitation Profiling L3 1 month 0.25 degree x 0.25 degree V05 (GPM_3GPROFMETOPBMHS_CLIM) at GES DISC',
#  175: 'GPM SSMIS on F18 (GPROF) Radiometer Precipitation Profiling L3 1 month 0.25 degree x 0.25 degree V05 (GPM_3GPROFF18SSMIS) at GES DISC',
#  176: 'OCO-3 Level 2 CO2 prior based on CO2 monthly flask record, global meteorology, and age of air VEarly (OCO3_L2_CO2Prior) at GES DISC',
#  177: 'HIRDLS/Aura Level 3 Nitrogen Dioxide (NO2) 1deg Lat Zonal Fourier Coefficients V007 (H3ZFCNO2) at GES DISC',
#  178: 'NLDAS Secondary Forcing Data L4 Monthly Climatology 0.125 x 0.125 degree V002 (NLDAS_FORB0125_MC) at GES DISC',
#  179: 'MERRA-2 const_2d_ctm_Nx: Constant Model Parameters for Usage by CTM 0.625 x 0.5 degree V5.12.4 (M2C0NXCTM) at GES DISC',
#  180: 'MSU Daily Oceanic Precipitation with Limb93 Correction L3 1 day 2.5 degree x 2.5 degree V001 (MSUOP) at GES DISC',
#  181: 'MLS/Aura Near-Real-Time L2 Nitrous Oxide (N2O) Mixing Ratio V005 (ML2N2O_NRT) at GES DISC',
#  182: 'OCO-3 Level 2 spatially ordered geolocated retrievals screened using the A-band Preprocessor VEarly (OCO3_L2_ABand) at GES DISC',
#  183: 'MLS/Aura Level 3 Bromine Monoxide (BrO) Daily 10degrees Lat Zonal Mean V003 (ML3DZMBRO) at GES DISC',
#  184: 'MLS/Aura Level 3 Daily Binned Carbon Monoxide (CO) Mixing Ratio on Assorted Grids V005 (ML3DBCO) at GES DISC',
#  185: 'OMI/Aura Near UV Aerosol Optical Depth and Single Scattering Albedo Daily L2 Global Gridded 0.25 degree x 0.25 degree V3 (OMAERUVG) at GES DISC',
#  186: 'SBUV2/NOAA-14 Ozone (O3) Profile and Total Column Ozone 1 Month Zonal Mean L3 Global 5.0 degree Latitude Zones V1 (SBUV2N14L3zm) at GES DISC',
#  187: 'OMI/Aura Level 1B Averaged Solar Irradiances V004 (OML1BIRR) at GES DISC',
#  188: 'TOVS GLA MONTHLY GRIDS from TIROS-N 02 (TOVSAMTN) at GES DISC',
#  189: 'MERRA-2 tavgM_3d_udt_Np: 3d,Monthly mean,Time-Averaged,Pressure-Level,Assimilation,Wind Tendencies 0.625 x 0.5 degree V5.12.4 (M2TMNPUDT) at GES DISC',
#  190: 'Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_HIRS2_AM_OBS) at GES DISC',
#  191: 'Gridded Monthly Time-Mean Observation minus Forecast (omf) Values 0.5 x 0.667 degree V001 (MA_HIRS2_NOAA06_OMF) at GES DISC',
#  192: 'Sentinel-5P TROPOMI Radiance product band 4 (UVIS detector) L1B 5.5km x 3.5km V2 (S5P_L1B_RA_BD4_HiR) at GES DISC',
#  193: 'AMSR-MODIS Boundary Layer Water Vapor L3 Monthly 1 degree x 1 degree V2 (AMMBLWV) at GES DISC',
#  194: 'Multi-Satellite Air Quality Sulfur Dioxide (SO2) Database Long-Term L4 Global V1 (MSAQSO2L4) at GES DISC',
#  195: 'GOZCARDS Source Water Vapor 1 month L3 10 degree Zonal Means on a Vertical Pressure Grid V1 (GozSmlpH2O) at GES DISC',
#  196: 'CAR ARMCAS Arctic Cloud Radiation Measurements L1 V1 (CAR_ARMCAS_L1C) at GES DISC',
#  197: 'Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_SSMI_DMSP13_OBS) at GES DISC',
#  198: 'GPM ATMS on NOAA-20 (GPROF) Radiometer Precipitation Profiling L3 1 day 0.25 degree x 0.25 degree  V05 (GPM_3GPROFNOAA20ATMS_DAY) at GES DISC',
#  199: 'TOVS LMD DAILY GRIDS from NOAA-12 V01 (TOVSBDND) at GES DISC',
#  200: 'MERRA-2 inst1_2d_asm_Nx: 2d,1-Hourly,Instantaneous,Single-Level,Assimilation,Single-Level Diagnostics 0.625 x 0.5 degree V5.12.4 (M2I1NXASM) at GES DISC',
#  201: 'OCO-3 Level 2 spatially ordered geolocated retrievals screened using the IMAP-DOAS Preprocessor (IDP), Retrospective Processing V10r (OCO3_L2_IMAPDOAS) at GES DISC',
#  202: 'TOVS GLA DAILY GRIDS from NOAA-11 V01 (TOVSADNH) at GES DISC',
#  203: 'CAR CLASIC BRDF Measurements V2 (CAR_CLASIC_BRDF) at GES DISC',
#  204: 'TROPESS CrIS-SNPP L2 Ozone IRK for Forward Stream, Standard Product V1 (TRPSDL2O3IRKCRSFS) at GES DISC',
#  205: 'Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_SSMI_DMSP14_OBS) at GES DISC',
#  206: 'THIR/Nimbus-6 Images of Daytime and Nighttime Brightness Temperature on 70 mm Film V001 (THIRN6IM) at GES DISC',
#  207: 'Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_HIRS2_NOAA08_OBS) at GES DISC',
#  208: 'tavgU_3d_cld_Cp: MERRA 3D IAU Diagnostic, Cloud Properties, Diurnal  1.25 x 1.25 degree V5.2.0 (MATUCPCLD) at GES DISC',
#  209: 'GLDAS VIC Land Surface Model L4 monthly 1.0 x 1.0 degree V2.1 (GLDAS_VIC10_M) at GES DISC',
#  210: 'TIROS-3 Medium-Resolution Scanning Radiometer Level 1 Final Meteorological Radiation Data V001 (TIROS3L1FMRT) at GES DISC',
#  211: 'Gridded Monthly Time-Mean Observation minus Analysis (oma) Values 0.5 x 0.667 degree V001 (MA_MSU_NOAA10_OMA) at GES DISC',
#  212: 'MLS/Aura Near-Real-Time L2 Sulfur Dioxide (SO2) Mixing Ratio V004 (ML2SO2_NRT) at GES DISC',
#  213: 'TRMM Microwave Imager Precipitation Profile L3 1 month 0.5 degree x 0.5 degree V7 (TRMM_3A12) at GES DISC',
#  214: 'Goddard Satellite-Based Surface Turbulent Fluxes, 0.25 x 0.25 deg, Daily Grid F13 V3 (GSSTF_F13) at GES DISC',
#  215: 'OMI/Aura Level 2 Near UV Aerosol Optical Depth and Single Scattering Albedo 200-m swath subset along CloudSat track V003 (OMAERUV_CPR) at GES DISC',
#  216: 'TROPESS AIRS-Aqua L2 Ozone IRK for Forward Stream, Standard Product V1 (TRPSDL2O3IRKAIRSFS) at GES DISC',
#  217: 'GPM SSMI on F13 Common Calibrated Brightness Temperatures L1C 1.5 hours 13 km V06 (GPM_1CF13SSMI) at GES DISC',
#  218: 'GPM DPR Spectral Latent Heating Profiles L3 1 day 0.5 degree x 0.5 degree V06 (GPM_3HSLH_DAY) at GES DISC',
#  219: 'MLS/Aura Level 3 Daily Binned Temperature on Zonal and Similar Grids V005 (ML3DZT) at GES DISC',
#  220: 'Multi-Satellite Volcanic Sulfur Dioxide L4 Long-Term Global Database V4 (MSVOLSO2L4) at GES DISC',
#  221: 'GPM SSMI on F14 (GPROF) Climate-based Radiometer Precipitation Profiling L3 1 month 0.25 degree x 0.25 degree V05 (GPM_3GPROFF14SSMI_CLIM) at GES DISC',
#  222: 'GLDAS VIC Land Surface Model L4 monthly 1.0 x 1.0 degree V2.0 (GLDAS_VIC10_M) at GES DISC',
#  223: 'Gridded Monthly Time-Mean Observation minus Analysis (oma) Values 0.5 x 0.667 degree V001 (MA_AMSUA_NOAA15_OMA) at GES DISC',
#  224: 'TOMS Nimbus-7 UV Aerosol Index Monthly L3 Global 1 deg x 1.25 deg Lat/Lon Grid V008 (TOMSN7L3maer) at GES DISC',
#  225: 'MLS/Aura Near-Real-Time L2 Sulfur Dioxide (SO2) Mixing Ratio V005 (ML2SO2_NRT) at GES DISC',
#  226: 'OMI/Aura Formaldehyde (HCHO) Total Column Daily L3 Weighted Mean Global 0.1deg Lat/Lon Grid V003 (OMHCHOd) at GES DISC',
#  227: 'AIRS/Aqua L3 Monthly Standard Physical Retrieval (AIRS+AMSU+HSB) 1 degree x 1 degree V006 (AIRH3STM) at GES DISC',
#  228: 'GPM DPR Spectral Latent Heating Profiles L3 1 day 0.5 degree x 0.5 degree V07 (GPM_3HSLH_DAY) at GES DISC',
#  229: 'MLS/Aura Level 3 Daily Binned Temperature on Zonal and Similar Grids V004 (ML3DZT) at GES DISC',
#  230: 'Sentinel-5P TROPOMI Tropospheric NO2 1-Orbit L2 5.5km x 3.5km V1 (S5P_L2__NO2____HiR) at GES DISC',
#  231: 'SORCE Level 3 Total Solar Irradiance Daily Means V017 (SOR3TSID) at GES DISC',
#  232: 'Sentinel-5P TROPOMI Methane CH4 1-Orbit L2 7km x 7km V1 (S5P_L2__CH4___) at GES DISC',
#  233: 'Carbon Monitoring System Carbon Flux from the Net Biome Exchange L4 V2 (CMSFluxNBE) at GES DISC',
#  234: 'Sounder SIPS: AQUA AIRS IR   MW Level 3 CLIMCAPS : Specific Quality Control Gridded Daily V2 at GES DISC',
#  235: 'AIRS/Aqua L2 Cloud-Cleared Infrared Radiances (AIRS-only) V006 (AIRS2CCF) at GES DISC',
#  236: 'Goddard Satellite-Based Surface Turbulent Fluxes, 0.25 x 0.25 deg, Monthly Grid V3 (GSSTFM) at GES DISC',
#  237: 'GOZCARDS Merged Water Vapor 1 month L3 10 degree Zonal Means on a Vertical Pressure Grid V1 (GozMmlpH2O) at GES DISC',
#  238: 'TROPESS CrIS-JPSS1 L2 Ozone for Forward Stream, Standard Product V1 (TRPSDL2O3CRS1FS) at GES DISC',
#  239: 'Aqua/AIRS  L2 Support Retrieval (AIRS+AMSU) V7.0 at GES DISC',
#  240: 'OMPS-NPP L2 LP Aerosol Extinction Vertical Profile swath daily 3slit V1 (OMPS_NPP_LP_L2_AER675_DAILY) at GES DISC',
#  241: 'OMI/Aura Cloud Pressure and Fraction (O2-O2 Absorption) 1-Orbit L2 Swath 13x24km V003 (OMCLDO2) at GES DISC',
#  242: 'tavgM_3d_trb_Cp: MERRA 3D IAU Diagnostic, Turbulence, Monthly Mean  1.25 x 1.25 degree V5.2.0 (MATMCPTRB) at GES DISC',
#  243: 'TRMM Combined Precipitation Radar and Microwave Imager Rainfall Profile L2 1.5 hours V7 (TRMM_2B31) at GES DISC',
#  244: 'tavgU_3d_rad_Cp: MERRA 3D IAU Diagnostic, Radiation, Diurnal  1.25 x 1.25 degree V5.2.0 (MATUCPRAD) at GES DISC',
#  245: 'OCO-2 Level 1B calibrated, geolocated calibration spectra, Retrospective Processing V10r (OCO2_L1B_Calibration) at GES DISC',
#  246: 'NLDAS Primary Forcing Data L4 Monthly Climatology 0.125 x 0.125 degree V2.0 (NLDAS_FORA0125_MC) at GES DISC',
#  247: 'OCO-3 Level 2 geolocated XCO2 retrievals results, physical model VEarly (OCO3_L2_Standard) at GES DISC',
#  248: 'Gridded Monthly Time-Mean Observation minus Analysis (oma) Values 0.5 x 0.667 degree V001 (MA_SSU_NOAA14_OMA) at GES DISC',
#  249: 'TROPESS CrIS-SNPP L2 Atmospheric Temperature for Forward Stream, Standard Product V1 (TRPSDL2TATMCRSFS) at GES DISC',
#  250: 'Gridded Monthly Time-Mean Observation minus Forecast (omf) Values 0.5 x 0.667 degree V001 (MA_MSU_NOAA09_OMF) at GES DISC',
#  251: 'MERRA-2 tavg3_3d_mst_Nv: 3d,3-Hourly,Time-Averaged,Model-Level,Assimilation,Moist Processes Diagnostics 0.625 x 0.5 degree V5.12.4 (M2T3NVMST) at GES DISC',
#  252: 'OMPS-NPP L1 NM ANC Data Swath Orbital V2 (OMPS_NPP_NM_ANC_L1) at GES DISC',
#  253: 'HIRDLS/Aura Level 3 Temperature 1deg Lat Zonal Fourier Coefficients V007 (H3ZFCT) at GES DISC',
#  254: 'TIROS-2 Medium-Resolution Scanning Radiometer Level 1 Final Meteorological Radiation Data V001 (TIROS2L1FMRT) at GES DISC',
#  255: 'CAR SnowEx17 Snow Mass and Energy Measurements L1 V1 (CAR_SNOWEX17_L1C) at GES DISC',
#  256: 'GPM MHS on NOAA-19 (GPROF) Radiometer Precipitation Profiling L2A 1.5 hours 17 km V05 (GPM_2AGPROFNOAA19MHS) at GES DISC',
#  257: 'SeaWiFS Deep Blue Aerosol Optical Thickness Monthly Level 3 Climatology Data Gridded at 0.5 Degrees V004 (SWDB_L3MC05) at GES DISC',
#  258: 'SIRS/Nimbus-3 Level 1 Radiance Data V001 (SIRSN3L1) at GES DISC',
#  259: 'GPS Radio Occultation Boundary Layer Depth Seasonal L3 V2 (GPSROZPBLS) at GES DISC',
#  260: 'AIRS/Aqua L3 Daily Support Daily Product (AIRS+AMSU+HSB) 1 degree x 1 degree V006 (AIRH3SPD) at GES DISC',
#  261: 'TOMS EP UV Reflectivity Daily and Monthly Zonal Means V008 (TOMSEPL3zref) at GES DISC',
#  262: 'TOMS Nimbus-7 UV-B Erythemal Local Noon Irradiance Monthly L3 Global 1 deg x 1.25 deg Lat/Lon Grid V008 (TOMSN7L3mery) at GES DISC',
#  263: 'Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_AMSUB_NOAA16_OBS) at GES DISC',
#  264: 'BUV/Nimbus-4 Dark Current Study Master Data V001 (BUVN4L1DCM) at GES DISC',
#  265: 'TRMM Radar Rain Distributions L3 1 month 5 degree x 5 degree V7 (TRMM_3A26) at GES DISC',
#  266: 'MLS/Aura Level 3 Daily Binned Carbon Monoxide (CO) Mixing Ratio on Assorted Grids V004 (ML3DBCO) at GES DISC',
#  267: 'Sounder SIPS: Suomi NPP CrIMSS Level 3 Comprehensive Quality Control Gridded Monthly CLIMCAPS Full Spectral Resolution V2 at GES DISC',
#  268: 'HIRDLS/Aura Level 3 Water Vapor (H2O) 1deg Lat Zonal Fourier Coefficients V007 (H3ZFCH2O) at GES DISC',
#  269: 'NLDAS Noah Land Surface Model L4 Hourly 0.125 x 0.125 degree V002 (NLDAS_NOAH0125_H) at GES DISC',
#  270: 'Sounder SIPS: Suomi NPP CrIMSS Level 2 CLIMCAPS Normal Spectral Resolution: Cloud Cleared Radiances V2 at GES DISC',
#  271: 'OCO-2 Level 2 preprocessor using Generic Algorithm for Single Band Acquisition of Gases (GASBAG), Retrospective Processing V10r (OCO2_L2_GASBAG) at GES DISC',
#  272: 'instM_3d_asm_Cp: MERRA 3D IAU State, Meteorology Monthly Mean  1.25 x 1.25 degree V5.2.0 (MAIMCPASM) at GES DISC',
#  273: 'TRMM Ground Validation Radar Site Rain Type Totals Map L3 1 month 2 km V7 (TRMM_3A54UW) at GES DISC',
#  274: 'NASA Ocean Biogeochemical Model assimilating satellite chlorophyll data global monthly VR2017 (NOBM_MON) at GES DISC',
#  275: 'MLS/Aura Near-Real-Time L2 Nitrous Oxide (N2O) Mixing Ratio V004 (ML2N2O_NRT) at GES DISC',
#  276: 'CAR Kuwait Oil Fire Spectral Reflectance L1 V1 (CAR_KUWAITOILFIRE_L1C) at GES DISC',
#  277: 'OMI/Aura Level 1B VIS Zoom-in Geolocated Earthshine Radiances V004 (OML1BRVZ) at GES DISC',
#  278: 'GPM GMI RSS Common Calibrated Brightness Temperatures L1BASE 1.5 hours 13 km V05 (GPM_BASEGPMGMI_RSS) at GES DISC',
#  279: 'Sentinel-5P TROPOMI Sulphur Dioxide SO2 1-Orbit L2 7km x 3.5km V1 (S5P_L2__SO2___) at GES DISC',
#  280: 'LRIR/Nimbus-6 Level 2 Inverted Profiles of Temperature and Ozone V001 (LRIRN6L2IPAT) at GES DISC',
#  281: 'Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_MSU_NOAA07_OBS) at GES DISC',
#  282: 'HIRDLS/Aura Level 3 Geopotential Height 1deg Lat Zonal Fourier Coefficients V007 (H3ZFCGPH) at GES DISC',
#  283: 'Sounder SIPS: AQUA AIRS IR-only Level 2 CLIMCAPS : Atmosphere, cloud and surface geophysical state V2 at GES DISC',
#  284: 'GPM SSMIS on F18 (GPROF) Radiometer Precipitation Profiling L3 1 day 0.25 degree x 0.25 degree V05 (GPM_3GPROFF18SSMIS_DAY) at GES DISC',
#  285: 'GPM MHS on METOP-B (GPROF) Radiometer Precipitation Profiling L2A 1.5 hours 17 km V05 (GPM_2AGPROFMETOPBMHS) at GES DISC',
#  286: 'CAR CLASIC Cloud and Land Surface Measurements L1 V1 (CAR_CLASIC_L1C) at GES DISC',
#  287: 'NASA Energy and Water cycle Study (NEWS) Annual Climatology of the 1st decade of the 21st Century V1.0 (NEWS_WEB_ACLIM) at GES DISC',
#  288: 'AIRS/Aqua L2 CO2 in the free troposphere (AIRS+AMSU) V005 (AIRX2STC) at GES DISC',
#  289: 'TOVS GLA MONTHLY GRIDS from NOAA-9 V01 (TOVSAMNF) at GES DISC',
#  290: 'GPM SSMIS on F18 (GPROF) Climate-based Radiometer Precipitation Profiling L3 1 month 0.25 degree x 0.25 degree V05 (GPM_3GPROFF18SSMIS_CLIM) at GES DISC',
#  291: 'GLDAS VIC Land Surface Model L4 3 hourly 1.0 x 1.0 degree V2.1 (GLDAS_VIC10_3H) at GES DISC',
#  292: 'AIRS/Aqua L3 8-day Standard Physical Retrieval (AIRS+AMSU+HSB) 1 degree x 1 degree V006 (AIRH3ST8) at GES DISC',
#  293: 'TROPESS CrIS-SNPP L2 Carbon Monoxide for Buchholz2021 TS1, Standard Product V1 (TRPSDL2COCRSTS1) at GES DISC',
#  294: 'MODIS Aqua L2 model predicted low cloud types of chopped blocks in which low cloud dominates (block size: 128pixels x 128pixels)',
#  295: 'MLS/Aura Level 3 Daily Binned Hydrogen Cyanide (HCN) Mixing Ratio on Zonal and Similar Grids V004 (ML3DZHCN) at GES DISC',
#  296: 'Sentinel-5P TROPOMI Total Ozone Column 1-Orbit L2 5.5km x 3.5km V2 (S5P_L2__O3_TOT_HiR) at GES DISC',
#  297: 'TROPESS TROPOMI-S5P L2 Methane for Forward Stream, Standard Product V1 (TRPSDL2CH4TRPOMIFS) at GES DISC',
#  298: 'MLS/Aura Level 3 Daily Binned Nitrous Oxide (N2O) Mixing Ratio on Assorted Grids V005 (ML3DBN2O) at GES DISC',
#  299: 'tavg1_2d_lnd_Nx: MERRA 2D IAU Diagnostic, Land Only States and Diagnostics, Time Average 1-hourly  0.667 x 0.5 degree V5.2.0 (MAT1NXLND) at GES DISC',
#  300: 'Explorer-7 Thermal Radiation Experiment Selected White Sensor Temperature (Nighttime) Values V001 (EXP7L1TRTWHT) at GES DISC',
#  301: 'TOMS Nimbus-7 Total Column Ozone Daily L3 Global 1 deg x 1.25 deg Lat/Lon Grid V008 (TOMSN7L3dtoz) at GES DISC',
#  302: 'Sentinel-5P TROPOMI Radiance product band 1 (UV detector) L1B 5.5km x 21km V2 (S5P_L1B_RA_BD1_HiR) at GES DISC',
#  303: 'HIRDLS/Aura Level 3 Nitric Acid (HNO3) 1deg Lat Zonal Fourier Coefficients V007 (H3ZFCHNO3) at GES DISC',
#  304: 'Goddard Satellite-Based Surface Turbulent Fluxes, 0.25 x 0.25 deg, Daily Grid F11 V3 (GSSTF_F11) at GES DISC',
#  305: 'Gridded Monthly Time-Mean Observation minus Analysis (oma) Values 0.5 x 0.667 degree V001 (MA_SSU_NOAA06_OMA) at GES DISC',
#  306: 'GPM IMERG Final Precipitation L3 1 month 0.1 degree x 0.1 degree V06 (GPM_3IMERGM) at GES DISC',
#  307: 'AIRS/Aqua L1B Infrared (IR) quality assurance subset V005 (AIRIBQAP) at GES DISC',
#  308: 'GLDAS Catchment Land Surface Model L4 3 hourly 1.0 x 1.0 degree Early Product V2.1 (GLDAS_CLSM10_3H_EP) at GES DISC',
#  309: 'CAR Eco-3D Vegetation Response to Changing Forcing Factors L1 V1 (CAR_ECO3D_L1C) at GES DISC',
#  310: 'Carbon Monitoring System Flux for Posterior Fire Carbon L4 V1 (CMSFluxFirepost) at GES DISC',
#  311: 'SORCE XPS Level 3 Solar Spectral Irradiance Daily Means V011 (SOR3XPSD) at GES DISC',
#  312: 'MLS/Aura Level 3 Daily Binned Relative Humidity With Respect To Ice (RHI) on Assorted Grids V005 (ML3DBRHI) at GES DISC',
#  313: 'MLS/Aura Level 2 Diagnostics, Geophysical Parameter Grid V004 (ML2DGG) at GES DISC',
#  314: 'GPM DPR Ka Environment L2A 1.5 hours 5 km V06 (GPM_2AKaENV) at GES DISC',
#  315: 'SAMS/Nimbus-7 Level 1 Radiance Data from CD-ROM V001 (SAMSN7L1RAD_CDROM) at GES DISC',
#  316: 'TROPESS CrIS-SNPP and TROPOMI-S5P L2 Methane for Forward Stream, Standard Product V1 (TRPSDL2CH4CRSTRPOMIFS) at GES DISC',
#  317: 'Sounder SIPS: Suomi NPP CrIMSS Level 3 Comprehensive Quality Control Gridded Daily CHART Normal Spectral Resolution V1',
#  318: 'Aqua/AIRS L2 Cloud-Cleared Infrared Radiances (AIRS+AMSU) V7.0 at GES DISC',
#  319: 'OCO-3 Level 1B calibrated, geolocated science spectra,  Early (OCO3_L1B_Science) at GES DISC',
#  320: 'Gridded 6 hours Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_MON_CONV_OBS) at GES DISC',
#  321: 'Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_MSU_NOAA12_OBS) at GES DISC',
#  322: 'OMPS-NPP L2 LP Ozone (O3) Vertical Profile swath daily 3slit V2.5 (OMPS_NPP_LP_L2_O3_DAILY) at GES DISC',
#  323: 'TOMS Meteor-3 Total Ozone UV-Reflectivity Daily L3 Global 1 deg x 1.25 deg V008 (TOMSM3L3) at GES DISC',
#  324: 'GPM MHS on NOAA18 (GPROF) Radiometer Precipitation Profiling L3 1 month 0.25 degree x 0.25 degree V05 (GPM_3GPROFNOAA18MHS_CLIM) at GES DISC',
#  325: 'HIRDLS/Aura Level 3 Chlorofluorocarbon-11 (CFC-11) 1deg Lat Zonal Fourier Coefficients V007 (H3ZFCCFC11) at GES DISC',
#  326: 'UARS Particle Environment Monitor (PEM) Level 3AT V004 (UARPE3AT) at GES DISC',
#  327: 'MLS/Aura Level 2 Hydrogen Chloride (HCl) Mixing Ratio V004 (ML2HCL) at GES DISC',
#  328: 'OMI/Aura Nitrogen Dioxide (NO2) Total and Tropospheric Column 1-orbit L2 Swath 13x24 km V003 (OMNO2) at GES DISC',
#  329: 'MLS/Aura Level 3 Daily Binned Sulfur Dioxide (SO2) Mixing Ratio on Assorted Grids V005 (ML3DBSO2) at GES DISC',
#  330: 'MLS/Aura Level 3 Daily Binned Hydroxyl (OH) Mixing Ratio on Assorted Grids V005 (ML3DBOH) at GES DISC',
#  331: 'MERRA-2 inst6_3d_ana_Np: 3d,6-Hourly,Instantaneous,Pressure-Level,Analysis,Analyzed Meteorological Fields 0.625 x 0.5 degree V5.12.4 (M2I6NPANA) at GES DISC',
#  332: 'TOVS GLA MONTHLY GRIDS from NOAA-7 02 (TOVSAMNC) at GES DISC',
#  333: 'GPM IMERG Final Precipitation L3 Half Hourly 0.1 degree x 0.1 degree V06 (GPM_3IMERGHH) at GES DISC',
#  334: 'TRMM Precipitation Radar Spectral Latent Heating L3 1 month 0.5 degree x 0.5 degree V7 (TRMM_3H25) at GES DISC',
#  335: 'OCO-2 Level 2 bias-corrected solar-induced fluorescence and other select fields from the IMAP-DOAS algorithm aggregated as daily files, Retrospective processing V10r (OCO2_L2_Lite_SIF) at GES DISC',
#  336: 'tavg1_2d_mld_Nx: MERRA Simulated 2D Incremental Analysis Update (IAU) MERRA-Land reanalysis, GEOSldas-MERRALand, Time Average 1-hourly  0.667 x 0.5 degree V5.2.0 (MST1NXMLD) at GES DISC',
#  337: 'tavgU_3d_qdt_Cp: MERRA 3D IAU Tendency, Specific Humidity, Diurnal  1.25 x 1.25 degree V5.2.0 (MATUCPQDT) at GES DISC',
#  338: 'SBUV2/NOAA-11 Ozone (O3) Profile and Total Column Ozone 1 Month Zonal Mean L3 Global 5.0 degree Latitude Zones V1 (SBUV2N11L3zm) at GES DISC',
#  339: 'TROPESS CrIS-JPSS1 L2 Ammonia for Forward Stream, Standard Product V1 (TRPSDL2NH3CRS1FS) at GES DISC',
#  340: 'Gridded Monthly Time-Mean Observation minus Analysis (oma) Values 0.5 x 0.667 degree V001 (MA_SSMI_DMSP11_OMA) at GES DISC',
#  341: 'MLS/Aura Level 3 Monthly Binned Hypochlorous Acid (HOCl) Mixing Ratio on Assorted Grids V005 (ML3MBHOCL) at GES DISC',
#  342: 'GPM DPR and GMI Combined Convective Stratiform Heating L3 1 month 0.5 degree x 0.5 degree V06 (GPM_3HCSH) at GES DISC',
#  343: 'CMS (Carbon Monitoring System) Methane (CH4) Flux for North America 0.5 degree x 0.667 degree V1 (CMS_CH4_FLX_NA) at GES DISC',
#  344: 'Sounder SIPS: AQUA AIRS IR-only Level 2 CLIMCAPS: Cloud Cleared Radiances V2 at GES DISC',
#  345: 'THIR/Nimbus-5 Level 1 Meteorological Radiation Data at 11.5 microns V001 (THIRN5L1CH115) at GES DISC',
#  346: 'MERRA-2 tavgM_2d_chm_Nx: 2d,Monthly mean,Time-Averaged,Single-Level,Assimilation,Carbon Monoxide and Ozone Diagnostics 0.625 x 0.5 degree V5.12.4 (M2TMNXCHM) at GES DISC',
#  347: 'GPM SAPHIR on MT1 (PRPS) Climate-based Radiometer Precipitation Profiling L3 1 day 0.25 x 0.25 degree V06 (GPM_3PRPSMT1SAPHIR_DAY_CLIM) at GES DISC',
#  348: 'OMPS/NPP L1B NM Radiance EV Calibrated Geolocated Swath Orbital V2 (OMPS_NPP_NMEV_L1B) at GES DISC',
#  349: 'instM_3d_ana_Np: MERRA 3D Analyzed State, Meteorology Monthly Mean  0.667 x 0.5 degree V5.2.0 (MAIMNPANA) at GES DISC',
#  350: 'AIRS-CloudSat cloud mask, radar reflectivities, and cloud classification matchups V3.2 (AIRS_CPR_MAT) at GES DISC',
#  351: 'MLS/Aura Level 3 Monthly Binned Chlorine Monoxide (ClO) Mixing Ratio on Assorted Grids V004 (ML3MBCLO) at GES DISC',
#  352: 'SCAMS/Nimbus-6 Level 2 Water Vapor and Temperature, as well as Antenna and Brightness Temperature V001 (SCAMSN6L2) at GES DISC',
#  353: 'FLDAS Noah Land Surface Model L4 Global Monthly Climatology 0.1 x 0.1 degree (MERRA-2 and CHIRPS) V001 (FLDAS_NOAH01_C_GL_MC) at GES DISC',
#  354: 'Multisensor Advanced Climatology Total Liquid Water Path L3 Monthly 1 degree x 1 degree V1 (MACTWP_mean) at GES DISC',
#  355: 'SORCE XPS Level 4 Solar Spectral Irradiance 0.1nm Res 24-Hour Means V012 (SOR4XPSD_HIGH) at GES DISC',
#  356: 'TSIS TIM Level 3 Total Solar Irradiance 6-Hour Means V03 (TSIS_TSI_L3_06HR) at GES DISC',
#  357: 'OCO-3 Level 2 spatially ordered geolocated retrievals screened using the IMAP-DOAS Preprocessor (IDP) VEarly (OCO3_L2_IMAPDOAS) at GES DISC',
#  358: 'High Resolution Altitude Corrected Precipitation based on TMPA and other sources L4 Monthly 1 km x 1 km V1 (HRAC_Precip) at GES DISC',
#  359: 'MLS/Aura Near-Real-Time L2 Water Vapor (H2O) Mixing Ratio V005 (ML2H2O_NRT) at GES DISC',
#  360: 'S-NPP CrIS IMG_COL: Array indices for collocated VIIRS observations V2 (SNDRSNCrISL1BIMGC) at GES DISC',
#  361: 'AMSR-E/Aqua level 3 global monthly Surface Soil Moisture Averages V005 (AMSRE_AVRMO) at GES DISC',
#  362: 'MERRA-2 tavg3_3d_tdt_Np: 3d,3-Hourly,Time-Averaged,Pressure-Level,Assimilation,Temperature Tendencies 0.625 x 0.5 degree V5.12.4 (M2T3NPTDT) at GES DISC',
#  363: 'MERRA-2 tavgU_3d_mst_Np: 3d,diurnal,Time-Averaged,Pressure-Level,Assimilation,Moist Processes Diagnostics 0.625 x 0.5 degree V5.12.4 (M2TUNPMST) at GES DISC',
#  364: 'GPM SSMIS on F19 (GPROF) Radiometer Precipitation Profiling L3 1 month 0.25 degree x 0.25 degree V05 (GPM_3GPROFF19SSMIS) at GES DISC',
#  365: 'tavgM_2d_rad_Nx: MERRA 2D IAU Diagnostic, Radiation Surface and TOA, Monthly Mean  0.667 x 0.5 degree V5.2.0 (MATMNXRAD) at GES DISC',
#  366: 'Aqua/AIRS L2 Standard Physical Retrieval (AIRS+AMSU+HSB) V7.0 at GES DISC',
#  367: 'MERRA-2 tavgC_2d_ltm_Nx: 2d, Single-Level, Long Term Mean Diagnostics V1 (M2TCNXLTM) at GES DISC',
#  368: 'GPM PR on TRMM Precipitation Statistics, at Surface and Fixed Heights 1 day 0.25x0.25 degree V06 (GPM_3PRD) at GES DISC',
#  369: 'AIRS/Aqua L3 Monthly CO2 in the free troposphere (AIRS+AMSU) 2.5 degrees x 2 degrees V005 (AIRX3C2M) at GES DISC',
#  370: 'TOMS Nimbus-7 UV Aerosol Index Daily L3 Global 1 deg x 1.25 deg Lat/Lon Grid V008 (TOMSN7L3daer) at GES DISC',
#  371: 'GPCP Precipitation Level 3 Monthly 0.5-Degree V3.2 (GPCPMON) at GES DISC',
#  372: 'MLS/Aura Level 3 Daily Binned Geopotential Height (GPH) on Zonal and Similar Grids V004 (ML3DZGPH) at GES DISC',
#  373: 'MLS/Aura Level 3 Daily Binned Ozone (O3) Mixing Ratio on Zonal and Similar Grids V005 (ML3DZO3) at GES DISC',
#  374: 'Gridded Monthly Time-Mean Observation minus Analysis (oma) Values 0.5 x 0.667 degree V001 (MA_MSU_NOAA11_OMA) at GES DISC',
#  375: 'TMI/TRMM surface soil moisture (LPRM) L2 V001 (LPRM_TMI_SOILM2) at GES DISC',
#  376: 'Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_HIRS2_NOAA09_OBS) at GES DISC',
#  377: 'Sentinel-5P TROPOMI Tropospheric Formaldehyde HCHO 1-Orbit L2 5.5km x 3.5km V2 (S5P_L2__HCHO___HiR) at GES DISC',
#  378: 'GEOS-Carb CASA-GFED Monthly Fire Fuel NPP Rh NEE Fluxes 0.5 degree x 0.5 degree V2 (GEOS_CASAGFED_M_FLUX) at GES DISC',
#  379: 'TSIS SIM Level 3 Solar Spectral Irradiance 12-Hour Means V05 (TSIS_SSI_L3_12HR) at GES DISC',
#  380: 'AIRS/Aqua L3 daily CO2 in the free troposphere (AIRS-only) 1 degree x 1 degree V006 (AIRS3C2D) at GES DISC',
#  381: 'UARS High Resolution Doppler Imager (HRDI) Level 3AL V011 (UARHR3AL) at GES DISC',
#  382: 'HIRDLS/Aura Level 2 Daily Geophysical Parameters V007 (HIRDLS2) at GES DISC',
#  383: 'Gridded Monthly Time-Mean Observation minus Forecast (omf) Values 0.5 x 0.667 degree V001 (MA_HIRS3_NOAA15_OMF) at GES DISC',
#  384: 'Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_SSMI_DMSP15_OBS) at GES DISC',
#  385: 'Sentinel-5P TROPOMI Radiance product band 2 (UV detector) L1B 5.5km x 3.5km V1 (S5P_L1B_RA_BD2_HiR) at GES DISC',
#  386: 'GPM AMSR-2 on GCOM-W1 (GPROF) Climate-based Radiometer Precipitation Profiling L3 1 month 0.25 degree x 0.25 degree V05 (GPM_3GPROFGCOMW1AMSR2_CLIM) at GES DISC',
#  387: 'GPM MHS on METOP-C (GPROF) Climate-based Radiometer Precipitation Profiling L2A 1.5 hours 17 km V05 (GPM_2AGPROFMETOPCMHS_CLIM) at GES DISC',
#  388: 'Gridded Monthly Time-Mean Observation minus Forecast (omf) Values 0.5 x 0.667 degree V001 (MA_SSU_TIROSN_OMF) at GES DISC',
#  389: 'TROPESS CrIS-SNPP L2 Methane for Australian Fires, Standard Product V1 (TRPSDL2CH4CRSAUS) at GES DISC',
#  390: 'MLS/Aura Level 3 Monthly Binned Carbon Monoxide (CO) Mixing Ratio on Assorted Grids V004 (ML3MBCO) at GES DISC',
#  391: 'OCO-2 Level 2 CO2 prior based on CO2 monthly flask record, global meteorology, and age of air V10 (OCO2_L2_CO2Prior) at GES DISC',
#  392: 'GPM GMI unpacked data L1A 1.5 hours 13 km V05 (GPM_1AGMI) at GES DISC',
#  393: 'MLS/Aura Level 3 Daily Binned Water Vapor (H2O) Mixing Ratio on Zonal and Similar Grids V004 (ML3DZH2O) at GES DISC',
#  394: 'TOMS Nimbus-7 UV-B Erythemal Local Noon Irradiance Daily L3 Global 1 deg x 1.25 deg Lat/Lon Grid V008 (TOMSN7L3dery) at GES DISC',
#  395: 'GPM SAPHIR on MT1 (PRPS) Climate-based Radiometer Precipitation Profiling L2 1.5 hours 10 km V06 (GPM_2APRPSMT1SAPHIR_CLIM) at GES DISC',
#  396: 'Multi-Satellite Lambertian Equivalent Reflectivity (Local Satellite Time) 10-Day L3 Global 2.0x5.0deg Lat/Lon Grid V1 (MSLERLSTL3d10) at GES DISC',
#  397: 'AMSR-E L2 Rainfall Subset, collocated with CloudSat track V002 (AMSERR_CPR) at GES DISC',
#  398: 'GPM ATMS on SUOMI-NPP (GPROF) Radiometer Precipitation Profiling L3 1 day 0.25 degree x 0.25 degree V05 (GPM_3GPROFNPPATMS_DAY_CLIM) at GES DISC',
#  399: 'Gridded Monthly Time-Mean Observation minus Forecast (omf) Values 0.5 x 0.667 degree V001 (MA_HIRS2_NOAA07_OMF) at GES DISC',
#  400: 'GPM AMSUB on NOAA17 (GPROF) Climate-based Radiometer Precipitation Profiling L3 1 month 0.25 degree x 0.25 degree  V05 (GPM_3GPROFNOAA17AMSUB_CLIM) at GES DISC',
# ...
#  863: 'GPM MHS on NOAA19 (GPROF) Radiometer Precipitation Profiling L3 1 day 0.25 degree x 0.25 degree  V05 (GPM_3GPROFNOAA19MHS_DAY) at GES DISC',
#  864: 'MLS/Aura Level 3 Monthly Binned Geopotential Height (GPH) on Assorted Grids V004 (ML3MBGPH) at GES DISC',
#  865: 'Sounder SIPS: Suomi NPP CrIMSS Level 3 Specific Quality Control Gridded Daily CHART Normal Spectral Resolution V1',
#  866: 'Goddard Satellite-Based Surface Turbulent Fluxes Climatology, 0.25 x 0.25 deg, Yearly Grid V3 (GSSTFYC) at GES DISC',
#  867: 'GPM MHS on METOP-C (GPROF) Climate-based Radiometer Precipitation Profiling L3 1 month 0.25 degree x 0.25 degree V05 (GPM_3GPROFMETOPCMHS_CLIM) at GES DISC',
#  868: 'MODIS/Aqua Geolocation Fields 1km 5-Min 1A Swath Subset along MLS V002 (MAM03S0) at GES DISC',
#  869: 'SeaWiFS Deep Blue Aerosol Optical Depth and Angstrom Exponent Level 2 Data V004 (SWDB_L2) at GES DISC V004',
#  870: 'MLS/Aura Near-Real-Time L2 Temperature V005 (ML2T_NRT) at GES DISC',
#  871: 'Gridded Monthly Time-Mean Observation minus Forecast (omf) Values 0.5 x 0.667 degree V001 (MA_MSU_NOAA10_OMF) at GES DISC',
#  872: 'Aqua/AIRS L3 Monthly Support Monthly Product (AIRS+AMSU+HSB) 1 degree x 1 degree V7.0 at GES DISC',
#  873: 'OMI/Aura Near UV Aerosol Index, Optical Depth and Single Scattering Albedo 1-Orbit L2 13x24km',
#  874: 'GPM DPR Precipitation Profile 1 Day Descending 0.25 degree x 0.25 degree V07 (GPM_3DPR_DES) at GES DISC',
#  875: 'GPM ATMS on NOAA-20 (GPROF) Climate-based Radiometer Precipitation Profiling L2A 1.5 hours 17 km V05 (GPM_2AGPROFNOAA20ATMS_CLIM) at GES DISC',
#  876: 'TOMS Meteor-3 Ground Station Overpass Data V008 (TOMSM3OVP) at GES DISC',
#  877: 'GPM DPR Ka-band Received Power L1B 1.5 hours 5 km V05 (GPM_PRL1KA) at GES DISC',
#  878: 'GPM SSMIS on F16 (GPROF) Climate-based Radiometer Precipitation Profiling L3 1 day 0.25 degree x 0.25 degree V05 (GPM_3GPROFF16SSMIS_DAY_CLIM) at GES DISC',
#  879: 'GOZCARDS Source Nitrous Oxide 1 month L3 10 degree Zonal Means on a Vertical Pressure Grid V1 (GozSmlpN2O) at GES DISC',
#  880: 'Gridded Monthly Time-Mean Observation minus Analysis (oma) Values 0.5 x 0.667 degree V001 (MA_HIRS2_NOAA06_OMA) at GES DISC',
#  881: 'GLDAS Noah Land Surface Model L4 3 hourly 1.0 x 1.0 degree V2.0 (GLDAS_NOAH10_3H) at GES DISC',
#  882: 'MLS/Aura Level 3 Daily Binned Chlorine Monoxide (ClO) Mixing Ratio on Zonal and Similar Grids V004 (ML3DZCLO) at GES DISC',
#  883: 'Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_HIRS3_AM_OBS) at GES DISC',
#  884: 'GPM DPR Spectral Latent Heating Profiles L2 1.5 hours 5 km V07 (GPM_2HSLH) at GES DISC',
#  885: 'TOVS GLA MONTHLY GRIDS from NOAA-8 02 (TOVSAMNE) at GES DISC',
#  886: 'MLS/Aura Level 2 Geopotential Height V004 (ML2GPH) at GES DISC',
#  887: 'Sounder SIPS: Suomi NPP CrIMSS Level 3 Comprehensive Quality Control Gridded Monthly CLIMCAPS Normal Spectral Resolution V2 at GES DISC',
#  888: 'OMI/Aura Level 2 Sulphur Dioxide (SO2) Trace Gas Column Data 1-Orbit Subset and Collocated Swath along CloudSat V003 (OMSO2_CPR) at GES DISC',
#  889: 'SCR/Nimbus-5 Level 1 Radiance Data from CD-ROM V001 (SCRN5L1RAD_CDROM) at GES DISC',
#  890: 'Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_SSU_TIROSN_OBS) at GES DISC',
#  891: 'TCTE Level 3 Total Solar Irradiance 6-Hour Means V002 (TCTE3TSI6) at GES DISC',
#  892: 'GPM MHS on NOAA-18 (GPROF) Radiometer Precipitation Profiling L2A 1.5 hours 17 km V05 (GPM_2AGPROFNOAA18MHS) at GES DISC',
#  893: 'Gridded Monthly Time-Mean Observation minus Analysis (oma) Values 0.5 x 0.667 degree V001 (MA_AMSUA_AQUA_OMA) at GES DISC',
#  894: 'inst3_3d_chm_Ne: MERRA Chem 3D IAU Edge Pressure, Instantaneous 3-Hourly  0.667 x 0.5 degree V5.2.0 (MAI3NECHM) at GES DISC',
#  895: 'AMSR-E/Aqua root zone soil moisture (LPRM) L3 1 day 25 km x 25 km descending and 2-Layer Palmer Water Balance Model V001 (LPRM_AMSRE_D_RZSM3) at GES DISC',
#  896: 'TOMS Nimbus-7 UV Aerosol Index Daily and Monthly Zonal Means V008 (TOMSN7L3zaer) at GES DISC',
#  897: 'GPM GMI (GPROF) Radiometer Precipitation Profiling L3 1 month 0.25 degree x 0.25 degree V05 (GPM_3GPROFGPMGMI) at GES DISC',
#  898: 'FLDAS Noah Land Surface Model L4 Global Monthly Anomaly 0.1 x 0.1 degree (MERRA-2 and CHIRPS) V001 (FLDAS_NOAH01_C_GL_MA) at GES DISC',
#  899: 'GPM SSMIS on F16 (GPROF) Climate-based Radiometer Precipitation Profiling L3 1 month 0.25 degree x 0.25 degree V05 (GPM_3GPROFF16SSMIS_CLIM) at GES DISC',
#  900: 'Sentinel-5P TROPOMI Total Ozone Column 1-Orbit L2 7km x 3.5km V1 (S5P_L2__O3_TOT) at GES DISC',
#  901: 'Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_HIRS2_NOAA07_OBS) at GES DISC',
#  902: 'MERRA-2 tavgM_2d_aer_Nx: 2d,Monthly mean,Time-averaged,Single-Level,Assimilation,Aerosol Diagnostics 0.625 x 0.5 degree V5.12.4 (M2TMNXAER) at GES DISC',
#  903: 'Gridded 6 hours Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_CONV_OMA) at GES DISC',
#  904: 'THIR/Nimbus-6 Level 1 Meteorological Radiation Data at 11.5 microns V001 (THIRN6L1CH115) at GES DISC',
#  905: 'MLS/Aura Level 2 Water Vapor (H2O) Mixing Ratio V004 (ML2H2O) at GES DISC',
#  906: 'Sentinel-5P TROPOMI Tropospheric Formaldehyde HCHO 1-Orbit L2 7km x 3.5km V1 (S5P_L2__HCHO__) at GES DISC',
#  907: 'TIROS-4 Low-Resolution Omnidirectional Radiometer Level 1 Temperature Data V001 (TIROS4L1ORT) at GES DISC',
#  908: 'Gridded Monthly Time-Mean Observation minus Forecast (omf) Values 0.5 x 0.667 degree V001 (MA_HIRS2_NOAA09_OMF) at GES DISC',
#  909: 'AIRS/Aqua L3 Monthly Support Product (AIRS+AMSU+HSB) 1 degree x 1 degree V006 (AIRH3SPM) at GES DISC',
#  910: 'MLS/Aura Level 3 Monthly Binned Temperature on Assorted Grids V005 (ML3MBT) at GES DISC',
#  911: 'Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_HIRS3_NOAA15_OBS) at GES DISC',
#  912: 'Gridded Monthly Time-Mean Observation minus Forecast (omf) Values 0.5 x 0.667 degree V001 (MA_SSMI_DMSP15_OMF) at GES DISC',
#  913: 'GPM AMSUB on NOAA15 (GPROF) Climate-based Radiometer Precipitation Profiling L3 1 day 0.25 degree x 0.25 degree  V05 (GPM_3GPROFNOAA15AMSUB_DAY_CLIM) at GES DISC',
#  914: 'TROPESS CrIS-JPSS1 L2 Deuterated Water Vapor for Forward Stream, Standard Product V1 (TRPSDL2HDOCRS1FS) at GES DISC',
#  915: 'GPM MHS on METOP-C (GPROF) Radiometer Precipitation Profiling L2A 1.5 hours 17 km V05 (GPM_2AGPROFMETOPCMHS) at GES DISC',
#  916: 'TOMS Earth Probe UV Reflectivity Monthly L3 Global 1 deg x 1.25 deg Lat/Lon Grid V008 (TOMSEPL3mref) at GES DISC',
#  917: 'GPM IMERG Early Precipitation L3 1 day 0.1 degree x 0.1 degree V06 (GPM_3IMERGDE) at GES DISC',
#  918: 'AIRS/Aqua L2 CO2 support retrieval (AIRS+AMSU) V005 (AIRX2SPC) at GES DISC',
#  919: 'OMI/Aura Level 1B UV Zoom-in Geolocated Earthshine Radiances 1-orbit L2 Swath 13x12 km V003 (OML1BRUZ) at GES DISC',
#  920: 'GPM DPR and GMI (Combined Precipitation) L3 1 month 0.25 degree x 0.25 degree V06 (GPM_3CMB) at GES DISC',
#  921: 'GPM SSMIS on F19 (GPROF) Climate-based Radiometer Precipitation Profiling L3 1 day 0.25 degree x 0.25 degree V05 (GPM_3GPROFF19SSMIS_DAY_CLIM) at GES DISC',
#  922: 'MODIS_CR_Equal_Angle_3h',
#  923: 'Carbon Monitoring System Carbon Flux for Fire L4 V1 (CMSFluxFire) at GES DISC',
#  924: 'Carbon Monitoring System Flux for Posterior Total Carbon L4 V1 (CMSFluxTotalpost) at GES DISC',
#  925: 'GPM DPR Ku-band Received Power L1B 1.5 hours 5 km V07 (GPM_PRL1KU) at GES DISC',
#  926: 'GPS Radio Occultation Boundary Layer Depth Annual L3 V1 (GPSROZPBLA) at GES DISC',
#  927: 'GPM DPR and GMI Combined Precipitation L2B 1.5 hours 5 km V06 (GPM_2BCMB) at GES DISC',
#  928: 'TROPESS CrIS-SNPP L2 Carbon Monoxide for Buchholz2021 TS2, Standard Product V1 (TRPSDL2COCRSTS2) at GES DISC',
#  929: 'AIRS/Aqua L3 Daily Standard Physical Retrieval (AIRS+AMSU+HSB) 1 degree x 1 degree V006 (AIRH3STD) at GES DISC',
#  930: 'NCA-LDAS Noah-3.3 Land Surface Model L4 Daily 0.125 x 0.125 degree V2.0 (NCALDAS_NOAH0125_D) at GES DISC',
#  931: 'TOMS/EP Near UV Aerosol Index and LER 1-Orbit L2 40x40km at GES DISC',
#  932: 'MLS/Aura Level 3 Daily Binned Chlorine Monoxide (ClO) Mixing Ratio on Assorted Grids V004 (ML3DBCLO) at GES DISC',
#  933: 'CAR ARCTAS BRDF Measurements  V2 (CAR_ARCTAS_BRDF) at GES DISC',
#  934: 'GPM GMI Common Calibrated Brightness Temperatures Collocated L1C 1.5 hours 13 km V05 (GPM_1CGPMGMI) at GES DISC',
#  935: 'GPM SSMIS on F17 (GPROF) Radiometer Precipitation Profiling L3 1 month 0.25 degree x 0.25 degree V05 (GPM_3GPROFF17SSMIS) at GES DISC',
#  936: 'TROPESS CrIS-SNPP L2 Carbon Monoxide for West Coast Fires, Standard Product V1 (TRPSDL2COCRSWCF) at GES DISC',
#  937: 'GPM ATMS on SUOMI-NPP (GPROF) Radiometer Precipitation Profiling L2 1.5 hours 16 km V05 (GPM_2AGPROFNPPATMS_CLIM) at GES DISC',
#  938: 'ESMR/Nimbus-5 Images of Brightness Temperature on 70 mm Film V001 (ESMRN5IM) at GES DISC',
#  939: 'Sentinel-6A Level 1B GNSS Radio Occultation Precise Orbit Determination  V1 (S6A_RO_1B_POD_RNX_) at GES DISC',
#  940: 'TRMM Radar Rainfall Statistics L3 1 month (5 x 5) and (0.5  x 0.5) degree V7 (TRMM_3A25) at GES DISC',
#  941: 'MLS/Aura Level 3 Daily Binned Cloud Ice (IWC) on Zonal and Similar Grids V005 (ML3DZIWC) at GES DISC',
#  942: 'TROPESS AIRS-Aqua L2 Carbon Monoxide for Forward Stream, Standard Product V1 (TRPSDL2COAIRSFS) at GES DISC',
#  943: 'tavgM_3d_mst_Cp: MERRA 3D IAU Diagnostic, Moist Physics, Monthly Mean  1.25 x 1.25 degree V5.2.0 (MATMCPMST) at GES DISC',
#  944: 'MLS/Aura Level 3 Daily Binned Nitric Acid (HNO3) Mixing Ratio on Assorted Grids V005 (ML3DBHNO3) at GES DISC',
#  945: 'MLS/Aura Near-Real-Time L2 Nitric Acid (HNO3) Mixing Ratio V005 (ML2HNO3_NRT) at GES DISC',
#  946: 'MERRA-2 tavg3_3d_trb_Np: 3d,3-Hourly,Time-Averaged,Pressure-Level,Assimilation,Turbulence Diagnostics 0.625 x 0.5 degree V5.12.4 (M2T3NPTRB) at GES DISC',
#  947: 'Global methane fluxes optimized with GOSAT data for 2010-2018 V1 (CMSGCH4F)',
#  948: 'WindSat/Coriolis surface soil moisture (LPRM) L3 1 day 25 km x 25 km daytime V001 (LPRM_WINDSAT_DY_SOILM3) at GES DISC',
#  949: 'TRMM (TMPA) Precipitation L3 1 day 0.25 degree x 0.25 degree V7 (TRMM_3B42_Daily) at GES DISC',
#  950: 'Multi-Satellite Lambertian Equivalent Reflectivity (Noon Normalized) 1 day L3 Global 5.0deg Lat Zones V1 (MSLERNNL3zm) at GES DISC',
#  951: 'tavgU_2d_lnd_Nx: MERRA 2D IAU Diagnostic, Land Only States and Diagnostics, Diurnal  0.667 x 0.5 degree V5.2.0 (MATUNXLND) at GES DISC',
#  952: 'MERRA-2 inst3_2d_gas_Nx: 2d,3-Hourly,Instantaneous,Single-Level,Assimilation,Aerosol Optical Depth Analysis 0.625 x 0.5 degree V5.12.4 (M2I3NXGAS) at GES DISC',
#  953: 'Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_HIRS2_NOAA12_OBS) at GES DISC',
#  954: 'AIRS/Aqua L2 Near Real Time (NRT) Cloud-Cleared Infrared Radiances (AIRS-only) V006 (AIRS2CCF_NRT) at GES DISC',
#  955: 'TRMM Microwave Imager Calibrated Radiances L1B 1.5 hours V7 (TRMM_1B11) at GES DISC',
#  956: 'tavg3_3d_udt_Cp: MERRA 3D IAU Tendency, Wind Components, Time average 3-hourly  1.25 x 1.25 degree V5.2.0 (MAT3CPUDT) at GES DISC',
#  957: 'CAR SnowEx17 BRDF Measurements L1 V2 (CAR_SNOWEX17_BRDF) at GES DISC',
#  958: 'Gridded Monthly Time-Mean Observation minus Analysis (oma) Values 0.5 x 0.667 degree V001 (MA_MHS_NOAA18_OMA) at GES DISC',
#  959: 'JPSS-1 CrIS IMG: Collocated VIIRS level 1 / cloud mask statistical summary V2 (SNDRJ1CrISL1BIMG) at GES DISC',
#  960: 'OMI/Aura Sulphur Dioxide (SO2) Total Column Daily L2 Global Gridded 0.125 degree x 0.125 degree V3 (OMSO2G) at GES DISC',
#  961: 'TOVS GLA 5 DAY GRIDS from NOAA-9 V01 (TOVSA5NF) at GES DISC',
#  962: 'MERRA-2 tavgM_2d_lnd_Nx: 2d,Monthly mean,Time-Averaged,Single-Level,Assimilation,Land Surface Diagnostics 0.625 x 0.5 degree V5.12.4 (M2TMNXLND) at GES DISC',
#  963: 'AIRS/Aqua L3 8-day Support Multiday Product (AIRS+AMSU+HSB) 1 degree x 1 degree V006 (AIRH3SP8) at GES DISC',
#  964: 'CAR SCAR-B Smoke, Clouds, and Radiation-Brazil L1 V1 (CAR_SCARB_L1C) at GES DISC',
#  965: 'CAR ECO3D BRDF Measurements V2 (CAR_ECO3D_BRDF) at GES DISC',
#  966: 'GPM PR on TRMM Spectral Latent Heating Profiles L2 1.5 hours 5 km V06 (GPM_2HSLH_TRMM) at GES DISC',
#  967: 'SCR/Nimbus-4 Level 1 Radiance Data from CD-ROM V001 (SCRN4L1RAD_CDROM) at GES DISC',
#  968: 'TROPESS CrIS-SNPP L2 Carbon Monoxide for West Coast Fires HiRes, Standard Product V1 (TRPSDL2COCRSWCFHI) at GES DISC',
#  969: 'MLS/Aura Level 2 Hypochlorous Acid (HOCl) Mixing Ratio V004 (ML2HOCL) at GES DISC',
#  970: 'GPM AMSU-B on NOAA15 (GPROF) Climate-based Radiometer Precipitation Profiling L2 1.5 hours 16 km V05 (GPM_2AGPROFNOAA15AMSUB) at GES DISC',
#  971: 'SBUV2/NOAA-9 Ozone (O3) Nadir Profile and Total Column 1 Day L2 V1 (SBUV2N09L2) at GES DISC',
#  972: 'NCEP/DOE Reanalysis II, for GSSTF, 0.25 x 0.25 deg, Daily Grid V3 (GSSTF_NCEP) at GES DISC',
#  973: 'Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_AMSUA_NOAA18_OBS) at GES DISC',
#  974: 'tavgU_2d_mld_Nx: MERRA Simulated 2D Incremental Analysis Update (IAU) MERRA-Land reanalysis, GEOSldas-MERRALand, Time Average Diurnal  0.667 x 0.5 degree V5.2.0 (MSTUNXMLD) at GES DISC',
#  975: 'GOZCARDS Source Hydrogen Chloride 1 month L3 10 degree Zonal Means on a Vertical Pressure Grid V1 (GozSmlpHCl) at GES DISC',
#  976: 'Ocean Biogeochemistry in the California Current System 2007-2010 L4 Monthly',
#  977: 'Gridded Monthly Time-Mean Observation minus Forecast (omf) Values 0.5 x 0.667 degree V001 (MA_AMSUA_NOAA16_OMF) at GES DISC',
#  978: 'MERRA-2 inst3_3d_asm_Np: 3d,3-Hourly,Instantaneous,Pressure-Level,Assimilation,Assimilated Meteorological Fields 0.625 x 0.5 degree V5.12.4 (M2I3NPASM) at GES DISC',
#  979: 'NLDAS Secondary Forcing Data L4 Monthly Climatology 0.125 x 0.125 degree V2.0 (NLDAS_FORB0125_MC) at GES DISC',
#  980: 'AIRS/Aqua L2 Support Retrieval (AIRS-only) V006 (AIRS2SUP) at GES DISC',
#  981: 'OMI/Aura TOMS-Like Ozone and Radiative Cloud Fraction L3 1 day 0.25 degree x 0.25 degree V3 (OMTO3e) at GES DISC',
#  982: 'GPM ATMS on SUOMI-NPP (GPROF) Radiometer Precipitation Profiling L3 1 day 0.25 degree x 0.25 degree V05 (GPM_3GPROFNPPATMS_DAY) at GES DISC',
#  983: 'TRMM Ground Validation Radar Site Rain Type Totals Map L3 1 month 2 km V7 (TRMM_3A54) at GES DISC',
#  984: 'OMI/Aura TOMS-Like Ozone, Aerosol Index, Cloud Radiance Fraction L3 1 day 1 degree x 1 degree V3 (OMTO3d) at GES DISC',
#  985: 'Gridded Monthly Time-Mean Observation minus Forecast (omf) Values 0.5 x 0.667 degree V001 (MA_AIRS_AQUA_OMF) at GES DISC',
#  986: 'MLS/Aura L1 Radiances from Filter Banks for THz V005 (ML1RADT) at GES DISC',
#  987: 'inst3_3d_asm_Cp: MERRA 3D IAU State, Meteorology Instantaneous 3-hourly  1.25 x 1.25 degree V5.2.0 (MAI3CPASM) at GES DISC',
#  988: 'Sentinel-5P TROPOMI Radiance product band 6 (NIR detector) L1B V2 (S5P_L1B_RA_BD6) at GES DISC',
#  989: 'OMI/Aura Surface UV Irradiance 1-orbit L2 Swath 13x24 km V003 (OMUVB) at GES DISC',
#  990: 'TRMM Ground Validation Rain Existence L2 1 month V7 (TRMM_2A52) at GES DISC',
#  991: 'GPM IMERG Late Precipitation L3 1 day 0.1 degree x 0.1 degree V06 (GPM_3IMERGDL) at GES DISC',
#  992: 'TMI/TRMM surface soil moisture (LPRM) L3 1 day 25 km x 25 km nighttime V001 (LPRM_TMI_NT_SOILM3) at GES DISC',
#  993: 'SORCE SOLSTICE FUV Level 3 Solar Spectral Irradiance Daily Means V016 (SOR3SOLFUVD) at GES DISC',
#  994: 'BUV/Nimbus-4 Ozone (O3) Nadir Profile and Total Column 1 Day L2 V1 (BUVN04L2) at GES DISC',
#  995: 'NLDAS Primary Forcing Data L4 Hourly 0.125 x 0.125 degree V002 (NLDAS_FORA0125_H) at GES DISC',
#  996: 'OMI/Aura Formaldehyde (HCHO) Total Column Daily L2 Global Gridded 0.25 degree x 0.25 degree V3 (OMHCHOG) at GES DISC',
#  997: 'Sounder SIPS: Suomi NPP CrIMSS Level 2 CHART Normal Spectral Resolution: Cloud Cleared Radiances V1',
#  998: 'TOMS/N7 Near UV Aerosol Index and LER 1-Orbit L2 50x50 km',
#  999: 'Gridded Monthly Time-Mean Observation minus Forecast (omf) Values 0.5 x 0.667 degree V001 (MA_MSU_NOAA07_OMF) at GES DISC',
#  ...}

# %%
list(df_tfidf.columns)[:5]
# Out:
# ['00003', '00004', '00007', '0001', '00010']

# %%
relevance_dict = {index: 0 for index in range(len(titles_list))}

# %%
split_query = clean_text(query).split()
for word in split_query:
    tfidf_scores = df_tfidf[word].tolist()
    for index, score in enumerate(tfidf_scores):
        relevance_dict[index] += score

# %%
sorted_relevance_dict = sorted(relevance_dict.items(), key=lambda item: item[1], reverse=True)

# %%
def get_top_datasets(n):
    top_n = sorted_relevance_dict[:n]
    return [index2title[index] for index, score in top_n]

# %%
get_top_datasets(10)
# Out:
# ['GPM DPR and GMI (Combined Precipitation) L3 1 day 0.25 degree x 0.25 degree V06 (GPM_3CMB_DAY) at GES DISC',
#  'GPM DPR and GMI (Combined Precipitation) L3 1 day 0.25 degree x 0.25 degree V07 (GPM_3CMB_DAY) at GES DISC',
#  'GPM DPR and GMI (Combined Precipitation) L3 1 month 0.25 degree x 0.25 degree V06 (GPM_3CMB) at GES DISC',
#  'GPM DPR and GMI (Combined Precipitation) L3 1 month 0.25 degree x 0.25 degree V07 (GPM_3CMB) at GES DISC',
#  'GPM MHS on METOP-C (GPROF) Radiometer Precipitation Profiling L3 1 day 0.25 degree x 0.25 degree V05 (GPM_3GPROFMETOPCMHS_DAY) at GES DISC',
#  'GPM ATMS on SUOMI-NPP (GPROF) Radiometer Precipitation Profiling L3 1 month 0.25 degree x 0.25 degree V05 (GPM_3GPROFNPPATMS) at GES DISC',
#  'GPM MHS on METOP-C (GPROF) Radiometer Precipitation Profiling L3 1 month 0.25 degree x 0.25 degree V05 (GPM_3GPROFMETOPCMHS) at GES DISC',
#  'GPM ATMS on NOAA-20 (GPROF) Radiometer Precipitation Profiling L3 1 month 0.25 degree x 0.25 degree V05 (GPM_3GPROFNOAA20ATMS) at GES DISC',
#  'GPM GMI (GPROF) Radiometer Precipitation Profiling L3 1 day 0.25 degree x 0.25 degree V05 (GPM_3GPROFGPMGMI_DAY) at GES DISC',
#  'GPM GMI (GPROF) Radiometer Precipitation Profiling L3 1 month 0.25 degree x 0.25 degree V05 (GPM_3GPROFGPMGMI) at GES DISC']

# %%
title2index
# Out:
# {'Gridded Monthly Time-Mean Observation minus Analysis (oma) Values 0.5 x 0.667 degree V001 (MA_HIRS2_TIROSN_OMA) at GES DISC': 0,
#  'Suomi NPP CrIS Level 1B Full Spectral Resolution V2 (SNPPCrISL1B) at GES DISC': 1,
#  'GPM SSM/I on F13 (GPROF) Climate-based Radiometer Precipitation Profiling L2 1.5 hours 12 km V05 (GPM_2AGPROFF13SSMI_CLIM) at GES DISC': 2,
#  'Sentinel-5P TROPOMI Radiance product band 7 (SWIR detector) L1B 5.5km x 7km V1 (S5P_L1B_RA_BD7_HiR) at GES DISC': 3,
#  'OMI/Aura NO2 Tropospheric, Stratospheric & Total Columns MINDS Daily L2 Global Gridded 0.25 degree x 0.25 degree V1.1 (OMI_MINDS_NO2G) at GES DISC': 4,
#  'MLS/Aura Level 3 Monthly Binned Hydroxyl (OH) Mixing Ratio on Assorted Grids V004 (ML3MBOH) at GES DISC': 5,
#  'Gridded Monthly Time-Mean Observation minus Analysis (oma) Values 0.5 x 0.667 degree V001 (MA_SSU_NOAA07_OMA) at GES DISC': 6,
#  'Suomi NPP CrIS Level 1B Normal Spectral Resolution V1 (SNPPCrISL1BNSR) at GES DISC': 7,
#  'MODIS/Aqua Aerosol 5-Min L2 Swath Subset 10km along MLS V002 (MAM04S0) at GES DISC': 8,
#  'GPM GMI Antenna Temperatures L1BASE 1.5 hours 13 km V05 (GPM_BASEGPMGMI) at GES DISC': 9,
#  'GPM MHS on NOAA-19 (GPROF) Radiometer Precipitation Profiling L2A 1.5 hours 17 km V05 (GPM_2AGPROFNOAA19MHS_CLIM) at GES DISC': 10,
#  'WindSat/Coriolis surface soil moisture (LPRM) L3 1 day 25 km x 25 km nighttime V001 (LPRM_WINDSAT_NT_SOILM3) at GES DISC': 11,
#  'ATMOS L2 Trace Gases on Altitude Grid, Tab Delimited Format V3 (ATMOSL2AT) at GES DISC': 12,
#  'TOVS LMD 5 DAY GRIDS from NOAA-12 V01 (TOVSB5ND) at GES DISC': 13,
#  'TROPESS CrIS-SNPP L2 Ammonia for West Coast Fires, Standard Product V1 (TRPSDL2NH3CRSWCF) at GES DISC': 14,
#  'MLS/Aura Level 2 Diagnostics, Miscellaneous Grid V005 (ML2DGM) at GES DISC': 15,
#  'TOVS GLA 5 DAY GRIDS from NOAA-11 V01 (TOVSA5NH) at GES DISC': 16,
#  'Suomi NPP ATMS Sounder Science Investigator-led Processing System (SIPS) Level 1B Brightness Temperature V3 (SNPPATMSL1B) at GES DISC': 17,
#  'SORCE XPS Level 4 Solar Spectral Irradiance 0.1nm Res 5-Minute V012 (SOR4XPS5) at GES DISC': 18,
#  'Aqua/AIRS L3 Daily Support Product (AIRS-only) 1 degree x 1 degree V7.0 at GES DISC': 19,
#  'AIRS/Aqua L3 8-day Support Multiday Product (AIRS+AMSU) 1 degree x 1 degree V006 (AIRX3SP8) at GES DISC': 20,
#  'MLS/Aura Level 2 Cloud Ice Product V004 (ML2IWC) at GES DISC': 21,
#  'TROPESS AIRS-Aqua L2 Ammonia for Forward Stream, Standard Product V1 (TRPSDL2NH3AIRSFS) at GES DISC': 22,
#  'tavg3_3d_chm_Fe: MERRA Chem 3D IAU, Precip Mass Flux, Time average 3-hourly  1.25 x 1 degree V5.2.0 (MAT3FECHM) at GES DISC': 23,
#  'TSIS SIM Level 3 Solar Spectral Irradiance 24-Hour Means V06 (TSIS_SSI_L3_24HR) at GES DISC': 24,
#  'Gridded Monthly Time-Mean Observation minus Analysis (oma) Values 0.5 x 0.667 degree V001 (MA_SSMI_DMSP10_OMA) at GES DISC': 25,
#  'OCO-3 Level 2 bias-corrected XCO2 and other select fields from the full-physics retrieval aggregated as daily files, Retrospective processing VEarlyR (OCO3_L2_Lite_FP) at GES DISC': 26,
#  'Sounder SIPS: JPSS-1 CrIS Level 3 Specific Quality Control Gridded Daily CLIMCAPS V2 at GES DISC': 27,
#  'MERRA-2 tavgU_3d_cld_Np: 3d,diurnal,Time-Averaged,Pressure-Level,Assimilation,Cloud Diagnostics 0.625 x 0.5 degree V5.12.4 (M2TUNPCLD) at GES DISC': 28,
#  'OCO-2 Level 2 meteorological parameters interpolated from global assimilation model for each sounding V10 (OCO2_L2_Met) at GES DISC': 29,
#  'GPM PR on TRMM Reflectivity, Precipitation Statistics, Histograms, at Surface and Fixed Heights, 1 month 5x5 and 0.25x0.25 degree V06 (GPM_3PR) at GES DISC': 30,
#  'MLS/Aura Level 3 Daily Binned Temperature on Assorted Grids V005 (ML3DBT) at GES DISC': 31,
#  'NLDAS VIC Land Surface Model L4 Monthly 0.125 x 0.125 degree V002 (NLDAS_VIC0125_M) at GES DISC': 32,
#  'TROPESS CrIS-SNPP L2 Methanol for Forward Stream, Standard Product V1 (TRPSDL2CH3OHCRSFS) at GES DISC': 33,
#  'OCO-3 Level 2 geolocated XCO2 retrievals results, physical model VEarlyR (OCO3_L2_Standard) at GES DISC': 34,
#  'GPM TMI on TRMM (GPROF) Climate-based Radiometer Precipitation Profiling L2A 1.5 hours 13 km V05 (GPM_2AGPROFTRMMTMI_CLIM) at GES DISC': 35,
#  'Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_MSU_NOAA14_OBS) at GES DISC': 36,
#  'Carbon Monitoring System Lake Michigan Primary Production Monthly V1 (CMSLakeMichiganPPM) at GES DISC': 37,
#  'Aqua/AIRS L3 Monthly Standard Physical Retrieval (AIRS-only) 1 degree x 1 degree V7.0 at GES DISC': 38,
#  'GPM SAPHIR on MT1 (PRPS) Radiometer Precipitation Profiling L2 1.5 hours 10 km V06 (GPM_2APRPSMT1SAPHIR) at GES DISC': 39,
#  'MERRA-2 inst6_3d_ana_Nv: 3d,6-Hourly,Instantaneous,Model-Level,Analysis,Analyzed Meteorological Fields 0.625 x 0.5 degree V5.12.4 (M2I6NVANA) at GES DISC': 40,
#  'NLDAS Primary Forcing Data L4 Hourly 0.125 x 0.125 degree V2.0 (NLDAS_FORA0125_H) at GES DISC': 41,
#  'GPM VIRS on TRMM Radiance L1B 1.5 hours 2 km V05 (GPM_1BVIRS) at GES DISC': 42,
#  'GPM AMSR-2 on GCOM-W1 (GPROF) Radiometer Precipitation Profiling L3 1 month 0.25 degree x 0.25 degree V05 (GPM_3GPROFGCOMW1AMSR2) at GES DISC': 43,
#  'GPM SSMIS on F19 (GPROF) Climate-based Radiometer Precipitation Profiling L3 1 month 0.25 degree x 0.25 degree V05 (GPM_3GPROFF19SSMIS_CLIM) at GES DISC': 44,
#  'Aqua/AIRS L2 Cloud-Cleared Infrared Radiances (AIRS+AMSU+HSB) V7.0 at GES DISC': 45,
#  'GPCP Precipitation Level 3 Daily 0.5-Degree V3.1 (GPCPDAY) at GES DISC': 46,
#  'Sounder SIPS: Suomi NPP CrIMSS Level 3 Comprehensive Quality Control Gridded Daily CLIMCAPS Normal Spectral Resolution V2 at GES DISC': 47,
#  'ATMOS L2 Trace Gases on Potential Temperature Grid, Tab Delimited Format V3 (ATMOSL2TT) at GES DISC': 48,
#  'GLDAS CLM Land Surface Model L4 3 hourly 1.0 x 1.0 degree Subsetted V001 (GLDAS_CLM10SUBP_3H) at GES DISC': 49,
#  'OCO-3 Level 1B calibrated, geolocated calibration spectra, Retrospective Processing EarlyR (OCO3_L1B_Calibration) at GES DISC': 50,
#  'TOMS Nimbus-7 UV Reflectivity Daily L3 Global 1 deg x 1.25 deg Lat/Lon Grid V008 (TOMSN7L3dref) at GES DISC': 51,
#  'MERRA-2 inst1_2d_int_Nx: 2d,1-Hourly,Instantaneous,Single-Level,Assimilation,Vertically Integrated Diagnostics 0.625 x 0.5 degree V5.12.4 (M2I1NXINT) at GES DISC': 52,
#  'Sentinel-5P TROPOMI Tropospheric Ozone Profile 1-Orbit L2 5.5km x 3.5km V1 (S5P_L2__O3_TPR_HiR) at GES DISC': 53,
#  'SBUV2/NOAA-16 Level 2 Daily Ozone Profile and Total Column from CD-ROM V008 (SBUV2N16O3) at GES DISC': 54,
#  'NLDAS Mosaic Land Surface Model L4 Hourly 0.125 x 0.125 degree V002 (NLDAS_MOS0125_H) at GES DISC': 55,
#  'TROPESS CrIS-SNPP and TROPOMI-S5P L2 Carbon Monoxide for Forward Stream, Standard Product V1 (TRPSDL2COCRSTRPOMIFS) at GES DISC': 56,
#  'OMI/Aura NO2 Tropospheric, Stratospheric & Total Columns MINDS 1-Orbit L2 Swath 13 km x 24 km V1 (OMI_MINDS_NO2) at GES DISC': 57,
#  'MERRA-2 tavgM_2d_glc_Nx: 2d,Monthly mean,Time-Averaged,Single-Level,Assimilation,Land Ice Surface Diagnostics 0.625 x 0.5 degree V5.12.4 (M2TMNXGLC) at GES DISC': 58,
#  'GPM SSMIS on F17 (GPROF) Radiometer Precipitation Profiling L3 1 day 0.25 degree x 0.25 degree V05 (GPM_3GPROFF17SSMIS_DAY) at GES DISC': 59,
#  'Sentinel-5P TROPOMI Carbon Monoxide CO Column 1-Orbit L2 5.5km x 7km V1 (S5P_L2__CO_____HiR) at GES DISC': 60,
#  'GPM PR and TMI on TRMM Combined Convective-Stratiform Latent Heating Profiles L3 1 month 0.25x0.25 degree V06 (GPM_3HCSH_TRMM) at GES DISC': 61,
#  'TRMM Attitude and VIRS Packets and Header Record L1A V7 (TRMM_1A01) at GES DISC': 62,
#  'Sentinel-5P TROPOMI Ozone Profile 1-Orbit L2 30km x 30km V2 (S5P_L2__O3__PR_HiR) at GES DISC': 63,
#  'MLS/Aura Level 3 Monthly Binned Carbon Monoxide (CO) Mixing Ratio on Assorted Grids V005 (ML3MBCO) at GES DISC': 64,
#  'NCEP/DOE Reanalysis II in HDF-EOS5, for GSSTF2c, 1x1 deg Daily grid V2c (GSSTF_NCEP) at GES DISC': 65,
#  'MLS/Aura Level 3 Daily Binned Water Vapor (H2O) Mixing Ratio on Zonal and Similar Grids V005 (ML3DZH2O) at GES DISC': 66,
#  'TROPESS TROPOMI-S5P L2 Ozone for Forward Stream, Standard Product V1 (TRPSDL2O3TRPOMIFS) at GES DISC': 67,
#  'tavgM_2d_chm_Fx: MERRA Chem 2D IAU Diagnostics, Fluxes and Meteorology, Monthly Mean  1.25 x 1 degree V5.2.0 (MATMFXCHM) at GES DISC': 68,
#  'Sentinel-5P TROPOMI Sulphur Dioxide SO2 1-Orbit L2 5.5km x 3.5km V1 (S5P_L2__SO2____HiR) at GES DISC': 69,
#  'HIRDLS-MLS/Aura Level 3 Monthly 10 x 20 deg Ice Water Content V002 (HIRMLS3IWC) at GES DISC': 70,
#  'MLS/Aura Level 3 Daily Binned Geopotential Height (GPH) on Zonal and Similar Grids V005 (ML3DZGPH) at GES DISC': 71,
#  'TRMM Ground Validation Radar Site Rain Rate Map L2 1 hour 2 km V7 (TRMM_2A53) at GES DISC': 72,
#  'MLS/Aura Level 3 Daily Binned Ozone (O3) Mixing Ratio on Zonal and Similar Grids V004 (ML3DZO3) at GES DISC': 73,
#  'AIRS/Aqua L3 Monthly Support Product (AIRS+AMSU) 1 degree x 1 degree V006 (AIRX3SPM) at GES DISC': 74,
#  'Sentinel-5P TROPOMI Irradiance product SWIR module L1B V2 (S5P_L1B_IR_SIR) at GES DISC': 75,
#  'Sentinel-5P TROPOMI Radiance product band 7 (SWIR detector) L1B V2 (S5P_L1B_RA_BD7) at GES DISC': 76,
#  'WindSat/Coriolis surface soil moisture (LPRM) L2 V001 (LPRM_WINDSAT_SOILM2) at GES DISC': 77,
#  'FLDAS Noah Land Surface Model L4 Global Monthly 0.1 x 0.1 degree (GDAS and CHIRPS-PRELIM) V001 (FLDAS_NOAH01_CP_GL_M) at GES DISC': 78,
#  'Carbon Monitoring System Flux for Prior Total Carbon L4 V1 (CMSFluxTotalprior) at GES DISC': 79,
#  'TOMS EP Total Column Ozone Daily and Monthly Zonal Means V008 (TOMSEPL3ztoz) at GES DISC': 80,
#  'Sentinel-5P TROPOMI Carbon Monoxide CO Column 1-Orbit L2 7km x 7km V1 (S5P_L2__CO____) at GES DISC': 81,
#  'GEOS-Carb CASA-GFED Monthly Fire Fuel NPP Rh NEE Fluxes 0.5 degree x 0.5 degree V3 (GEOS_CASAGFED_M_FLUX) at GES DISC': 82,
#  'MERRA-2 tavgU_3d_tdt_Np: 3d,diurnal,Time-Averaged,Pressure-Level,Assimilation,Temperature Tendencies 0.625 x 0.5 degree V5.12.4 (M2TUNPTDT) at GES DISC': 83,
#  'OCO-2 Level 0 spacecraft attitude data V10 (OCO2_Att) at GES DISC': 84,
#  'MERRA-2 tavg3_3d_mst_Np: 3d,3-Hourly,Time-Averaged,Pressure-Level,Assimilation,Moist Processes Diagnostics 0.625 x 0.5 degree V5.12.4 (M2T3NPMST) at GES DISC': 85,
#  'TROPESS CrIS-SNPP L2 Ozone for West Coast Fires, Standard Product V1 (TRPSDL2O3CRSWCF) at GES DISC': 86,
#  'Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_MSU_NOAA06_OBS) at GES DISC': 87,
#  'MRIR/Nimbus-3 Level 1 Meteorological Radiation Data V001 (MRIRN3L1) at GES DISC': 88,
#  'OMI/Aura Level 1B UV Global Geolocated Earthshine Radiances 1-orbit L2 Swath 13x24 km V003 (OML1BRUG) at GES DISC': 89,
#  'GPM PR on TRMM Echo Power L1B 1.5 hours 5 km V05 (GPM_1BPR) at GES DISC': 90,
#  'tavg3_3d_chm_Ne: MERRA Chem 3D IAU C-Grid Edge Mass Flux, Time Average 3-Hourly  0.667 x 0.5 degree V5.2.0 (MAT3NECHM) at GES DISC': 91,
#  'SBUV2/NOAA-19 Ozone (O3) Profile and Total Column Ozone 1 Month Zonal Mean L3 Global 5.0 degree Latitude Zones V1 (SBUV2N19L3zm) at GES DISC': 92,
#  'TIROS-4 Medium-Resolution Scanning Radiometer Level 1 Final Meteorological Radiation Data V001 (TIROS4L1FMRT) at GES DISC': 93,
#  'TROPESS AIRS-Aqua L2 Ozone for Forward Stream, Standard Product V1 (TRPSDL2O3AIRSFS) at GES DISC': 94,
#  'NLDAS Mosaic Land Surface Model L4 Monthly Climatology 0.125 x 0.125 degree V2.0 (NLDAS_MOS0125_MC) at GES DISC': 95,
#  'OMPS-NPP L2 NM Cloud Pressure and Fraction swath orbital V2 (OMPS_NPP_NMCLDRR_L2) at GES DISC': 96,
#  'SBUV2/NOAA-16 Ozone (O3) Nadir Profile and Total Column 1 Day L2 V1 (SBUV2N16L2) at GES DISC': 97,
#  'SAMS/Nimbus-7 Level 3 Zonal Means Composition Data V001 (SAMSN7L3ZMTG) at GES DISC': 98,
#  'SBUV2/NOAA-17 Ozone (O3) Nadir Profile and Total Column 1 Day L2 V1 (SBUV2N17L2) at GES DISC': 99,
#  'CAR Safari South African Biogeophysics and Biogeochemistry L1 V1 (CAR_SAFARI_L1C) at GES DISC': 100,
#  'Sentinel-5P TROPOMI Radiance product band 2 (UV detector) L1B V1 (S5P_L1B_RA_BD2) at GES DISC': 101,
#  'Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_AMSUB_NOAA17_OBS) at GES DISC': 102,
#  'OCO-2 Level 1A collated, parsed, calibration data, Retrospective Processing V10r (OCO2_L1aIn_Pixel) at GES DISC': 103,
#  'GPM SSMI on F15 (GPROF) Climate-based Radiometer Precipitation Profiling L3 1 day 0.25 degree x 0.25 degree V05 (GPM_3GPROFF15SSMI_DAY_CLIM) at GES DISC': 104,
#  'Carbon Monitoring System Lake Michigan Primary Production Yearly V1 (CMSLakeMichiganPPY) at GES DISC': 105,
#  'NLDAS Secondary Forcing Data L4 Monthly 0.125 x 0.125 degree V002 (NLDAS_FORB0125_M) at GES DISC': 106,
#  'MERRA-2 inst3_3d_aer_Nv: 3d,3-Hourly,Instantaneous,Model-Level,Assimilation,Aerosol Mixing Ratio 0.625 x 0.5 degree V5.12.4 (M2I3NVAER) at GES DISC': 107,
#  'Sounder SIPS: AQUA AIRS IR-only Level 3 CLIMCAPS: Comprehensive Quality Control Gridded Monthly V2 at GES DISC': 108,
#  'AIRS/Aqua L3 Daily Standard Physical Retrieval (AIRS+AMSU) 1 degree x 1 degree V006 (AIRX3STD) at GES DISC': 109,
#  'Carbon Monitoring System Carbon Flux for Ocean Prior L4 V2 (CMSFluxOceanPrior) at GES DISC': 110,
#  'MLS/Aura Near-Real-Time L2 Water Vapor (H2O) Mixing Ratio V004 (ML2H2O_NRT) at GES DISC': 111,
#  'Gridded Monthly Time-Mean Observation minus Forecast (omf) Values 0.5 x 0.667 degree V001 (MA_MSU_NOAA08_OMF) at GES DISC': 112,
#  'MLS/Aura Level 3 Monthly Binned Chlorine Monoxide (ClO) Mixing Ratio on Assorted Grids V005 (ML3MBCLO) at GES DISC': 113,
#  'GLDAS Noah Land Surface Model L4 3 hourly 0.25 x 0.25 degree Early Product V2.1 (GLDAS_NOAH025_3H_EP) at GES DISC': 114,
#  'Goddard Satellite-Based Surface Turbulent Fluxes, 1x1 deg Daily Grid, Satellite F14 V2c (GSSTF_F14) at GES DISC': 115,
#  'UARS Cryogenic Limb Array Etalon Spectrometer (CLAES) Level 3AL V009 (UARCL3AL) at GES DISC': 116,
#  'MODIS/Aqua Total Precip Water Vapor 1km and 5km 5-Min L2 Narrow Swath Subset along CloudSat V002 (MAC05S0) at GES DISC': 117,
#  'HIRDLS/Aura Level 3 Chlorine Nitrate (ClONO2) 1deg Lat Zonal Fourier Coefficients V007 (H3ZFCCLONO2) at GES DISC': 118,
#  'OCO-3 Level 2 meteorological parameters interpolated from global assimilation model for each sounding, Retrospective Processing V10r (OCO3_L2_Met) at GES DISC': 119,
#  'MERRA-2 tavgM_3d_qdt_Np: 3d,Monthly mean,Time-Averaged,Pressure-Level,Assimilation,Moist Tendencies 0.625 x 0.5 degree V5.12.4 (M2TMNPQDT) at GES DISC': 120,
#  'MLS/Aura Level 3 Monthly Binned Hypochlorous Acid (HOCl) Mixing Ratio on Assorted Grids V004 (ML3MBHOCL) at GES DISC': 121,
#  'GPM SSMIS on F18 (GPROF) Climate-based Radiometer Precipitation Profiling L3 1 day 0.25 degree x 0.25 degree V05 (GPM_3GPROFF18SSMIS_DAY_CLIM) at GES DISC': 122,
#  'MODIS/Aqua Total Precip Water Vapor 1km and 5km 5-Min L2 Wide Swath Subset along CloudSat V002 (MAC05S1) at GES DISC': 123,
#  'TROPESS AIRS-Aqua L2 Atmospheric Temperature for Forward Stream, Standard Product V1 (TRPSDL2TATMAIRSFS) at GES DISC': 124,
#  'GPM DPR and GMI Combined Convective Stratiform Heating L3 1 month 0.5 degree x 0.5 degree V07 (GPM_3HCSH) at GES DISC': 125,
#  'Multi-Satellite Lambertian Equivalent Reflectivity (Noon Normalized) 10-Day L3 Global 2.0x5.0deg Lat/Lon Grid V1 (MSLERNNL3d10) at GES DISC': 126,
#  'FLDAS Noah Land Surface Model L4 Central Asia Daily 0.01 x 0.01 degree V001 (FLDAS_NOAH001_G_CA_D) at GES DISC': 127,
#  'tavg1_2d_ocn_Nx: MERRA 2D IAU Ocean Surface Diagnostic, Time Average 1-hourly  0.667 x 0.5 degree V5.2.0 (MAT1NXOCN) at GES DISC': 128,
#  'TOMS EP UV Aerosol Index Daily and Monthly Zonal Means V008 (TOMSEPL3zaer) at GES DISC': 129,
#  'THIR/Nimbus-4 Images of Daytime and Nighttime Brightness Temperature at 6.7 microns on 70 mm Film V001 (THIRN4IMCH67) at GES DISC': 130,
#  'Multi-Satellite Merged Ozone (O3) Profile and Total Column 1 Month Zonal Mean L3 Global 5.0 degree Latitude Zones V1 (MSO3L3zm5) at GES DISC': 131,
#  'AMSR2/GCOM-W1 surface soil moisture (LPRM) L3 1 day 25 km x 25 km descending V001 (LPRM_AMSR2_D_SOILM3) at GES DISC': 132,
#  'Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_SSU_NOAA11_OBS) at GES DISC': 133,
#  'GPM PR and TMI on TRMM Combined Gridded Orbital Convective-Stratiform Latent Heating Profiles L3 1.5 hours 0.25x0.25 degree V06 (GPM_3GCSH_TRMM) at GES DISC': 134,
#  'OMPS-NPP L2 NM Nitrogen Dioxide (NO2) Total and Tropospheric Column swath orbital V2 (OMPS_NPP_NMNO2_L2) at GES DISC': 135,
#  'MLS/Aura Level 2 Hydrogen Chloride (HCl) Mixing Ratio V005 (ML2HCL) at GES DISC': 136,
#  'MERRA-2 tavg3_3d_cld_Nv: 3d,3-Hourly,Time-Averaged,Model-Level,Assimilation,Cloud Diagnostics 0.625 x 0.5 degree V5.12.4 (M2T3NVCLD) at GES DISC': 137,
#  'MLS/Aura Level 3 Daily Binned Sulfur Dioxide (SO2) Mixing Ratio on Assorted Grids V004 (ML3DBSO2) at GES DISC': 138,
#  'MLS/Aura Level 3 Daily Binned Hydroxyl (OH) Mixing Ratio on Assorted Grids V004 (ML3DBOH) at GES DISC': 139,
#  'Land/Sea static mask relevant to TMPA precipitation 0.25x0.25 degree V2 (TRMM_TMPA_LandSeaMask) at GES DISC': 140,
#  'Aqua AIRS Level 3 Spectral Outgoing Longwave Radiation (OLR) Monthly': 141,
#  'tavgU_3d_odt_Cp: MERRA 3D IAU Tendency, Ozone, Diurnal  1.25 x 1.25 degree V5.2.0 (MATUCPODT) at GES DISC': 142,
#  'AIRS/Aqua L3 Monthly Quantization in Physical Units (AIRS-only) 5 degrees x 5 degrees V006 (AIRS3QPM) at GES DISC': 143,
#  'Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_AMSUA_NOAA17_OBS) at GES DISC': 144,
#  'Sounder SIPS: Sun Synchronous 13:30 orbit Climate Hyperspectral InfraRed Product (CHIRP): Calibrated Radiances from S-NPP, V2 (SNDR13CHRP1SNCal) at GES DISC': 145,
#  'MLS/Aura Level 3 Daily Binned Relative Humidity With Respect To Ice (RHI) on Assorted Grids V004 (ML3DBRHI) at GES DISC': 146,
#  'Gridded Monthly Time-Mean Observation minus Forecast (omf) Values 0.5 x 0.667 degree V001 (MA_SSMI_DMSP08_OMF) at GES DISC': 147,
#  'GLDAS Noah Land Surface Model L4 monthly 0.25 x 0.25 degree Early Product V2.1 (GLDAS_NOAH025_M_EP) at GES DISC': 148,
#  'TOMS Nimbus-7 UV Reflectivity Monthly L3 Global 1 deg x 1.25 deg Lat/Lon Grid V008 (TOMSN7L3mref) at GES DISC': 149,
#  'MLS/Aura Level 2 Diagnostics, Geophysical Parameter Grid V005 (ML2DGG) at GES DISC': 150,
#  'TRMM Ground Validation Radar Site 3D Rain Map L3 1 month 2 km V7 (TRMM_3A55) at GES DISC': 151,
#  'ACOS GOSAT/TANSO-FTS Level 2 bias-corrected XCO2 and other select fields from the full-physics retrieval aggregated as daily files V9r (ACOS_L2_Lite_FP) at GES DISC': 152,
#  'GPM DPR Ka Environment L2A 1.5 hours 5 km V07 (GPM_2AKaENV) at GES DISC': 153,
#  'BUV/Nimbus-4 Ozone (O3) Profile and Total Column Ozone 1 Month Zonal Mean L3 Global 5.0 degree Latitude Zones V1 (BUVN04L3zm) at GES DISC': 154,
#  'TOVS GLA MONTHLY GRIDS from NOAA-10 V01 (TOVSAMNG) at GES DISC': 155,
#  'instU_2d_int_Nx: MERRA 2D IAU Diagnostic, Vertical Integrals and Budget Terms, Diurnal  0.667 x 0.5 degree V5.2.0 (MAIUNXINT) at GES DISC': 156,
#  'AIRS/Aqua L2 Standard Physical Retrieval (AIRS-only) V006 (AIRS2RET) at GES DISC': 157,
#  'Gridded Monthly Time-Mean Observation minus Forecast (omf) Values 0.5 x 0.667 degree V001 (MA_HIRS2_NOAA14_OMF) at GES DISC': 158,
#  'OCO-3 Level 2 CO2 prior based on CO2 monthly flask record, global meteorology, and age of air, Retrospective Processing V10r (OCO3_L2_CO2Prior) at GES DISC': 159,
#  'GPM AMSR-E on Aqua (GPROF) Climate-based Radiometer Precipitation Profiling L2 1.5 hours 5 km V05 (GPM_2AGPROFAQUAAMSRE_CLIM) at GES DISC': 160,
#  'MUSTARD-EMLS Level 2 Standard Products V1 (MUSEMLSL2DGG) at GES DISC': 161,
#  'GPM TMI on TRMM unpacked data L1A 1.5 hours 13 km V05 (GPM_1ATMI) at GES DISC': 162,
#  'GLDAS VIC Land Surface Model L4 3 hourly 1.0 x 1.0 degree V2.0 (GLDAS_VIC10_3H) at GES DISC': 163,
#  'HRIR/Nimbus-2 Images of Nighttime Brightness Temperature on 70 mm Film V001 (HRIRN2IM) at GES DISC': 164,
#  'GPM AMSUB on NOAA16 (GPROF) Climate-based Radiometer Precipitation Profiling L3 1 month 0.25 degree x 0.25 degree  V05 (GPM_3GPROFNOAA16AMSUB_CLIM) at GES DISC': 165,
#  'tavgM_3d_tdt_Cp: MERRA 3D IAU Tendency, Temperature, Monthly Mean  1.25 x 1.25 degree V5.2.0 (MATMCPTDT) at GES DISC': 166,
#  'GPM AMSR-2 on GCOM-W1 (GPROF) Radiometer Precipitation Profiling L2A 1.5 hours 10 km V05 (GPM_2AGPROFGCOMW1AMSR2) at GES DISC': 167,
#  'MLS/Aura Level 3 Daily Binned Hydrogen Cyanide (HCN) Mixing Ratio on Zonal and Similar Grids V005 (ML3DZHCN) at GES DISC': 168,
#  'MLS/Aura Level 3 Daily Binned Nitrous Oxide (N2O) Mixing Ratio on Assorted Grids V004 (ML3DBN2O) at GES DISC': 169,
#  'GLDAS Catchment Land Surface Model L4 daily 0.25 x 0.25 degree GRACE-DA1 V2.2 (GLDAS_CLSM025_DA1_D_EP) at GES DISC': 170,
#  'GPM AMSR-2 on GCOM-W1 (GPROF) Radiometer Precipitation Profiling L3 1 day 0.25 degree x 0.25 degree V05 (GPM_3GPROFGCOMW1AMSR2_DAY) at GES DISC': 171,
#  'OCO-3 Level 1B calibrated, geolocated science spectra, Retrospective Processing EarlyR (OCO3_L1B_Science) at GES DISC': 172,
#  'TMI/TRMM surface soil moisture (LPRM) L3 1 day 25 km x 25 km daytime V001 (LPRM_TMI_DY_SOILM3) at GES DISC': 173,
#  'GPM MHS on METOP-B (GPROF) Climate-based Radiometer Precipitation Profiling L3 1 month 0.25 degree x 0.25 degree V05 (GPM_3GPROFMETOPBMHS_CLIM) at GES DISC': 174,
#  'GPM SSMIS on F18 (GPROF) Radiometer Precipitation Profiling L3 1 month 0.25 degree x 0.25 degree V05 (GPM_3GPROFF18SSMIS) at GES DISC': 175,
#  'OCO-3 Level 2 CO2 prior based on CO2 monthly flask record, global meteorology, and age of air VEarly (OCO3_L2_CO2Prior) at GES DISC': 176,
#  'HIRDLS/Aura Level 3 Nitrogen Dioxide (NO2) 1deg Lat Zonal Fourier Coefficients V007 (H3ZFCNO2) at GES DISC': 177,
#  'NLDAS Secondary Forcing Data L4 Monthly Climatology 0.125 x 0.125 degree V002 (NLDAS_FORB0125_MC) at GES DISC': 178,
#  'MERRA-2 const_2d_ctm_Nx: Constant Model Parameters for Usage by CTM 0.625 x 0.5 degree V5.12.4 (M2C0NXCTM) at GES DISC': 179,
#  'MSU Daily Oceanic Precipitation with Limb93 Correction L3 1 day 2.5 degree x 2.5 degree V001 (MSUOP) at GES DISC': 180,
#  'MLS/Aura Near-Real-Time L2 Nitrous Oxide (N2O) Mixing Ratio V005 (ML2N2O_NRT) at GES DISC': 181,
#  'OCO-3 Level 2 spatially ordered geolocated retrievals screened using the A-band Preprocessor VEarly (OCO3_L2_ABand) at GES DISC': 182,
#  'MLS/Aura Level 3 Bromine Monoxide (BrO) Daily 10degrees Lat Zonal Mean V003 (ML3DZMBRO) at GES DISC': 183,
#  'MLS/Aura Level 3 Daily Binned Carbon Monoxide (CO) Mixing Ratio on Assorted Grids V005 (ML3DBCO) at GES DISC': 184,
#  'OMI/Aura Near UV Aerosol Optical Depth and Single Scattering Albedo Daily L2 Global Gridded 0.25 degree x 0.25 degree V3 (OMAERUVG) at GES DISC': 185,
#  'SBUV2/NOAA-14 Ozone (O3) Profile and Total Column Ozone 1 Month Zonal Mean L3 Global 5.0 degree Latitude Zones V1 (SBUV2N14L3zm) at GES DISC': 186,
#  'OMI/Aura Level 1B Averaged Solar Irradiances V004 (OML1BIRR) at GES DISC': 187,
#  'TOVS GLA MONTHLY GRIDS from TIROS-N 02 (TOVSAMTN) at GES DISC': 188,
#  'MERRA-2 tavgM_3d_udt_Np: 3d,Monthly mean,Time-Averaged,Pressure-Level,Assimilation,Wind Tendencies 0.625 x 0.5 degree V5.12.4 (M2TMNPUDT) at GES DISC': 189,
#  'Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_HIRS2_AM_OBS) at GES DISC': 190,
#  'Gridded Monthly Time-Mean Observation minus Forecast (omf) Values 0.5 x 0.667 degree V001 (MA_HIRS2_NOAA06_OMF) at GES DISC': 191,
#  'Sentinel-5P TROPOMI Radiance product band 4 (UVIS detector) L1B 5.5km x 3.5km V2 (S5P_L1B_RA_BD4_HiR) at GES DISC': 192,
#  'AMSR-MODIS Boundary Layer Water Vapor L3 Monthly 1 degree x 1 degree V2 (AMMBLWV) at GES DISC': 193,
#  'Multi-Satellite Air Quality Sulfur Dioxide (SO2) Database Long-Term L4 Global V1 (MSAQSO2L4) at GES DISC': 194,
#  'GOZCARDS Source Water Vapor 1 month L3 10 degree Zonal Means on a Vertical Pressure Grid V1 (GozSmlpH2O) at GES DISC': 195,
#  'CAR ARMCAS Arctic Cloud Radiation Measurements L1 V1 (CAR_ARMCAS_L1C) at GES DISC': 196,
#  'Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_SSMI_DMSP13_OBS) at GES DISC': 197,
#  'GPM ATMS on NOAA-20 (GPROF) Radiometer Precipitation Profiling L3 1 day 0.25 degree x 0.25 degree  V05 (GPM_3GPROFNOAA20ATMS_DAY) at GES DISC': 198,
#  'TOVS LMD DAILY GRIDS from NOAA-12 V01 (TOVSBDND) at GES DISC': 199,
#  'MERRA-2 inst1_2d_asm_Nx: 2d,1-Hourly,Instantaneous,Single-Level,Assimilation,Single-Level Diagnostics 0.625 x 0.5 degree V5.12.4 (M2I1NXASM) at GES DISC': 200,
#  'OCO-3 Level 2 spatially ordered geolocated retrievals screened using the IMAP-DOAS Preprocessor (IDP), Retrospective Processing V10r (OCO3_L2_IMAPDOAS) at GES DISC': 201,
#  'TOVS GLA DAILY GRIDS from NOAA-11 V01 (TOVSADNH) at GES DISC': 202,
#  'CAR CLASIC BRDF Measurements V2 (CAR_CLASIC_BRDF) at GES DISC': 203,
#  'TROPESS CrIS-SNPP L2 Ozone IRK for Forward Stream, Standard Product V1 (TRPSDL2O3IRKCRSFS) at GES DISC': 204,
#  'Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_SSMI_DMSP14_OBS) at GES DISC': 205,
#  'THIR/Nimbus-6 Images of Daytime and Nighttime Brightness Temperature on 70 mm Film V001 (THIRN6IM) at GES DISC': 206,
#  'Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_HIRS2_NOAA08_OBS) at GES DISC': 207,
#  'tavgU_3d_cld_Cp: MERRA 3D IAU Diagnostic, Cloud Properties, Diurnal  1.25 x 1.25 degree V5.2.0 (MATUCPCLD) at GES DISC': 208,
#  'GLDAS VIC Land Surface Model L4 monthly 1.0 x 1.0 degree V2.1 (GLDAS_VIC10_M) at GES DISC': 209,
#  'TIROS-3 Medium-Resolution Scanning Radiometer Level 1 Final Meteorological Radiation Data V001 (TIROS3L1FMRT) at GES DISC': 210,
#  'Gridded Monthly Time-Mean Observation minus Analysis (oma) Values 0.5 x 0.667 degree V001 (MA_MSU_NOAA10_OMA) at GES DISC': 211,
#  'MLS/Aura Near-Real-Time L2 Sulfur Dioxide (SO2) Mixing Ratio V004 (ML2SO2_NRT) at GES DISC': 212,
#  'TRMM Microwave Imager Precipitation Profile L3 1 month 0.5 degree x 0.5 degree V7 (TRMM_3A12) at GES DISC': 213,
#  'Goddard Satellite-Based Surface Turbulent Fluxes, 0.25 x 0.25 deg, Daily Grid F13 V3 (GSSTF_F13) at GES DISC': 214,
#  'OMI/Aura Level 2 Near UV Aerosol Optical Depth and Single Scattering Albedo 200-m swath subset along CloudSat track V003 (OMAERUV_CPR) at GES DISC': 215,
#  'TROPESS AIRS-Aqua L2 Ozone IRK for Forward Stream, Standard Product V1 (TRPSDL2O3IRKAIRSFS) at GES DISC': 216,
#  'GPM SSMI on F13 Common Calibrated Brightness Temperatures L1C 1.5 hours 13 km V06 (GPM_1CF13SSMI) at GES DISC': 217,
#  'GPM DPR Spectral Latent Heating Profiles L3 1 day 0.5 degree x 0.5 degree V06 (GPM_3HSLH_DAY) at GES DISC': 218,
#  'MLS/Aura Level 3 Daily Binned Temperature on Zonal and Similar Grids V005 (ML3DZT) at GES DISC': 219,
#  'Multi-Satellite Volcanic Sulfur Dioxide L4 Long-Term Global Database V4 (MSVOLSO2L4) at GES DISC': 220,
#  'GPM SSMI on F14 (GPROF) Climate-based Radiometer Precipitation Profiling L3 1 month 0.25 degree x 0.25 degree V05 (GPM_3GPROFF14SSMI_CLIM) at GES DISC': 221,
#  'GLDAS VIC Land Surface Model L4 monthly 1.0 x 1.0 degree V2.0 (GLDAS_VIC10_M) at GES DISC': 222,
#  'Gridded Monthly Time-Mean Observation minus Analysis (oma) Values 0.5 x 0.667 degree V001 (MA_AMSUA_NOAA15_OMA) at GES DISC': 223,
#  'TOMS Nimbus-7 UV Aerosol Index Monthly L3 Global 1 deg x 1.25 deg Lat/Lon Grid V008 (TOMSN7L3maer) at GES DISC': 224,
#  'MLS/Aura Near-Real-Time L2 Sulfur Dioxide (SO2) Mixing Ratio V005 (ML2SO2_NRT) at GES DISC': 225,
#  'OMI/Aura Formaldehyde (HCHO) Total Column Daily L3 Weighted Mean Global 0.1deg Lat/Lon Grid V003 (OMHCHOd) at GES DISC': 226,
#  'AIRS/Aqua L3 Monthly Standard Physical Retrieval (AIRS+AMSU+HSB) 1 degree x 1 degree V006 (AIRH3STM) at GES DISC': 227,
#  'GPM DPR Spectral Latent Heating Profiles L3 1 day 0.5 degree x 0.5 degree V07 (GPM_3HSLH_DAY) at GES DISC': 228,
#  'MLS/Aura Level 3 Daily Binned Temperature on Zonal and Similar Grids V004 (ML3DZT) at GES DISC': 229,
#  'Sentinel-5P TROPOMI Tropospheric NO2 1-Orbit L2 5.5km x 3.5km V1 (S5P_L2__NO2____HiR) at GES DISC': 230,
#  'SORCE Level 3 Total Solar Irradiance Daily Means V017 (SOR3TSID) at GES DISC': 231,
#  'Sentinel-5P TROPOMI Methane CH4 1-Orbit L2 7km x 7km V1 (S5P_L2__CH4___) at GES DISC': 232,
#  'Carbon Monitoring System Carbon Flux from the Net Biome Exchange L4 V2 (CMSFluxNBE) at GES DISC': 233,
#  'Sounder SIPS: AQUA AIRS IR   MW Level 3 CLIMCAPS : Specific Quality Control Gridded Daily V2 at GES DISC': 234,
#  'AIRS/Aqua L2 Cloud-Cleared Infrared Radiances (AIRS-only) V006 (AIRS2CCF) at GES DISC': 235,
#  'Goddard Satellite-Based Surface Turbulent Fluxes, 0.25 x 0.25 deg, Monthly Grid V3 (GSSTFM) at GES DISC': 236,
#  'GOZCARDS Merged Water Vapor 1 month L3 10 degree Zonal Means on a Vertical Pressure Grid V1 (GozMmlpH2O) at GES DISC': 237,
#  'TROPESS CrIS-JPSS1 L2 Ozone for Forward Stream, Standard Product V1 (TRPSDL2O3CRS1FS) at GES DISC': 238,
#  'Aqua/AIRS  L2 Support Retrieval (AIRS+AMSU) V7.0 at GES DISC': 239,
#  'OMPS-NPP L2 LP Aerosol Extinction Vertical Profile swath daily 3slit V1 (OMPS_NPP_LP_L2_AER675_DAILY) at GES DISC': 240,
#  'OMI/Aura Cloud Pressure and Fraction (O2-O2 Absorption) 1-Orbit L2 Swath 13x24km V003 (OMCLDO2) at GES DISC': 241,
#  'tavgM_3d_trb_Cp: MERRA 3D IAU Diagnostic, Turbulence, Monthly Mean  1.25 x 1.25 degree V5.2.0 (MATMCPTRB) at GES DISC': 242,
#  'TRMM Combined Precipitation Radar and Microwave Imager Rainfall Profile L2 1.5 hours V7 (TRMM_2B31) at GES DISC': 243,
#  'tavgU_3d_rad_Cp: MERRA 3D IAU Diagnostic, Radiation, Diurnal  1.25 x 1.25 degree V5.2.0 (MATUCPRAD) at GES DISC': 244,
#  'OCO-2 Level 1B calibrated, geolocated calibration spectra, Retrospective Processing V10r (OCO2_L1B_Calibration) at GES DISC': 245,
#  'NLDAS Primary Forcing Data L4 Monthly Climatology 0.125 x 0.125 degree V2.0 (NLDAS_FORA0125_MC) at GES DISC': 246,
#  'OCO-3 Level 2 geolocated XCO2 retrievals results, physical model VEarly (OCO3_L2_Standard) at GES DISC': 247,
#  'Gridded Monthly Time-Mean Observation minus Analysis (oma) Values 0.5 x 0.667 degree V001 (MA_SSU_NOAA14_OMA) at GES DISC': 248,
#  'TROPESS CrIS-SNPP L2 Atmospheric Temperature for Forward Stream, Standard Product V1 (TRPSDL2TATMCRSFS) at GES DISC': 249,
#  'Gridded Monthly Time-Mean Observation minus Forecast (omf) Values 0.5 x 0.667 degree V001 (MA_MSU_NOAA09_OMF) at GES DISC': 250,
#  'MERRA-2 tavg3_3d_mst_Nv: 3d,3-Hourly,Time-Averaged,Model-Level,Assimilation,Moist Processes Diagnostics 0.625 x 0.5 degree V5.12.4 (M2T3NVMST) at GES DISC': 251,
#  'OMPS-NPP L1 NM ANC Data Swath Orbital V2 (OMPS_NPP_NM_ANC_L1) at GES DISC': 252,
#  'HIRDLS/Aura Level 3 Temperature 1deg Lat Zonal Fourier Coefficients V007 (H3ZFCT) at GES DISC': 253,
#  'TIROS-2 Medium-Resolution Scanning Radiometer Level 1 Final Meteorological Radiation Data V001 (TIROS2L1FMRT) at GES DISC': 254,
#  'CAR SnowEx17 Snow Mass and Energy Measurements L1 V1 (CAR_SNOWEX17_L1C) at GES DISC': 255,
#  'GPM MHS on NOAA-19 (GPROF) Radiometer Precipitation Profiling L2A 1.5 hours 17 km V05 (GPM_2AGPROFNOAA19MHS) at GES DISC': 256,
#  'SeaWiFS Deep Blue Aerosol Optical Thickness Monthly Level 3 Climatology Data Gridded at 0.5 Degrees V004 (SWDB_L3MC05) at GES DISC': 257,
#  'SIRS/Nimbus-3 Level 1 Radiance Data V001 (SIRSN3L1) at GES DISC': 258,
#  'GPS Radio Occultation Boundary Layer Depth Seasonal L3 V2 (GPSROZPBLS) at GES DISC': 259,
#  'AIRS/Aqua L3 Daily Support Daily Product (AIRS+AMSU+HSB) 1 degree x 1 degree V006 (AIRH3SPD) at GES DISC': 260,
#  'TOMS EP UV Reflectivity Daily and Monthly Zonal Means V008 (TOMSEPL3zref) at GES DISC': 261,
#  'TOMS Nimbus-7 UV-B Erythemal Local Noon Irradiance Monthly L3 Global 1 deg x 1.25 deg Lat/Lon Grid V008 (TOMSN7L3mery) at GES DISC': 262,
#  'Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_AMSUB_NOAA16_OBS) at GES DISC': 263,
#  'BUV/Nimbus-4 Dark Current Study Master Data V001 (BUVN4L1DCM) at GES DISC': 264,
#  'TRMM Radar Rain Distributions L3 1 month 5 degree x 5 degree V7 (TRMM_3A26) at GES DISC': 265,
#  'MLS/Aura Level 3 Daily Binned Carbon Monoxide (CO) Mixing Ratio on Assorted Grids V004 (ML3DBCO) at GES DISC': 266,
#  'Sounder SIPS: Suomi NPP CrIMSS Level 3 Comprehensive Quality Control Gridded Monthly CLIMCAPS Full Spectral Resolution V2 at GES DISC': 267,
#  'HIRDLS/Aura Level 3 Water Vapor (H2O) 1deg Lat Zonal Fourier Coefficients V007 (H3ZFCH2O) at GES DISC': 268,
#  'NLDAS Noah Land Surface Model L4 Hourly 0.125 x 0.125 degree V002 (NLDAS_NOAH0125_H) at GES DISC': 269,
#  'Sounder SIPS: Suomi NPP CrIMSS Level 2 CLIMCAPS Normal Spectral Resolution: Cloud Cleared Radiances V2 at GES DISC': 270,
#  'OCO-2 Level 2 preprocessor using Generic Algorithm for Single Band Acquisition of Gases (GASBAG), Retrospective Processing V10r (OCO2_L2_GASBAG) at GES DISC': 271,
#  'instM_3d_asm_Cp: MERRA 3D IAU State, Meteorology Monthly Mean  1.25 x 1.25 degree V5.2.0 (MAIMCPASM) at GES DISC': 272,
#  'TRMM Ground Validation Radar Site Rain Type Totals Map L3 1 month 2 km V7 (TRMM_3A54UW) at GES DISC': 273,
#  'NASA Ocean Biogeochemical Model assimilating satellite chlorophyll data global monthly VR2017 (NOBM_MON) at GES DISC': 274,
#  'MLS/Aura Near-Real-Time L2 Nitrous Oxide (N2O) Mixing Ratio V004 (ML2N2O_NRT) at GES DISC': 275,
#  'CAR Kuwait Oil Fire Spectral Reflectance L1 V1 (CAR_KUWAITOILFIRE_L1C) at GES DISC': 276,
#  'OMI/Aura Level 1B VIS Zoom-in Geolocated Earthshine Radiances V004 (OML1BRVZ) at GES DISC': 277,
#  'GPM GMI RSS Common Calibrated Brightness Temperatures L1BASE 1.5 hours 13 km V05 (GPM_BASEGPMGMI_RSS) at GES DISC': 278,
#  'Sentinel-5P TROPOMI Sulphur Dioxide SO2 1-Orbit L2 7km x 3.5km V1 (S5P_L2__SO2___) at GES DISC': 279,
#  'LRIR/Nimbus-6 Level 2 Inverted Profiles of Temperature and Ozone V001 (LRIRN6L2IPAT) at GES DISC': 280,
#  'Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_MSU_NOAA07_OBS) at GES DISC': 281,
#  'HIRDLS/Aura Level 3 Geopotential Height 1deg Lat Zonal Fourier Coefficients V007 (H3ZFCGPH) at GES DISC': 282,
#  'Sounder SIPS: AQUA AIRS IR-only Level 2 CLIMCAPS : Atmosphere, cloud and surface geophysical state V2 at GES DISC': 283,
#  'GPM SSMIS on F18 (GPROF) Radiometer Precipitation Profiling L3 1 day 0.25 degree x 0.25 degree V05 (GPM_3GPROFF18SSMIS_DAY) at GES DISC': 284,
#  'GPM MHS on METOP-B (GPROF) Radiometer Precipitation Profiling L2A 1.5 hours 17 km V05 (GPM_2AGPROFMETOPBMHS) at GES DISC': 285,
#  'CAR CLASIC Cloud and Land Surface Measurements L1 V1 (CAR_CLASIC_L1C) at GES DISC': 286,
#  'NASA Energy and Water cycle Study (NEWS) Annual Climatology of the 1st decade of the 21st Century V1.0 (NEWS_WEB_ACLIM) at GES DISC': 287,
#  'AIRS/Aqua L2 CO2 in the free troposphere (AIRS+AMSU) V005 (AIRX2STC) at GES DISC': 288,
#  'TOVS GLA MONTHLY GRIDS from NOAA-9 V01 (TOVSAMNF) at GES DISC': 289,
#  'GPM SSMIS on F18 (GPROF) Climate-based Radiometer Precipitation Profiling L3 1 month 0.25 degree x 0.25 degree V05 (GPM_3GPROFF18SSMIS_CLIM) at GES DISC': 290,
#  'GLDAS VIC Land Surface Model L4 3 hourly 1.0 x 1.0 degree V2.1 (GLDAS_VIC10_3H) at GES DISC': 291,
#  'AIRS/Aqua L3 8-day Standard Physical Retrieval (AIRS+AMSU+HSB) 1 degree x 1 degree V006 (AIRH3ST8) at GES DISC': 292,
#  'TROPESS CrIS-SNPP L2 Carbon Monoxide for Buchholz2021 TS1, Standard Product V1 (TRPSDL2COCRSTS1) at GES DISC': 293,
#  'MODIS Aqua L2 model predicted low cloud types of chopped blocks in which low cloud dominates (block size: 128pixels x 128pixels)': 294,
#  'MLS/Aura Level 3 Daily Binned Hydrogen Cyanide (HCN) Mixing Ratio on Zonal and Similar Grids V004 (ML3DZHCN) at GES DISC': 295,
#  'Sentinel-5P TROPOMI Total Ozone Column 1-Orbit L2 5.5km x 3.5km V2 (S5P_L2__O3_TOT_HiR) at GES DISC': 296,
#  'TROPESS TROPOMI-S5P L2 Methane for Forward Stream, Standard Product V1 (TRPSDL2CH4TRPOMIFS) at GES DISC': 297,
#  'MLS/Aura Level 3 Daily Binned Nitrous Oxide (N2O) Mixing Ratio on Assorted Grids V005 (ML3DBN2O) at GES DISC': 298,
#  'tavg1_2d_lnd_Nx: MERRA 2D IAU Diagnostic, Land Only States and Diagnostics, Time Average 1-hourly  0.667 x 0.5 degree V5.2.0 (MAT1NXLND) at GES DISC': 299,
#  'Explorer-7 Thermal Radiation Experiment Selected White Sensor Temperature (Nighttime) Values V001 (EXP7L1TRTWHT) at GES DISC': 300,
#  'TOMS Nimbus-7 Total Column Ozone Daily L3 Global 1 deg x 1.25 deg Lat/Lon Grid V008 (TOMSN7L3dtoz) at GES DISC': 301,
#  'Sentinel-5P TROPOMI Radiance product band 1 (UV detector) L1B 5.5km x 21km V2 (S5P_L1B_RA_BD1_HiR) at GES DISC': 302,
#  'HIRDLS/Aura Level 3 Nitric Acid (HNO3) 1deg Lat Zonal Fourier Coefficients V007 (H3ZFCHNO3) at GES DISC': 303,
#  'Goddard Satellite-Based Surface Turbulent Fluxes, 0.25 x 0.25 deg, Daily Grid F11 V3 (GSSTF_F11) at GES DISC': 304,
#  'Gridded Monthly Time-Mean Observation minus Analysis (oma) Values 0.5 x 0.667 degree V001 (MA_SSU_NOAA06_OMA) at GES DISC': 305,
#  'GPM IMERG Final Precipitation L3 1 month 0.1 degree x 0.1 degree V06 (GPM_3IMERGM) at GES DISC': 306,
#  'AIRS/Aqua L1B Infrared (IR) quality assurance subset V005 (AIRIBQAP) at GES DISC': 307,
#  'GLDAS Catchment Land Surface Model L4 3 hourly 1.0 x 1.0 degree Early Product V2.1 (GLDAS_CLSM10_3H_EP) at GES DISC': 308,
#  'CAR Eco-3D Vegetation Response to Changing Forcing Factors L1 V1 (CAR_ECO3D_L1C) at GES DISC': 309,
#  'Carbon Monitoring System Flux for Posterior Fire Carbon L4 V1 (CMSFluxFirepost) at GES DISC': 310,
#  'SORCE XPS Level 3 Solar Spectral Irradiance Daily Means V011 (SOR3XPSD) at GES DISC': 311,
#  'MLS/Aura Level 3 Daily Binned Relative Humidity With Respect To Ice (RHI) on Assorted Grids V005 (ML3DBRHI) at GES DISC': 312,
#  'MLS/Aura Level 2 Diagnostics, Geophysical Parameter Grid V004 (ML2DGG) at GES DISC': 313,
#  'GPM DPR Ka Environment L2A 1.5 hours 5 km V06 (GPM_2AKaENV) at GES DISC': 314,
#  'SAMS/Nimbus-7 Level 1 Radiance Data from CD-ROM V001 (SAMSN7L1RAD_CDROM) at GES DISC': 315,
#  'TROPESS CrIS-SNPP and TROPOMI-S5P L2 Methane for Forward Stream, Standard Product V1 (TRPSDL2CH4CRSTRPOMIFS) at GES DISC': 316,
#  'Sounder SIPS: Suomi NPP CrIMSS Level 3 Comprehensive Quality Control Gridded Daily CHART Normal Spectral Resolution V1': 317,
#  'Aqua/AIRS L2 Cloud-Cleared Infrared Radiances (AIRS+AMSU) V7.0 at GES DISC': 318,
#  'OCO-3 Level 1B calibrated, geolocated science spectra,  Early (OCO3_L1B_Science) at GES DISC': 319,
#  'Gridded 6 hours Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_MON_CONV_OBS) at GES DISC': 320,
#  'Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_MSU_NOAA12_OBS) at GES DISC': 321,
#  'OMPS-NPP L2 LP Ozone (O3) Vertical Profile swath daily 3slit V2.5 (OMPS_NPP_LP_L2_O3_DAILY) at GES DISC': 322,
#  'TOMS Meteor-3 Total Ozone UV-Reflectivity Daily L3 Global 1 deg x 1.25 deg V008 (TOMSM3L3) at GES DISC': 323,
#  'GPM MHS on NOAA18 (GPROF) Radiometer Precipitation Profiling L3 1 month 0.25 degree x 0.25 degree V05 (GPM_3GPROFNOAA18MHS_CLIM) at GES DISC': 324,
#  'HIRDLS/Aura Level 3 Chlorofluorocarbon-11 (CFC-11) 1deg Lat Zonal Fourier Coefficients V007 (H3ZFCCFC11) at GES DISC': 325,
#  'UARS Particle Environment Monitor (PEM) Level 3AT V004 (UARPE3AT) at GES DISC': 326,
#  'MLS/Aura Level 2 Hydrogen Chloride (HCl) Mixing Ratio V004 (ML2HCL) at GES DISC': 327,
#  'OMI/Aura Nitrogen Dioxide (NO2) Total and Tropospheric Column 1-orbit L2 Swath 13x24 km V003 (OMNO2) at GES DISC': 328,
#  'MLS/Aura Level 3 Daily Binned Sulfur Dioxide (SO2) Mixing Ratio on Assorted Grids V005 (ML3DBSO2) at GES DISC': 329,
#  'MLS/Aura Level 3 Daily Binned Hydroxyl (OH) Mixing Ratio on Assorted Grids V005 (ML3DBOH) at GES DISC': 330,
#  'MERRA-2 inst6_3d_ana_Np: 3d,6-Hourly,Instantaneous,Pressure-Level,Analysis,Analyzed Meteorological Fields 0.625 x 0.5 degree V5.12.4 (M2I6NPANA) at GES DISC': 331,
#  'TOVS GLA MONTHLY GRIDS from NOAA-7 02 (TOVSAMNC) at GES DISC': 332,
#  'GPM IMERG Final Precipitation L3 Half Hourly 0.1 degree x 0.1 degree V06 (GPM_3IMERGHH) at GES DISC': 333,
#  'TRMM Precipitation Radar Spectral Latent Heating L3 1 month 0.5 degree x 0.5 degree V7 (TRMM_3H25) at GES DISC': 334,
#  'OCO-2 Level 2 bias-corrected solar-induced fluorescence and other select fields from the IMAP-DOAS algorithm aggregated as daily files, Retrospective processing V10r (OCO2_L2_Lite_SIF) at GES DISC': 335,
#  'tavg1_2d_mld_Nx: MERRA Simulated 2D Incremental Analysis Update (IAU) MERRA-Land reanalysis, GEOSldas-MERRALand, Time Average 1-hourly  0.667 x 0.5 degree V5.2.0 (MST1NXMLD) at GES DISC': 336,
#  'tavgU_3d_qdt_Cp: MERRA 3D IAU Tendency, Specific Humidity, Diurnal  1.25 x 1.25 degree V5.2.0 (MATUCPQDT) at GES DISC': 337,
#  'SBUV2/NOAA-11 Ozone (O3) Profile and Total Column Ozone 1 Month Zonal Mean L3 Global 5.0 degree Latitude Zones V1 (SBUV2N11L3zm) at GES DISC': 338,
#  'TROPESS CrIS-JPSS1 L2 Ammonia for Forward Stream, Standard Product V1 (TRPSDL2NH3CRS1FS) at GES DISC': 339,
#  'Gridded Monthly Time-Mean Observation minus Analysis (oma) Values 0.5 x 0.667 degree V001 (MA_SSMI_DMSP11_OMA) at GES DISC': 340,
#  'MLS/Aura Level 3 Monthly Binned Hypochlorous Acid (HOCl) Mixing Ratio on Assorted Grids V005 (ML3MBHOCL) at GES DISC': 341,
#  'GPM DPR and GMI Combined Convective Stratiform Heating L3 1 month 0.5 degree x 0.5 degree V06 (GPM_3HCSH) at GES DISC': 342,
#  'CMS (Carbon Monitoring System) Methane (CH4) Flux for North America 0.5 degree x 0.667 degree V1 (CMS_CH4_FLX_NA) at GES DISC': 343,
#  'Sounder SIPS: AQUA AIRS IR-only Level 2 CLIMCAPS: Cloud Cleared Radiances V2 at GES DISC': 344,
#  'THIR/Nimbus-5 Level 1 Meteorological Radiation Data at 11.5 microns V001 (THIRN5L1CH115) at GES DISC': 345,
#  'MERRA-2 tavgM_2d_chm_Nx: 2d,Monthly mean,Time-Averaged,Single-Level,Assimilation,Carbon Monoxide and Ozone Diagnostics 0.625 x 0.5 degree V5.12.4 (M2TMNXCHM) at GES DISC': 346,
#  'GPM SAPHIR on MT1 (PRPS) Climate-based Radiometer Precipitation Profiling L3 1 day 0.25 x 0.25 degree V06 (GPM_3PRPSMT1SAPHIR_DAY_CLIM) at GES DISC': 347,
#  'OMPS/NPP L1B NM Radiance EV Calibrated Geolocated Swath Orbital V2 (OMPS_NPP_NMEV_L1B) at GES DISC': 348,
#  'instM_3d_ana_Np: MERRA 3D Analyzed State, Meteorology Monthly Mean  0.667 x 0.5 degree V5.2.0 (MAIMNPANA) at GES DISC': 349,
#  'AIRS-CloudSat cloud mask, radar reflectivities, and cloud classification matchups V3.2 (AIRS_CPR_MAT) at GES DISC': 350,
#  'MLS/Aura Level 3 Monthly Binned Chlorine Monoxide (ClO) Mixing Ratio on Assorted Grids V004 (ML3MBCLO) at GES DISC': 351,
#  'SCAMS/Nimbus-6 Level 2 Water Vapor and Temperature, as well as Antenna and Brightness Temperature V001 (SCAMSN6L2) at GES DISC': 352,
#  'FLDAS Noah Land Surface Model L4 Global Monthly Climatology 0.1 x 0.1 degree (MERRA-2 and CHIRPS) V001 (FLDAS_NOAH01_C_GL_MC) at GES DISC': 353,
#  'Multisensor Advanced Climatology Total Liquid Water Path L3 Monthly 1 degree x 1 degree V1 (MACTWP_mean) at GES DISC': 354,
#  'SORCE XPS Level 4 Solar Spectral Irradiance 0.1nm Res 24-Hour Means V012 (SOR4XPSD_HIGH) at GES DISC': 355,
#  'TSIS TIM Level 3 Total Solar Irradiance 6-Hour Means V03 (TSIS_TSI_L3_06HR) at GES DISC': 356,
#  'OCO-3 Level 2 spatially ordered geolocated retrievals screened using the IMAP-DOAS Preprocessor (IDP) VEarly (OCO3_L2_IMAPDOAS) at GES DISC': 357,
#  'High Resolution Altitude Corrected Precipitation based on TMPA and other sources L4 Monthly 1 km x 1 km V1 (HRAC_Precip) at GES DISC': 358,
#  'MLS/Aura Near-Real-Time L2 Water Vapor (H2O) Mixing Ratio V005 (ML2H2O_NRT) at GES DISC': 359,
#  'S-NPP CrIS IMG_COL: Array indices for collocated VIIRS observations V2 (SNDRSNCrISL1BIMGC) at GES DISC': 360,
#  'AMSR-E/Aqua level 3 global monthly Surface Soil Moisture Averages V005 (AMSRE_AVRMO) at GES DISC': 361,
#  'MERRA-2 tavg3_3d_tdt_Np: 3d,3-Hourly,Time-Averaged,Pressure-Level,Assimilation,Temperature Tendencies 0.625 x 0.5 degree V5.12.4 (M2T3NPTDT) at GES DISC': 362,
#  'MERRA-2 tavgU_3d_mst_Np: 3d,diurnal,Time-Averaged,Pressure-Level,Assimilation,Moist Processes Diagnostics 0.625 x 0.5 degree V5.12.4 (M2TUNPMST) at GES DISC': 363,
#  'GPM SSMIS on F19 (GPROF) Radiometer Precipitation Profiling L3 1 month 0.25 degree x 0.25 degree V05 (GPM_3GPROFF19SSMIS) at GES DISC': 364,
#  'tavgM_2d_rad_Nx: MERRA 2D IAU Diagnostic, Radiation Surface and TOA, Monthly Mean  0.667 x 0.5 degree V5.2.0 (MATMNXRAD) at GES DISC': 365,
#  'Aqua/AIRS L2 Standard Physical Retrieval (AIRS+AMSU+HSB) V7.0 at GES DISC': 366,
#  'MERRA-2 tavgC_2d_ltm_Nx: 2d, Single-Level, Long Term Mean Diagnostics V1 (M2TCNXLTM) at GES DISC': 367,
#  'GPM PR on TRMM Precipitation Statistics, at Surface and Fixed Heights 1 day 0.25x0.25 degree V06 (GPM_3PRD) at GES DISC': 368,
#  'AIRS/Aqua L3 Monthly CO2 in the free troposphere (AIRS+AMSU) 2.5 degrees x 2 degrees V005 (AIRX3C2M) at GES DISC': 369,
#  'TOMS Nimbus-7 UV Aerosol Index Daily L3 Global 1 deg x 1.25 deg Lat/Lon Grid V008 (TOMSN7L3daer) at GES DISC': 370,
#  'GPCP Precipitation Level 3 Monthly 0.5-Degree V3.2 (GPCPMON) at GES DISC': 371,
#  'MLS/Aura Level 3 Daily Binned Geopotential Height (GPH) on Zonal and Similar Grids V004 (ML3DZGPH) at GES DISC': 372,
#  'MLS/Aura Level 3 Daily Binned Ozone (O3) Mixing Ratio on Zonal and Similar Grids V005 (ML3DZO3) at GES DISC': 373,
#  'Gridded Monthly Time-Mean Observation minus Analysis (oma) Values 0.5 x 0.667 degree V001 (MA_MSU_NOAA11_OMA) at GES DISC': 374,
#  'TMI/TRMM surface soil moisture (LPRM) L2 V001 (LPRM_TMI_SOILM2) at GES DISC': 375,
#  'Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_HIRS2_NOAA09_OBS) at GES DISC': 376,
#  'Sentinel-5P TROPOMI Tropospheric Formaldehyde HCHO 1-Orbit L2 5.5km x 3.5km V2 (S5P_L2__HCHO___HiR) at GES DISC': 377,
#  'GEOS-Carb CASA-GFED Monthly Fire Fuel NPP Rh NEE Fluxes 0.5 degree x 0.5 degree V2 (GEOS_CASAGFED_M_FLUX) at GES DISC': 378,
#  'TSIS SIM Level 3 Solar Spectral Irradiance 12-Hour Means V05 (TSIS_SSI_L3_12HR) at GES DISC': 379,
#  'AIRS/Aqua L3 daily CO2 in the free troposphere (AIRS-only) 1 degree x 1 degree V006 (AIRS3C2D) at GES DISC': 380,
#  'UARS High Resolution Doppler Imager (HRDI) Level 3AL V011 (UARHR3AL) at GES DISC': 381,
#  'HIRDLS/Aura Level 2 Daily Geophysical Parameters V007 (HIRDLS2) at GES DISC': 382,
#  'Gridded Monthly Time-Mean Observation minus Forecast (omf) Values 0.5 x 0.667 degree V001 (MA_HIRS3_NOAA15_OMF) at GES DISC': 383,
#  'Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_SSMI_DMSP15_OBS) at GES DISC': 384,
#  'Sentinel-5P TROPOMI Radiance product band 2 (UV detector) L1B 5.5km x 3.5km V1 (S5P_L1B_RA_BD2_HiR) at GES DISC': 385,
#  'GPM AMSR-2 on GCOM-W1 (GPROF) Climate-based Radiometer Precipitation Profiling L3 1 month 0.25 degree x 0.25 degree V05 (GPM_3GPROFGCOMW1AMSR2_CLIM) at GES DISC': 386,
#  'GPM MHS on METOP-C (GPROF) Climate-based Radiometer Precipitation Profiling L2A 1.5 hours 17 km V05 (GPM_2AGPROFMETOPCMHS_CLIM) at GES DISC': 387,
#  'Gridded Monthly Time-Mean Observation minus Forecast (omf) Values 0.5 x 0.667 degree V001 (MA_SSU_TIROSN_OMF) at GES DISC': 388,
#  'TROPESS CrIS-SNPP L2 Methane for Australian Fires, Standard Product V1 (TRPSDL2CH4CRSAUS) at GES DISC': 389,
#  'MLS/Aura Level 3 Monthly Binned Carbon Monoxide (CO) Mixing Ratio on Assorted Grids V004 (ML3MBCO) at GES DISC': 390,
#  'OCO-2 Level 2 CO2 prior based on CO2 monthly flask record, global meteorology, and age of air V10 (OCO2_L2_CO2Prior) at GES DISC': 391,
#  'GPM GMI unpacked data L1A 1.5 hours 13 km V05 (GPM_1AGMI) at GES DISC': 392,
#  'MLS/Aura Level 3 Daily Binned Water Vapor (H2O) Mixing Ratio on Zonal and Similar Grids V004 (ML3DZH2O) at GES DISC': 393,
#  'TOMS Nimbus-7 UV-B Erythemal Local Noon Irradiance Daily L3 Global 1 deg x 1.25 deg Lat/Lon Grid V008 (TOMSN7L3dery) at GES DISC': 394,
#  'GPM SAPHIR on MT1 (PRPS) Climate-based Radiometer Precipitation Profiling L2 1.5 hours 10 km V06 (GPM_2APRPSMT1SAPHIR_CLIM) at GES DISC': 395,
#  'Multi-Satellite Lambertian Equivalent Reflectivity (Local Satellite Time) 10-Day L3 Global 2.0x5.0deg Lat/Lon Grid V1 (MSLERLSTL3d10) at GES DISC': 396,
#  'AMSR-E L2 Rainfall Subset, collocated with CloudSat track V002 (AMSERR_CPR) at GES DISC': 397,
#  'GPM ATMS on SUOMI-NPP (GPROF) Radiometer Precipitation Profiling L3 1 day 0.25 degree x 0.25 degree V05 (GPM_3GPROFNPPATMS_DAY_CLIM) at GES DISC': 398,
#  'Gridded Monthly Time-Mean Observation minus Forecast (omf) Values 0.5 x 0.667 degree V001 (MA_HIRS2_NOAA07_OMF) at GES DISC': 399,
#  'GPM AMSUB on NOAA17 (GPROF) Climate-based Radiometer Precipitation Profiling L3 1 month 0.25 degree x 0.25 degree  V05 (GPM_3GPROFNOAA17AMSUB_CLIM) at GES DISC': 400,
# ...
#  'GPM MHS on NOAA19 (GPROF) Radiometer Precipitation Profiling L3 1 day 0.25 degree x 0.25 degree  V05 (GPM_3GPROFNOAA19MHS_DAY) at GES DISC': 863,
#  'MLS/Aura Level 3 Monthly Binned Geopotential Height (GPH) on Assorted Grids V004 (ML3MBGPH) at GES DISC': 864,
#  'Sounder SIPS: Suomi NPP CrIMSS Level 3 Specific Quality Control Gridded Daily CHART Normal Spectral Resolution V1': 865,
#  'Goddard Satellite-Based Surface Turbulent Fluxes Climatology, 0.25 x 0.25 deg, Yearly Grid V3 (GSSTFYC) at GES DISC': 866,
#  'GPM MHS on METOP-C (GPROF) Climate-based Radiometer Precipitation Profiling L3 1 month 0.25 degree x 0.25 degree V05 (GPM_3GPROFMETOPCMHS_CLIM) at GES DISC': 867,
#  'MODIS/Aqua Geolocation Fields 1km 5-Min 1A Swath Subset along MLS V002 (MAM03S0) at GES DISC': 868,
#  'SeaWiFS Deep Blue Aerosol Optical Depth and Angstrom Exponent Level 2 Data V004 (SWDB_L2) at GES DISC V004': 869,
#  'MLS/Aura Near-Real-Time L2 Temperature V005 (ML2T_NRT) at GES DISC': 870,
#  'Gridded Monthly Time-Mean Observation minus Forecast (omf) Values 0.5 x 0.667 degree V001 (MA_MSU_NOAA10_OMF) at GES DISC': 871,
#  'Aqua/AIRS L3 Monthly Support Monthly Product (AIRS+AMSU+HSB) 1 degree x 1 degree V7.0 at GES DISC': 872,
#  'OMI/Aura Near UV Aerosol Index, Optical Depth and Single Scattering Albedo 1-Orbit L2 13x24km': 873,
#  'GPM DPR Precipitation Profile 1 Day Descending 0.25 degree x 0.25 degree V07 (GPM_3DPR_DES) at GES DISC': 874,
#  'GPM ATMS on NOAA-20 (GPROF) Climate-based Radiometer Precipitation Profiling L2A 1.5 hours 17 km V05 (GPM_2AGPROFNOAA20ATMS_CLIM) at GES DISC': 875,
#  'TOMS Meteor-3 Ground Station Overpass Data V008 (TOMSM3OVP) at GES DISC': 876,
#  'GPM DPR Ka-band Received Power L1B 1.5 hours 5 km V05 (GPM_PRL1KA) at GES DISC': 877,
#  'GPM SSMIS on F16 (GPROF) Climate-based Radiometer Precipitation Profiling L3 1 day 0.25 degree x 0.25 degree V05 (GPM_3GPROFF16SSMIS_DAY_CLIM) at GES DISC': 878,
#  'GOZCARDS Source Nitrous Oxide 1 month L3 10 degree Zonal Means on a Vertical Pressure Grid V1 (GozSmlpN2O) at GES DISC': 879,
#  'Gridded Monthly Time-Mean Observation minus Analysis (oma) Values 0.5 x 0.667 degree V001 (MA_HIRS2_NOAA06_OMA) at GES DISC': 880,
#  'GLDAS Noah Land Surface Model L4 3 hourly 1.0 x 1.0 degree V2.0 (GLDAS_NOAH10_3H) at GES DISC': 881,
#  'MLS/Aura Level 3 Daily Binned Chlorine Monoxide (ClO) Mixing Ratio on Zonal and Similar Grids V004 (ML3DZCLO) at GES DISC': 882,
#  'Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_HIRS3_AM_OBS) at GES DISC': 883,
#  'GPM DPR Spectral Latent Heating Profiles L2 1.5 hours 5 km V07 (GPM_2HSLH) at GES DISC': 884,
#  'TOVS GLA MONTHLY GRIDS from NOAA-8 02 (TOVSAMNE) at GES DISC': 885,
#  'MLS/Aura Level 2 Geopotential Height V004 (ML2GPH) at GES DISC': 886,
#  'Sounder SIPS: Suomi NPP CrIMSS Level 3 Comprehensive Quality Control Gridded Monthly CLIMCAPS Normal Spectral Resolution V2 at GES DISC': 887,
#  'OMI/Aura Level 2 Sulphur Dioxide (SO2) Trace Gas Column Data 1-Orbit Subset and Collocated Swath along CloudSat V003 (OMSO2_CPR) at GES DISC': 888,
#  'SCR/Nimbus-5 Level 1 Radiance Data from CD-ROM V001 (SCRN5L1RAD_CDROM) at GES DISC': 889,
#  'Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_SSU_TIROSN_OBS) at GES DISC': 890,
#  'TCTE Level 3 Total Solar Irradiance 6-Hour Means V002 (TCTE3TSI6) at GES DISC': 891,
#  'GPM MHS on NOAA-18 (GPROF) Radiometer Precipitation Profiling L2A 1.5 hours 17 km V05 (GPM_2AGPROFNOAA18MHS) at GES DISC': 892,
#  'Gridded Monthly Time-Mean Observation minus Analysis (oma) Values 0.5 x 0.667 degree V001 (MA_AMSUA_AQUA_OMA) at GES DISC': 893,
#  'inst3_3d_chm_Ne: MERRA Chem 3D IAU Edge Pressure, Instantaneous 3-Hourly  0.667 x 0.5 degree V5.2.0 (MAI3NECHM) at GES DISC': 894,
#  'AMSR-E/Aqua root zone soil moisture (LPRM) L3 1 day 25 km x 25 km descending and 2-Layer Palmer Water Balance Model V001 (LPRM_AMSRE_D_RZSM3) at GES DISC': 895,
#  'TOMS Nimbus-7 UV Aerosol Index Daily and Monthly Zonal Means V008 (TOMSN7L3zaer) at GES DISC': 896,
#  'GPM GMI (GPROF) Radiometer Precipitation Profiling L3 1 month 0.25 degree x 0.25 degree V05 (GPM_3GPROFGPMGMI) at GES DISC': 897,
#  'FLDAS Noah Land Surface Model L4 Global Monthly Anomaly 0.1 x 0.1 degree (MERRA-2 and CHIRPS) V001 (FLDAS_NOAH01_C_GL_MA) at GES DISC': 898,
#  'GPM SSMIS on F16 (GPROF) Climate-based Radiometer Precipitation Profiling L3 1 month 0.25 degree x 0.25 degree V05 (GPM_3GPROFF16SSMIS_CLIM) at GES DISC': 899,
#  'Sentinel-5P TROPOMI Total Ozone Column 1-Orbit L2 7km x 3.5km V1 (S5P_L2__O3_TOT) at GES DISC': 900,
#  'Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_HIRS2_NOAA07_OBS) at GES DISC': 901,
#  'MERRA-2 tavgM_2d_aer_Nx: 2d,Monthly mean,Time-averaged,Single-Level,Assimilation,Aerosol Diagnostics 0.625 x 0.5 degree V5.12.4 (M2TMNXAER) at GES DISC': 902,
#  'Gridded 6 hours Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_CONV_OMA) at GES DISC': 903,
#  'THIR/Nimbus-6 Level 1 Meteorological Radiation Data at 11.5 microns V001 (THIRN6L1CH115) at GES DISC': 904,
#  'MLS/Aura Level 2 Water Vapor (H2O) Mixing Ratio V004 (ML2H2O) at GES DISC': 905,
#  'Sentinel-5P TROPOMI Tropospheric Formaldehyde HCHO 1-Orbit L2 7km x 3.5km V1 (S5P_L2__HCHO__) at GES DISC': 906,
#  'TIROS-4 Low-Resolution Omnidirectional Radiometer Level 1 Temperature Data V001 (TIROS4L1ORT) at GES DISC': 907,
#  'Gridded Monthly Time-Mean Observation minus Forecast (omf) Values 0.5 x 0.667 degree V001 (MA_HIRS2_NOAA09_OMF) at GES DISC': 908,
#  'AIRS/Aqua L3 Monthly Support Product (AIRS+AMSU+HSB) 1 degree x 1 degree V006 (AIRH3SPM) at GES DISC': 909,
#  'MLS/Aura Level 3 Monthly Binned Temperature on Assorted Grids V005 (ML3MBT) at GES DISC': 910,
#  'Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_HIRS3_NOAA15_OBS) at GES DISC': 911,
#  'Gridded Monthly Time-Mean Observation minus Forecast (omf) Values 0.5 x 0.667 degree V001 (MA_SSMI_DMSP15_OMF) at GES DISC': 912,
#  'GPM AMSUB on NOAA15 (GPROF) Climate-based Radiometer Precipitation Profiling L3 1 day 0.25 degree x 0.25 degree  V05 (GPM_3GPROFNOAA15AMSUB_DAY_CLIM) at GES DISC': 913,
#  'TROPESS CrIS-JPSS1 L2 Deuterated Water Vapor for Forward Stream, Standard Product V1 (TRPSDL2HDOCRS1FS) at GES DISC': 914,
#  'GPM MHS on METOP-C (GPROF) Radiometer Precipitation Profiling L2A 1.5 hours 17 km V05 (GPM_2AGPROFMETOPCMHS) at GES DISC': 915,
#  'TOMS Earth Probe UV Reflectivity Monthly L3 Global 1 deg x 1.25 deg Lat/Lon Grid V008 (TOMSEPL3mref) at GES DISC': 916,
#  'GPM IMERG Early Precipitation L3 1 day 0.1 degree x 0.1 degree V06 (GPM_3IMERGDE) at GES DISC': 917,
#  'AIRS/Aqua L2 CO2 support retrieval (AIRS+AMSU) V005 (AIRX2SPC) at GES DISC': 918,
#  'OMI/Aura Level 1B UV Zoom-in Geolocated Earthshine Radiances 1-orbit L2 Swath 13x12 km V003 (OML1BRUZ) at GES DISC': 919,
#  'GPM DPR and GMI (Combined Precipitation) L3 1 month 0.25 degree x 0.25 degree V06 (GPM_3CMB) at GES DISC': 920,
#  'GPM SSMIS on F19 (GPROF) Climate-based Radiometer Precipitation Profiling L3 1 day 0.25 degree x 0.25 degree V05 (GPM_3GPROFF19SSMIS_DAY_CLIM) at GES DISC': 921,
#  'MODIS_CR_Equal_Angle_3h': 922,
#  'Carbon Monitoring System Carbon Flux for Fire L4 V1 (CMSFluxFire) at GES DISC': 923,
#  'Carbon Monitoring System Flux for Posterior Total Carbon L4 V1 (CMSFluxTotalpost) at GES DISC': 924,
#  'GPM DPR Ku-band Received Power L1B 1.5 hours 5 km V07 (GPM_PRL1KU) at GES DISC': 925,
#  'GPS Radio Occultation Boundary Layer Depth Annual L3 V1 (GPSROZPBLA) at GES DISC': 926,
#  'GPM DPR and GMI Combined Precipitation L2B 1.5 hours 5 km V06 (GPM_2BCMB) at GES DISC': 927,
#  'TROPESS CrIS-SNPP L2 Carbon Monoxide for Buchholz2021 TS2, Standard Product V1 (TRPSDL2COCRSTS2) at GES DISC': 928,
#  'AIRS/Aqua L3 Daily Standard Physical Retrieval (AIRS+AMSU+HSB) 1 degree x 1 degree V006 (AIRH3STD) at GES DISC': 929,
#  'NCA-LDAS Noah-3.3 Land Surface Model L4 Daily 0.125 x 0.125 degree V2.0 (NCALDAS_NOAH0125_D) at GES DISC': 930,
#  'TOMS/EP Near UV Aerosol Index and LER 1-Orbit L2 40x40km at GES DISC': 931,
#  'MLS/Aura Level 3 Daily Binned Chlorine Monoxide (ClO) Mixing Ratio on Assorted Grids V004 (ML3DBCLO) at GES DISC': 932,
#  'CAR ARCTAS BRDF Measurements  V2 (CAR_ARCTAS_BRDF) at GES DISC': 933,
#  'GPM GMI Common Calibrated Brightness Temperatures Collocated L1C 1.5 hours 13 km V05 (GPM_1CGPMGMI) at GES DISC': 934,
#  'GPM SSMIS on F17 (GPROF) Radiometer Precipitation Profiling L3 1 month 0.25 degree x 0.25 degree V05 (GPM_3GPROFF17SSMIS) at GES DISC': 935,
#  'TROPESS CrIS-SNPP L2 Carbon Monoxide for West Coast Fires, Standard Product V1 (TRPSDL2COCRSWCF) at GES DISC': 936,
#  'GPM ATMS on SUOMI-NPP (GPROF) Radiometer Precipitation Profiling L2 1.5 hours 16 km V05 (GPM_2AGPROFNPPATMS_CLIM) at GES DISC': 937,
#  'ESMR/Nimbus-5 Images of Brightness Temperature on 70 mm Film V001 (ESMRN5IM) at GES DISC': 938,
#  'Sentinel-6A Level 1B GNSS Radio Occultation Precise Orbit Determination  V1 (S6A_RO_1B_POD_RNX_) at GES DISC': 939,
#  'TRMM Radar Rainfall Statistics L3 1 month (5 x 5) and (0.5  x 0.5) degree V7 (TRMM_3A25) at GES DISC': 940,
#  'MLS/Aura Level 3 Daily Binned Cloud Ice (IWC) on Zonal and Similar Grids V005 (ML3DZIWC) at GES DISC': 941,
#  'TROPESS AIRS-Aqua L2 Carbon Monoxide for Forward Stream, Standard Product V1 (TRPSDL2COAIRSFS) at GES DISC': 942,
#  'tavgM_3d_mst_Cp: MERRA 3D IAU Diagnostic, Moist Physics, Monthly Mean  1.25 x 1.25 degree V5.2.0 (MATMCPMST) at GES DISC': 943,
#  'MLS/Aura Level 3 Daily Binned Nitric Acid (HNO3) Mixing Ratio on Assorted Grids V005 (ML3DBHNO3) at GES DISC': 944,
#  'MLS/Aura Near-Real-Time L2 Nitric Acid (HNO3) Mixing Ratio V005 (ML2HNO3_NRT) at GES DISC': 945,
#  'MERRA-2 tavg3_3d_trb_Np: 3d,3-Hourly,Time-Averaged,Pressure-Level,Assimilation,Turbulence Diagnostics 0.625 x 0.5 degree V5.12.4 (M2T3NPTRB) at GES DISC': 946,
#  'Global methane fluxes optimized with GOSAT data for 2010-2018 V1 (CMSGCH4F)': 947,
#  'WindSat/Coriolis surface soil moisture (LPRM) L3 1 day 25 km x 25 km daytime V001 (LPRM_WINDSAT_DY_SOILM3) at GES DISC': 948,
#  'TRMM (TMPA) Precipitation L3 1 day 0.25 degree x 0.25 degree V7 (TRMM_3B42_Daily) at GES DISC': 949,
#  'Multi-Satellite Lambertian Equivalent Reflectivity (Noon Normalized) 1 day L3 Global 5.0deg Lat Zones V1 (MSLERNNL3zm) at GES DISC': 950,
#  'tavgU_2d_lnd_Nx: MERRA 2D IAU Diagnostic, Land Only States and Diagnostics, Diurnal  0.667 x 0.5 degree V5.2.0 (MATUNXLND) at GES DISC': 951,
#  'MERRA-2 inst3_2d_gas_Nx: 2d,3-Hourly,Instantaneous,Single-Level,Assimilation,Aerosol Optical Depth Analysis 0.625 x 0.5 degree V5.12.4 (M2I3NXGAS) at GES DISC': 952,
#  'Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_HIRS2_NOAA12_OBS) at GES DISC': 953,
#  'AIRS/Aqua L2 Near Real Time (NRT) Cloud-Cleared Infrared Radiances (AIRS-only) V006 (AIRS2CCF_NRT) at GES DISC': 954,
#  'TRMM Microwave Imager Calibrated Radiances L1B 1.5 hours V7 (TRMM_1B11) at GES DISC': 955,
#  'tavg3_3d_udt_Cp: MERRA 3D IAU Tendency, Wind Components, Time average 3-hourly  1.25 x 1.25 degree V5.2.0 (MAT3CPUDT) at GES DISC': 956,
#  'CAR SnowEx17 BRDF Measurements L1 V2 (CAR_SNOWEX17_BRDF) at GES DISC': 957,
#  'Gridded Monthly Time-Mean Observation minus Analysis (oma) Values 0.5 x 0.667 degree V001 (MA_MHS_NOAA18_OMA) at GES DISC': 958,
#  'JPSS-1 CrIS IMG: Collocated VIIRS level 1 / cloud mask statistical summary V2 (SNDRJ1CrISL1BIMG) at GES DISC': 959,
#  'OMI/Aura Sulphur Dioxide (SO2) Total Column Daily L2 Global Gridded 0.125 degree x 0.125 degree V3 (OMSO2G) at GES DISC': 960,
#  'TOVS GLA 5 DAY GRIDS from NOAA-9 V01 (TOVSA5NF) at GES DISC': 961,
#  'MERRA-2 tavgM_2d_lnd_Nx: 2d,Monthly mean,Time-Averaged,Single-Level,Assimilation,Land Surface Diagnostics 0.625 x 0.5 degree V5.12.4 (M2TMNXLND) at GES DISC': 962,
#  'AIRS/Aqua L3 8-day Support Multiday Product (AIRS+AMSU+HSB) 1 degree x 1 degree V006 (AIRH3SP8) at GES DISC': 963,
#  'CAR SCAR-B Smoke, Clouds, and Radiation-Brazil L1 V1 (CAR_SCARB_L1C) at GES DISC': 964,
#  'CAR ECO3D BRDF Measurements V2 (CAR_ECO3D_BRDF) at GES DISC': 965,
#  'GPM PR on TRMM Spectral Latent Heating Profiles L2 1.5 hours 5 km V06 (GPM_2HSLH_TRMM) at GES DISC': 966,
#  'SCR/Nimbus-4 Level 1 Radiance Data from CD-ROM V001 (SCRN4L1RAD_CDROM) at GES DISC': 967,
#  'TROPESS CrIS-SNPP L2 Carbon Monoxide for West Coast Fires HiRes, Standard Product V1 (TRPSDL2COCRSWCFHI) at GES DISC': 968,
#  'MLS/Aura Level 2 Hypochlorous Acid (HOCl) Mixing Ratio V004 (ML2HOCL) at GES DISC': 969,
#  'GPM AMSU-B on NOAA15 (GPROF) Climate-based Radiometer Precipitation Profiling L2 1.5 hours 16 km V05 (GPM_2AGPROFNOAA15AMSUB) at GES DISC': 970,
#  'SBUV2/NOAA-9 Ozone (O3) Nadir Profile and Total Column 1 Day L2 V1 (SBUV2N09L2) at GES DISC': 971,
#  'NCEP/DOE Reanalysis II, for GSSTF, 0.25 x 0.25 deg, Daily Grid V3 (GSSTF_NCEP) at GES DISC': 972,
#  'Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_AMSUA_NOAA18_OBS) at GES DISC': 973,
#  'tavgU_2d_mld_Nx: MERRA Simulated 2D Incremental Analysis Update (IAU) MERRA-Land reanalysis, GEOSldas-MERRALand, Time Average Diurnal  0.667 x 0.5 degree V5.2.0 (MSTUNXMLD) at GES DISC': 974,
#  'GOZCARDS Source Hydrogen Chloride 1 month L3 10 degree Zonal Means on a Vertical Pressure Grid V1 (GozSmlpHCl) at GES DISC': 975,
#  'Ocean Biogeochemistry in the California Current System 2007-2010 L4 Monthly': 976,
#  'Gridded Monthly Time-Mean Observation minus Forecast (omf) Values 0.5 x 0.667 degree V001 (MA_AMSUA_NOAA16_OMF) at GES DISC': 977,
#  'MERRA-2 inst3_3d_asm_Np: 3d,3-Hourly,Instantaneous,Pressure-Level,Assimilation,Assimilated Meteorological Fields 0.625 x 0.5 degree V5.12.4 (M2I3NPASM) at GES DISC': 978,
#  'NLDAS Secondary Forcing Data L4 Monthly Climatology 0.125 x 0.125 degree V2.0 (NLDAS_FORB0125_MC) at GES DISC': 979,
#  'AIRS/Aqua L2 Support Retrieval (AIRS-only) V006 (AIRS2SUP) at GES DISC': 980,
#  'OMI/Aura TOMS-Like Ozone and Radiative Cloud Fraction L3 1 day 0.25 degree x 0.25 degree V3 (OMTO3e) at GES DISC': 981,
#  'GPM ATMS on SUOMI-NPP (GPROF) Radiometer Precipitation Profiling L3 1 day 0.25 degree x 0.25 degree V05 (GPM_3GPROFNPPATMS_DAY) at GES DISC': 982,
#  'TRMM Ground Validation Radar Site Rain Type Totals Map L3 1 month 2 km V7 (TRMM_3A54) at GES DISC': 983,
#  'OMI/Aura TOMS-Like Ozone, Aerosol Index, Cloud Radiance Fraction L3 1 day 1 degree x 1 degree V3 (OMTO3d) at GES DISC': 984,
#  'Gridded Monthly Time-Mean Observation minus Forecast (omf) Values 0.5 x 0.667 degree V001 (MA_AIRS_AQUA_OMF) at GES DISC': 985,
#  'MLS/Aura L1 Radiances from Filter Banks for THz V005 (ML1RADT) at GES DISC': 986,
#  'inst3_3d_asm_Cp: MERRA 3D IAU State, Meteorology Instantaneous 3-hourly  1.25 x 1.25 degree V5.2.0 (MAI3CPASM) at GES DISC': 987,
#  'Sentinel-5P TROPOMI Radiance product band 6 (NIR detector) L1B V2 (S5P_L1B_RA_BD6) at GES DISC': 988,
#  'OMI/Aura Surface UV Irradiance 1-orbit L2 Swath 13x24 km V003 (OMUVB) at GES DISC': 989,
#  'TRMM Ground Validation Rain Existence L2 1 month V7 (TRMM_2A52) at GES DISC': 990,
#  'GPM IMERG Late Precipitation L3 1 day 0.1 degree x 0.1 degree V06 (GPM_3IMERGDL) at GES DISC': 991,
#  'TMI/TRMM surface soil moisture (LPRM) L3 1 day 25 km x 25 km nighttime V001 (LPRM_TMI_NT_SOILM3) at GES DISC': 992,
#  'SORCE SOLSTICE FUV Level 3 Solar Spectral Irradiance Daily Means V016 (SOR3SOLFUVD) at GES DISC': 993,
#  'BUV/Nimbus-4 Ozone (O3) Nadir Profile and Total Column 1 Day L2 V1 (BUVN04L2) at GES DISC': 994,
#  'NLDAS Primary Forcing Data L4 Hourly 0.125 x 0.125 degree V002 (NLDAS_FORA0125_H) at GES DISC': 995,
#  'OMI/Aura Formaldehyde (HCHO) Total Column Daily L2 Global Gridded 0.25 degree x 0.25 degree V3 (OMHCHOG) at GES DISC': 996,
#  'Sounder SIPS: Suomi NPP CrIMSS Level 2 CHART Normal Spectral Resolution: Cloud Cleared Radiances V1': 997,
#  'TOMS/N7 Near UV Aerosol Index and LER 1-Orbit L2 50x50 km': 998,
#  'Gridded Monthly Time-Mean Observation minus Forecast (omf) Values 0.5 x 0.667 degree V001 (MA_MSU_NOAA07_OMF) at GES DISC': 999,
#  ...}

# %% [markdown]
# ## Embedding Datasets

# %% [markdown]
# ### Edge Index

# %%
science_keywords = df['ScienceKeywords'].tolist()

# %%
len(science_keywords)
# Out:
# 1738

# %%
"""
Create the hierarchy of keywords for each dataset.
Take each keyword and backtrack all the way to the root, Earth Science.
Now, for each keyword, we can get the list of all superfield keywords so we know the structure of keywords for making the graph.
"""
keyword_dict = {}
for dataset in science_keywords:
    for keyword in dataset:
        title = lambda x: x.title()
        hierarchy, deepest_class = list(map(title, list(keyword.values())))[:-1], list(keyword.keys())[-1]
        hierarchy.reverse()
        deepest_keyword = keyword[deepest_class].title()
        if deepest_keyword not in keyword_dict.keys():
            keyword_dict[deepest_keyword] = hierarchy

# %%
all_keywords = list(set(list(keyword_dict.keys()) + [item for sublist in list(keyword_dict.values()) for item in sublist]))

# %%
kywrd2kywid = dict(zip(all_keywords, range(len(index2title), len(index2title) + len(all_keywords))))
kywid2kywrd = {index: keyword for keyword, index in kywrd2kywid.items()}

# %%
kywrd2kywid
# Out:
# {'Solar Activity': 1738,
#  'Precipitation Amount': 1739,
#  'Cloud Radiative Forcing': 1740,
#  'Energy Deposition': 1741,
#  'Methyl Cyanide': 1742,
#  'Biosphere': 1743,
#  'Trace Gases/Trace Species': 1744,
#  'Temperature Indicators': 1745,
#  'Ionosphere/Magnetosphere Dynamics': 1746,
#  'Canopy Characteristics': 1747,
#  'Cloud Fraction': 1748,
#  'Eruption Dynamics': 1749,
#  'Air Quality': 1750,
#  'Vegetation': 1751,
#  'Antenna Temperature': 1752,
#  'Aerosol Optical Depth': 1753,
#  'Infrared Flux': 1754,
#  'Glaciers': 1755,
#  'Average Flow': 1756,
#  'Halocarbons And Halogens': 1757,
#  'Ozone (O3) Profile': 1758,
#  'Phosphate': 1759,
#  'Earth Radiation Budget': 1760,
#  'Soil Moisture': 1761,
#  'Radar': 1762,
#  'Cloud Precipitable Water': 1763,
#  'Reflected Flux': 1764,
#  '12.1 Micron Extinction': 1765,
#  'Flight Data Logs': 1766,
#  'Sensible Heat Flux': 1767,
#  'Air Temperature Profile': 1768,
#  'Common Sense Climate Index': 1769,
#  'Atmospheric Chemistry': 1770,
#  'Snow Water Equivalent': 1771,
#  'Atmospheric Temperature': 1772,
#  'Snow/Ice Temperature': 1773,
#  'Nitrate': 1774,
#  'Sea Level Pressure': 1775,
#  'Ocean Color': 1776,
#  'Soil Porosity': 1777,
#  'Optical Depth/Thickness': 1778,
#  'Runoff Rate': 1779,
#  'Land Use/Land Cover Classification': 1780,
#  'Plant Characteristics': 1781,
#  'Chlorine Dioxide': 1782,
#  'Radiance @ 12.0Um': 1783,
#  'Water Vapor Concentration Profiles': 1784,
#  '24 Hour Minimum Temperature': 1785,
#  'Alkalinity': 1786,
#  'Layered Precipitable Water': 1787,
#  'Radiance @ 1.6Um': 1788,
#  'Airglow': 1789,
#  'Sigma Naught': 1790,
#  'Hydrogen Cyanide': 1791,
#  'Volcanic Eruptions': 1792,
#  'Runoff': 1793,
#  'Vertical Profiles': 1794,
#  'Fire Occurrence': 1795,
#  'Climate Indicators': 1796,
#  'Sulfur Hexafluoride': 1797,
#  'Visible Radiance': 1798,
#  'Atmospheric Ozone': 1799,
#  'Visible Imagery': 1800,
#  'Total Runoff': 1801,
#  'Water Vapor': 1802,
#  'Surface Winds': 1803,
#  'Surface Temperature': 1804,
#  'Hydroxyl': 1805,
#  'Hypochlorous Acid': 1806,
#  'Volcanic Activity': 1807,
#  'Conduction': 1808,
#  'Isoprene': 1809,
#  'Carbon Monoxide': 1810,
#  'Wetlands': 1811,
#  'Vertical Wind Velocity/Speed': 1812,
#  'Uv Reflectivity': 1813,
#  'Water Vapor Indicators': 1814,
#  'Ultraviolet Radiation': 1815,
#  'Uv And Visible Solar Irradiances And Precisions': 1816,
#  'Longwave Radiation': 1817,
#  'Potential Evapotranspiration': 1818,
#  'Deep Convective Cloud Systems': 1819,
#  'Infrared Radiance': 1820,
#  'Water Vapor Profiles': 1821,
#  'Geolocation': 1822,
#  'Surface Water': 1823,
#  'Temperature Trends': 1824,
#  'Glaciers/Ice Sheets': 1825,
#  'Condensation': 1826,
#  'Leaf Characteristics': 1827,
#  'Infrared Wavelengths': 1828,
#  'Ocean Mixed Layer': 1829,
#  'Skin Temperature': 1830,
#  'Oxygen Compounds': 1831,
#  'Sea Surface Temperature': 1832,
#  'Chemical Composition': 1833,
#  'Agriculture': 1834,
#  'Extreme Drought': 1835,
#  'Ozone Profile And Total Column': 1836,
#  'Radiative Flux': 1837,
#  'Radiative Forcing': 1838,
#  'Solid Precipitation': 1839,
#  'Cloud Fraction Vertical Distribution': 1840,
#  'Cfc-11': 1841,
#  'Atmospheric Carbon Monoxide': 1842,
#  'Ground Water Processes/Measurements': 1843,
#  'Snow Melt': 1844,
#  'Nitrous Oxide': 1845,
#  'Carbon Tetrachloride': 1846,
#  'Ground Ice': 1847,
#  'Subsurface Flow': 1848,
#  'Smog': 1849,
#  'Wind Speed': 1850,
#  'Hcfc-22': 1851,
#  'Atmospheric Carbon Dioxide': 1852,
#  'Total And Tropospheric Nitrogen Dioxide (No2)': 1853,
#  'Drought Indices': 1854,
#  'Sensor Characteristics': 1855,
#  'Precipitation': 1856,
#  'Net Radiation': 1857,
#  'Fire Ecology': 1858,
#  'Land Surface Temperature': 1859,
#  'Cloud Top Height': 1860,
#  'Terrestrial Ecosystems': 1861,
#  'Radar Reflectivity': 1862,
#  'Particulate Matter Concentrations': 1863,
#  'Albedo': 1864,
#  'Snow Depth': 1865,
#  'Spectral/Engineering': 1866,
#  'Droplet Size': 1867,
#  'Sea Surface Height': 1868,
#  'Cloud Frequency': 1869,
#  'Liquid Water Equivalent': 1870,
#  'V Wind Component': 1871,
#  'Upper Level Winds': 1872,
#  'Ocean Pressure': 1873,
#  'Hydrogen Fluoride': 1874,
#  'Ultraviolet Radiance': 1875,
#  'Cloud Radiative Transfer': 1876,
#  'Ultraviolet Wavelengths': 1877,
#  'Geopotential Height': 1878,
#  'Wind Dynamics': 1879,
#  'Ecosystems': 1880,
#  'Sea Surface Skin Temperature': 1881,
#  'Dissolved Gases': 1882,
#  'Solar Energetic Particle Properties': 1883,
#  'Public Health': 1884,
#  'Floods': 1885,
#  'Global Precipitation': 1886,
#  'Microwave': 1887,
#  'Granule Coverage': 1888,
#  'Precipitation Rate': 1889,
#  'Total Column Ozone (O3)': 1890,
#  'Wind Direction Tendency': 1891,
#  'Angstrom Exponent': 1892,
#  'Carbon And Hydrocarbon Compounds': 1893,
#  'Oxygen': 1894,
#  'Aerosol Optical Depth/Thickness': 1895,
#  'Surface Thermal Properties': 1896,
#  'Solid Earth': 1897,
#  'Temperature Variability': 1898,
#  'Solar Induced Fluorescence': 1899,
#  'Chlorine Monoxide': 1900,
#  'Upper Air Temperature': 1901,
#  'Ice Fraction': 1902,
#  'Solar Irradiance': 1903,
#  'Nitrogen Compounds': 1904,
#  'Glacier Runoff': 1905,
#  'Cloud Droplet Concentration/Size': 1906,
#  'Hydrochlorofluorocarbons': 1907,
#  'Reflectance': 1908,
#  'Potential Temperature': 1909,
#  'Bromine Monoxide': 1910,
#  'Radiance @ 0.63Um': 1911,
#  'Photosynthetically Active Radiation': 1912,
#  'Methyl Chloride': 1913,
#  'Radiance @ 3.75Um': 1914,
#  'Outgoing Longwave Radiation': 1915,
#  'Cloud Types': 1916,
#  'Water Vapor Processes': 1917,
#  'Visible Flux': 1918,
#  'Sulfur Dioxide': 1919,
#  'Heat Flux': 1920,
#  'Cloud Liquid Water/Ice': 1921,
#  'Terrain Elevation': 1922,
#  'Land Surface': 1923,
#  'Sea Salt': 1924,
#  'Formaldehyde': 1925,
#  'Ocean Temperature': 1926,
#  'Ecosystem Functions': 1927,
#  'Aerosol Radiance': 1928,
#  'Sensor Counts': 1929,
#  'X-Ray Flux': 1930,
#  'Particulates': 1931,
#  'Soils': 1932,
#  'Precipitation Profiles': 1933,
#  'Vorticity': 1934,
#  'Column Amount Ozone': 1935,
#  'Surface Water Features': 1936,
#  'Vegetation Cover': 1937,
#  'Turbulence': 1938,
#  'Sun-Earth Interactions': 1939,
#  'Organic Particles': 1940,
#  'Atmospheric Nitric Acid': 1941,
#  'Extreme Precipitation': 1942,
#  'Aerosol Single-Scattering Albedo': 1943,
#  'Cloud Microphysics': 1944,
#  'Air Mass/Density': 1945,
#  'Zonal Winds': 1946,
#  'Cloud Emissivity': 1947,
#  'Ice Temperature': 1948,
#  'Total Surface Precipitation Rate': 1949,
#  'Cloud Reflectance': 1950,
#  'Total Column Ozone': 1951,
#  'Chlorophyll': 1952,
#  'Hydrogen-Deuterium Oxide': 1953,
#  'Atmospheric Winds': 1954,
#  'Water Vapor Flux': 1955,
#  'Rain': 1956,
#  'Nitrogen Oxides': 1957,
#  'Black Carbon': 1958,
#  '24 Hour Maximum Temperature': 1959,
#  'Oceanic Precipitation': 1960,
#  'Rivers/Streams': 1961,
#  'Sulfur Oxides': 1962,
#  'Reflectivity': 1963,
#  'Cloud Top Pressure': 1964,
#  'Virtual Temperature': 1965,
#  'Root Zone Soil Moisture': 1966,
#  'Ground Water': 1967,
#  'Total Solar Irradiance': 1968,
#  'Radar Backscatter': 1969,
#  'Emissions': 1970,
#  'Aerosol Particle Properties': 1971,
#  'Solar Energetic Particle Flux': 1972,
#  'Magnetic Fields/Magnetic Currents': 1973,
#  'Tropopause': 1974,
#  'Sea Ice': 1975,
#  'Landslides': 1976,
#  'Ozone': 1977,
#  'Cloud Vertical Distribution': 1978,
#  'Dimethyl Sulfide': 1979,
#  'Atmospheric Pressure': 1980,
#  'Erythemal Irradiance': 1981,
#  'Aod': 1982,
#  'Snow': 1983,
#  'Vegetation Index': 1984,
#  'Soil Temperature': 1985,
#  'Air Temperature': 1986,
#  'Boundary Layer Winds': 1987,
#  'Radiance @ 10.8Um': 1988,
#  'Carbon': 1989,
#  'Convection': 1990,
#  'Solar Radiation': 1991,
#  'Total Ozone': 1992,
#  'Incoming Solar Radiation': 1993,
#  'Scattering': 1994,
#  'Infrared Imagery': 1995,
#  'Cloud Properties': 1996,
#  'Radio Wave': 1997,
#  'Ocean Optics': 1998,
#  'Cloud Optical Depth/Thickness': 1999,
#  'Hydroperoxy': 2000,
#  'Vis Aerosol Index': 2001,
#  'Atmosphere': 2002,
#  'Soil Moisture/Water Content': 2003,
#  'Land Use/Land Cover': 2004,
#  'Snow/Ice': 2005,
#  'Visible Wavelengths': 2006,
#  'Liquid Precipitation': 2007,
#  'Reflective Band Radiance': 2008,
#  'Chlorofluorocarbons': 2009,
#  'Carbon Dioxide': 2010,
#  'Dew Point Temperature': 2011,
#  'Water Vapor Tendency': 2012,
#  'Solar Spectral Irradiance': 2013,
#  'Maximum/Minimum Temperature': 2014,
#  'Dinitrogen Pentoxide': 2015,
#  'Cloud Mass Flux': 2016,
#  'Chlorine Nitrate': 2017,
#  'Proton Flux': 2018,
#  'Paleoclimate Indicators': 2019,
#  'Precipitation Trends': 2020,
#  'Surface Radiative Properties': 2021,
#  'Total Precipitable Water': 2022,
#  'Altitude': 2023,
#  'Diffusion': 2024,
#  'Viewing Geometry': 2025,
#  'Lambert Equivalent Surface Reflectance': 2026,
#  'Protists': 2027,
#  'Nitric Oxide': 2028,
#  'Surface Soil Moisture': 2029,
#  'Relative Humidity': 2030,
#  'Ozone Profiles And Total Column': 2031,
#  'Biological Classification': 2032,
#  'Absorption': 2033,
#  'Brightness Temperature': 2034,
#  'Snow Cover': 2035,
#  'Sea Ice Concentration': 2036,
#  'Biogeochemical Cycles': 2037,
#  'Attitude Characteristics': 2038,
#  'Ammonia': 2039,
#  'Methanol': 2040,
#  'Hydrogen Chloride': 2041,
#  'Latent Heating': 2042,
#  'Vertical Velocity': 2043,
#  'Plankton': 2044,
#  'Cloud Dynamics': 2045,
#  'Colocation Information': 2046,
#  'Cloud Height': 2047,
#  'Satellite Soil Moisture Index': 2048,
#  'Formic Acid': 2049,
#  'Aerosol Absorption Optical Depth': 2050,
#  'Microwave Imagery': 2051,
#  'Emissivity': 2052,
#  'Atmospheric Heating': 2053,
#  'Meridional Winds': 2054,
#  'Temperature Tendency': 2055,
#  'Clouds': 2056,
#  'Conditional Rain Rate': 2057,
#  'Latent Heat Flux': 2058,
#  'Wind Stress': 2059,
#  'Precipitation Indicators': 2060,
#  'Particle Size Distribution': 2061,
#  'Surface Pressure': 2062,
#  'Boundary Layer Temperature': 2063,
#  'Land Use Classes': 2064,
#  'Human Dimensions': 2065,
#  'Tectonics': 2066,
#  'Pigments': 2067,
#  'Ocean Chemistry': 2068,
#  'Leaf Area Index (Lai)': 2069,
#  'Wind Speed Tendency': 2070,
#  'Nitrogen Dioxide': 2071,
#  'Primary Production': 2072,
#  'Shortwave Radiation': 2073,
#  'Cryosphere': 2074,
#  'Cfc-12': 2075,
#  'Atmospheric Pressure Measurements': 2076,
#  'Methane': 2077,
#  'Sulfur Compounds': 2078,
#  'Land Surface/Agriculture Indicators': 2079,
#  'Surface Roughness': 2080,
#  'Humidity': 2081,
#  'Aerosol Backscatter': 2082,
#  'Convective Surface Precipitation Rate': 2083,
#  'Temperature Anomalies': 2084,
#  'Atmospheric Radiation': 2085,
#  'Vegetation Water Content': 2086,
#  'Ocean Heat Budget': 2087,
#  'Thermal Infrared': 2088,
#  'Rain Probability': 2089,
#  'Soil Heat Budget': 2090,
#  'Electron Flux': 2091,
#  'Sulfate': 2092,
#  'U/V Wind Components': 2093,
#  'Surface Water Processes/Measurements': 2094,
#  'Sea Surface Topography': 2095,
#  'Cloud Top Temperature': 2096,
#  'Nutrients': 2097,
#  'Atmospheric Water Vapor': 2098,
#  'Extreme Weather': 2099,
#  'Ph': 2100,
#  'Tropospheric Ozone': 2101,
#  'Dust/Ash/Smoke': 2102,
#  'Carbonaceous Aerosols': 2103,
#  'Particulate Matter': 2104,
#  'Cloud Base Pressure': 2105,
#  'Earth Science': 2106,
#  'Water Vapor Mixing Ratio Profiles': 2107,
#  'Evaporation': 2108,
#  'Microwave Radiance': 2109,
#  'Frozen Ground': 2110,
#  'Atmospheric/Ocean Indicators': 2111,
#  'Satellite Local Zenith Angle': 2112,
#  'Phase And Amplitude': 2113,
#  'Oceans': 2114,
#  'Environmental Health Factors': 2115,
#  'Pressure Thickness': 2116,
#  'Carbonyl Sulfide': 2117,
#  'Terrestrial Hydrosphere': 2118,
#  'Platform Characteristics': 2119,
#  'Soil Infiltration': 2120,
#  'Cloud Condensation Nuclei': 2121,
#  'Cloud-Cleared Infrared Radiance': 2122,
#  'Hydrogen Compounds': 2123,
#  'Barometric Altitude': 2124,
#  'Aerosol Extinction Optical Depth': 2125,
#  'Deposition': 2126,
#  'Potential Vorticity': 2127,
#  'Natural Hazards': 2128,
#  'Heat/Cold Wave Frequency/Intensity': 2129,
#  'Peroxyacetyl Nitrate': 2130,
#  'Aerosol Extinction': 2131,
#  'Temperature Indices': 2132,
#  'Gas/Aerosol Composition': 2133,
#  'Ecological Dynamics': 2134,
#  'U Wind Component': 2135,
#  'Atmospheric Emitted Radiation': 2136,
#  'Specific Humidity': 2137,
#  'Convective Clouds/Systems (Observed/Analyzed)': 2138,
#  'Topography': 2139,
#  'Orbital Characteristics': 2140,
#  'Planetary Boundary Layer Height': 2141,
#  'Sulfate Particles': 2142,
#  'Phytoplankton': 2143,
#  'Transmitted Flux': 2144,
#  '8.3 Micron Extinction': 2145,
#  'Evapotranspiration': 2146,
#  'Aerosols': 2147,
#  'Lambertian Equivalent Reflectivity': 2148,
#  'Uv Aerosol Index': 2149}

# %%
titles_keywords_raw = df[['EntryTitle', 'ScienceKeywords']].to_numpy()

# %%
def get_deepest_keywords(dataset):
    deepest_keywords = []
    for keyword in dataset:
        deepest_class = list(keyword.keys())[-1]
        deepest_keywords.append(keyword[deepest_class].title())
    return deepest_keywords

# %%
title2kywrd = {}
for title, keywords_raw in titles_keywords_raw:
    keywords = get_deepest_keywords(keywords_raw)
    title2kywrd[title] = keywords

# %%
index2kywrd = {title2index[title]: keywords for title, keywords in title2kywrd.items()}

# %%
get_kywrd_index = lambda x: kywrd2kywid[x]
keyword_index_dict = {kywrd2kywid[key]: list(map(get_kywrd_index, value)) for key, value in keyword_dict.items()}

# %%
keyword_edges = set()
for key, value in keyword_index_dict.items():
    val_len = len(value)
    if val_len > 0:
        keyword_edges.add((key, value[0]))
        keyword_edges.add((value[0], key))
        for i in range(val_len - 1):
            keyword_edges.add((value[i], value[i+1]))
            keyword_edges.add((value[i+1], value[i]))

# %%
to_name = lambda x: (kywid2kywrd[x[0]], kywid2kywrd[x[1]])
list(map(to_name, keyword_edges))[:10]
# Out:
# [('Cloud Properties', 'Cloud Height'),
#  ('Snow', 'Solid Precipitation'),
#  ('Atmospheric Winds', 'Surface Winds'),
#  ('Particulate Matter', 'Aerosols'),
#  ('Cloud Properties', 'Clouds'),
#  ('Cloud Top Pressure', 'Cloud Properties'),
#  ('Chlorofluorocarbons', 'Halocarbons And Halogens'),
#  ('Solid Precipitation', 'Snow'),
#  ('Cryosphere', 'Sea Ice'),
#  ('Aerosol Optical Depth/Thickness', 'Aod')]

# %%
dataset_edges = set()
for index, keywords in index2kywrd.items():
    if keywords:
        dataset_edges.add((index, kywrd2kywid[keywords[0]]))
        dataset_edges.add((kywrd2kywid[keywords[0]], index))
        for i in range(len(keywords) - 1):
            dataset_edges.add((kywrd2kywid[keywords[i]], kywrd2kywid[keywords[i+1]]))
            dataset_edges.add((kywrd2kywid[keywords[i+1]], kywrd2kywid[keywords[i]]))

# %%
list(dataset_edges)[:10]
# Out:
# [(1954, 1803),
#  (1838, 1857),
#  (1964, 1996),
#  (1196, 2124),
#  (800, 2124),
#  (1727, 1760),
#  (1928, 1750),
#  (2084, 2034),
#  (1815, 1994),
#  (1920, 61)]

# %%
edges = keyword_edges | dataset_edges
edges = sorted(edges, key=lambda x: x[0])

# %%
edges[:10]
# Out:
# [(0, 2124),
#  (1, 2034),
#  (2, 2098),
#  (3, 2136),
#  (4, 1941),
#  (5, 1805),
#  (6, 2124),
#  (7, 2034),
#  (8, 2082),
#  (9, 2098)]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch_geometric.transforms as T
import umap.umap_ as umap
from sklearn.linear_model import LogisticRegression
from torch_cluster import random_walk
from torch_geometric.datasets import Planetoid
from torch_geometric.loader import NeighborSampler as RawNeighborSampler
from torch_geometric.nn import SAGEConv

# %%
from torch_geometric.data import Data

edge_index = torch.tensor(edges, dtype=torch.long).t().contiguous()
edge_index
# Out:
# tensor([[   0,    1,    2,  ..., 2149, 2149, 2149],
#         [2124, 2034, 2098,  ..., 1970, 1609, 1908]])

# %% [markdown]
# ### Node Features

# %%
kywrd2kywid
# Out:
# {'Solar Activity': 1738,
#  'Precipitation Amount': 1739,
#  'Cloud Radiative Forcing': 1740,
#  'Energy Deposition': 1741,
#  'Methyl Cyanide': 1742,
#  'Biosphere': 1743,
#  'Trace Gases/Trace Species': 1744,
#  'Temperature Indicators': 1745,
#  'Ionosphere/Magnetosphere Dynamics': 1746,
#  'Canopy Characteristics': 1747,
#  'Cloud Fraction': 1748,
#  'Eruption Dynamics': 1749,
#  'Air Quality': 1750,
#  'Vegetation': 1751,
#  'Antenna Temperature': 1752,
#  'Aerosol Optical Depth': 1753,
#  'Infrared Flux': 1754,
#  'Glaciers': 1755,
#  'Average Flow': 1756,
#  'Halocarbons And Halogens': 1757,
#  'Ozone (O3) Profile': 1758,
#  'Phosphate': 1759,
#  'Earth Radiation Budget': 1760,
#  'Soil Moisture': 1761,
#  'Radar': 1762,
#  'Cloud Precipitable Water': 1763,
#  'Reflected Flux': 1764,
#  '12.1 Micron Extinction': 1765,
#  'Flight Data Logs': 1766,
#  'Sensible Heat Flux': 1767,
#  'Air Temperature Profile': 1768,
#  'Common Sense Climate Index': 1769,
#  'Atmospheric Chemistry': 1770,
#  'Snow Water Equivalent': 1771,
#  'Atmospheric Temperature': 1772,
#  'Snow/Ice Temperature': 1773,
#  'Nitrate': 1774,
#  'Sea Level Pressure': 1775,
#  'Ocean Color': 1776,
#  'Soil Porosity': 1777,
#  'Optical Depth/Thickness': 1778,
#  'Runoff Rate': 1779,
#  'Land Use/Land Cover Classification': 1780,
#  'Plant Characteristics': 1781,
#  'Chlorine Dioxide': 1782,
#  'Radiance @ 12.0Um': 1783,
#  'Water Vapor Concentration Profiles': 1784,
#  '24 Hour Minimum Temperature': 1785,
#  'Alkalinity': 1786,
#  'Layered Precipitable Water': 1787,
#  'Radiance @ 1.6Um': 1788,
#  'Airglow': 1789,
#  'Sigma Naught': 1790,
#  'Hydrogen Cyanide': 1791,
#  'Volcanic Eruptions': 1792,
#  'Runoff': 1793,
#  'Vertical Profiles': 1794,
#  'Fire Occurrence': 1795,
#  'Climate Indicators': 1796,
#  'Sulfur Hexafluoride': 1797,
#  'Visible Radiance': 1798,
#  'Atmospheric Ozone': 1799,
#  'Visible Imagery': 1800,
#  'Total Runoff': 1801,
#  'Water Vapor': 1802,
#  'Surface Winds': 1803,
#  'Surface Temperature': 1804,
#  'Hydroxyl': 1805,
#  'Hypochlorous Acid': 1806,
#  'Volcanic Activity': 1807,
#  'Conduction': 1808,
#  'Isoprene': 1809,
#  'Carbon Monoxide': 1810,
#  'Wetlands': 1811,
#  'Vertical Wind Velocity/Speed': 1812,
#  'Uv Reflectivity': 1813,
#  'Water Vapor Indicators': 1814,
#  'Ultraviolet Radiation': 1815,
#  'Uv And Visible Solar Irradiances And Precisions': 1816,
#  'Longwave Radiation': 1817,
#  'Potential Evapotranspiration': 1818,
#  'Deep Convective Cloud Systems': 1819,
#  'Infrared Radiance': 1820,
#  'Water Vapor Profiles': 1821,
#  'Geolocation': 1822,
#  'Surface Water': 1823,
#  'Temperature Trends': 1824,
#  'Glaciers/Ice Sheets': 1825,
#  'Condensation': 1826,
#  'Leaf Characteristics': 1827,
#  'Infrared Wavelengths': 1828,
#  'Ocean Mixed Layer': 1829,
#  'Skin Temperature': 1830,
#  'Oxygen Compounds': 1831,
#  'Sea Surface Temperature': 1832,
#  'Chemical Composition': 1833,
#  'Agriculture': 1834,
#  'Extreme Drought': 1835,
#  'Ozone Profile And Total Column': 1836,
#  'Radiative Flux': 1837,
#  'Radiative Forcing': 1838,
#  'Solid Precipitation': 1839,
#  'Cloud Fraction Vertical Distribution': 1840,
#  'Cfc-11': 1841,
#  'Atmospheric Carbon Monoxide': 1842,
#  'Ground Water Processes/Measurements': 1843,
#  'Snow Melt': 1844,
#  'Nitrous Oxide': 1845,
#  'Carbon Tetrachloride': 1846,
#  'Ground Ice': 1847,
#  'Subsurface Flow': 1848,
#  'Smog': 1849,
#  'Wind Speed': 1850,
#  'Hcfc-22': 1851,
#  'Atmospheric Carbon Dioxide': 1852,
#  'Total And Tropospheric Nitrogen Dioxide (No2)': 1853,
#  'Drought Indices': 1854,
#  'Sensor Characteristics': 1855,
#  'Precipitation': 1856,
#  'Net Radiation': 1857,
#  'Fire Ecology': 1858,
#  'Land Surface Temperature': 1859,
#  'Cloud Top Height': 1860,
#  'Terrestrial Ecosystems': 1861,
#  'Radar Reflectivity': 1862,
#  'Particulate Matter Concentrations': 1863,
#  'Albedo': 1864,
#  'Snow Depth': 1865,
#  'Spectral/Engineering': 1866,
#  'Droplet Size': 1867,
#  'Sea Surface Height': 1868,
#  'Cloud Frequency': 1869,
#  'Liquid Water Equivalent': 1870,
#  'V Wind Component': 1871,
#  'Upper Level Winds': 1872,
#  'Ocean Pressure': 1873,
#  'Hydrogen Fluoride': 1874,
#  'Ultraviolet Radiance': 1875,
#  'Cloud Radiative Transfer': 1876,
#  'Ultraviolet Wavelengths': 1877,
#  'Geopotential Height': 1878,
#  'Wind Dynamics': 1879,
#  'Ecosystems': 1880,
#  'Sea Surface Skin Temperature': 1881,
#  'Dissolved Gases': 1882,
#  'Solar Energetic Particle Properties': 1883,
#  'Public Health': 1884,
#  'Floods': 1885,
#  'Global Precipitation': 1886,
#  'Microwave': 1887,
#  'Granule Coverage': 1888,
#  'Precipitation Rate': 1889,
#  'Total Column Ozone (O3)': 1890,
#  'Wind Direction Tendency': 1891,
#  'Angstrom Exponent': 1892,
#  'Carbon And Hydrocarbon Compounds': 1893,
#  'Oxygen': 1894,
#  'Aerosol Optical Depth/Thickness': 1895,
#  'Surface Thermal Properties': 1896,
#  'Solid Earth': 1897,
#  'Temperature Variability': 1898,
#  'Solar Induced Fluorescence': 1899,
#  'Chlorine Monoxide': 1900,
#  'Upper Air Temperature': 1901,
#  'Ice Fraction': 1902,
#  'Solar Irradiance': 1903,
#  'Nitrogen Compounds': 1904,
#  'Glacier Runoff': 1905,
#  'Cloud Droplet Concentration/Size': 1906,
#  'Hydrochlorofluorocarbons': 1907,
#  'Reflectance': 1908,
#  'Potential Temperature': 1909,
#  'Bromine Monoxide': 1910,
#  'Radiance @ 0.63Um': 1911,
#  'Photosynthetically Active Radiation': 1912,
#  'Methyl Chloride': 1913,
#  'Radiance @ 3.75Um': 1914,
#  'Outgoing Longwave Radiation': 1915,
#  'Cloud Types': 1916,
#  'Water Vapor Processes': 1917,
#  'Visible Flux': 1918,
#  'Sulfur Dioxide': 1919,
#  'Heat Flux': 1920,
#  'Cloud Liquid Water/Ice': 1921,
#  'Terrain Elevation': 1922,
#  'Land Surface': 1923,
#  'Sea Salt': 1924,
#  'Formaldehyde': 1925,
#  'Ocean Temperature': 1926,
#  'Ecosystem Functions': 1927,
#  'Aerosol Radiance': 1928,
#  'Sensor Counts': 1929,
#  'X-Ray Flux': 1930,
#  'Particulates': 1931,
#  'Soils': 1932,
#  'Precipitation Profiles': 1933,
#  'Vorticity': 1934,
#  'Column Amount Ozone': 1935,
#  'Surface Water Features': 1936,
#  'Vegetation Cover': 1937,
#  'Turbulence': 1938,
#  'Sun-Earth Interactions': 1939,
#  'Organic Particles': 1940,
#  'Atmospheric Nitric Acid': 1941,
#  'Extreme Precipitation': 1942,
#  'Aerosol Single-Scattering Albedo': 1943,
#  'Cloud Microphysics': 1944,
#  'Air Mass/Density': 1945,
#  'Zonal Winds': 1946,
#  'Cloud Emissivity': 1947,
#  'Ice Temperature': 1948,
#  'Total Surface Precipitation Rate': 1949,
#  'Cloud Reflectance': 1950,
#  'Total Column Ozone': 1951,
#  'Chlorophyll': 1952,
#  'Hydrogen-Deuterium Oxide': 1953,
#  'Atmospheric Winds': 1954,
#  'Water Vapor Flux': 1955,
#  'Rain': 1956,
#  'Nitrogen Oxides': 1957,
#  'Black Carbon': 1958,
#  '24 Hour Maximum Temperature': 1959,
#  'Oceanic Precipitation': 1960,
#  'Rivers/Streams': 1961,
#  'Sulfur Oxides': 1962,
#  'Reflectivity': 1963,
#  'Cloud Top Pressure': 1964,
#  'Virtual Temperature': 1965,
#  'Root Zone Soil Moisture': 1966,
#  'Ground Water': 1967,
#  'Total Solar Irradiance': 1968,
#  'Radar Backscatter': 1969,
#  'Emissions': 1970,
#  'Aerosol Particle Properties': 1971,
#  'Solar Energetic Particle Flux': 1972,
#  'Magnetic Fields/Magnetic Currents': 1973,
#  'Tropopause': 1974,
#  'Sea Ice': 1975,
#  'Landslides': 1976,
#  'Ozone': 1977,
#  'Cloud Vertical Distribution': 1978,
#  'Dimethyl Sulfide': 1979,
#  'Atmospheric Pressure': 1980,
#  'Erythemal Irradiance': 1981,
#  'Aod': 1982,
#  'Snow': 1983,
#  'Vegetation Index': 1984,
#  'Soil Temperature': 1985,
#  'Air Temperature': 1986,
#  'Boundary Layer Winds': 1987,
#  'Radiance @ 10.8Um': 1988,
#  'Carbon': 1989,
#  'Convection': 1990,
#  'Solar Radiation': 1991,
#  'Total Ozone': 1992,
#  'Incoming Solar Radiation': 1993,
#  'Scattering': 1994,
#  'Infrared Imagery': 1995,
#  'Cloud Properties': 1996,
#  'Radio Wave': 1997,
#  'Ocean Optics': 1998,
#  'Cloud Optical Depth/Thickness': 1999,
#  'Hydroperoxy': 2000,
#  'Vis Aerosol Index': 2001,
#  'Atmosphere': 2002,
#  'Soil Moisture/Water Content': 2003,
#  'Land Use/Land Cover': 2004,
#  'Snow/Ice': 2005,
#  'Visible Wavelengths': 2006,
#  'Liquid Precipitation': 2007,
#  'Reflective Band Radiance': 2008,
#  'Chlorofluorocarbons': 2009,
#  'Carbon Dioxide': 2010,
#  'Dew Point Temperature': 2011,
#  'Water Vapor Tendency': 2012,
#  'Solar Spectral Irradiance': 2013,
#  'Maximum/Minimum Temperature': 2014,
#  'Dinitrogen Pentoxide': 2015,
#  'Cloud Mass Flux': 2016,
#  'Chlorine Nitrate': 2017,
#  'Proton Flux': 2018,
#  'Paleoclimate Indicators': 2019,
#  'Precipitation Trends': 2020,
#  'Surface Radiative Properties': 2021,
#  'Total Precipitable Water': 2022,
#  'Altitude': 2023,
#  'Diffusion': 2024,
#  'Viewing Geometry': 2025,
#  'Lambert Equivalent Surface Reflectance': 2026,
#  'Protists': 2027,
#  'Nitric Oxide': 2028,
#  'Surface Soil Moisture': 2029,
#  'Relative Humidity': 2030,
#  'Ozone Profiles And Total Column': 2031,
#  'Biological Classification': 2032,
#  'Absorption': 2033,
#  'Brightness Temperature': 2034,
#  'Snow Cover': 2035,
#  'Sea Ice Concentration': 2036,
#  'Biogeochemical Cycles': 2037,
#  'Attitude Characteristics': 2038,
#  'Ammonia': 2039,
#  'Methanol': 2040,
#  'Hydrogen Chloride': 2041,
#  'Latent Heating': 2042,
#  'Vertical Velocity': 2043,
#  'Plankton': 2044,
#  'Cloud Dynamics': 2045,
#  'Colocation Information': 2046,
#  'Cloud Height': 2047,
#  'Satellite Soil Moisture Index': 2048,
#  'Formic Acid': 2049,
#  'Aerosol Absorption Optical Depth': 2050,
#  'Microwave Imagery': 2051,
#  'Emissivity': 2052,
#  'Atmospheric Heating': 2053,
#  'Meridional Winds': 2054,
#  'Temperature Tendency': 2055,
#  'Clouds': 2056,
#  'Conditional Rain Rate': 2057,
#  'Latent Heat Flux': 2058,
#  'Wind Stress': 2059,
#  'Precipitation Indicators': 2060,
#  'Particle Size Distribution': 2061,
#  'Surface Pressure': 2062,
#  'Boundary Layer Temperature': 2063,
#  'Land Use Classes': 2064,
#  'Human Dimensions': 2065,
#  'Tectonics': 2066,
#  'Pigments': 2067,
#  'Ocean Chemistry': 2068,
#  'Leaf Area Index (Lai)': 2069,
#  'Wind Speed Tendency': 2070,
#  'Nitrogen Dioxide': 2071,
#  'Primary Production': 2072,
#  'Shortwave Radiation': 2073,
#  'Cryosphere': 2074,
#  'Cfc-12': 2075,
#  'Atmospheric Pressure Measurements': 2076,
#  'Methane': 2077,
#  'Sulfur Compounds': 2078,
#  'Land Surface/Agriculture Indicators': 2079,
#  'Surface Roughness': 2080,
#  'Humidity': 2081,
#  'Aerosol Backscatter': 2082,
#  'Convective Surface Precipitation Rate': 2083,
#  'Temperature Anomalies': 2084,
#  'Atmospheric Radiation': 2085,
#  'Vegetation Water Content': 2086,
#  'Ocean Heat Budget': 2087,
#  'Thermal Infrared': 2088,
#  'Rain Probability': 2089,
#  'Soil Heat Budget': 2090,
#  'Electron Flux': 2091,
#  'Sulfate': 2092,
#  'U/V Wind Components': 2093,
#  'Surface Water Processes/Measurements': 2094,
#  'Sea Surface Topography': 2095,
#  'Cloud Top Temperature': 2096,
#  'Nutrients': 2097,
#  'Atmospheric Water Vapor': 2098,
#  'Extreme Weather': 2099,
#  'Ph': 2100,
#  'Tropospheric Ozone': 2101,
#  'Dust/Ash/Smoke': 2102,
#  'Carbonaceous Aerosols': 2103,
#  'Particulate Matter': 2104,
#  'Cloud Base Pressure': 2105,
#  'Earth Science': 2106,
#  'Water Vapor Mixing Ratio Profiles': 2107,
#  'Evaporation': 2108,
#  'Microwave Radiance': 2109,
#  'Frozen Ground': 2110,
#  'Atmospheric/Ocean Indicators': 2111,
#  'Satellite Local Zenith Angle': 2112,
#  'Phase And Amplitude': 2113,
#  'Oceans': 2114,
#  'Environmental Health Factors': 2115,
#  'Pressure Thickness': 2116,
#  'Carbonyl Sulfide': 2117,
#  'Terrestrial Hydrosphere': 2118,
#  'Platform Characteristics': 2119,
#  'Soil Infiltration': 2120,
#  'Cloud Condensation Nuclei': 2121,
#  'Cloud-Cleared Infrared Radiance': 2122,
#  'Hydrogen Compounds': 2123,
#  'Barometric Altitude': 2124,
#  'Aerosol Extinction Optical Depth': 2125,
#  'Deposition': 2126,
#  'Potential Vorticity': 2127,
#  'Natural Hazards': 2128,
#  'Heat/Cold Wave Frequency/Intensity': 2129,
#  'Peroxyacetyl Nitrate': 2130,
#  'Aerosol Extinction': 2131,
#  'Temperature Indices': 2132,
#  'Gas/Aerosol Composition': 2133,
#  'Ecological Dynamics': 2134,
#  'U Wind Component': 2135,
#  'Atmospheric Emitted Radiation': 2136,
#  'Specific Humidity': 2137,
#  'Convective Clouds/Systems (Observed/Analyzed)': 2138,
#  'Topography': 2139,
#  'Orbital Characteristics': 2140,
#  'Planetary Boundary Layer Height': 2141,
#  'Sulfate Particles': 2142,
#  'Phytoplankton': 2143,
#  'Transmitted Flux': 2144,
#  '8.3 Micron Extinction': 2145,
#  'Evapotranspiration': 2146,
#  'Aerosols': 2147,
#  'Lambertian Equivalent Reflectivity': 2148,
#  'Uv Aerosol Index': 2149}

# %%
import json

with open('06-27-2022_ScienceKeywordClassificationDict.txt') as f:
    data = f.read()

kywrd2class = json.loads(data)

# %%
class2index = {
    'Dataset': 0,
    'Category': 1,
    'Topic': 2,
    'Term': 3,
    'VariableLevel1': 4,
    'VariableLevel2': 5,
    'VariableLevel3': 6,
    'DetailedVariable': 7
}

# %%
dataset_classes = torch.zeros(1738)

# %%
ordered_kywrds = kywrd2kywid.keys()
keyword_classes = torch.tensor([class2index[kywrd2class[keyword]] for keyword in ordered_kywrds], dtype=torch.long)

# %%
y = torch.cat((dataset_classes, keyword_classes))

# %%
tfidf_tensor = torch.tensor(df_tfidf.to_numpy(), dtype=torch.long)
keyword_tfidf_tensor = torch.zeros((len(kywrd2kywid), df_tfidf.shape[1]))
x = torch.cat((tfidf_tensor, keyword_tfidf_tensor))

# %%
train_mask = [True]*400 + [False]*(len(index2title)-400) + [True]*100 + [False]*(len(kywid2kywrd)-100)
val_mask = [False]*400 + [True]*400 + [False]*(len(index2title)-800) + [False]*100 + [True]*100 + [False]*(len(kywid2kywrd)-200)
test_mask = [False]*800 + [True]*(len(index2title)-800) + [False]*200 + [True]*(len(kywid2kywrd)-200)

# %%
data = Data(x=x, edge_index=edge_index, y=y, train_mask=train_mask, val_mask=val_mask, test_mask=test_mask)

# %% [markdown]
# ### Learn Embeddings

# %%
class NeighborSampler(RawNeighborSampler):
    def sample(self, batch):
        batch = torch.tensor(batch)
        row, col, _ = self.adj_t.coo()

        # For each node in `batch`, we sample a direct neighbor (as positive
        # example) and a random node (as negative example):
        pos_batch = random_walk(row, col, batch, walk_length=1, coalesced=False)[:, 1]

        neg_batch = torch.randint(
            0, self.adj_t.size(1), (batch.numel(),), dtype=torch.long
        )

        batch = torch.cat([batch, pos_batch, neg_batch], dim=0)
        return super(NeighborSampler, self).sample(batch)


train_loader = NeighborSampler(
    data.edge_index,
    sizes=[10, 10],
    batch_size=256,
    shuffle=True,
    num_nodes=data.num_nodes,
)


class SAGE(nn.Module):
    def __init__(self, in_channels, hidden_channels, num_layers):
        super(SAGE, self).__init__()
        self.num_layers = num_layers
        self.convs = nn.ModuleList()

        for i in range(num_layers):
            in_channels = in_channels if i == 0 else hidden_channels
            self.convs.append(SAGEConv(in_channels, hidden_channels))

    def forward(self, x, adjs):
        for i, (edge_index, _, size) in enumerate(adjs):
            x_target = x[: size[1]]  # Target nodes are always placed first.
            x = self.convs[i]((x, x_target), edge_index)
            if i != self.num_layers - 1:
                x = x.relu()
                x = F.dropout(x, p=0.5, training=self.training)
        return x

    def full_forward(self, x, edge_index):
        for i, conv in enumerate(self.convs):
            x = conv(x, edge_index)
            if i != self.num_layers - 1:
                x = x.relu()
                x = F.dropout(x, p=0.5, training=self.training)
        return x


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = SAGE(data.num_node_features, hidden_channels=64, num_layers=2)
model = model.to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
x, edge_index = data.x.to(device), data.edge_index.to(device)


def train():
    model.train()

    total_loss = 0
    for batch_size, n_id, adjs in train_loader:
        # `adjs` holds a list of `(edge_index, e_id, size)` tuples.
        adjs = [adj.to(device) for adj in adjs]
        optimizer.zero_grad()

        out = model(x[n_id], adjs)
        out, pos_out, neg_out = out.split(out.size(0) // 3, dim=0)

        pos_loss = F.logsigmoid((out * pos_out).sum(-1)).mean()
        neg_loss = F.logsigmoid(-(out * neg_out).sum(-1)).mean()
        loss = -pos_loss - neg_loss
        loss.backward()
        optimizer.step()

        total_loss += float(loss) * out.size(0)

    return total_loss / data.num_nodes


@torch.no_grad()
def test():
    model.eval()
    out = model.full_forward(x, edge_index).cpu()

    clf = LogisticRegression()
    clf.fit(out[data.train_mask], data.y[data.train_mask])

    val_acc = clf.score(out[data.val_mask], data.y[data.val_mask])
    test_acc = clf.score(out[data.test_mask], data.y[data.test_mask])

    return val_acc, test_acc


for epoch in range(1, 201):
    loss = train()
    val_acc, test_acc = test()
    print(
        f"Epoch: {epoch:03d}, Loss: {loss:.4f}, "
        f"Val: {val_acc:.4f}, Test: {test_acc:.4f}"
    )
# Out:
# Epoch: 001, Loss: 1.3109, Val: 0.8920, Test: 0.8861
# Epoch: 002, Loss: 1.1033, Val: 0.8580, Test: 0.8670
# Epoch: 003, Loss: 1.0204, Val: 0.8400, Test: 0.8574
# Epoch: 004, Loss: 0.9708, Val: 0.8300, Test: 0.8539
# Epoch: 005, Loss: 0.9379, Val: 0.8480, Test: 0.8513
# Epoch: 006, Loss: 0.9375, Val: 0.8580, Test: 0.8600
# Epoch: 007, Loss: 0.8940, Val: 0.8440, Test: 0.8600
# Epoch: 008, Loss: 0.8909, Val: 0.8540, Test: 0.8548
# Epoch: 009, Loss: 0.9030, Val: 0.8520, Test: 0.8583
# Epoch: 010, Loss: 0.9111, Val: 0.8560, Test: 0.8643
# Epoch: 011, Loss: 0.8934, Val: 0.8560, Test: 0.8757
# Epoch: 012, Loss: 0.8477, Val: 0.8660, Test: 0.8757
# Epoch: 013, Loss: 0.9216, Val: 0.8520, Test: 0.8635
# Epoch: 014, Loss: 0.9194, Val: 0.8500, Test: 0.8478
# Epoch: 015, Loss: 0.8816, Val: 0.8400, Test: 0.8522
# Epoch: 016, Loss: 0.9012, Val: 0.8400, Test: 0.8487
# Epoch: 017, Loss: 0.8753, Val: 0.8400, Test: 0.8470
# Epoch: 018, Loss: 0.8418, Val: 0.8480, Test: 0.8513
# Epoch: 019, Loss: 0.8705, Val: 0.8540, Test: 0.8678
# Epoch: 020, Loss: 0.8597, Val: 0.8480, Test: 0.8670
# Epoch: 021, Loss: 0.8567, Val: 0.8540, Test: 0.8704
# Epoch: 022, Loss: 0.8919, Val: 0.8600, Test: 0.8730
# Epoch: 023, Loss: 0.8835, Val: 0.8560, Test: 0.8670
# Epoch: 024, Loss: 0.9053, Val: 0.8620, Test: 0.8670
# Epoch: 025, Loss: 0.8822, Val: 0.8560, Test: 0.8522
# Epoch: 026, Loss: 0.8747, Val: 0.8660, Test: 0.8591
# Epoch: 027, Loss: 0.8617, Val: 0.8640, Test: 0.8670
# Epoch: 028, Loss: 0.8763, Val: 0.8560, Test: 0.8635
# Epoch: 029, Loss: 0.8525, Val: 0.8480, Test: 0.8670
# Epoch: 030, Loss: 0.8723, Val: 0.8480, Test: 0.8652
# Epoch: 031, Loss: 0.8653, Val: 0.8560, Test: 0.8730
# Epoch: 032, Loss: 0.8680, Val: 0.8600, Test: 0.8687
# Epoch: 033, Loss: 0.8651, Val: 0.8560, Test: 0.8635
# Epoch: 034, Loss: 0.8795, Val: 0.8600, Test: 0.8643
# Epoch: 035, Loss: 0.8718, Val: 0.8620, Test: 0.8687
# Epoch: 036, Loss: 0.8370, Val: 0.8680, Test: 0.8713
# Epoch: 037, Loss: 0.9379, Val: 0.8700, Test: 0.8661
# Epoch: 038, Loss: 0.8749, Val: 0.8780, Test: 0.8617
# Epoch: 039, Loss: 0.8808, Val: 0.8780, Test: 0.8591
# Epoch: 040, Loss: 0.8896, Val: 0.8660, Test: 0.8583
# Epoch: 041, Loss: 0.8579, Val: 0.8720, Test: 0.8678
# Epoch: 042, Loss: 0.8757, Val: 0.8720, Test: 0.8661
# Epoch: 043, Loss: 0.8679, Val: 0.8640, Test: 0.8696
# Epoch: 044, Loss: 0.8983, Val: 0.8580, Test: 0.8600
# Epoch: 045, Loss: 0.8540, Val: 0.8600, Test: 0.8704
# Epoch: 046, Loss: 0.9064, Val: 0.8680, Test: 0.8687
# Epoch: 047, Loss: 0.8815, Val: 0.8700, Test: 0.8678
# Epoch: 048, Loss: 0.8623, Val: 0.8740, Test: 0.8687
# Epoch: 049, Loss: 0.8764, Val: 0.8700, Test: 0.8557
# Epoch: 050, Loss: 0.8634, Val: 0.8660, Test: 0.8470
# Epoch: 051, Loss: 0.9026, Val: 0.8480, Test: 0.8443
# Epoch: 052, Loss: 0.8606, Val: 0.8480, Test: 0.8478
# Epoch: 053, Loss: 0.8544, Val: 0.8540, Test: 0.8522
# Epoch: 054, Loss: 0.8517, Val: 0.8620, Test: 0.8574
# Epoch: 055, Loss: 0.8781, Val: 0.8680, Test: 0.8548
# Epoch: 056, Loss: 0.8883, Val: 0.8640, Test: 0.8574
# Epoch: 057, Loss: 0.8704, Val: 0.8760, Test: 0.8600
# Epoch: 058, Loss: 0.9017, Val: 0.8620, Test: 0.8565
# Epoch: 059, Loss: 0.8497, Val: 0.8700, Test: 0.8574
# Epoch: 060, Loss: 0.8724, Val: 0.8740, Test: 0.8600
# Epoch: 061, Loss: 0.8697, Val: 0.8760, Test: 0.8626
# Epoch: 062, Loss: 0.8837, Val: 0.8740, Test: 0.8609
# Epoch: 063, Loss: 0.8564, Val: 0.8700, Test: 0.8591
# Epoch: 064, Loss: 0.8941, Val: 0.8720, Test: 0.8635
# Epoch: 065, Loss: 0.8850, Val: 0.8680, Test: 0.8670
# Epoch: 066, Loss: 0.9022, Val: 0.8720, Test: 0.8713
# Epoch: 067, Loss: 0.8831, Val: 0.8740, Test: 0.8704
# Epoch: 068, Loss: 0.8712, Val: 0.8680, Test: 0.8626
# Epoch: 069, Loss: 0.8736, Val: 0.8780, Test: 0.8643
# Epoch: 070, Loss: 0.8788, Val: 0.8760, Test: 0.8670
# Epoch: 071, Loss: 0.8788, Val: 0.8740, Test: 0.8661
# Epoch: 072, Loss: 0.8812, Val: 0.8760, Test: 0.8635
# Epoch: 073, Loss: 0.8522, Val: 0.8720, Test: 0.8678
# Epoch: 074, Loss: 0.8908, Val: 0.8660, Test: 0.8643
# Epoch: 075, Loss: 0.8697, Val: 0.8680, Test: 0.8643
# Epoch: 076, Loss: 0.8812, Val: 0.8680, Test: 0.8574
# Epoch: 077, Loss: 0.8573, Val: 0.8640, Test: 0.8583
# Epoch: 078, Loss: 0.8894, Val: 0.8660, Test: 0.8574
# Epoch: 079, Loss: 0.8903, Val: 0.8660, Test: 0.8600
# Epoch: 080, Loss: 0.8831, Val: 0.8700, Test: 0.8617
# Epoch: 081, Loss: 0.8527, Val: 0.8680, Test: 0.8643
# Epoch: 082, Loss: 0.8591, Val: 0.8660, Test: 0.8591
# Epoch: 083, Loss: 0.8962, Val: 0.8540, Test: 0.8539
# Epoch: 084, Loss: 0.8543, Val: 0.8580, Test: 0.8643
# Epoch: 085, Loss: 0.8804, Val: 0.8720, Test: 0.8643
# Epoch: 086, Loss: 0.9105, Val: 0.8620, Test: 0.8513
# Epoch: 087, Loss: 0.8732, Val: 0.8580, Test: 0.8548
# Epoch: 088, Loss: 0.8868, Val: 0.8560, Test: 0.8643
# Epoch: 089, Loss: 0.9000, Val: 0.8540, Test: 0.8617
# Epoch: 090, Loss: 0.8681, Val: 0.8600, Test: 0.8574
# Epoch: 091, Loss: 0.8893, Val: 0.8580, Test: 0.8591
# Epoch: 092, Loss: 0.8893, Val: 0.8580, Test: 0.8591
# Epoch: 093, Loss: 0.8550, Val: 0.8600, Test: 0.8591
# Epoch: 094, Loss: 0.8796, Val: 0.8720, Test: 0.8652
# Epoch: 095, Loss: 0.8526, Val: 0.8660, Test: 0.8626
# Epoch: 096, Loss: 0.8822, Val: 0.8640, Test: 0.8670
# Epoch: 097, Loss: 0.8732, Val: 0.8760, Test: 0.8678
# Epoch: 098, Loss: 0.8678, Val: 0.8680, Test: 0.8687
# Epoch: 099, Loss: 0.8829, Val: 0.8640, Test: 0.8626
# Epoch: 100, Loss: 0.9045, Val: 0.8600, Test: 0.8670
# Epoch: 101, Loss: 0.8788, Val: 0.8540, Test: 0.8696
# Epoch: 102, Loss: 0.8507, Val: 0.8680, Test: 0.8687
# Epoch: 103, Loss: 0.8774, Val: 0.8580, Test: 0.8583
# Epoch: 104, Loss: 0.8988, Val: 0.8500, Test: 0.8461
# Epoch: 105, Loss: 0.8636, Val: 0.8540, Test: 0.8600
# Epoch: 106, Loss: 0.8899, Val: 0.8640, Test: 0.8583
# Epoch: 107, Loss: 0.8954, Val: 0.8620, Test: 0.8557
# Epoch: 108, Loss: 0.8886, Val: 0.8700, Test: 0.8583
# Epoch: 109, Loss: 0.8854, Val: 0.8560, Test: 0.8583
# Epoch: 110, Loss: 0.8826, Val: 0.8640, Test: 0.8539
# Epoch: 111, Loss: 0.8680, Val: 0.8700, Test: 0.8591
# Epoch: 112, Loss: 0.8937, Val: 0.8680, Test: 0.8643
# Epoch: 113, Loss: 0.8506, Val: 0.8640, Test: 0.8626
# Epoch: 114, Loss: 0.9130, Val: 0.8700, Test: 0.8670
# Epoch: 115, Loss: 0.8818, Val: 0.8640, Test: 0.8670
# Epoch: 116, Loss: 0.8903, Val: 0.8620, Test: 0.8670
# Epoch: 117, Loss: 0.8832, Val: 0.8620, Test: 0.8617
# Epoch: 118, Loss: 0.8806, Val: 0.8460, Test: 0.8600
# Epoch: 119, Loss: 0.8914, Val: 0.8460, Test: 0.8565
# Epoch: 120, Loss: 0.8849, Val: 0.8540, Test: 0.8643
# Epoch: 121, Loss: 0.8879, Val: 0.8480, Test: 0.8643
# Epoch: 122, Loss: 0.8940, Val: 0.8560, Test: 0.8626
# Epoch: 123, Loss: 0.8544, Val: 0.8640, Test: 0.8609
# Epoch: 124, Loss: 0.8818, Val: 0.8680, Test: 0.8670
# Epoch: 125, Loss: 0.8773, Val: 0.8640, Test: 0.8687
# Epoch: 126, Loss: 0.8761, Val: 0.8560, Test: 0.8617
# Epoch: 127, Loss: 0.8924, Val: 0.8420, Test: 0.8522
# Epoch: 128, Loss: 0.9035, Val: 0.8360, Test: 0.8557
# Epoch: 129, Loss: 0.8987, Val: 0.8720, Test: 0.8557
# Epoch: 130, Loss: 0.8725, Val: 0.8680, Test: 0.8565
# Epoch: 131, Loss: 0.8673, Val: 0.8700, Test: 0.8548
# Epoch: 132, Loss: 0.8653, Val: 0.8680, Test: 0.8574
# Epoch: 133, Loss: 0.8565, Val: 0.8740, Test: 0.8626
# Epoch: 134, Loss: 0.9127, Val: 0.8680, Test: 0.8626
# Epoch: 135, Loss: 0.8673, Val: 0.8580, Test: 0.8565
# Epoch: 136, Loss: 0.9248, Val: 0.8760, Test: 0.8609
# Epoch: 137, Loss: 0.8717, Val: 0.8680, Test: 0.8548
# Epoch: 138, Loss: 0.8762, Val: 0.8760, Test: 0.8557
# Epoch: 139, Loss: 0.8848, Val: 0.8740, Test: 0.8617
# Epoch: 140, Loss: 0.8475, Val: 0.8660, Test: 0.8713
# Epoch: 141, Loss: 0.8958, Val: 0.8640, Test: 0.8713
# Epoch: 142, Loss: 0.8741, Val: 0.8680, Test: 0.8687
# Epoch: 143, Loss: 0.8810, Val: 0.8800, Test: 0.8652
# Epoch: 144, Loss: 0.8845, Val: 0.8720, Test: 0.8635
# Epoch: 145, Loss: 0.8604, Val: 0.8600, Test: 0.8617
# Epoch: 146, Loss: 0.8692, Val: 0.8600, Test: 0.8591
# Epoch: 147, Loss: 0.8980, Val: 0.8640, Test: 0.8652
# Epoch: 148, Loss: 0.8618, Val: 0.8620, Test: 0.8678
# Epoch: 149, Loss: 0.8897, Val: 0.8580, Test: 0.8635
# Epoch: 150, Loss: 0.8771, Val: 0.8680, Test: 0.8609
# Epoch: 151, Loss: 0.9107, Val: 0.8640, Test: 0.8617
# Epoch: 152, Loss: 0.8892, Val: 0.8580, Test: 0.8600
# Epoch: 153, Loss: 0.8950, Val: 0.8740, Test: 0.8635
# Epoch: 154, Loss: 0.8567, Val: 0.8720, Test: 0.8643
# Epoch: 155, Loss: 0.8598, Val: 0.8640, Test: 0.8626
# Epoch: 156, Loss: 0.8807, Val: 0.8600, Test: 0.8661
# Epoch: 157, Loss: 0.8737, Val: 0.8580, Test: 0.8652
# Epoch: 158, Loss: 0.8496, Val: 0.8620, Test: 0.8617
# Epoch: 159, Loss: 0.8816, Val: 0.8600, Test: 0.8548
# Epoch: 160, Loss: 0.8765, Val: 0.8720, Test: 0.8609
# Epoch: 161, Loss: 0.8632, Val: 0.8700, Test: 0.8652
# Epoch: 162, Loss: 0.8546, Val: 0.8700, Test: 0.8670
# Epoch: 163, Loss: 0.8762, Val: 0.8700, Test: 0.8661
# Epoch: 164, Loss: 0.8965, Val: 0.8680, Test: 0.8635
# Epoch: 165, Loss: 0.8638, Val: 0.8660, Test: 0.8652
# Epoch: 166, Loss: 0.8661, Val: 0.8700, Test: 0.8635
# Epoch: 167, Loss: 0.8962, Val: 0.8660, Test: 0.8739
# Epoch: 168, Loss: 0.8800, Val: 0.8720, Test: 0.8713
# Epoch: 169, Loss: 0.8707, Val: 0.8680, Test: 0.8704
# Epoch: 170, Loss: 0.8534, Val: 0.8760, Test: 0.8687
# Epoch: 171, Loss: 0.8868, Val: 0.8700, Test: 0.8617
# Epoch: 172, Loss: 0.8745, Val: 0.8760, Test: 0.8687
# Epoch: 173, Loss: 0.8535, Val: 0.8780, Test: 0.8730
# Epoch: 174, Loss: 0.8946, Val: 0.8700, Test: 0.8704
# Epoch: 175, Loss: 0.8583, Val: 0.8680, Test: 0.8704
# Epoch: 176, Loss: 0.9034, Val: 0.8620, Test: 0.8730
# Epoch: 177, Loss: 0.8575, Val: 0.8600, Test: 0.8748
# Epoch: 178, Loss: 0.8762, Val: 0.8600, Test: 0.8696
# Epoch: 179, Loss: 0.8908, Val: 0.8560, Test: 0.8678
# Epoch: 180, Loss: 0.8510, Val: 0.8600, Test: 0.8739
# Epoch: 181, Loss: 0.8641, Val: 0.8640, Test: 0.8661
# Epoch: 182, Loss: 0.8834, Val: 0.8640, Test: 0.8704
# Epoch: 183, Loss: 0.8500, Val: 0.8620, Test: 0.8678
# Epoch: 184, Loss: 0.8573, Val: 0.8620, Test: 0.8600
# Epoch: 185, Loss: 0.8962, Val: 0.8560, Test: 0.8574
# Epoch: 186, Loss: 0.8518, Val: 0.8540, Test: 0.8609
# Epoch: 187, Loss: 0.8903, Val: 0.8660, Test: 0.8635
# Epoch: 188, Loss: 0.8665, Val: 0.8700, Test: 0.8609
# Epoch: 189, Loss: 0.8562, Val: 0.8560, Test: 0.8626
# Epoch: 190, Loss: 0.8898, Val: 0.8620, Test: 0.8704
# Epoch: 191, Loss: 0.8556, Val: 0.8580, Test: 0.8643
# Epoch: 192, Loss: 0.8745, Val: 0.8640, Test: 0.8670
# Epoch: 193, Loss: 0.8571, Val: 0.8640, Test: 0.8643
# Epoch: 194, Loss: 0.8875, Val: 0.8740, Test: 0.8652
# Epoch: 195, Loss: 0.8881, Val: 0.8640, Test: 0.8748
# Epoch: 196, Loss: 0.8851, Val: 0.8660, Test: 0.8696
# Epoch: 197, Loss: 0.8809, Val: 0.8700, Test: 0.8739
# Epoch: 198, Loss: 0.8838, Val: 0.8600, Test: 0.8757
# Epoch: 199, Loss: 0.8803, Val: 0.8660, Test: 0.8774
# Epoch: 200, Loss: 0.8852, Val: 0.8580, Test: 0.8748

# %%
with torch.no_grad():
    model.eval()
    out = model.full_forward(x, edge_index).cpu()

# %%
palette = {}

for n, y in enumerate(set(data.y.numpy())):
    palette[y] = f"C{n}"

# %%
embd = umap.UMAP().fit_transform(out.cpu().numpy())
# Out:
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.

# %%
kywrd_count = len(kywrd2kywid)

# %%
x_vals, y_vals = embd.T[0][:-kywrd_count], embd.T[1][:-kywrd_count]
labels = (list(index2title.values()) + list(kywid2kywrd.values()))[:-kywrd_count]

# %%
topics
# Out:
# ['Climate Indicators',
#  'Oceans',
#  'Human Dimensions',
#  'Solid Earth',
#  'Sun-Earth Interactions',
#  'Biosphere',
#  'Biological Classification',
#  'Terrestrial Hydrosphere',
#  'Atmosphere',
#  'Agriculture',
#  'Spectral/Engineering',
#  'Land Surface',
#  'Cryosphere']

# %%
# Get the set of keywords for each dataset
title2topic = dict(zip(labels, [[]]*len(labels)))
for title in labels:
    topics_for_this_title = set()
    kywrds_for_title = index2kywrd[title2index[title]]
    for keyword in kywrds_for_title:
        topic = keyword_dict[keyword][-2]
        topics_for_this_title.add(topic)
    title2topic[title] = list(topics_for_this_title)[0]
    print(topics_for_this_title)
# Out:
# {'Land Surface', 'Atmosphere'}
# {'Spectral/Engineering'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Spectral/Engineering'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Biosphere', 'Land Surface'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Spectral/Engineering'}
# {'Sun-Earth Interactions'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Sun-Earth Interactions'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Biosphere', 'Terrestrial Hydrosphere', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Biosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Spectral/Engineering'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering'}
# {'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Terrestrial Hydrosphere', 'Land Surface', 'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Biosphere', 'Terrestrial Hydrosphere', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Terrestrial Hydrosphere', 'Cryosphere', 'Land Surface'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Biosphere', 'Land Surface'}
# {'Terrestrial Hydrosphere', 'Cryosphere', 'Land Surface', 'Atmosphere'}
# {'Oceans', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Oceans', 'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Spectral/Engineering'}
# {'Spectral/Engineering'}
# {'Spectral/Engineering'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering'}
# {'Atmosphere'}
# {'Biosphere', 'Terrestrial Hydrosphere', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Atmosphere'}
# {'Biosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Oceans', 'Atmosphere'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Terrestrial Hydrosphere', 'Land Surface', 'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Terrestrial Hydrosphere', 'Cryosphere', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering'}
# {'Atmosphere'}
# {'Biosphere', 'Land Surface'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Terrestrial Hydrosphere', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Oceans', 'Spectral/Engineering', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Spectral/Engineering'}
# {'Terrestrial Hydrosphere', 'Land Surface', 'Atmosphere'}
# {'Spectral/Engineering'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Terrestrial Hydrosphere', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Biosphere', 'Land Surface'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Sun-Earth Interactions'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Atmosphere'}
# {'Human Dimensions', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Spectral/Engineering'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Terrestrial Hydrosphere', 'Land Surface', 'Atmosphere'}
# {'Spectral/Engineering'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Human Dimensions', 'Atmosphere'}
# {'Atmosphere'}
# {'Terrestrial Hydrosphere', 'Land Surface', 'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Sun-Earth Interactions'}
# {'Atmosphere'}
# {'Oceans', 'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Spectral/Engineering'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Oceans', 'Spectral/Engineering', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering'}
# {'Atmosphere'}
# {'Spectral/Engineering'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering'}
# {'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Spectral/Engineering'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Biosphere', 'Terrestrial Hydrosphere', 'Land Surface', 'Atmosphere'}
# {'Spectral/Engineering'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Oceans', 'Biological Classification'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Terrestrial Hydrosphere', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Terrestrial Hydrosphere', 'Land Surface', 'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering'}
# {'Terrestrial Hydrosphere', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Sun-Earth Interactions'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Spectral/Engineering'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Sun-Earth Interactions'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Oceans', 'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Biosphere', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering'}
# {'Spectral/Engineering'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Land Surface', 'Terrestrial Hydrosphere', 'Atmosphere'}
# {'Atmosphere'}
# {'Sun-Earth Interactions'}
# {'Sun-Earth Interactions'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering'}
# {'Land Surface'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Biosphere', 'Land Surface'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Oceans', 'Atmosphere'}
# {'Sun-Earth Interactions'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Solid Earth', 'Atmosphere'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Spectral/Engineering'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Oceans', 'Atmosphere', 'Cryosphere', 'Terrestrial Hydrosphere', 'Land Surface'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Biosphere', 'Agriculture'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Terrestrial Hydrosphere', 'Atmosphere'}
# {'Spectral/Engineering'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering'}
# {'Spectral/Engineering'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Sun-Earth Interactions'}
# {'Spectral/Engineering'}
# {'Land Surface', 'Atmosphere'}
# {'Spectral/Engineering'}
# {'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Terrestrial Hydrosphere', 'Atmosphere'}
# {'Spectral/Engineering'}
# {'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering'}
# {'Biosphere', 'Terrestrial Hydrosphere', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Sun-Earth Interactions'}
# {'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Atmosphere'}
# {'Terrestrial Hydrosphere', 'Land Surface', 'Atmosphere'}
# {'Spectral/Engineering'}
# {'Human Dimensions', 'Climate Indicators', 'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering'}
# {'Sun-Earth Interactions'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Terrestrial Hydrosphere', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Biosphere'}
# {'Human Dimensions'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Oceans', 'Atmosphere'}
# {'Spectral/Engineering'}
# {'Atmosphere'}
# {'Spectral/Engineering'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Sun-Earth Interactions'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Spectral/Engineering'}
# {'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Spectral/Engineering'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Spectral/Engineering'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Biosphere', 'Terrestrial Hydrosphere', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Biosphere', 'Terrestrial Hydrosphere', 'Land Surface', 'Atmosphere'}
# {'Oceans', 'Atmosphere'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering'}
# {'Atmosphere'}
# {'Biosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Sun-Earth Interactions'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Atmosphere'}
# {'Sun-Earth Interactions'}
# {'Terrestrial Hydrosphere', 'Land Surface', 'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Biosphere', 'Terrestrial Hydrosphere', 'Land Surface', 'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Oceans', 'Atmosphere', 'Cryosphere', 'Terrestrial Hydrosphere', 'Land Surface'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Terrestrial Hydrosphere', 'Land Surface', 'Atmosphere'}
# {'Oceans', 'Spectral/Engineering', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Sun-Earth Interactions'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Terrestrial Hydrosphere', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Sun-Earth Interactions'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering'}
# {'Biosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Spectral/Engineering'}
# {'Atmosphere'}
# {'Sun-Earth Interactions'}
# {'Land Surface', 'Atmosphere'}
# {'Terrestrial Hydrosphere', 'Land Surface', 'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Terrestrial Hydrosphere', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Biosphere', 'Terrestrial Hydrosphere', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Sun-Earth Interactions'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Terrestrial Hydrosphere', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Spectral/Engineering'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Oceans', 'Atmosphere', 'Cryosphere', 'Terrestrial Hydrosphere', 'Land Surface'}
# {'Spectral/Engineering'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Terrestrial Hydrosphere', 'Atmosphere'}
# {'Spectral/Engineering'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Biosphere', 'Land Surface'}
# {'Oceans', 'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Sun-Earth Interactions'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Sun-Earth Interactions'}
# {'Atmosphere'}
# {'Agriculture'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering'}
# {'Atmosphere'}
# {'Spectral/Engineering'}
# {'Spectral/Engineering'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Biosphere', 'Land Surface'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Spectral/Engineering'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Spectral/Engineering'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Land Surface'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Biosphere', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Human Dimensions', 'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Spectral/Engineering'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Spectral/Engineering'}
# {'Spectral/Engineering'}
# {'Biosphere', 'Atmosphere', 'Cryosphere', 'Terrestrial Hydrosphere', 'Land Surface'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Oceans', 'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Spectral/Engineering'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Spectral/Engineering'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Terrestrial Hydrosphere', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Sun-Earth Interactions'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Sun-Earth Interactions'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Sun-Earth Interactions'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Terrestrial Hydrosphere', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering'}
# {'Atmosphere'}
# {'Land Surface'}
# {'Spectral/Engineering'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Atmosphere'}
# {'Sun-Earth Interactions'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Land Surface'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Terrestrial Hydrosphere', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering'}
# {'Land Surface', 'Atmosphere'}
# {'Sun-Earth Interactions'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Land Surface'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Terrestrial Hydrosphere', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Spectral/Engineering'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Oceans', 'Atmosphere'}
# {'Oceans', 'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Biosphere', 'Atmosphere', 'Cryosphere', 'Terrestrial Hydrosphere', 'Land Surface'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering'}
# {'Sun-Earth Interactions', 'Climate Indicators', 'Spectral/Engineering'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Biosphere', 'Land Surface'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Spectral/Engineering'}
# {'Spectral/Engineering'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Atmosphere'}
# {'Oceans', 'Spectral/Engineering', 'Land Surface', 'Atmosphere'}
# {'Biosphere', 'Atmosphere', 'Cryosphere', 'Terrestrial Hydrosphere', 'Land Surface'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Oceans'}
# {'Land Surface', 'Atmosphere'}
# {'Oceans', 'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Spectral/Engineering'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Climate Indicators', 'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Atmosphere'}
# {'Biosphere', 'Land Surface'}
# {'Sun-Earth Interactions'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Atmosphere'}
# {'Oceans', 'Atmosphere'}
# {'Biosphere', 'Terrestrial Hydrosphere', 'Land Surface', 'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Biosphere', 'Land Surface'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Oceans', 'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Solid Earth', 'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering'}
# {'Sun-Earth Interactions'}
# {'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Terrestrial Hydrosphere', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Terrestrial Hydrosphere', 'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Spectral/Engineering'}
# {'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Climate Indicators'}
# {'Land Surface', 'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Sun-Earth Interactions'}
# {'Atmosphere'}
# {'Biosphere', 'Terrestrial Hydrosphere', 'Land Surface', 'Atmosphere'}
# {'Oceans', 'Atmosphere', 'Cryosphere', 'Terrestrial Hydrosphere', 'Land Surface'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Human Dimensions', 'Atmosphere'}
# {'Spectral/Engineering'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Sun-Earth Interactions', 'Climate Indicators', 'Spectral/Engineering'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Sun-Earth Interactions'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Oceans', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Sun-Earth Interactions'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Biosphere', 'Land Surface'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Biosphere', 'Land Surface'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Atmosphere'}
# {'Biosphere', 'Terrestrial Hydrosphere', 'Land Surface', 'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Land Surface'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere', 'Cryosphere', 'Terrestrial Hydrosphere', 'Climate Indicators', 'Land Surface'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Atmosphere'}
# {'Sun-Earth Interactions'}
# {'Atmosphere'}
# {'Spectral/Engineering'}
# {'Land Surface', 'Atmosphere'}
# {'Biosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Atmosphere'}
# {'Oceans', 'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Spectral/Engineering'}
# {'Atmosphere'}
# {'Spectral/Engineering'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering'}
# {'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Sun-Earth Interactions', 'Climate Indicators', 'Spectral/Engineering'}
# {'Terrestrial Hydrosphere', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Terrestrial Hydrosphere', 'Land Surface', 'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Oceans', 'Spectral/Engineering', 'Land Surface', 'Atmosphere'}
# {'Land Surface'}
# {'Land Surface', 'Atmosphere'}
# {'Spectral/Engineering'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering'}
# {'Land Surface', 'Atmosphere'}
# {'Sun-Earth Interactions'}
# {'Oceans', 'Atmosphere'}
# {'Land Surface'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Land Surface'}
# {'Oceans', 'Atmosphere'}
# {'Climate Indicators', 'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Oceans', 'Atmosphere'}
# {'Atmosphere'}
# {'Sun-Earth Interactions'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Spectral/Engineering'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Sun-Earth Interactions'}
# {'Oceans', 'Atmosphere', 'Cryosphere', 'Terrestrial Hydrosphere', 'Land Surface'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Sun-Earth Interactions'}
# {'Land Surface', 'Atmosphere'}
# {'Spectral/Engineering'}
# {'Oceans', 'Atmosphere'}
# {'Biosphere', 'Land Surface'}
# {'Atmosphere'}
# {'Human Dimensions', 'Climate Indicators', 'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Biosphere', 'Terrestrial Hydrosphere', 'Land Surface', 'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Sun-Earth Interactions'}
# {'Atmosphere'}
# {'Spectral/Engineering'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Sun-Earth Interactions'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Land Surface'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Cryosphere'}
# {'Atmosphere'}
# {'Biosphere', 'Land Surface'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Spectral/Engineering'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Sun-Earth Interactions'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering'}
# {'Land Surface', 'Atmosphere'}
# {'Spectral/Engineering'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Sun-Earth Interactions'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Biosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering'}
# {'Sun-Earth Interactions'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Spectral/Engineering'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering'}
# {'Sun-Earth Interactions'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering'}
# {'Spectral/Engineering'}
# {'Atmosphere'}
# {'Spectral/Engineering'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Terrestrial Hydrosphere', 'Atmosphere'}
# {'Biosphere', 'Terrestrial Hydrosphere', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Terrestrial Hydrosphere', 'Land Surface', 'Atmosphere'}
# {'Spectral/Engineering'}
# {'Spectral/Engineering'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Sun-Earth Interactions'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering'}
# {'Oceans', 'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Terrestrial Hydrosphere', 'Cryosphere', 'Land Surface', 'Atmosphere'}
# {'Biosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Terrestrial Hydrosphere', 'Atmosphere'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Spectral/Engineering'}
# {'Spectral/Engineering'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Land Surface'}
# {'Spectral/Engineering', 'Land Surface'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Oceans', 'Atmosphere'}
# {'Land Surface'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Terrestrial Hydrosphere', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Biosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Terrestrial Hydrosphere', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Solid Earth', 'Atmosphere'}
# {'Spectral/Engineering'}
# {'Land Surface'}
# {'Spectral/Engineering'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Spectral/Engineering'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Terrestrial Hydrosphere', 'Cryosphere', 'Land Surface'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Sun-Earth Interactions'}
# {'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Biosphere', 'Atmosphere', 'Cryosphere', 'Terrestrial Hydrosphere', 'Land Surface'}
# {'Spectral/Engineering'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering'}
# {'Atmosphere'}
# {'Sun-Earth Interactions'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Terrestrial Hydrosphere', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Oceans', 'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Biosphere', 'Terrestrial Hydrosphere', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Terrestrial Hydrosphere', 'Land Surface', 'Atmosphere'}
# {'Biosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Land Surface'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Sun-Earth Interactions'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Biosphere', 'Terrestrial Hydrosphere', 'Land Surface', 'Atmosphere'}
# {'Spectral/Engineering'}
# {'Biosphere', 'Terrestrial Hydrosphere', 'Land Surface', 'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Spectral/Engineering'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Sun-Earth Interactions'}
# {'Spectral/Engineering'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Spectral/Engineering'}
# {'Spectral/Engineering'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Oceans', 'Spectral/Engineering', 'Land Surface', 'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering'}
# {'Cryosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Spectral/Engineering'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Climate Indicators', 'Atmosphere'}
# {'Biosphere', 'Land Surface'}
# {'Atmosphere'}
# {'Spectral/Engineering'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Atmosphere'}
# {'Oceans', 'Cryosphere', 'Spectral/Engineering', 'Atmosphere'}
# {'Human Dimensions', 'Climate Indicators', 'Atmosphere'}
# {'Atmosphere'}
# {'Sun-Earth Interactions'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering'}
# {'Land Surface', 'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Spectral/Engineering'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Oceans', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering'}
# {'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Sun-Earth Interactions'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Spectral/Engineering'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Terrestrial Hydrosphere', 'Cryosphere', 'Land Surface'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Terrestrial Hydrosphere', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Sun-Earth Interactions'}
# {'Atmosphere'}
# {'Biosphere', 'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Terrestrial Hydrosphere', 'Land Surface', 'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Sun-Earth Interactions'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Oceans', 'Atmosphere', 'Cryosphere', 'Terrestrial Hydrosphere', 'Land Surface'}
# {'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Biosphere', 'Terrestrial Hydrosphere', 'Land Surface', 'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Oceans', 'Biological Classification'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Oceans', 'Atmosphere'}
# {'Spectral/Engineering'}
# {'Atmosphere'}
# {'Spectral/Engineering'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Sun-Earth Interactions'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Terrestrial Hydrosphere', 'Land Surface', 'Atmosphere'}
# {'Spectral/Engineering'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Sun-Earth Interactions'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Spectral/Engineering'}
# {'Atmosphere'}
# {'Land Surface', 'Atmosphere'}
# {'Oceans', 'Land Surface', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Sun-Earth Interactions'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Spectral/Engineering', 'Atmosphere'}

# %%
# Backtrack and get the terms for each of the deepest keywords for each dataset
title2term = dict(zip(labels, [[]]*len(labels)))
for title in labels:
    terms_for_this_title = set()
    kywrds_for_title = index2kywrd[title2index[title]]
    for keyword in kywrds_for_title:
        if len(keyword_dict[keyword]) > 2:
            term = keyword_dict[keyword][-3]
        else:
            term = keyword_dict[keyword][-2]
        terms_for_this_title.add(term)
    title2term[title] = list(terms_for_this_title)[0]
    print(terms_for_this_title)
# Out:
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Infrared Wavelengths'}
# {'Atmosphere'}
# {'Platform Characteristics', 'Spectral/Engineering', 'Atmospheric Radiation', 'Sensor Characteristics'}
# {'Atmospheric Chemistry'}
# {'Atmospheric Chemistry'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Infrared Wavelengths'}
# {'Aerosols', 'Atmospheric Radiation'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Soils', 'Surface Thermal Properties', 'Vegetation'}
# {'Atmospheric Water Vapor', 'Atmospheric Chemistry'}
# {'Surface Thermal Properties', 'Atmospheric Chemistry', 'Atmosphere', 'Atmospheric Water Vapor', 'Atmospheric Temperature'}
# {'Atmospheric Chemistry'}
# {'Microwave'}
# {'Surface Thermal Properties', 'Atmospheric Chemistry', 'Atmospheric Radiation', 'Sea Surface Topography', 'Atmospheric Water Vapor', 'Atmospheric Pressure', 'Ocean Pressure', 'Clouds', 'Ocean Temperature', 'Precipitation', 'Atmospheric Temperature'}
# {'Microwave', 'Infrared Wavelengths'}
# {'Solar Activity'}
# {'Altitude', 'Surface Thermal Properties', 'Atmospheric Chemistry', 'Atmospheric Radiation', 'Air Quality', 'Atmospheric Water Vapor', 'Atmospheric Pressure', 'Clouds', 'Ocean Temperature', 'Precipitation', 'Atmospheric Temperature', 'Surface Radiative Properties'}
# {'Altitude', 'Surface Thermal Properties', 'Atmospheric Chemistry', 'Air Quality', 'Atmospheric Radiation', 'Atmospheric Water Vapor', 'Atmospheric Pressure', 'Clouds', 'Ocean Temperature', 'Precipitation', 'Atmospheric Temperature', 'Surface Radiative Properties'}
# {'Clouds'}
# {'Atmospheric Chemistry'}
# {'Atmospheric Radiation', 'Atmospheric Water Vapor', 'Clouds', 'Precipitation', 'Atmospheric Temperature'}
# {'Solar Activity'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Atmospheric Chemistry'}
# {'Altitude', 'Surface Thermal Properties', 'Atmospheric Chemistry', 'Atmospheric Radiation', 'Air Quality', 'Atmospheric Water Vapor', 'Atmospheric Pressure', 'Clouds', 'Ocean Temperature', 'Precipitation', 'Atmospheric Temperature', 'Surface Radiative Properties'}
# {'Clouds', 'Atmospheric Water Vapor'}
# {'Atmospheric Chemistry'}
# {'Precipitation'}
# {'Atmospheric Temperature'}
# {'Surface Radiative Properties', 'Surface Thermal Properties', 'Vegetation', 'Atmospheric Radiation', 'Atmospheric Water Vapor', 'Surface Water', 'Snow/Ice', 'Precipitation', 'Atmospheric Temperature', 'Soils'}
# {'Atmospheric Chemistry'}
# {'Atmospheric Chemistry'}
# {'Atmosphere'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Ecological Dynamics'}
# {'Altitude', 'Surface Thermal Properties', 'Atmospheric Chemistry', 'Atmospheric Radiation', 'Air Quality', 'Atmospheric Water Vapor', 'Atmospheric Pressure', 'Clouds', 'Ocean Temperature', 'Atmospheric Temperature', 'Surface Radiative Properties'}
# {'Atmosphere'}
# {'Altitude', 'Atmospheric Chemistry', 'Atmosphere', 'Atmospheric Water Vapor', 'Atmospheric Winds', 'Atmospheric Pressure', 'Atmospheric Temperature'}
# {'Surface Thermal Properties', 'Atmospheric Radiation', 'Atmospheric Winds', 'Atmospheric Water Vapor', 'Atmospheric Pressure', 'Precipitation', 'Atmospheric Temperature'}
# {'Visible Wavelengths', 'Infrared Wavelengths', 'Platform Characteristics', 'Sensor Characteristics'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Infrared Wavelengths'}
# {'Precipitation', 'Atmosphere'}
# {'Altitude', 'Surface Thermal Properties', 'Atmospheric Chemistry', 'Atmospheric Radiation', 'Air Quality', 'Atmospheric Water Vapor', 'Atmospheric Pressure', 'Clouds', 'Ocean Temperature', 'Precipitation', 'Atmospheric Temperature', 'Surface Radiative Properties'}
# {'Atmospheric Water Vapor', 'Atmospheric Chemistry'}
# {'Surface Thermal Properties', 'Atmospheric Radiation', 'Atmospheric Winds', 'Atmospheric Water Vapor', 'Surface Water', 'Atmospheric Pressure', 'Snow/Ice', 'Precipitation', 'Atmospheric Temperature', 'Soils'}
# {'Infrared Wavelengths', 'Atmospheric Chemistry'}
# {'Atmospheric Radiation'}
# {'Atmospheric Chemistry', 'Atmosphere', 'Atmospheric Water Vapor', 'Atmospheric Pressure', 'Clouds', 'Atmospheric Temperature'}
# {'Atmospheric Chemistry'}
# {'Aerosols', 'Atmospheric Chemistry', 'Atmospheric Radiation'}
# {'Surface Radiative Properties', 'Surface Thermal Properties', 'Vegetation', 'Atmospheric Radiation', 'Atmospheric Water Vapor', 'Surface Water', 'Snow/Ice', 'Precipitation', 'Atmospheric Temperature', 'Soils'}
# {'Air Quality'}
# {'Atmospheric Chemistry'}
# {'Glaciers/Ice Sheets', 'Surface Radiative Properties', 'Snow/Ice'}
# {'Atmosphere'}
# {'Atmospheric Chemistry', 'Air Quality', 'Atmosphere'}
# {'Atmospheric Radiation'}
# {'Visible Wavelengths', 'Infrared Wavelengths', 'Platform Characteristics', 'Sensor Characteristics'}
# {'Atmospheric Chemistry'}
# {'Atmospheric Chemistry'}
# {'Surface Thermal Properties', 'Atmospheric Radiation', 'Atmospheric Winds', 'Atmospheric Water Vapor', 'Ocean Heat Budget', 'Ocean Pressure', 'Ocean Temperature', 'Atmospheric Temperature'}
# {'Atmospheric Water Vapor'}
# {'Atmospheric Chemistry'}
# {'Atmospheric Radiation', 'Atmospheric Water Vapor', 'Clouds', 'Precipitation', 'Atmospheric Temperature'}
# {'Aerosols', 'Atmospheric Chemistry', 'Air Quality'}
# {'Clouds'}
# {'Altitude'}
# {'Precipitation', 'Radar'}
# {'Atmospheric Chemistry'}
# {'Altitude', 'Surface Thermal Properties', 'Atmospheric Chemistry', 'Air Quality', 'Atmospheric Radiation', 'Atmospheric Water Vapor', 'Atmospheric Pressure', 'Clouds', 'Ocean Temperature', 'Precipitation', 'Atmospheric Temperature', 'Surface Radiative Properties'}
# {'Platform Characteristics', 'Sensor Characteristics', 'Atmospheric Radiation'}
# {'Platform Characteristics', 'Spectral/Engineering', 'Atmospheric Radiation', 'Sensor Characteristics'}
# {'Soils', 'Surface Thermal Properties', 'Vegetation'}
# {'Surface Thermal Properties', 'Atmospheric Radiation', 'Atmospheric Winds', 'Atmospheric Water Vapor', 'Surface Water', 'Atmospheric Pressure', 'Snow/Ice', 'Precipitation', 'Atmospheric Temperature', 'Soils'}
# {'Atmospheric Chemistry', 'Ocean Chemistry'}
# {'Atmospheric Chemistry'}
# {'Atmospheric Chemistry', 'Air Quality', 'Atmosphere'}
# {'Atmospheric Chemistry', 'Ocean Chemistry'}
# {'Atmospheric Temperature'}
# {'Platform Characteristics'}
# {'Atmospheric Water Vapor', 'Precipitation'}
# {'Atmospheric Chemistry'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Infrared Wavelengths'}
# {'Ultraviolet Wavelengths'}
# {'Radar'}
# {'Atmospheric Radiation', 'Atmospheric Water Vapor', 'Clouds', 'Precipitation', 'Atmospheric Temperature'}
# {'Atmospheric Chemistry'}
# {'Infrared Wavelengths', 'Visible Wavelengths'}
# {'Atmospheric Chemistry'}
# {'Surface Radiative Properties', 'Surface Thermal Properties', 'Vegetation', 'Atmospheric Radiation', 'Atmospheric Water Vapor', 'Surface Water', 'Snow/Ice', 'Precipitation', 'Atmospheric Temperature', 'Soils'}
# {'Clouds'}
# {'Atmospheric Chemistry'}
# {'Atmospheric Chemistry'}
# {'Atmospheric Chemistry'}
# {'Aerosols', 'Atmospheric Radiation', 'Clouds'}
# {'Atmospheric Radiation', 'Sensor Characteristics', 'Ultraviolet Wavelengths', 'Platform Characteristics', 'Spectral/Engineering'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Infrared Wavelengths', 'Atmospheric Chemistry'}
# {'Atmosphere'}
# {'Ecological Dynamics'}
# {'Altitude', 'Surface Thermal Properties', 'Atmospheric Radiation', 'Atmospheric Water Vapor', 'Atmospheric Winds', 'Atmospheric Pressure', 'Precipitation', 'Atmospheric Temperature'}
# {'Atmospheric Chemistry', 'Air Quality', 'Atmosphere', 'Atmospheric Water Vapor', 'Atmospheric Pressure', 'Aerosols'}
# {'Altitude', 'Surface Thermal Properties', 'Atmospheric Chemistry', 'Atmospheric Radiation', 'Air Quality', 'Atmospheric Water Vapor', 'Atmospheric Pressure', 'Clouds', 'Ocean Temperature', 'Precipitation', 'Atmospheric Temperature', 'Surface Radiative Properties'}
# {'Altitude', 'Surface Thermal Properties', 'Atmospheric Chemistry', 'Air Quality', 'Atmospheric Radiation', 'Atmospheric Water Vapor', 'Atmospheric Pressure', 'Clouds', 'Ocean Temperature', 'Atmospheric Temperature', 'Surface Radiative Properties'}
# {'Atmospheric Chemistry', 'Ocean Chemistry'}
# {'Atmospheric Water Vapor'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Atmospheric Chemistry'}
# {'Surface Thermal Properties', 'Atmospheric Radiation', 'Atmospheric Winds', 'Atmospheric Water Vapor', 'Surface Water', 'Atmospheric Pressure', 'Snow/Ice', 'Precipitation', 'Atmospheric Temperature', 'Soils'}
# {'Surface Thermal Properties', 'Atmospheric Radiation', 'Atmospheric Winds', 'Atmospheric Water Vapor', 'Ocean Heat Budget', 'Ocean Pressure', 'Ocean Temperature', 'Atmospheric Temperature'}
# {'Aerosols', 'Atmospheric Water Vapor', 'Atmospheric Temperature', 'Atmospheric Chemistry'}
# {'Atmospheric Water Vapor'}
# {'Atmospheric Chemistry'}
# {'Atmospheric Chemistry'}
# {'Atmospheric Water Vapor'}
# {'Atmospheric Chemistry'}
# {'Atmosphere'}
# {'Atmospheric Water Vapor'}
# {'Atmospheric Temperature'}
# {'Atmosphere'}
# {'Atmospheric Radiation'}
# {'Surface Thermal Properties', 'Atmospheric Radiation', 'Atmospheric Water Vapor', 'Surface Water', 'Atmospheric Pressure', 'Snow/Ice', 'Precipitation', 'Atmospheric Temperature', 'Soils'}
# {'Atmospheric Radiation', 'Atmospheric Water Vapor', 'Clouds', 'Precipitation', 'Atmospheric Temperature'}
# {'Aerosols'}
# {'Infrared Wavelengths'}
# {'Atmospheric Chemistry'}
# {'Soils', 'Surface Thermal Properties', 'Vegetation'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Atmospheric Radiation'}
# {'Atmospheric Chemistry'}
# {'Atmospheric Chemistry'}
# {'Clouds', 'Atmospheric Pressure', 'Atmospheric Water Vapor'}
# {'Atmospheric Chemistry'}
# {'Atmospheric Chemistry'}
# {'Atmosphere'}
# {'Atmospheric Radiation'}
# {'Atmospheric Radiation', 'Atmospheric Water Vapor', 'Clouds', 'Precipitation', 'Atmospheric Temperature'}
# {'Clouds', 'Atmospheric Water Vapor', 'Atmospheric Temperature'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Aerosols', 'Infrared Wavelengths', 'Atmospheric Chemistry'}
# {'Atmospheric Water Vapor'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Surface Thermal Properties', 'Atmospheric Radiation', 'Atmospheric Winds', 'Atmospheric Water Vapor', 'Surface Water', 'Atmospheric Pressure', 'Snow/Ice', 'Precipitation', 'Atmospheric Temperature', 'Soils'}
# {'Atmospheric Radiation'}
# {'Atmospheric Chemistry', 'Atmosphere', 'Microwave', 'Atmospheric Water Vapor', 'Clouds'}
# {'Precipitation', 'Radar'}
# {'Atmospheric Chemistry'}
# {'Atmosphere'}
# {'Atmospheric Chemistry', 'Atmosphere'}
# {'Surface Thermal Properties', 'Atmospheric Chemistry', 'Atmospheric Radiation', 'Microwave', 'Sea Surface Topography', 'Atmospheric Water Vapor', 'Infrared Wavelengths', 'Atmospheric Pressure', 'Ocean Pressure', 'Clouds', 'Ocean Temperature', 'Precipitation', 'Atmospheric Temperature'}
# {'Atmospheric Chemistry'}
# {'Altitude', 'Surface Thermal Properties', 'Atmospheric Chemistry', 'Air Quality', 'Atmospheric Radiation', 'Atmospheric Water Vapor', 'Atmospheric Pressure', 'Clouds', 'Ocean Temperature', 'Atmospheric Temperature', 'Surface Radiative Properties'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Atmospheric Chemistry'}
# {'Atmosphere'}
# {'Atmospheric Chemistry', 'Atmosphere', 'Microwave', 'Atmospheric Water Vapor', 'Clouds'}
# {'Visible Wavelengths', 'Infrared Wavelengths', 'Platform Characteristics', 'Sensor Characteristics'}
# {'Surface Thermal Properties', 'Atmospheric Radiation', 'Atmospheric Winds', 'Atmospheric Water Vapor', 'Surface Water', 'Atmospheric Pressure', 'Snow/Ice', 'Precipitation', 'Atmospheric Temperature', 'Soils'}
# {'Infrared Wavelengths'}
# {'Atmosphere'}
# {'Atmospheric Radiation', 'Atmospheric Water Vapor', 'Clouds', 'Precipitation', 'Atmospheric Temperature'}
# {'Atmosphere'}
# {'Atmospheric Chemistry'}
# {'Atmospheric Chemistry'}
# {'Surface Thermal Properties', 'Atmospheric Radiation', 'Atmospheric Winds', 'Atmospheric Water Vapor', 'Surface Water', 'Atmospheric Pressure', 'Snow/Ice', 'Precipitation', 'Atmospheric Temperature', 'Soils'}
# {'Atmosphere'}
# {'Infrared Wavelengths', 'Atmospheric Chemistry'}
# {'Vegetation', 'Surface Thermal Properties', 'Soils'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmospheric Chemistry'}
# {'Atmospheric Chemistry'}
# {'Altitude', 'Surface Thermal Properties', 'Atmospheric Radiation', 'Atmospheric Water Vapor', 'Atmospheric Winds', 'Atmospheric Pressure', 'Precipitation', 'Atmospheric Temperature'}
# {'Altitude'}
# {'Precipitation', 'Infrared Wavelengths'}
# {'Atmospheric Chemistry'}
# {'Atmospheric Chemistry'}
# {'Atmospheric Chemistry'}
# {'Atmospheric Chemistry'}
# {'Aerosols'}
# {'Atmospheric Chemistry'}
# {'Solar Activity'}
# {'Surface Thermal Properties', 'Atmospheric Radiation', 'Atmosphere', 'Atmospheric Water Vapor', 'Atmospheric Pressure', 'Clouds', 'Precipitation', 'Atmospheric Temperature'}
# {'Atmospheric Winds'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Atmospheric Radiation', 'Sensor Characteristics', 'Ultraviolet Wavelengths', 'Platform Characteristics', 'Spectral/Engineering'}
# {'Atmosphere'}
# {'Aerosols', 'Natural Hazards', 'Atmospheric Chemistry', 'Air Quality'}
# {'Atmospheric Water Vapor'}
# {'Aerosols', 'Atmospheric Radiation', 'Clouds'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Atmosphere'}
# {'Surface Thermal Properties', 'Atmospheric Chemistry', 'Atmosphere', 'Atmospheric Water Vapor', 'Atmospheric Temperature'}
# {'Surface Thermal Properties', 'Atmospheric Chemistry', 'Atmosphere', 'Atmospheric Winds', 'Atmospheric Water Vapor', 'Clouds', 'Atmospheric Pressure', 'Ocean Pressure', 'Atmospheric Temperature'}
# {'Atmospheric Chemistry'}
# {'Surface Thermal Properties', 'Atmospheric Chemistry', 'Atmospheric Radiation', 'Atmospheric Water Vapor', 'Atmospheric Pressure', 'Clouds', 'Ocean Temperature', 'Precipitation', 'Atmospheric Temperature'}
# {'Atmospheric Radiation'}
# {'Atmospheric Chemistry'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Infrared Wavelengths'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Atmospheric Radiation', 'Atmospheric Water Vapor', 'Clouds', 'Precipitation', 'Atmospheric Temperature'}
# {'Surface Thermal Properties', 'Atmospheric Radiation', 'Atmospheric Winds', 'Atmospheric Water Vapor', 'Surface Water', 'Atmospheric Pressure', 'Snow/Ice', 'Precipitation', 'Atmospheric Temperature', 'Soils'}
# {'Infrared Wavelengths', 'Visible Wavelengths'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Atmospheric Chemistry'}
# {'Clouds', 'Precipitation', 'Atmospheric Water Vapor', 'Atmospheric Radiation'}
# {'Surface Thermal Properties', 'Atmospheric Radiation', 'Atmospheric Winds', 'Atmospheric Water Vapor', 'Ocean Heat Budget', 'Ocean Pressure', 'Ocean Temperature', 'Atmospheric Temperature'}
# {'Aerosols'}
# {'Atmospheric Chemistry'}
# {'Infrared Wavelengths', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmospheric Temperature'}
# {'Aerosols', 'Natural Hazards', 'Atmospheric Chemistry', 'Air Quality'}
# {'Atmosphere'}
# {'Surface Thermal Properties', 'Atmospheric Radiation', 'Atmospheric Winds', 'Atmospheric Water Vapor', 'Surface Water', 'Atmospheric Pressure', 'Snow/Ice', 'Precipitation', 'Atmospheric Temperature', 'Soils'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Aerosols'}
# {'Atmospheric Chemistry'}
# {'Atmospheric Chemistry'}
# {'Altitude', 'Surface Thermal Properties', 'Atmospheric Chemistry', 'Air Quality', 'Atmospheric Radiation', 'Atmospheric Water Vapor', 'Atmospheric Pressure', 'Clouds', 'Ocean Temperature', 'Atmospheric Temperature', 'Surface Radiative Properties'}
# {'Atmosphere'}
# {'Atmospheric Temperature'}
# {'Atmospheric Chemistry', 'Atmosphere'}
# {'Solar Activity'}
# {'Atmospheric Chemistry', 'Atmosphere'}
# {'Atmospheric Chemistry', 'Ocean Chemistry'}
# {'Altitude', 'Surface Thermal Properties', 'Atmospheric Chemistry', 'Atmospheric Radiation', 'Air Quality', 'Atmospheric Water Vapor', 'Atmospheric Pressure', 'Clouds', 'Ocean Temperature', 'Precipitation', 'Atmospheric Temperature', 'Surface Radiative Properties'}
# {'Infrared Wavelengths'}
# {'Surface Thermal Properties', 'Atmospheric Radiation', 'Atmospheric Water Vapor', 'Atmospheric Winds', 'Ocean Heat Budget', 'Ocean Pressure', 'Ocean Temperature', 'Atmospheric Temperature'}
# {'Atmospheric Water Vapor'}
# {'Atmospheric Chemistry'}
# {'Altitude', 'Surface Thermal Properties', 'Atmospheric Chemistry', 'Atmospheric Radiation', 'Air Quality', 'Atmospheric Water Vapor', 'Infrared Wavelengths', 'Atmospheric Pressure', 'Clouds', 'Ocean Temperature', 'Precipitation', 'Atmospheric Temperature', 'Surface Radiative Properties'}
# {'Aerosols'}
# {'Clouds'}
# {'Atmospheric Radiation', 'Atmospheric Water Vapor', 'Clouds', 'Precipitation', 'Atmospheric Temperature'}
# {'Clouds', 'Precipitation'}
# {'Atmospheric Radiation', 'Atmospheric Water Vapor', 'Clouds', 'Precipitation', 'Atmospheric Temperature'}
# {'Infrared Wavelengths', 'Atmospheric Chemistry'}
# {'Surface Thermal Properties', 'Atmospheric Radiation', 'Atmospheric Winds', 'Atmospheric Water Vapor', 'Atmospheric Pressure', 'Precipitation', 'Atmospheric Temperature'}
# {'Atmospheric Chemistry'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Atmospheric Temperature'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Atmospheric Pressure', 'Precipitation'}
# {'Ultraviolet Wavelengths'}
# {'Atmospheric Temperature'}
# {'Visible Wavelengths'}
# {'Aerosols', 'Atmospheric Radiation', 'Clouds'}
# {'Atmosphere'}
# {'Aerosols', 'Atmospheric Radiation'}
# {'Infrared Wavelengths'}
# {'Altitude'}
# {'Altitude', 'Surface Thermal Properties', 'Atmospheric Chemistry', 'Air Quality', 'Atmospheric Radiation', 'Atmospheric Water Vapor', 'Atmospheric Pressure', 'Clouds', 'Ocean Temperature', 'Precipitation', 'Atmospheric Temperature', 'Surface Radiative Properties'}
# {'Atmospheric Radiation'}
# {'Atmospheric Radiation'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Ultraviolet Wavelengths'}
# {'Precipitation'}
# {'Atmospheric Chemistry'}
# {'Altitude', 'Surface Thermal Properties', 'Atmospheric Chemistry', 'Atmospheric Radiation', 'Air Quality', 'Atmospheric Water Vapor', 'Atmospheric Pressure', 'Clouds', 'Ocean Temperature', 'Precipitation', 'Atmospheric Temperature', 'Surface Radiative Properties'}
# {'Atmospheric Water Vapor'}
# {'Surface Radiative Properties', 'Surface Thermal Properties', 'Vegetation', 'Atmospheric Radiation', 'Atmospheric Water Vapor', 'Surface Water', 'Snow/Ice', 'Precipitation', 'Atmospheric Temperature', 'Soils'}
# {'Microwave', 'Infrared Wavelengths'}
# {'Atmospheric Chemistry'}
# {'Atmospheric Radiation', 'Atmospheric Water Vapor', 'Clouds', 'Precipitation', 'Atmospheric Temperature'}
# {'Precipitation', 'Radar'}
# {'Protists', 'Ocean Temperature', 'Ocean Optics', 'Ocean Chemistry'}
# {'Atmospheric Chemistry'}
# {'Aerosols', 'Atmospheric Radiation', 'Clouds'}
# {'Visible Wavelengths'}
# {'Atmosphere'}
# {'Aerosols', 'Atmospheric Chemistry', 'Air Quality'}
# {'Infrared Wavelengths', 'Atmospheric Temperature', 'Atmospheric Chemistry'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Altitude'}
# {'Altitude', 'Surface Thermal Properties', 'Atmospheric Chemistry', 'Atmospheric Radiation', 'Air Quality', 'Atmospheric Water Vapor', 'Atmospheric Pressure', 'Clouds', 'Ocean Temperature', 'Precipitation', 'Atmospheric Temperature', 'Surface Radiative Properties'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Aerosols', 'Atmospheric Radiation', 'Clouds'}
# {'Atmospheric Radiation', 'Atmosphere', 'Atmospheric Water Vapor', 'Surface Water', 'Terrestrial Hydrosphere', 'Soils'}
# {'Atmospheric Chemistry'}
# {'Surface Thermal Properties', 'Atmospheric Chemistry', 'Atmospheric Radiation', 'Atmospheric Water Vapor', 'Atmospheric Pressure', 'Clouds', 'Ocean Temperature', 'Precipitation', 'Atmospheric Temperature'}
# {'Atmosphere'}
# {'Surface Thermal Properties', 'Atmospheric Radiation', 'Atmospheric Winds', 'Atmospheric Water Vapor', 'Surface Water', 'Atmospheric Pressure', 'Snow/Ice', 'Precipitation', 'Atmospheric Temperature', 'Soils'}
# {'Altitude', 'Surface Thermal Properties', 'Atmospheric Chemistry', 'Air Quality', 'Atmospheric Radiation', 'Atmospheric Water Vapor', 'Atmospheric Pressure', 'Clouds', 'Ocean Temperature', 'Atmospheric Temperature', 'Surface Radiative Properties'}
# {'Air Quality'}
# {'Clouds', 'Atmosphere'}
# {'Atmospheric Chemistry'}
# {'Atmospheric Chemistry', 'Atmosphere'}
# {'Atmospheric Chemistry'}
# {'Atmospheric Chemistry'}
# {'Atmospheric Radiation', 'Atmospheric Water Vapor', 'Clouds', 'Precipitation', 'Atmospheric Temperature'}
# {'Atmospheric Radiation'}
# {'Atmospheric Chemistry'}
# {'Atmospheric Radiation', 'Sensor Characteristics', 'Ultraviolet Wavelengths', 'Platform Characteristics', 'Spectral/Engineering'}
# {'Atmospheric Chemistry'}
# {'Surface Thermal Properties', 'Atmospheric Radiation', 'Atmospheric Winds', 'Atmospheric Water Vapor', 'Ocean Heat Budget', 'Ocean Pressure', 'Ocean Temperature', 'Atmospheric Temperature'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Precipitation', 'Atmosphere'}
# {'Infrared Wavelengths'}
# {'Surface Thermal Properties', 'Atmospheric Radiation', 'Atmospheric Winds', 'Atmospheric Water Vapor', 'Surface Water', 'Atmospheric Pressure', 'Snow/Ice', 'Precipitation', 'Atmospheric Temperature', 'Soils'}
# {'Aerosols', 'Atmospheric Radiation', 'Clouds'}
# {'Atmospheric Chemistry'}
# {'Solar Activity'}
# {'Atmospheric Water Vapor'}
# {'Atmospheric Chemistry', 'Atmosphere', 'Microwave', 'Atmospheric Water Vapor', 'Clouds'}
# {'Atmosphere'}
# {'Infrared Wavelengths', 'Atmospheric Temperature'}
# {'Atmospheric Chemistry'}
# {'Altitude', 'Surface Thermal Properties', 'Atmospheric Chemistry', 'Atmospheric Radiation', 'Air Quality', 'Atmospheric Water Vapor', 'Atmospheric Pressure', 'Clouds', 'Ocean Temperature', 'Precipitation', 'Atmospheric Temperature', 'Surface Radiative Properties'}
# {'Infrared Wavelengths'}
# {'Infrared Wavelengths', 'Atmospheric Chemistry'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Atmospheric Chemistry'}
# {'Atmospheric Chemistry', 'Atmospheric Radiation'}
# {'Atmosphere'}
# {'Atmospheric Chemistry'}
# {'Solar Energetic Particle Properties'}
# {'Atmospheric Chemistry'}
# {'Atmospheric Chemistry'}
# {'Atmospheric Chemistry'}
# {'Atmospheric Chemistry'}
# {'Altitude', 'Atmospheric Chemistry', 'Atmospheric Water Vapor', 'Atmospheric Winds', 'Atmospheric Pressure', 'Ocean Pressure', 'Atmospheric Temperature'}
# {'Surface Thermal Properties', 'Atmospheric Radiation', 'Atmosphere', 'Atmospheric Water Vapor', 'Atmospheric Pressure', 'Clouds', 'Precipitation', 'Atmospheric Temperature'}
# {'Precipitation', 'Atmosphere'}
# {'Atmospheric Radiation'}
# {'Atmospheric Chemistry', 'Vegetation'}
# {'Atmospheric Radiation', 'Atmospheric Water Vapor', 'Clouds', 'Precipitation', 'Atmospheric Temperature'}
# {'Atmospheric Radiation', 'Atmospheric Water Vapor', 'Clouds', 'Precipitation', 'Atmospheric Temperature'}
# {'Atmospheric Chemistry'}
# {'Atmospheric Chemistry'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Atmospheric Chemistry'}
# {'Atmosphere'}
# {'Atmospheric Chemistry'}
# {'Microwave', 'Infrared Wavelengths'}
# {'Infrared Wavelengths'}
# {'Atmospheric Chemistry', 'Air Quality'}
# {'Atmosphere'}
# {'Ultraviolet Wavelengths'}
# {'Altitude', 'Atmospheric Temperature', 'Atmospheric Chemistry', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmospheric Chemistry'}
# {'Microwave', 'Atmospheric Water Vapor', 'Atmospheric Temperature', 'Infrared Wavelengths'}
# {'Atmospheric Water Vapor', 'Surface Water', 'Precipitation', 'Atmospheric Temperature', 'Soils'}
# {'Clouds'}
# {'Solar Activity'}
# {'Solar Activity'}
# {'Atmospheric Chemistry'}
# {'Atmosphere'}
# {'Atmospheric Water Vapor'}
# {'Infrared Wavelengths', 'Visible Wavelengths'}
# {'Soils'}
# {'Atmospheric Temperature'}
# {'Atmospheric Water Vapor', 'Precipitation'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Altitude', 'Surface Thermal Properties', 'Atmospheric Chemistry', 'Atmospheric Radiation', 'Air Quality', 'Atmospheric Water Vapor', 'Atmospheric Pressure', 'Clouds', 'Ocean Temperature', 'Atmospheric Temperature', 'Surface Radiative Properties'}
# {'Precipitation', 'Atmospheric Temperature'}
# {'Precipitation'}
# {'Atmospheric Chemistry', 'Atmospheric Radiation'}
# {'Aerosols'}
# {'Precipitation', 'Atmosphere'}
# {'Altitude'}
# {'Atmospheric Chemistry'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Vegetation', 'Surface Thermal Properties', 'Soils'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Atmospheric Chemistry', 'Atmosphere'}
# {'Atmospheric Chemistry', 'Ocean Chemistry'}
# {'Solar Activity'}
# {'Atmospheric Chemistry', 'Atmospheric Radiation'}
# {'Atmospheric Winds', 'Atmospheric Temperature', 'Atmospheric Radiation'}
# {'Altitude', 'Atmospheric Chemistry', 'Atmospheric Water Vapor', 'Clouds', 'Aerosols', 'Atmospheric Temperature'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Atmospheric Radiation', 'Sensor Characteristics', 'Ultraviolet Wavelengths', 'Platform Characteristics', 'Spectral/Engineering'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Atmospheric Chemistry'}
# {'Atmospheric Chemistry'}
# {'Atmospheric Chemistry'}
# {'Atmosphere'}
# {'Atmospheric Water Vapor'}
# {'Atmospheric Radiation'}
# {'Atmosphere'}
# {'Atmospheric Radiation'}
# {'Precipitation'}
# {'Atmosphere'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Atmosphere'}
# {'Tectonics', 'Atmospheric Chemistry', 'Air Quality', 'Atmosphere', 'Aerosols'}
# {'Atmospheric Chemistry', 'Atmosphere'}
# {'Clouds', 'Surface Radiative Properties'}
# {'Infrared Wavelengths'}
# {'Altitude', 'Atmospheric Pressure', 'Atmospheric Temperature', 'Atmosphere'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Altitude', 'Surface Thermal Properties', 'Topography', 'Atmospheric Radiation', 'Atmospheric Water Vapor', 'Atmospheric Winds', 'Terrestrial Hydrosphere', 'Ocean Heat Budget', 'Precipitation', 'Atmospheric Temperature', 'Sea Ice'}
# {'Atmospheric Chemistry'}
# {'Atmosphere'}
# {'Atmospheric Chemistry'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Surface Thermal Properties', 'Atmospheric Radiation', 'Atmosphere', 'Atmospheric Water Vapor', 'Atmospheric Pressure', 'Clouds', 'Precipitation', 'Atmospheric Temperature'}
# {'Atmosphere'}
# {'Ecosystems', 'Soils'}
# {'Clouds', 'Atmospheric Water Vapor'}
# {'Atmospheric Chemistry'}
# {'Atmospheric Chemistry'}
# {'Atmospheric Chemistry'}
# {'Terrestrial Hydrosphere', 'Precipitation', 'Atmospheric Radiation'}
# {'Visible Wavelengths', 'Infrared Wavelengths', 'Platform Characteristics', 'Sensor Characteristics'}
# {'Atmospheric Chemistry', 'Atmospheric Radiation'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Atmospheric Temperature'}
# {'Microwave'}
# {'Microwave', 'Infrared Wavelengths'}
# {'Atmospheric Radiation'}
# {'Atmospheric Temperature'}
# {'Atmospheric Radiation', 'Atmospheric Water Vapor', 'Clouds', 'Precipitation', 'Atmospheric Temperature'}
# {'Clouds'}
# {'Solar Activity'}
# {'Infrared Wavelengths', 'Visible Wavelengths'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Infrared Wavelengths'}
# {'Atmospheric Chemistry'}
# {'Surface Thermal Properties', 'Atmospheric Radiation', 'Atmospheric Winds', 'Atmospheric Water Vapor', 'Ocean Heat Budget', 'Ocean Pressure', 'Ocean Temperature', 'Atmospheric Temperature'}
# {'Aerosols', 'Atmospheric Chemistry', 'Atmospheric Radiation'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Atmospheric Radiation', 'Sensor Characteristics', 'Ultraviolet Wavelengths', 'Platform Characteristics', 'Spectral/Engineering'}
# {'Atmospheric Chemistry'}
# {'Atmosphere'}
# {'Clouds', 'Atmospheric Water Vapor', 'Atmospheric Temperature'}
# {'Aerosols', 'Atmospheric Chemistry', 'Atmospheric Radiation'}
# {'Atmospheric Radiation', 'Atmosphere', 'Atmospheric Water Vapor', 'Terrestrial Hydrosphere', 'Clouds'}
# {'Infrared Wavelengths'}
# {'Atmospheric Chemistry'}
# {'Surface Thermal Properties', 'Atmospheric Radiation', 'Atmospheric Winds', 'Atmospheric Water Vapor', 'Ocean Heat Budget', 'Ocean Pressure', 'Ocean Temperature', 'Atmospheric Temperature'}
# {'Aerosols'}
# {'Atmospheric Radiation', 'Atmospheric Water Vapor', 'Clouds', 'Precipitation', 'Atmospheric Temperature'}
# {'Atmospheric Chemistry'}
# {'Atmosphere'}
# {'Aerosols', 'Infrared Wavelengths', 'Atmospheric Chemistry'}
# {'Atmosphere'}
# {'Atmospheric Chemistry'}
# {'Atmospheric Chemistry'}
# {'Infrared Wavelengths', 'Visible Wavelengths'}
# {'Surface Radiative Properties', 'Surface Thermal Properties', 'Vegetation', 'Atmospheric Radiation', 'Atmospheric Water Vapor', 'Surface Water', 'Snow/Ice', 'Precipitation', 'Atmospheric Temperature', 'Soils'}
# {'Atmosphere'}
# {'Atmospheric Chemistry'}
# {'Solar Activity'}
# {'Atmosphere'}
# {'Altitude', 'Surface Thermal Properties', 'Atmospheric Chemistry', 'Atmospheric Radiation', 'Air Quality', 'Atmospheric Water Vapor', 'Atmospheric Pressure', 'Clouds', 'Ocean Temperature', 'Precipitation', 'Atmospheric Temperature', 'Surface Radiative Properties'}
# {'Altitude', 'Surface Thermal Properties', 'Atmospheric Chemistry', 'Atmospheric Radiation', 'Air Quality', 'Atmospheric Water Vapor', 'Atmospheric Pressure', 'Clouds', 'Ocean Temperature', 'Precipitation', 'Atmospheric Temperature', 'Surface Radiative Properties'}
# {'Aerosols'}
# {'Atmosphere'}
# {'Precipitation', 'Radar'}
# {'Atmospheric Chemistry'}
# {'Surface Thermal Properties', 'Atmospheric Radiation', 'Atmospheric Winds', 'Atmospheric Water Vapor', 'Surface Water', 'Atmospheric Pressure', 'Snow/Ice', 'Precipitation', 'Atmospheric Temperature', 'Soils'}
# {'Microwave', 'Infrared Wavelengths'}
# {'Paleoclimate Indicators', 'Natural Hazards', 'Atmospheric Chemistry', 'Air Quality'}
# {'Precipitation', 'Radar'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Surface Thermal Properties', 'Atmospheric Chemistry', 'Atmospheric Radiation', 'Atmospheric Water Vapor', 'Clouds', 'Ocean Temperature', 'Precipitation', 'Atmospheric Temperature'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Precipitation', 'Atmospheric Temperature'}
# {'Surface Thermal Properties', 'Atmospheric Radiation', 'Atmospheric Winds', 'Atmospheric Water Vapor', 'Atmospheric Pressure', 'Precipitation', 'Atmospheric Temperature'}
# {'Infrared Wavelengths', 'Atmosphere'}
# {'Clouds', 'Atmosphere'}
# {'Clouds', 'Atmospheric Water Vapor', 'Atmospheric Temperature'}
# {'Atmospheric Winds', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmospheric Chemistry'}
# {'Atmosphere'}
# {'Infrared Wavelengths'}
# {'Solar Activity'}
# {'Atmospheric Radiation', 'Atmospheric Water Vapor', 'Clouds', 'Precipitation', 'Atmospheric Temperature'}
# {'Atmospheric Chemistry'}
# {'Surface Thermal Properties', 'Atmospheric Radiation', 'Atmospheric Winds', 'Atmospheric Water Vapor', 'Ocean Heat Budget', 'Ocean Pressure', 'Ocean Temperature', 'Atmospheric Temperature'}
# {'Altitude'}
# {'Aerosols'}
# {'Altitude', 'Surface Thermal Properties', 'Atmospheric Chemistry', 'Air Quality', 'Atmospheric Radiation', 'Atmospheric Water Vapor', 'Atmospheric Pressure', 'Clouds', 'Ocean Temperature', 'Atmospheric Temperature', 'Surface Radiative Properties'}
# {'Atmospheric Chemistry'}
# {'Infrared Wavelengths'}
# {'Altitude', 'Surface Thermal Properties', 'Atmospheric Chemistry', 'Atmospheric Radiation', 'Air Quality', 'Atmospheric Water Vapor', 'Atmospheric Pressure', 'Clouds', 'Ocean Temperature', 'Precipitation', 'Atmospheric Temperature', 'Surface Radiative Properties'}
# {'Atmospheric Chemistry'}
# {'Altitude', 'Atmospheric Pressure', 'Atmospheric Winds', 'Atmospheric Temperature'}
# {'Infrared Wavelengths'}
# {'Infrared Wavelengths', 'Atmosphere'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Surface Thermal Properties', 'Atmospheric Chemistry', 'Atmosphere', 'Atmospheric Winds', 'Atmospheric Water Vapor', 'Clouds', 'Atmospheric Pressure', 'Ocean Pressure', 'Atmospheric Temperature'}
# {'Surface Thermal Properties', 'Atmospheric Radiation', 'Atmospheric Winds', 'Atmospheric Water Vapor', 'Surface Water', 'Atmospheric Pressure', 'Snow/Ice', 'Precipitation', 'Atmospheric Temperature', 'Soils'}
# {'Atmospheric Chemistry'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Atmospheric Water Vapor'}
# {'Atmosphere'}
# {'Ecological Dynamics'}
# {'Natural Hazards'}
# {'Atmospheric Chemistry', 'Atmosphere'}
# {'Altitude', 'Atmospheric Water Vapor', 'Atmospheric Winds', 'Atmospheric Pressure', 'Precipitation', 'Atmospheric Temperature'}
# {'Surface Thermal Properties', 'Atmospheric Chemistry', 'Atmospheric Radiation', 'Atmospheric Water Vapor', 'Atmospheric Pressure', 'Ocean Pressure', 'Clouds', 'Ocean Temperature', 'Precipitation', 'Atmospheric Temperature'}
# {'Altitude', 'Atmospheric Pressure', 'Atmospheric Temperature', 'Atmosphere'}
# {'Atmospheric Radiation'}
# {'Atmosphere'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Atmospheric Radiation', 'Sensor Characteristics', 'Ultraviolet Wavelengths', 'Platform Characteristics', 'Spectral/Engineering'}
# {'Clouds'}
# {'Atmosphere'}
# {'Altitude', 'Atmospheric Winds', 'Atmospheric Temperature'}
# {'Atmospheric Radiation', 'Atmospheric Water Vapor', 'Clouds', 'Precipitation', 'Atmospheric Temperature'}
# {'Altitude', 'Atmospheric Chemistry', 'Atmosphere', 'Atmospheric Winds', 'Atmospheric Water Vapor', 'Clouds', 'Atmospheric Pressure', 'Ocean Pressure', 'Atmospheric Temperature'}
# {'Infrared Wavelengths'}
# {'Atmospheric Chemistry'}
# {'Visible Wavelengths'}
# {'Surface Thermal Properties', 'Atmospheric Chemistry', 'Atmospheric Radiation', 'Air Quality', 'Atmosphere', 'Atmospheric Water Vapor', 'Clouds', 'Ocean Temperature', 'Atmospheric Temperature'}
# {'Atmospheric Chemistry'}
# {'Clouds', 'Precipitation'}
# {'Altitude', 'Surface Thermal Properties', 'Atmospheric Radiation', 'Atmospheric Water Vapor', 'Atmospheric Winds', 'Atmospheric Pressure', 'Precipitation', 'Atmospheric Temperature'}
# {'Solar Activity'}
# {'Infrared Wavelengths', 'Atmospheric Chemistry'}
# {'Altitude', 'Surface Thermal Properties', 'Atmospheric Chemistry', 'Atmospheric Radiation', 'Air Quality', 'Atmospheric Water Vapor', 'Atmospheric Pressure', 'Clouds', 'Ocean Temperature', 'Precipitation', 'Atmospheric Temperature', 'Surface Radiative Properties'}
# {'Atmospheric Chemistry'}
# {'Atmospheric Chemistry'}
# {'Precipitation', 'Atmosphere'}
# {'Aerosols', 'Atmospheric Radiation', 'Clouds'}
# {'Infrared Wavelengths', 'Atmosphere'}
# {'Infrared Wavelengths'}
# {'Atmosphere'}
# {'Surface Thermal Properties', 'Atmospheric Radiation', 'Atmospheric Winds', 'Atmospheric Water Vapor', 'Ocean Heat Budget', 'Ocean Pressure', 'Ocean Temperature', 'Atmospheric Temperature'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Infrared Wavelengths'}
# {'Air Quality'}
# {'Surface Thermal Properties', 'Atmospheric Radiation', 'Atmosphere', 'Atmospheric Water Vapor', 'Atmospheric Pressure', 'Clouds', 'Precipitation', 'Atmospheric Temperature'}
# {'Microwave'}
# {'Surface Thermal Properties', 'Atmospheric Chemistry', 'Atmosphere', 'Atmospheric Water Vapor', 'Atmospheric Temperature'}
# {'Atmospheric Chemistry'}
# {'Atmospheric Chemistry'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Atmospheric Temperature'}
# {'Atmospheric Chemistry'}
# {'Surface Radiative Properties', 'Surface Thermal Properties', 'Vegetation', 'Atmospheric Radiation', 'Atmospheric Water Vapor', 'Surface Water', 'Snow/Ice', 'Precipitation', 'Atmospheric Temperature', 'Soils'}
# {'Atmosphere'}
# {'Atmospheric Temperature'}
# {'Surface Radiative Properties', 'Surface Thermal Properties', 'Vegetation', 'Atmospheric Radiation', 'Atmospheric Water Vapor', 'Surface Water', 'Snow/Ice', 'Precipitation', 'Atmospheric Temperature', 'Soils'}
# {'Atmospheric Chemistry', 'Ocean Chemistry'}
# {'Aerosols'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Infrared Wavelengths', 'Atmospheric Chemistry'}
# {'Aerosols', 'Atmospheric Radiation', 'Clouds'}
# {'Atmosphere'}
# {'Clouds'}
# {'Microwave'}
# {'Atmospheric Chemistry'}
# {'Ecological Dynamics'}
# {'Atmospheric Chemistry'}
# {'Atmosphere'}
# {'Atmospheric Winds'}
# {'Solar Energetic Particle Flux'}
# {'Atmospheric Radiation', 'Sensor Characteristics', 'Ultraviolet Wavelengths', 'Platform Characteristics', 'Spectral/Engineering'}
# {'Atmospheric Chemistry'}
# {'Clouds'}
# {'Atmosphere'}
# {'Atmospheric Chemistry'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Precipitation', 'Radar'}
# {'Clouds'}
# {'Solar Activity'}
# {'Surface Thermal Properties', 'Atmospheric Radiation', 'Atmospheric Winds', 'Atmospheric Water Vapor', 'Surface Water', 'Atmospheric Pressure', 'Snow/Ice', 'Precipitation', 'Atmospheric Temperature', 'Soils'}
# {'Precipitation', 'Radar'}
# {'Platform Characteristics', 'Spectral/Engineering', 'Atmospheric Radiation', 'Sensor Characteristics'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Atmospheric Radiation', 'Sensor Characteristics', 'Ultraviolet Wavelengths', 'Platform Characteristics', 'Spectral/Engineering'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmospheric Radiation', 'Atmospheric Water Vapor', 'Clouds', 'Precipitation', 'Atmospheric Temperature'}
# {'Altitude', 'Surface Thermal Properties', 'Atmospheric Chemistry', 'Air Quality', 'Atmosphere', 'Atmospheric Radiation', 'Atmospheric Water Vapor', 'Atmospheric Pressure', 'Clouds', 'Ocean Temperature', 'Precipitation', 'Atmospheric Temperature', 'Surface Radiative Properties'}
# {'Atmospheric Chemistry'}
# {'Clouds', 'Atmospheric Temperature', 'Atmosphere'}
# {'Atmospheric Chemistry'}
# {'Atmospheric Chemistry'}
# {'Atmosphere'}
# {'Atmospheric Water Vapor', 'Atmospheric Chemistry'}
# {'Atmospheric Chemistry'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmospheric Chemistry', 'Atmosphere', 'Atmospheric Water Vapor', 'Atmospheric Pressure', 'Clouds', 'Atmospheric Temperature'}
# {'Altitude', 'Surface Thermal Properties', 'Atmospheric Chemistry', 'Atmospheric Radiation', 'Air Quality', 'Atmospheric Water Vapor', 'Atmospheric Pressure', 'Clouds', 'Ocean Temperature', 'Precipitation', 'Atmospheric Temperature', 'Surface Radiative Properties'}
# {'Atmospheric Radiation'}
# {'Altitude', 'Surface Thermal Properties', 'Atmospheric Chemistry', 'Air Quality', 'Atmospheric Radiation', 'Atmospheric Water Vapor', 'Atmospheric Pressure', 'Clouds', 'Ocean Temperature', 'Precipitation', 'Atmospheric Temperature', 'Surface Radiative Properties'}
# {'Atmosphere'}
# {'Atmospheric Radiation', 'Microwave', 'Atmospheric Water Vapor', 'Infrared Wavelengths', 'Atmospheric Temperature'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Aerosols', 'Atmospheric Water Vapor', 'Atmospheric Temperature', 'Atmospheric Chemistry'}
# {'Surface Radiative Properties', 'Surface Thermal Properties', 'Vegetation', 'Atmospheric Radiation', 'Atmospheric Water Vapor', 'Surface Water', 'Snow/Ice', 'Precipitation', 'Atmospheric Temperature', 'Soils'}
# {'Atmospheric Radiation', 'Sensor Characteristics', 'Ultraviolet Wavelengths', 'Platform Characteristics', 'Spectral/Engineering'}
# {'Atmosphere'}
# {'Atmospheric Water Vapor'}
# {'Atmospheric Chemistry', 'Atmosphere'}
# {'Atmospheric Chemistry'}
# {'Atmospheric Radiation', 'Atmospheric Water Vapor', 'Clouds', 'Precipitation', 'Atmospheric Temperature'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Surface Thermal Properties', 'Atmospheric Chemistry', 'Atmosphere', 'Atmospheric Water Vapor', 'Atmospheric Temperature'}
# {'Atmosphere'}
# {'Infrared Wavelengths', 'Atmosphere'}
# {'Atmospheric Radiation', 'Atmospheric Water Vapor', 'Clouds', 'Precipitation', 'Atmospheric Temperature'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Atmospheric Radiation', 'Sensor Characteristics', 'Ultraviolet Wavelengths', 'Platform Characteristics', 'Spectral/Engineering'}
# {'Altitude', 'Surface Thermal Properties', 'Atmospheric Chemistry', 'Atmospheric Radiation', 'Air Quality', 'Atmospheric Water Vapor', 'Atmospheric Pressure', 'Clouds', 'Ocean Temperature', 'Atmospheric Temperature', 'Surface Radiative Properties'}
# {'Atmosphere'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Surface Thermal Properties', 'Atmospheric Radiation', 'Atmosphere', 'Atmospheric Water Vapor', 'Terrestrial Hydrosphere', 'Clouds', 'Ocean Temperature', 'Sea Ice'}
# {'Precipitation'}
# {'Atmospheric Water Vapor', 'Atmospheric Chemistry'}
# {'Infrared Wavelengths'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Altitude', 'Atmospheric Winds', 'Atmospheric Water Vapor', 'Atmospheric Pressure', 'Atmospheric Temperature'}
# {'Atmosphere'}
# {'Altitude', 'Surface Thermal Properties', 'Atmospheric Chemistry', 'Atmospheric Radiation', 'Air Quality', 'Atmospheric Water Vapor', 'Atmospheric Pressure', 'Clouds', 'Ocean Temperature', 'Precipitation', 'Atmospheric Temperature', 'Surface Radiative Properties'}
# {'Surface Thermal Properties', 'Atmospheric Radiation', 'Atmospheric Winds', 'Atmospheric Water Vapor', 'Surface Water', 'Atmospheric Pressure', 'Snow/Ice', 'Precipitation', 'Atmospheric Temperature', 'Soils'}
# {'Altitude', 'Surface Thermal Properties', 'Atmospheric Chemistry', 'Air Quality', 'Atmospheric Radiation', 'Atmospheric Water Vapor', 'Infrared Wavelengths', 'Atmospheric Pressure', 'Clouds', 'Ocean Temperature', 'Precipitation', 'Atmospheric Temperature', 'Surface Radiative Properties'}
# {'Atmospheric Chemistry'}
# {'Atmospheric Chemistry'}
# {'Atmospheric Chemistry'}
# {'Atmospheric Chemistry'}
# {'Altitude', 'Surface Thermal Properties', 'Atmospheric Chemistry', 'Atmospheric Radiation', 'Air Quality', 'Atmospheric Water Vapor', 'Atmospheric Pressure', 'Clouds', 'Ocean Temperature', 'Atmospheric Temperature', 'Surface Radiative Properties'}
# {'Atmospheric Water Vapor'}
# {'Atmospheric Chemistry', 'Air Quality', 'Atmosphere'}
# {'Atmospheric Water Vapor', 'Atmospheric Temperature'}
# {'Atmospheric Water Vapor', 'Atmospheric Temperature'}
# {'Surface Thermal Properties', 'Atmospheric Chemistry', 'Atmospheric Radiation', 'Atmospheric Water Vapor', 'Atmospheric Pressure', 'Clouds', 'Ocean Temperature', 'Precipitation', 'Atmospheric Temperature'}
# {'Atmosphere'}
# {'Infrared Wavelengths'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Aerosols', 'Atmospheric Radiation', 'Clouds'}
# {'Atmosphere'}
# {'Precipitation'}
# {'Atmospheric Chemistry'}
# {'Ionosphere/Magnetosphere Dynamics'}
# {'Atmospheric Chemistry'}
# {'Atmospheric Chemistry'}
# {'Clouds', 'Precipitation', 'Atmospheric Water Vapor'}
# {'Atmosphere'}
# {'Altitude', 'Surface Thermal Properties', 'Atmospheric Chemistry', 'Air Quality', 'Atmospheric Radiation', 'Atmospheric Water Vapor', 'Atmospheric Pressure', 'Clouds', 'Ocean Temperature', 'Precipitation', 'Atmospheric Temperature', 'Surface Radiative Properties'}
# {'Atmospheric Radiation'}
# {'Infrared Wavelengths', 'Visible Wavelengths', 'Atmospheric Radiation'}
# {'Atmosphere'}
# {'Atmospheric Chemistry'}
# {'Atmosphere'}
# {'Atmospheric Chemistry'}
# {'Surface Thermal Properties', 'Atmospheric Radiation', 'Atmospheric Winds', 'Atmospheric Water Vapor', 'Surface Water', 'Atmospheric Pressure', 'Snow/Ice', 'Precipitation', 'Atmospheric Temperature', 'Soils'}
# {'Atmospheric Radiation'}
# {'Atmosphere'}
# {'Solar Activity'}
# {'Altitude', 'Surface Thermal Properties', 'Atmospheric Chemistry', 'Air Quality', 'Atmospheric Radiation', 'Atmospheric Water Vapor', 'Atmospheric Pressure', 'Clouds', 'Ocean Temperature', 'Atmospheric Temperature', 'Surface Radiative Properties'}
# {'Precipitation', 'Atmosphere'}
# {'Platform Characteristics', 'Spectral/Engineering', 'Atmospheric Radiation', 'Sensor Characteristics'}
# {'Atmospheric Chemistry'}
# {'Atmospheric Chemistry'}
# {'Infrared Wavelengths'}
# {'Ecological Dynamics'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Atmospheric Chemistry'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Infrared Wavelengths', 'Visible Wavelengths'}
# {'Atmospheric Chemistry'}
# {'Solar Activity'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Surface Thermal Properties', 'Atmospheric Radiation', 'Atmospheric Winds', 'Atmospheric Water Vapor', 'Surface Water', 'Atmospheric Pressure', 'Snow/Ice', 'Precipitation', 'Atmospheric Temperature', 'Soils'}
# {'Surface Thermal Properties', 'Atmospheric Radiation', 'Atmosphere', 'Atmospheric Water Vapor', 'Atmospheric Pressure', 'Clouds', 'Precipitation', 'Atmospheric Temperature'}
# {'Aerosols', 'Atmospheric Chemistry', 'Atmospheric Radiation'}
# {'Aerosols', 'Atmospheric Chemistry', 'Atmospheric Radiation'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Atmospheric Chemistry'}
# {'Surface Thermal Properties', 'Atmospheric Radiation', 'Atmosphere', 'Land Surface', 'Clouds', 'Ocean Temperature', 'Surface Radiative Properties'}
# {'Precipitation'}
# {'Surface Thermal Properties', 'Atmospheric Radiation', 'Atmospheric Winds', 'Atmospheric Water Vapor', 'Surface Water', 'Atmospheric Pressure', 'Snow/Ice', 'Precipitation', 'Atmospheric Temperature', 'Soils'}
# {'Atmosphere'}
# {'Precipitation'}
# {'Atmospheric Radiation', 'Sensor Characteristics', 'Ultraviolet Wavelengths', 'Platform Characteristics', 'Spectral/Engineering'}
# {'Altitude', 'Surface Thermal Properties', 'Atmospheric Chemistry', 'Atmosphere', 'Atmospheric Winds', 'Atmospheric Water Vapor', 'Ocean Pressure', 'Atmospheric Pressure', 'Clouds', 'Atmospheric Temperature'}
# {'Surface Radiative Properties', 'Surface Thermal Properties', 'Vegetation', 'Atmospheric Radiation', 'Atmospheric Water Vapor', 'Surface Water', 'Snow/Ice', 'Precipitation', 'Atmospheric Temperature', 'Soils'}
# {'Atmospheric Chemistry', 'Air Quality', 'Atmosphere'}
# {'Atmospheric Radiation', 'Sensor Characteristics', 'Ultraviolet Wavelengths', 'Platform Characteristics', 'Spectral/Engineering'}
# {'Altitude', 'Surface Thermal Properties', 'Atmospheric Chemistry', 'Atmospheric Radiation', 'Air Quality', 'Atmospheric Water Vapor', 'Atmospheric Pressure', 'Clouds', 'Ocean Temperature', 'Precipitation', 'Atmospheric Temperature', 'Surface Radiative Properties'}
# {'Atmospheric Chemistry'}
# {'Atmospheric Chemistry'}
# {'Solar Activity'}
# {'Atmospheric Chemistry'}
# {'Atmospheric Chemistry'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Surface Thermal Properties', 'Atmospheric Radiation', 'Atmospheric Winds', 'Atmospheric Water Vapor', 'Surface Water', 'Atmospheric Pressure', 'Snow/Ice', 'Precipitation', 'Atmospheric Temperature', 'Soils'}
# {'Atmospheric Chemistry'}
# {'Aerosols', 'Atmospheric Radiation', 'Clouds'}
# {'Clouds', 'Surface Radiative Properties'}
# {'Infrared Wavelengths', 'Atmosphere'}
# {'Ultraviolet Wavelengths'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Atmospheric Chemistry'}
# {'Atmospheric Chemistry'}
# {'Atmosphere'}
# {'Atmospheric Chemistry', 'Atmospheric Radiation'}
# {'Altitude', 'Surface Thermal Properties', 'Topography', 'Atmospheric Radiation', 'Atmospheric Water Vapor', 'Atmospheric Winds', 'Terrestrial Hydrosphere', 'Ocean Heat Budget', 'Precipitation', 'Atmospheric Temperature', 'Sea Ice'}
# {'Infrared Wavelengths', 'Visible Wavelengths'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Atmospheric Chemistry'}
# {'Atmospheric Radiation', 'Atmosphere', 'Atmospheric Water Vapor', 'Terrestrial Hydrosphere', 'Clouds'}
# {'Platform Characteristics'}
# {'Atmospheric Chemistry'}
# {'Aerosols', 'Atmospheric Radiation', 'Clouds'}
# {'Atmospheric Chemistry'}
# {'Atmospheric Chemistry'}
# {'Altitude', 'Surface Thermal Properties', 'Atmospheric Chemistry', 'Atmospheric Radiation', 'Air Quality', 'Atmospheric Water Vapor', 'Atmospheric Pressure', 'Clouds', 'Ocean Temperature', 'Precipitation', 'Atmospheric Temperature', 'Surface Radiative Properties'}
# {'Soils', 'Surface Thermal Properties', 'Vegetation'}
# {'Altitude', 'Atmospheric Chemistry', 'Atmospheric Water Vapor', 'Atmospheric Winds', 'Atmospheric Pressure', 'Ocean Pressure', 'Atmospheric Temperature'}
# {'Altitude', 'Surface Thermal Properties', 'Atmospheric Chemistry', 'Atmospheric Radiation', 'Air Quality', 'Atmospheric Water Vapor', 'Atmospheric Pressure', 'Clouds', 'Ocean Temperature', 'Precipitation', 'Atmospheric Temperature', 'Surface Radiative Properties'}
# {'Surface Thermal Properties', 'Atmospheric Radiation', 'Atmospheric Winds', 'Atmospheric Water Vapor', 'Ocean Heat Budget', 'Ocean Pressure', 'Ocean Temperature', 'Atmospheric Temperature'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Clouds', 'Precipitation'}
# {'Atmospheric Radiation', 'Sensor Characteristics', 'Ultraviolet Wavelengths', 'Platform Characteristics', 'Spectral/Engineering'}
# {'Solar Activity'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmospheric Chemistry'}
# {'Aerosols', 'Atmospheric Radiation', 'Clouds'}
# {'Atmospheric Chemistry'}
# {'Atmospheric Chemistry'}
# {'Atmosphere'}
# {'Aerosols', 'Atmospheric Radiation', 'Clouds'}
# {'Atmosphere'}
# {'Atmospheric Water Vapor'}
# {'Solar Energetic Particle Flux'}
# {'Aerosols'}
# {'Agriculture'}
# {'Atmospheric Radiation'}
# {'Atmospheric Chemistry'}
# {'Atmospheric Chemistry'}
# {'Visible Wavelengths'}
# {'Atmosphere'}
# ...
# {'Surface Thermal Properties'}
# {'Atmospheric Chemistry'}
# {'Atmosphere'}
# {'Solar Activity'}
# {'Precipitation'}
# {'Infrared Wavelengths', 'Atmosphere'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Atmospheric Chemistry'}
# {'Infrared Wavelengths', 'Atmosphere'}
# {'Surface Radiative Properties', 'Surface Thermal Properties', 'Vegetation', 'Atmospheric Radiation', 'Atmospheric Water Vapor', 'Surface Water', 'Snow/Ice', 'Precipitation', 'Atmospheric Temperature', 'Soils'}
# {'Infrared Wavelengths'}
# {'Surface Radiative Properties', 'Surface Thermal Properties', 'Vegetation', 'Atmospheric Radiation', 'Atmospheric Water Vapor', 'Surface Water', 'Snow/Ice', 'Precipitation', 'Atmospheric Temperature', 'Soils'}
# {'Altitude', 'Surface Thermal Properties', 'Atmospheric Chemistry', 'Atmospheric Radiation', 'Air Quality', 'Atmospheric Water Vapor', 'Atmospheric Pressure', 'Clouds', 'Ocean Temperature', 'Precipitation', 'Atmospheric Temperature', 'Surface Radiative Properties'}
# {'Platform Characteristics'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Atmospheric Chemistry'}
# {'Atmosphere'}
# {'Atmospheric Winds'}
# {'Atmospheric Chemistry'}
# {'Solar Energetic Particle Flux'}
# {'Infrared Wavelengths'}
# {'Atmospheric Chemistry'}
# {'Precipitation'}
# {'Precipitation', 'Radar'}
# {'Radar'}
# {'Radar'}
# {'Altitude', 'Surface Thermal Properties', 'Atmospheric Radiation', 'Atmospheric Water Vapor', 'Atmospheric Winds', 'Atmospheric Pressure', 'Precipitation', 'Atmospheric Temperature'}
# {'Atmospheric Radiation'}
# {'Atmosphere'}
# {'Atmospheric Chemistry'}
# {'Platform Characteristics'}
# {'Altitude', 'Surface Thermal Properties', 'Atmospheric Chemistry', 'Atmospheric Radiation', 'Air Quality', 'Atmospheric Water Vapor', 'Atmospheric Pressure', 'Clouds', 'Ocean Temperature', 'Atmospheric Temperature', 'Surface Radiative Properties'}
# {'Atmospheric Chemistry'}
# {'Altitude', 'Surface Thermal Properties', 'Atmospheric Chemistry', 'Air Quality', 'Atmospheric Radiation', 'Atmospheric Water Vapor', 'Infrared Wavelengths', 'Atmospheric Pressure', 'Clouds', 'Ocean Temperature', 'Precipitation', 'Atmospheric Temperature', 'Surface Radiative Properties'}
# {'Surface Thermal Properties', 'Atmospheric Radiation', 'Atmospheric Winds', 'Atmospheric Water Vapor', 'Ocean Heat Budget', 'Ocean Pressure', 'Ocean Temperature', 'Atmospheric Temperature'}
# {'Precipitation'}
# {'Infrared Wavelengths'}
# {'Frozen Ground'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Aerosols', 'Atmospheric Radiation', 'Clouds'}
# {'Atmospheric Radiation', 'Atmospheric Water Vapor', 'Clouds', 'Precipitation', 'Atmospheric Temperature'}
# {'Atmospheric Radiation'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Atmospheric Chemistry'}
# {'Infrared Wavelengths', 'Atmosphere'}
# {'Infrared Wavelengths'}
# {'Aerosols', 'Atmospheric Radiation', 'Clouds'}
# {'Aerosols', 'Atmospheric Radiation'}
# {'Surface Thermal Properties', 'Atmospheric Radiation', 'Atmospheric Winds', 'Atmospheric Water Vapor', 'Ocean Heat Budget', 'Ocean Pressure', 'Ocean Temperature', 'Atmospheric Temperature'}
# {'Atmospheric Winds'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Clouds'}
# {'Precipitation', 'Atmospheric Temperature', 'Atmospheric/Ocean Indicators'}
# {'Soils', 'Surface Thermal Properties', 'Vegetation'}
# {'Altitude', 'Atmospheric Pressure', 'Atmospheric Temperature', 'Atmosphere'}
# {'Microwave'}
# {'Atmospheric Chemistry', 'Air Quality', 'Atmosphere'}
# {'Surface Thermal Properties', 'Atmospheric Radiation', 'Atmosphere', 'Atmospheric Water Vapor', 'Atmospheric Pressure', 'Clouds', 'Precipitation', 'Atmospheric Temperature'}
# {'Aerosols', 'Infrared Wavelengths', 'Atmospheric Chemistry'}
# {'Aerosols', 'Atmospheric Radiation', 'Clouds'}
# {'Aerosols', 'Atmospheric Chemistry', 'Atmospheric Radiation'}
# {'Infrared Wavelengths'}
# {'Atmospheric Chemistry'}
# {'Atmosphere'}
# {'Aerosols', 'Atmospheric Radiation', 'Clouds'}
# {'Altitude', 'Atmospheric Pressure', 'Atmospheric Winds', 'Atmospheric Temperature'}
# {'Infrared Wavelengths'}
# {'Atmosphere'}
# {'Atmospheric Water Vapor'}
# {'Atmosphere'}
# {'Aerosols', 'Infrared Wavelengths', 'Atmospheric Chemistry'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Atmospheric Water Vapor'}
# {'Atmosphere'}
# {'Atmospheric Chemistry'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Surface Thermal Properties', 'Atmospheric Radiation', 'Atmospheric Winds', 'Atmospheric Water Vapor', 'Ocean Heat Budget', 'Ocean Pressure', 'Ocean Temperature', 'Atmospheric Temperature'}
# {'Atmospheric Chemistry', 'Atmosphere'}
# {'Atmospheric Winds', 'Atmospheric Water Vapor', 'Atmospheric Pressure', 'Precipitation', 'Atmospheric Temperature'}
# {'Infrared Wavelengths', 'Atmospheric Chemistry'}
# {'Altitude', 'Atmospheric Water Vapor', 'Atmospheric Temperature', 'Atmospheric Chemistry'}
# {'Atmospheric Winds', 'Atmospheric Water Vapor', 'Infrared Wavelengths', 'Ocean Temperature', 'Sea Ice'}
# {'Paleoclimate Indicators', 'Natural Hazards', 'Atmospheric Chemistry', 'Air Quality'}
# {'Altitude', 'Atmospheric Water Vapor', 'Atmospheric Temperature', 'Atmospheric Chemistry'}
# {'Solar Activity'}
# {'Atmospheric Chemistry'}
# {'Atmospheric Chemistry'}
# {'Atmospheric Radiation'}
# {'Atmospheric Chemistry'}
# {'Atmospheric Radiation'}
# {'Ultraviolet Wavelengths'}
# {'Surface Thermal Properties', 'Atmospheric Chemistry', 'Atmospheric Radiation', 'Atmospheric Water Vapor', 'Atmospheric Pressure', 'Clouds', 'Precipitation', 'Atmospheric Temperature'}
# {'Surface Thermal Properties', 'Atmospheric Radiation', 'Atmospheric Winds', 'Atmospheric Water Vapor', 'Ocean Heat Budget', 'Ocean Pressure', 'Ocean Temperature', 'Atmospheric Temperature'}
# {'Platform Characteristics'}
# {'Altitude', 'Surface Thermal Properties', 'Atmospheric Chemistry', 'Atmospheric Radiation', 'Air Quality', 'Atmospheric Water Vapor', 'Atmospheric Pressure', 'Clouds', 'Ocean Temperature', 'Atmospheric Temperature', 'Surface Radiative Properties'}
# {'Atmospheric Chemistry'}
# {'Atmospheric Chemistry'}
# {'Infrared Wavelengths', 'Atmosphere'}
# {'Altitude', 'Atmospheric Temperature', 'Atmospheric Chemistry', 'Atmosphere'}
# {'Infrared Wavelengths', 'Atmospheric Radiation'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Atmospheric Water Vapor'}
# {'Atmospheric Radiation', 'Sensor Characteristics', 'Ultraviolet Wavelengths', 'Platform Characteristics', 'Spectral/Engineering'}
# {'Atmosphere'}
# {'Aerosols', 'Atmospheric Chemistry', 'Atmospheric Radiation'}
# {'Aerosols', 'Atmospheric Water Vapor', 'Atmospheric Temperature', 'Atmospheric Chemistry'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Atmospheric Water Vapor', 'Atmospheric Temperature'}
# {'Atmospheric Chemistry'}
# {'Infrared Wavelengths', 'Atmosphere'}
# {'Surface Thermal Properties', 'Atmospheric Chemistry', 'Atmospheric Radiation', 'Atmospheric Water Vapor', 'Atmospheric Pressure', 'Ocean Pressure', 'Clouds', 'Ocean Temperature', 'Precipitation', 'Atmospheric Temperature'}
# {'Atmospheric Chemistry'}
# {'Clouds', 'Atmosphere'}
# {'Atmosphere'}
# {'Atmospheric Chemistry', 'Ocean Chemistry'}
# {'Aerosols'}
# {'Atmospheric Chemistry'}
# {'Atmospheric Chemistry'}
# {'Ultraviolet Wavelengths', 'Infrared Wavelengths', 'Visible Wavelengths'}
# {'Atmospheric Chemistry'}
# {'Surface Thermal Properties', 'Atmospheric Chemistry', 'Atmospheric Radiation', 'Atmospheric Water Vapor', 'Atmospheric Pressure', 'Clouds', 'Ocean Temperature', 'Precipitation', 'Atmospheric Temperature'}
# {'Solar Activity'}
# {'Atmospheric Chemistry'}
# {'Altitude', 'Atmospheric Water Vapor', 'Atmospheric Temperature', 'Atmospheric Chemistry'}
# {'Infrared Wavelengths', 'Atmosphere'}
# {'Atmospheric Chemistry'}
# {'Platform Characteristics', 'Spectral/Engineering', 'Atmospheric Radiation', 'Sensor Characteristics'}
# {'Altitude', 'Surface Thermal Properties', 'Atmospheric Chemistry', 'Atmospheric Radiation', 'Air Quality', 'Atmospheric Water Vapor', 'Atmospheric Pressure', 'Clouds', 'Ocean Temperature', 'Atmospheric Temperature', 'Surface Radiative Properties'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Atmosphere'}
# {'Altitude', 'Surface Thermal Properties', 'Atmospheric Chemistry', 'Air Quality', 'Atmospheric Radiation', 'Atmospheric Water Vapor', 'Atmospheric Pressure', 'Clouds', 'Ocean Temperature', 'Atmospheric Temperature', 'Surface Radiative Properties'}
# {'Infrared Wavelengths'}
# {'Atmospheric Chemistry'}
# {'Aerosols'}
# {'Atmospheric Water Vapor'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Glaciers/Ice Sheets', 'Surface Radiative Properties', 'Snow/Ice'}
# {'Atmospheric Chemistry'}
# {'Atmospheric Chemistry'}
# {'Surface Thermal Properties', 'Atmospheric Radiation', 'Atmospheric Winds', 'Atmospheric Water Vapor', 'Surface Water', 'Atmospheric Pressure', 'Snow/Ice', 'Precipitation', 'Atmospheric Temperature', 'Soils'}
# {'Atmospheric Radiation', 'Atmospheric Water Vapor', 'Clouds', 'Precipitation', 'Atmospheric Temperature'}
# {'Altitude', 'Surface Thermal Properties', 'Atmospheric Chemistry', 'Atmospheric Radiation', 'Air Quality', 'Atmospheric Water Vapor', 'Atmospheric Pressure', 'Clouds', 'Ocean Temperature', 'Precipitation', 'Atmospheric Temperature', 'Surface Radiative Properties'}
# {'Atmospheric Chemistry'}
# {'Solar Activity'}
# {'Altitude'}
# {'Atmospheric Chemistry', 'Vegetation'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Atmosphere'}
# {'Surface Thermal Properties', 'Atmospheric Radiation', 'Atmospheric Winds', 'Atmospheric Water Vapor', 'Surface Water', 'Atmospheric Pressure', 'Snow/Ice', 'Precipitation', 'Atmospheric Temperature', 'Soils'}
# {'Altitude', 'Surface Thermal Properties', 'Atmospheric Chemistry', 'Atmospheric Radiation', 'Air Quality', 'Atmospheric Water Vapor', 'Atmospheric Pressure', 'Clouds', 'Ocean Temperature', 'Precipitation', 'Atmospheric Temperature', 'Surface Radiative Properties'}
# {'Altitude', 'Atmospheric Winds', 'Atmospheric Water Vapor', 'Atmospheric Pressure', 'Atmospheric Temperature'}
# {'Infrared Wavelengths', 'Atmospheric Chemistry'}
# {'Atmospheric Chemistry'}
# {'Clouds', 'Surface Radiative Properties'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Solar Energetic Particle Properties'}
# {'Altitude', 'Surface Thermal Properties', 'Atmospheric Chemistry', 'Atmospheric Radiation', 'Air Quality', 'Atmospheric Water Vapor', 'Atmospheric Pressure', 'Clouds', 'Ocean Temperature', 'Precipitation', 'Atmospheric Temperature', 'Surface Radiative Properties'}
# {'Infrared Wavelengths', 'Atmospheric Radiation'}
# {'Atmospheric Radiation'}
# {'Atmospheric Temperature'}
# {'Surface Thermal Properties', 'Atmospheric Radiation', 'Atmosphere', 'Atmospheric Water Vapor', 'Terrestrial Hydrosphere', 'Clouds', 'Ocean Temperature', 'Sea Ice'}
# {'Atmospheric Chemistry'}
# {'Surface Thermal Properties', 'Atmospheric Radiation', 'Atmospheric Winds', 'Atmospheric Water Vapor', 'Ocean Heat Budget', 'Ocean Pressure', 'Ocean Temperature', 'Atmospheric Temperature'}
# {'Atmospheric Chemistry'}
# {'Surface Thermal Properties', 'Atmospheric Radiation', 'Atmospheric Winds', 'Atmospheric Water Vapor', 'Ocean Heat Budget', 'Ocean Pressure', 'Ocean Temperature', 'Atmospheric Temperature'}
# {'Surface Radiative Properties', 'Surface Thermal Properties', 'Vegetation', 'Atmospheric Radiation', 'Atmospheric Water Vapor', 'Surface Water', 'Snow/Ice', 'Precipitation', 'Atmospheric Temperature', 'Soils'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Atmospheric Chemistry'}
# {'Precipitation', 'Atmosphere'}
# {'Altitude', 'Surface Thermal Properties', 'Atmospheric Chemistry', 'Atmospheric Radiation', 'Air Quality', 'Atmospheric Water Vapor', 'Atmospheric Pressure', 'Clouds', 'Ocean Temperature', 'Precipitation', 'Atmospheric Temperature', 'Surface Radiative Properties'}
# {'Atmospheric Chemistry'}
# {'Precipitation'}
# {'Atmospheric Chemistry'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Clouds'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Altitude', 'Surface Thermal Properties', 'Atmospheric Chemistry', 'Atmospheric Radiation', 'Air Quality', 'Atmospheric Water Vapor', 'Atmospheric Pressure', 'Clouds', 'Ocean Temperature', 'Precipitation', 'Atmospheric Temperature', 'Surface Radiative Properties'}
# {'Atmospheric Chemistry', 'Air Quality', 'Atmosphere'}
# {'Altitude', 'Surface Thermal Properties', 'Atmospheric Chemistry', 'Air Quality', 'Atmospheric Radiation', 'Atmospheric Water Vapor', 'Atmospheric Pressure', 'Clouds', 'Ocean Temperature', 'Atmospheric Temperature', 'Surface Radiative Properties'}
# {'Aerosols', 'Atmospheric Chemistry', 'Atmospheric Radiation'}
# {'Protists', 'Ocean Temperature', 'Ocean Optics', 'Ocean Chemistry'}
# {'Clouds'}
# {'Atmospheric Chemistry'}
# {'Surface Thermal Properties', 'Atmospheric Radiation', 'Atmospheric Winds', 'Atmospheric Water Vapor', 'Ocean Heat Budget', 'Ocean Pressure', 'Ocean Temperature', 'Atmospheric Temperature'}
# {'Atmosphere'}
# {'Atmospheric Chemistry'}
# {'Infrared Wavelengths'}
# {'Spectral/Engineering', 'Atmosphere'}
# {'Surface Thermal Properties', 'Atmospheric Chemistry', 'Atmosphere', 'Atmospheric Water Vapor', 'Atmospheric Temperature'}
# {'Atmospheric Chemistry'}
# {'Clouds'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Atmospheric Radiation', 'Atmospheric Water Vapor', 'Clouds', 'Precipitation', 'Atmospheric Temperature'}
# {'Atmospheric Chemistry', 'Ocean Chemistry'}
# {'Visible Wavelengths', 'Infrared Wavelengths', 'Platform Characteristics', 'Sensor Characteristics'}
# {'Aerosols', 'Atmospheric Chemistry', 'Air Quality'}
# {'Infrared Wavelengths'}
# {'Atmospheric Chemistry'}
# {'Aerosols', 'Atmospheric Radiation'}
# {'Solar Activity'}
# {'Atmosphere'}
# {'Clouds'}
# {'Atmospheric Chemistry'}
# {'Aerosols'}
# {'Platform Characteristics', 'Sensor Characteristics', 'Atmospheric Radiation'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Platform Characteristics', 'Spectral/Engineering', 'Atmospheric Radiation', 'Sensor Characteristics'}
# {'Surface Thermal Properties', 'Atmospheric Radiation', 'Atmospheric Winds', 'Atmospheric Water Vapor', 'Surface Water', 'Atmospheric Pressure', 'Snow/Ice', 'Precipitation', 'Atmospheric Temperature', 'Soils'}
# {'Infrared Wavelengths'}
# {'Atmosphere'}
# {'Precipitation', 'Atmosphere'}
# {'Altitude', 'Surface Thermal Properties', 'Atmospheric Chemistry', 'Atmospheric Radiation', 'Air Quality', 'Atmospheric Water Vapor', 'Atmospheric Pressure', 'Clouds', 'Ocean Temperature', 'Precipitation', 'Atmospheric Temperature', 'Surface Radiative Properties'}
# {'Atmospheric Chemistry'}
# {'Atmospheric Chemistry'}
# {'Atmosphere'}
# {'Clouds'}
# {'Microwave'}
# {'Clouds'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmosphere'}
# {'Atmospheric Chemistry'}
# {'Atmospheric Radiation', 'Sensor Characteristics', 'Ultraviolet Wavelengths', 'Platform Characteristics', 'Spectral/Engineering'}
# {'Atmospheric Chemistry'}
# {'Infrared Wavelengths', 'Atmospheric Chemistry'}
# {'Atmospheric Winds', 'Atmospheric Temperature'}
# {'Precipitation', 'Radar'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Altitude', 'Surface Thermal Properties', 'Atmospheric Chemistry', 'Air Quality', 'Atmospheric Radiation', 'Atmospheric Water Vapor', 'Atmospheric Pressure', 'Clouds', 'Ocean Temperature', 'Precipitation', 'Atmospheric Temperature', 'Surface Radiative Properties'}
# {'Clouds', 'Atmospheric Water Vapor'}
# {'Atmospheric Temperature'}
# {'Solar Activity'}
# {'Clouds'}
# {'Atmospheric Radiation'}
# {'Visible Wavelengths'}
# {'Atmospheric Radiation', 'Atmospheric Water Vapor', 'Clouds', 'Precipitation', 'Atmospheric Temperature'}
# {'Altitude', 'Topography', 'Land Use/Land Cover'}
# {'Surface Thermal Properties', 'Atmospheric Radiation', 'Atmospheric Winds', 'Atmospheric Water Vapor', 'Ocean Heat Budget', 'Ocean Pressure', 'Ocean Temperature', 'Atmospheric Temperature'}
# {'Atmospheric Chemistry'}
# {'Atmosphere'}
# {'Atmospheric Radiation', 'Atmospheric Water Vapor', 'Clouds', 'Precipitation', 'Atmospheric Temperature'}
# {'Solar Energetic Particle Flux'}
# {'Precipitation', 'Radar'}
# {'Aerosols', 'Infrared Wavelengths', 'Atmospheric Chemistry'}

# %%
title2deep = dict(zip(labels, [[]]*len(labels)))
for title in labels:
    kywrds_for_title = index2kywrd[title2index[title]]
    title2deep[title] = kywrds_for_title

# %%
topics = [keyword for keyword, kywrd_class in kywrd2class.items() if kywrd_class == 'Topic']

# %%
# Create DataFrame of x- and y-values of embeddings, the dataset title, and the topic associated with the dataset
df_embeddings_title_topic = pd.DataFrame(list(zip(x_vals, y_vals, labels)), columns=['x', 'y', 'title'])

# %%
df_embeddings_title_topic['topic'] = df_embeddings_title_topic['title'].map(title2topic)

# %%
df_embeddings_title_topic['term'] = df_embeddings_title_topic['title'].map(title2term)

# %%
topic2color = dict(zip(topics, range(len(topics))))

# %%
df_embeddings_title_topic['color'] = df_embeddings_title_topic['topic'].map(topic2color)

# %%
# Plot the embeddings color-coded based on term
import plotly.express as px

fig = px.scatter(df_embeddings_title_topic, x='x', y='y', hover_name="title", hover_data=["x", "y"], color="term")
fig.show()
fig.write_html('07-28-2022_DatasetEmbeddings_StratifiedByTerm.html')

if not os.path.exists("images"):
    os.mkdir("images")

fig.write_image("images/07-28-2022_DatasetEmbeddings_StratifiedByTerm.html.png")
# Out:
# <div>                            <div id="3c9dd305-986e-4cdf-b5fb-2e056e8fa3fc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3c9dd305-986e-4cdf-b5fb-2e056e8fa3fc")) {                    Plotly.newPlot(                        "3c9dd305-986e-4cdf-b5fb-2e056e8fa3fc",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>term=Altitude<br>x=%{x}<br>y=%{y}<extra></extra>","hovertext":["Gridded Monthly Time-Mean Observation minus Analysis (oma) Values 0.5 x 0.667 degree V001 (MA_HIRS2_TIROSN_OMA) at GES DISC","Gridded Monthly Time-Mean Observation minus Analysis (oma) Values 0.5 x 0.667 degree V001 (MA_SSU_NOAA07_OMA) at GES DISC","Aqua/AIRS L3 Daily Support Product (AIRS-only) 1 degree x 1 degree V7.0 at GES DISC","AIRS/Aqua L3 8-day Support Multiday Product (AIRS+AMSU) 1 degree x 1 degree V006 (AIRX3SP8) at GES DISC","Gridded Monthly Time-Mean Observation minus Analysis (oma) Values 0.5 x 0.667 degree V001 (MA_SSMI_DMSP10_OMA) at GES DISC","Sounder SIPS: JPSS-1 CrIS Level 3 Specific Quality Control Gridded Daily CLIMCAPS V2 at GES DISC","Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_MSU_NOAA14_OBS) at GES DISC","Aqua/AIRS L3 Monthly Standard Physical Retrieval (AIRS-only) 1 degree x 1 degree V7.0 at GES DISC","MERRA-2 inst6_3d_ana_Nv: 3d,6-Hourly,Instantaneous,Model-Level,Analysis,Analyzed Meteorological Fields 0.625 x 0.5 degree V5.12.4 (M2I6NVANA) at GES DISC","Sounder SIPS: Suomi NPP CrIMSS Level 3 Comprehensive Quality Control Gridded Daily CLIMCAPS Normal Spectral Resolution V2 at GES DISC","MLS/Aura Level 3 Daily Binned Geopotential Height (GPH) on Zonal and Similar Grids V005 (ML3DZGPH) at GES DISC","AIRS/Aqua L3 Monthly Support Product (AIRS+AMSU) 1 degree x 1 degree V006 (AIRX3SPM) at GES DISC","Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_MSU_NOAA06_OBS) at GES DISC","Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_AMSUB_NOAA17_OBS) at GES DISC","NLDAS Secondary Forcing Data L4 Monthly 0.125 x 0.125 degree V002 (NLDAS_FORB0125_M) at GES DISC","Sounder SIPS: AQUA AIRS IR-only Level 3 CLIMCAPS: Comprehensive Quality Control Gridded Monthly V2 at GES DISC","AIRS/Aqua L3 Daily Standard Physical Retrieval (AIRS+AMSU) 1 degree x 1 degree V006 (AIRX3STD) at GES DISC","Gridded Monthly Time-Mean Observation minus Forecast (omf) Values 0.5 x 0.667 degree V001 (MA_MSU_NOAA08_OMF) at GES DISC","Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_SSU_NOAA11_OBS) at GES DISC","Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_AMSUA_NOAA17_OBS) at GES DISC","Gridded Monthly Time-Mean Observation minus Forecast (omf) Values 0.5 x 0.667 degree V001 (MA_SSMI_DMSP08_OMF) at GES DISC","AIRS/Aqua L2 Standard Physical Retrieval (AIRS-only) V006 (AIRS2RET) at GES DISC","Gridded Monthly Time-Mean Observation minus Forecast (omf) Values 0.5 x 0.667 degree V001 (MA_HIRS2_NOAA14_OMF) at GES DISC","NLDAS Secondary Forcing Data L4 Monthly Climatology 0.125 x 0.125 degree V002 (NLDAS_FORB0125_MC) at GES DISC","MERRA-2 const_2d_ctm_Nx: Constant Model Parameters for Usage by CTM 0.625 x 0.5 degree V5.12.4 (M2C0NXCTM) at GES DISC","Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_HIRS2_AM_OBS) at GES DISC","Gridded Monthly Time-Mean Observation minus Forecast (omf) Values 0.5 x 0.667 degree V001 (MA_HIRS2_NOAA06_OMF) at GES DISC","Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_SSMI_DMSP13_OBS) at GES DISC","Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_SSMI_DMSP14_OBS) at GES DISC","Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 ( ...

# %%
# Plot the embeddings color-coded based on topic
fig = px.scatter(df_embeddings_title_topic, x='x', y='y', hover_name='title', hover_data=['x', 'y'], color='topic')
fig.show()
fig.write_html('07-28-2022_DatasetEmbeddings_StratifiedByTopic.html')
# Out:
# <div>                            <div id="b53c3709-a91d-4940-bcfc-2fa24cae3637" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b53c3709-a91d-4940-bcfc-2fa24cae3637")) {                    Plotly.newPlot(                        "b53c3709-a91d-4940-bcfc-2fa24cae3637",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>topic=Land Surface<br>x=%{x}<br>y=%{y}<extra></extra>","hovertext":["Gridded Monthly Time-Mean Observation minus Analysis (oma) Values 0.5 x 0.667 degree V001 (MA_HIRS2_TIROSN_OMA) at GES DISC","Gridded Monthly Time-Mean Observation minus Analysis (oma) Values 0.5 x 0.667 degree V001 (MA_SSU_NOAA07_OMA) at GES DISC","TOVS LMD 5 DAY GRIDS from NOAA-12 V01 (TOVSB5ND) at GES DISC","Gridded Monthly Time-Mean Observation minus Analysis (oma) Values 0.5 x 0.667 degree V001 (MA_SSMI_DMSP10_OMA) at GES DISC","Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_MSU_NOAA14_OBS) at GES DISC","NLDAS Primary Forcing Data L4 Hourly 0.125 x 0.125 degree V2.0 (NLDAS_FORA0125_H) at GES DISC","Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_MSU_NOAA06_OBS) at GES DISC","Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_AMSUB_NOAA17_OBS) at GES DISC","NLDAS Secondary Forcing Data L4 Monthly 0.125 x 0.125 degree V002 (NLDAS_FORB0125_M) at GES DISC","Gridded Monthly Time-Mean Observation minus Forecast (omf) Values 0.5 x 0.667 degree V001 (MA_MSU_NOAA08_OMF) at GES DISC","Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_SSU_NOAA11_OBS) at GES DISC","Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_AMSUA_NOAA17_OBS) at GES DISC","Gridded Monthly Time-Mean Observation minus Forecast (omf) Values 0.5 x 0.667 degree V001 (MA_SSMI_DMSP08_OMF) at GES DISC","Gridded Monthly Time-Mean Observation minus Forecast (omf) Values 0.5 x 0.667 degree V001 (MA_HIRS2_NOAA14_OMF) at GES DISC","NLDAS Secondary Forcing Data L4 Monthly Climatology 0.125 x 0.125 degree V002 (NLDAS_FORB0125_MC) at GES DISC","TOVS GLA MONTHLY GRIDS from TIROS-N 02 (TOVSAMTN) at GES DISC","Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_HIRS2_AM_OBS) at GES DISC","Gridded Monthly Time-Mean Observation minus Forecast (omf) Values 0.5 x 0.667 degree V001 (MA_HIRS2_NOAA06_OMF) at GES DISC","Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_SSMI_DMSP13_OBS) at GES DISC","TOVS LMD DAILY GRIDS from NOAA-12 V01 (TOVSBDND) at GES DISC","Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_SSMI_DMSP14_OBS) at GES DISC","Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_HIRS2_NOAA08_OBS) at GES DISC","Gridded Monthly Time-Mean Observation minus Analysis (oma) Values 0.5 x 0.667 degree V001 (MA_MSU_NOAA10_OMA) at GES DISC","Gridded Monthly Time-Mean Observation minus Analysis (oma) Values 0.5 x 0.667 degree V001 (MA_AMSUA_NOAA15_OMA) at GES DISC","NLDAS Primary Forcing Data L4 Monthly Climatology 0.125 x 0.125 degree V2.0 (NLDAS_FORA0125_MC) at GES DISC","Gridded Monthly Time-Mean Observation minus Analysis (oma) Values 0.5 x 0.667 degree V001 (MA_SSU_NOAA14_OMA) at GES DISC","Gridded Monthly Time-Mean Observation minus Forecast (omf) Values 0.5 x 0.667 degree V001 (MA_MSU_NOAA09_OMF) at GES DISC","Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_AMSUB_NOAA16_OBS) at GES DISC","Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_MSU_NOAA07_OBS) at GES DISC","Gridded Monthly Time-Mean Observation minus Analysis (oma) Values 0.5 x 0.667 degree V001 (MA_SSU_NOAA06_OMA) at GES DISC","Gridded 6 hours Time-Mean Observation (obs) ...

# %%
df_tfidf

# %% [markdown]
#  (name, summed_tfidf, count_datasets_summed)

# %%
hierarchy_chains = []
for deepest, hierarchy in keyword_dict.items():
    hierarchy.reverse()
    new_chain = hierarchy + [deepest]
    hierarchy_chains.append(new_chain)

# %% [markdown]
# def group_then_create_dict(hierarchies):
#     group by first element, now list of groups of hierarchies
#     for all groups:
#         if len(group) == 1:
#             continue
#         else:
#             new_dict = {common first elt: group_then_create_dict(lists but shaved off first elt)}
#             group_then_create_dict(new_dict.vals())

# %%
title2kywrd

# %%
keyword_dict

# %%
from copy import deepcopy

title2allkw = deepcopy(title2kywrd)
for title, keywords in title2kywrd.items():
    higher_keywords = set()
    for keyword in keywords:
        higher_keywords |= set(keyword_dict[keyword])
    title2allkw[title] += list(higher_keywords)

# %%
title2allkw
# Out:
# {'Gridded Monthly Time-Mean Observation minus Analysis (oma) Values 0.5 x 0.667 degree V001 (MA_HIRS2_TIROSN_OMA) at GES DISC': ['Barometric Altitude',
#   'Terrain Elevation',
#   'Land Use/Land Cover Classification',
#   'Altitude',
#   'Topography',
#   'Land Surface',
#   'Atmosphere',
#   'Land Use/Land Cover',
#   'Earth Science'],
#  'Suomi NPP CrIS Level 1B Full Spectral Resolution V2 (SNPPCrISL1B) at GES DISC': ['Brightness Temperature',
#   'Infrared Radiance',
#   'Infrared Wavelengths',
#   'Earth Science',
#   'Spectral/Engineering'],
#  'GPM SSM/I on F13 (GPROF) Climate-based Radiometer Precipitation Profiling L2 1.5 hours 12 km V05 (GPM_2AGPROFF13SSMI_CLIM) at GES DISC': ['Atmospheric Water Vapor',
#   'Precipitation',
#   'Earth Science',
#   'Atmosphere'],
#  'Sentinel-5P TROPOMI Radiance product band 7 (SWIR detector) L1B 5.5km x 7km V1 (S5P_L1B_RA_BD7_HiR) at GES DISC': ['Atmospheric Emitted Radiation',
#   'Net Radiation',
#   'Radiative Forcing',
#   'Scattering',
#   'Shortwave Radiation',
#   'Platform Characteristics',
#   'Flight Data Logs',
#   'Orbital Characteristics',
#   'Viewing Geometry',
#   'Geolocation',
#   'Viewing Geometry',
#   'Atmospheric Radiation',
#   'Atmosphere',
#   'Earth Science',
#   'Sensor Characteristics',
#   'Platform Characteristics',
#   'Spectral/Engineering'],
#  'OMI/Aura NO2 Tropospheric, Stratospheric & Total Columns MINDS Daily L2 Global Gridded 0.25 degree x 0.25 degree V1.1 (OMI_MINDS_NO2G) at GES DISC': ['Atmospheric Nitric Acid',
#   'Nitric Oxide',
#   'Nitrogen Dioxide',
#   'Nitrogen Oxides',
#   'Nitrous Oxide',
#   'Atmospheric Chemistry',
#   'Nitrogen Compounds',
#   'Atmosphere',
#   'Earth Science'],
#  'MLS/Aura Level 3 Monthly Binned Hydroxyl (OH) Mixing Ratio on Assorted Grids V004 (ML3MBOH) at GES DISC': ['Hydroxyl',
#   'Atmospheric Chemistry',
#   'Earth Science',
#   'Hydrogen Compounds',
#   'Atmosphere'],
#  'Gridded Monthly Time-Mean Observation minus Analysis (oma) Values 0.5 x 0.667 degree V001 (MA_SSU_NOAA07_OMA) at GES DISC': ['Barometric Altitude',
#   'Terrain Elevation',
#   'Land Use/Land Cover Classification',
#   'Altitude',
#   'Topography',
#   'Land Surface',
#   'Atmosphere',
#   'Land Use/Land Cover',
#   'Earth Science'],
#  'Suomi NPP CrIS Level 1B Normal Spectral Resolution V1 (SNPPCrISL1BNSR) at GES DISC': ['Brightness Temperature',
#   'Infrared Radiance',
#   'Infrared Wavelengths',
#   'Earth Science',
#   'Spectral/Engineering'],
#  'MODIS/Aqua Aerosol 5-Min L2 Swath Subset 10km along MLS V002 (MAM04S0) at GES DISC': ['Aerosol Backscatter',
#   'Aerosol Extinction',
#   'Aerosol Optical Depth/Thickness',
#   'Aerosol Particle Properties',
#   'Aerosol Radiance',
#   'Cloud Condensation Nuclei',
#   'Radiative Flux',
#   'Atmospheric Radiation',
#   'Atmosphere',
#   'Aerosols',
#   'Earth Science'],
#  'GPM GMI Antenna Temperatures L1BASE 1.5 hours 13 km V05 (GPM_BASEGPMGMI) at GES DISC': ['Atmospheric Water Vapor',
#   'Precipitation',
#   'Earth Science',
#   'Atmosphere'],
#  'GPM MHS on NOAA-19 (GPROF) Radiometer Precipitation Profiling L2A 1.5 hours 17 km V05 (GPM_2AGPROFNOAA19MHS_CLIM) at GES DISC': ['Atmospheric Water Vapor',
#   'Precipitation',
#   'Earth Science',
#   'Atmosphere'],
#  'WindSat/Coriolis surface soil moisture (LPRM) L3 1 day 25 km x 25 km nighttime V001 (LPRM_WINDSAT_NT_SOILM3) at GES DISC': ['Vegetation Water Content',
#   'Soil Moisture/Water Content',
#   'Skin Temperature',
#   'Biosphere',
#   'Surface Thermal Properties',
#   'Vegetation',
#   'Earth Science',
#   'Land Surface',
#   'Soils',
#   'Plant Characteristics'],
#  'ATMOS L2 Trace Gases on Altitude Grid, Tab Delimited Format V3 (ATMOSL2AT) at GES DISC': ['Water Vapor',
#   'Atmospheric Carbon Dioxide',
#   'Atmospheric Ozone',
#   'Nitrous Oxide',
#   'Atmospheric Carbon Monoxide',
#   'Methane',
#   'Nitric Oxide',
#   'Nitrogen Dioxide',
#   'Atmospheric Nitric Acid',
#   'Hydrogen Fluoride',
#   'Hydrogen Chloride',
#   'Carbonyl Sulfide',
#   'Formaldehyde',
#   'Hypochlorous Acid',
#   'Dinitrogen Pentoxide',
#   'Chlorine Nitrate',
#   'Hydrogen Cyanide',
#   'Methyl Chloride',
#   'Cfc-12',
#   'Cfc-11',
#   'Carbon Tetrachloride',
#   'Hcfc-22',
#   'Formic Acid',
#   'Hydrogen-Deuterium Oxide',
#   'Sulfur Hexafluoride',
#   'Water Vapor Indicators',
#   'Atmospheric Chemistry',
#   'Atmosphere',
#   'Oxygen Compounds',
#   'Nitrogen Compounds',
#   'Halocarbons And Halogens',
#   'Earth Science',
#   'Atmospheric Water Vapor',
#   'Hydrogen Compounds',
#   'Sulfur Compounds',
#   'Chlorofluorocarbons',
#   'Carbon And Hydrocarbon Compounds',
#   'Hydrochlorofluorocarbons'],
#  'TOVS LMD 5 DAY GRIDS from NOAA-12 V01 (TOVSB5ND) at GES DISC': ['Atmospheric Ozone',
#   'Skin Temperature',
#   'Upper Air Temperature',
#   'Humidity',
#   'Water Vapor',
#   'Water Vapor Profiles',
#   'Clouds',
#   'Surface Thermal Properties',
#   'Atmospheric Chemistry',
#   'Oxygen Compounds',
#   'Atmosphere',
#   'Water Vapor Indicators',
#   'Earth Science',
#   'Atmospheric Water Vapor',
#   'Land Surface',
#   'Atmospheric Temperature'],
#  'TROPESS CrIS-SNPP L2 Ammonia for West Coast Fires, Standard Product V1 (TRPSDL2NH3CRSWCF) at GES DISC': ['Ammonia',
#   'Earth Science',
#   'Atmospheric Chemistry',
#   'Nitrogen Compounds',
#   'Atmosphere'],
#  'MLS/Aura Level 2 Diagnostics, Miscellaneous Grid V005 (ML2DGM) at GES DISC': ['Microwave Radiance',
#   'Microwave',
#   'Earth Science',
#   'Spectral/Engineering'],
#  'TOVS GLA 5 DAY GRIDS from NOAA-11 V01 (TOVSA5NH) at GES DISC': ['Atmospheric Ozone',
#   'Atmospheric Pressure Measurements',
#   'Outgoing Longwave Radiation',
#   'Air Temperature',
#   'Skin Temperature',
#   'Virtual Temperature',
#   'Vertical Profiles',
#   'Virtual Temperature',
#   'Humidity',
#   'Relative Humidity',
#   'Layered Precipitable Water',
#   'Total Precipitable Water',
#   'Cloud Fraction',
#   'Cloud Top Pressure',
#   'Cloud Top Temperature',
#   'Precipitation Amount',
#   'Land Surface Temperature',
#   'Sea Level Pressure',
#   'Sea Surface Temperature',
#   'Sea Surface Height',
#   'Oceans',
#   'Surface Thermal Properties',
#   'Oxygen Compounds',
#   'Cloud Properties',
#   'Atmospheric Water Vapor',
#   'Land Surface',
#   'Ocean Pressure',
#   'Ocean Temperature',
#   'Precipitation',
#   'Upper Air Temperature',
#   'Humidity',
#   'Atmospheric Chemistry',
#   'Atmospheric Radiation',
#   'Atmosphere',
#   'Water Vapor Indicators',
#   'Sea Surface Topography',
#   'Earth Science',
#   'Surface Temperature',
#   'Atmospheric Pressure',
#   'Clouds',
#   'Atmospheric Temperature'],
#  'Suomi NPP ATMS Sounder Science Investigator-led Processing System (SIPS) Level 1B Brightness Temperature V3 (SNPPATMSL1B) at GES DISC': ['Antenna Temperature',
#   'Brightness Temperature',
#   'Infrared Wavelengths',
#   'Microwave',
#   'Earth Science',
#   'Spectral/Engineering'],
#  'SORCE XPS Level 4 Solar Spectral Irradiance 0.1nm Res 5-Minute V012 (SOR4XPS5) at GES DISC': ['Solar Spectral Irradiance',
#   'Solar Irradiance',
#   'Sun-Earth Interactions',
#   'Solar Activity',
#   'Earth Science'],
#  'Aqua/AIRS L3 Daily Support Product (AIRS-only) 1 degree x 1 degree V7.0 at GES DISC': ['Carbon Monoxide',
#   'Geopotential Height',
#   'Tropopause',
#   'Methane',
#   'Atmospheric Ozone',
#   'Surface Pressure',
#   'Outgoing Longwave Radiation',
#   'Air Temperature',
#   'Upper Air Temperature',
#   'Humidity',
#   'Total Precipitable Water',
#   'Water Vapor',
#   'Water Vapor Profiles',
#   'Cloud Droplet Concentration/Size',
#   'Cloud Liquid Water/Ice',
#   'Cloud Optical Depth/Thickness',
#   'Cloud Height',
#   'Cloud Top Pressure',
#   'Cloud Top Temperature',
#   'Cloud Vertical Distribution',
#   'Cloud Types',
#   'Precipitation Rate',
#   'Emissivity',
#   'Skin Temperature',
#   'Sea Surface Temperature',
#   'Oceans',
#   'Surface Thermal Properties',
#   'Oxygen Compounds',
#   'Cloud Properties',
#   'Atmospheric Water Vapor',
#   'Land Surface',
#   'Cloud Microphysics',
#   'Precipitation',
#   'Ocean Temperature',
#   'Surface Radiative Properties',
#   'Altitude',
#   'Atmospheric Chemistry',
#   'Air Quality',
#   'Atmosphere',
#   'Atmospheric Radiation',
#   'Water Vapor Indicators',
#   'Earth Science',
#   'Surface Temperature',
#   'Atmospheric Pressure',
#   'Carbon And Hydrocarbon Compounds',
#   'Clouds',
#   'Atmospheric Temperature'],
#  'AIRS/Aqua L3 8-day Support Multiday Product (AIRS+AMSU) 1 degree x 1 degree V006 (AIRX3SP8) at GES DISC': ['Tropopause',
#   'Surface Pressure',
#   'Air Temperature',
#   'Upper Air Temperature',
#   'Total Precipitable Water',
#   'Water Vapor',
#   'Cloud Height',
#   'Cloud Top Pressure',
#   'Cloud Top Temperature',
#   'Cloud Vertical Distribution',
#   'Emissivity',
#   'Sea Surface Temperature',
#   'Skin Temperature',
#   'Carbon Monoxide',
#   'Geopotential Height',
#   'Humidity',
#   'Water Vapor Profiles',
#   'Cloud Liquid Water/Ice',
#   'Outgoing Longwave Radiation',
#   'Methane',
#   'Atmospheric Ozone',
#   'Cloud Droplet Concentration/Size',
#   'Cloud Optical Depth/Thickness',
#   'Cloud Types',
#   'Precipitation Rate',
#   'Oceans',
#   'Surface Thermal Properties',
#   'Oxygen Compounds',
#   'Cloud Properties',
#   'Atmospheric Water Vapor',
#   'Land Surface',
#   'Ocean Temperature',
#   'Cloud Microphysics',
#   'Precipitation',
#   'Surface Radiative Properties',
#   'Altitude',
#   'Water Vapor Indicators',
#   'Air Quality',
#   'Atmosphere',
#   'Atmospheric Radiation',
#   'Atmospheric Chemistry',
#   'Earth Science',
#   'Surface Temperature',
#   'Atmospheric Pressure',
#   'Carbon And Hydrocarbon Compounds',
#   'Clouds',
#   'Atmospheric Temperature'],
#  'MLS/Aura Level 2 Cloud Ice Product V004 (ML2IWC) at GES DISC': ['Cloud Liquid Water/Ice',
#   'Clouds',
#   'Cloud Microphysics',
#   'Earth Science',
#   'Atmosphere'],
#  'TROPESS AIRS-Aqua L2 Ammonia for Forward Stream, Standard Product V1 (TRPSDL2NH3AIRSFS) at GES DISC': ['Ammonia',
#   'Earth Science',
#   'Atmospheric Chemistry',
#   'Nitrogen Compounds',
#   'Atmosphere'],
#  'tavg3_3d_chm_Fe: MERRA Chem 3D IAU, Precip Mass Flux, Time average 3-hourly  1.25 x 1 degree V5.2.0 (MAT3FECHM) at GES DISC': ['Cloud Properties',
#   'Heat Flux',
#   'Longwave Radiation',
#   'Humidity',
#   'Total Precipitable Water',
#   'Water Vapor',
#   'Precipitation Rate',
#   'Surface Temperature',
#   'Water Vapor Indicators',
#   'Atmospheric Radiation',
#   'Atmosphere',
#   'Atmospheric Water Vapor',
#   'Earth Science',
#   'Clouds',
#   'Precipitation',
#   'Atmospheric Temperature'],
#  'TSIS SIM Level 3 Solar Spectral Irradiance 24-Hour Means V06 (TSIS_SSI_L3_24HR) at GES DISC': ['Solar Spectral Irradiance',
#   'Solar Irradiance',
#   'Sun-Earth Interactions',
#   'Solar Activity',
#   'Earth Science'],
#  'Gridded Monthly Time-Mean Observation minus Analysis (oma) Values 0.5 x 0.667 degree V001 (MA_SSMI_DMSP10_OMA) at GES DISC': ['Barometric Altitude',
#   'Terrain Elevation',
#   'Land Use/Land Cover Classification',
#   'Altitude',
#   'Topography',
#   'Land Surface',
#   'Atmosphere',
#   'Land Use/Land Cover',
#   'Earth Science'],
#  'OCO-3 Level 2 bias-corrected XCO2 and other select fields from the full-physics retrieval aggregated as daily files, Retrospective processing VEarlyR (OCO3_L2_Lite_FP) at GES DISC': ['Atmospheric Carbon Dioxide',
#   'Carbon And Hydrocarbon Compounds',
#   'Earth Science',
#   'Atmospheric Chemistry',
#   'Atmosphere'],
#  'Sounder SIPS: JPSS-1 CrIS Level 3 Specific Quality Control Gridded Daily CLIMCAPS V2 at GES DISC': ['Tropospheric Ozone',
#   'Tropopause',
#   'Methane',
#   'Atmospheric Ozone',
#   'Surface Pressure',
#   'Outgoing Longwave Radiation',
#   'Surface Temperature',
#   'Air Temperature',
#   'Upper Air Temperature',
#   'Layered Precipitable Water',
#   'Total Precipitable Water',
#   'Water Vapor Profiles',
#   'Cloud Fraction',
#   'Cloud Top Pressure',
#   'Cloud Top Temperature',
#   'Cloud Vertical Distribution',
#   'Precipitation Rate',
#   'Emissivity',
#   'Skin Temperature',
#   'Sea Surface Temperature',
#   'Oceans',
#   'Surface Thermal Properties',
#   'Oxygen Compounds',
#   'Cloud Properties',
#   'Atmospheric Water Vapor',
#   'Land Surface',
#   'Ocean Temperature',
#   'Precipitation',
#   'Surface Radiative Properties',
#   'Altitude',
#   'Atmospheric Chemistry',
#   'Air Quality',
#   'Atmosphere',
#   'Atmospheric Radiation',
#   'Water Vapor Indicators',
#   'Earth Science',
#   'Surface Temperature',
#   'Atmospheric Pressure',
#   'Carbon And Hydrocarbon Compounds',
#   'Clouds',
#   'Atmospheric Temperature'],
#  'MERRA-2 tavgU_3d_cld_Np: 3d,diurnal,Time-Averaged,Pressure-Level,Assimilation,Cloud Diagnostics 0.625 x 0.5 degree V5.12.4 (M2TUNPCLD) at GES DISC': ['Relative Humidity',
#   'Cloud Liquid Water/Ice',
#   'Cloud Optical Depth/Thickness',
#   'Cloud Properties',
#   'Cloud Fraction',
#   'Cloud Mass Flux',
#   'Water Vapor Indicators',
#   'Cloud Properties',
#   'Atmosphere',
#   'Atmospheric Water Vapor',
#   'Earth Science',
#   'Clouds',
#   'Cloud Microphysics',
#   'Humidity'],
#  'OCO-2 Level 2 meteorological parameters interpolated from global assimilation model for each sounding V10 (OCO2_L2_Met) at GES DISC': ['Atmospheric Carbon Dioxide',
#   'Carbon And Hydrocarbon Compounds',
#   'Earth Science',
#   'Atmospheric Chemistry',
#   'Atmosphere'],
#  'GPM PR on TRMM Reflectivity, Precipitation Statistics, Histograms, at Surface and Fixed Heights, 1 month 5x5 and 0.25x0.25 degree V06 (GPM_3PR) at GES DISC': ['Precipitation Rate',
#   'Earth Science',
#   'Precipitation',
#   'Atmosphere'],
#  'MLS/Aura Level 3 Daily Binned Temperature on Assorted Grids V005 (ML3DBT) at GES DISC': ['Upper Air Temperature',
#   'Earth Science',
#   'Atmospheric Temperature',
#   'Atmosphere'],
#  'NLDAS VIC Land Surface Model L4 Monthly 0.125 x 0.125 degree V002 (NLDAS_VIC0125_M) at GES DISC': ['Heat Flux',
#   'Longwave Radiation',
#   'Shortwave Radiation',
#   'Surface Temperature',
#   'Evaporation',
#   'Evapotranspiration',
#   'Rain',
#   'Snow',
#   'Canopy Characteristics',
#   'Leaf Characteristics',
#   'Vegetation Cover',
#   'Soil Moisture/Water Content',
#   'Soil Temperature',
#   'Albedo',
#   'Land Surface Temperature',
#   'Snow Water Equivalent',
#   'Runoff',
#   'Surface Thermal Properties',
#   'Atmospheric Water Vapor',
#   'Surface Water',
#   'Terrestrial Hydrosphere',
#   'Liquid Precipitation',
#   'Land Surface',
#   'Precipitation',
#   'Surface Radiative Properties',
#   'Water Vapor Processes',
#   'Biosphere',
#   'Atmospheric Radiation',
#   'Atmosphere',
#   'Vegetation',
#   'Surface Water Processes/Measurements',
#   'Solid Precipitation',
#   'Earth Science',
#   'Snow/Ice',
#   'Atmospheric Temperature',
#   'Soils'],
#  'TROPESS CrIS-SNPP L2 Methanol for Forward Stream, Standard Product V1 (TRPSDL2CH3OHCRSFS) at GES DISC': ['Methanol',
#   'Halocarbons And Halogens',
#   'Earth Science',
#   'Atmospheric Chemistry',
#   'Atmosphere'],
#  'OCO-3 Level 2 geolocated XCO2 retrievals results, physical model VEarlyR (OCO3_L2_Standard) at GES DISC': ['Atmospheric Carbon Dioxide',
#   'Carbon And Hydrocarbon Compounds',
#   'Earth Science',
#   'Atmospheric Chemistry',
#   'Atmosphere'],
#  'GPM TMI on TRMM (GPROF) Climate-based Radiometer Precipitation Profiling L2A 1.5 hours 13 km V05 (GPM_2AGPROFTRMMTMI_CLIM) at GES DISC': ['Atmospheric Water Vapor',
#   'Precipitation',
#   'Earth Science',
#   'Atmosphere'],
#  'Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_MSU_NOAA14_OBS) at GES DISC': ['Barometric Altitude',
#   'Terrain Elevation',
#   'Land Use/Land Cover Classification',
#   'Altitude',
#   'Topography',
#   'Land Surface',
#   'Atmosphere',
#   'Land Use/Land Cover',
#   'Earth Science'],
#  'Carbon Monitoring System Lake Michigan Primary Production Monthly V1 (CMSLakeMichiganPPM) at GES DISC': ['Primary Production',
#   'Biosphere',
#   'Earth Science',
#   'Ecological Dynamics',
#   'Ecosystem Functions'],
#  'Aqua/AIRS L3 Monthly Standard Physical Retrieval (AIRS-only) 1 degree x 1 degree V7.0 at GES DISC': ['Carbon Monoxide',
#   'Geopotential Height',
#   'Tropopause',
#   'Methane',
#   'Atmospheric Ozone',
#   'Surface Pressure',
#   'Outgoing Longwave Radiation',
#   'Air Temperature',
#   'Upper Air Temperature',
#   'Humidity',
#   'Total Precipitable Water',
#   'Water Vapor',
#   'Water Vapor Profiles',
#   'Cloud Liquid Water/Ice',
#   'Cloud Height',
#   'Cloud Top Pressure',
#   'Cloud Top Temperature',
#   'Cloud Vertical Distribution',
#   'Emissivity',
#   'Skin Temperature',
#   'Sea Surface Temperature',
#   'Oceans',
#   'Surface Thermal Properties',
#   'Oxygen Compounds',
#   'Cloud Properties',
#   'Atmospheric Water Vapor',
#   'Land Surface',
#   'Cloud Microphysics',
#   'Ocean Temperature',
#   'Surface Radiative Properties',
#   'Altitude',
#   'Atmospheric Chemistry',
#   'Air Quality',
#   'Atmosphere',
#   'Atmospheric Radiation',
#   'Water Vapor Indicators',
#   'Earth Science',
#   'Surface Temperature',
#   'Atmospheric Pressure',
#   'Carbon And Hydrocarbon Compounds',
#   'Clouds',
#   'Atmospheric Temperature'],
#  'GPM SAPHIR on MT1 (PRPS) Radiometer Precipitation Profiling L2 1.5 hours 10 km V06 (GPM_2APRPSMT1SAPHIR) at GES DISC': ['Atmospheric Water Vapor',
#   'Precipitation',
#   'Earth Science',
#   'Atmosphere'],
#  'MERRA-2 inst6_3d_ana_Nv: 3d,6-Hourly,Instantaneous,Model-Level,Analysis,Analyzed Meteorological Fields 0.625 x 0.5 degree V5.12.4 (M2I6NVANA) at GES DISC': ['Geopotential Height',
#   'Atmospheric Ozone',
#   'Surface Pressure',
#   'Air Temperature',
#   'Upper Air Temperature',
#   'Atmospheric Water Vapor',
#   'Specific Humidity',
#   'U/V Wind Components',
#   'U/V Wind Components',
#   'Altitude',
#   'Atmospheric Chemistry',
#   'Oxygen Compounds',
#   'Atmosphere',
#   'Water Vapor Indicators',
#   'Earth Science',
#   'Atmospheric Water Vapor',
#   'Atmospheric Winds',
#   'Surface Temperature',
#   'Atmospheric Pressure',
#   'Upper Level Winds',
#   'Atmospheric Temperature',
#   'Humidity'],
#  'NLDAS Primary Forcing Data L4 Hourly 0.125 x 0.125 degree V2.0 (NLDAS_FORA0125_H) at GES DISC': ['Surface Pressure',
#   'Longwave Radiation',
#   'Shortwave Radiation',
#   'Surface Temperature',
#   'Evaporation',
#   'Humidity',
#   'Convection',
#   'Surface Winds',
#   'Rain',
#   'Land Surface Temperature',
#   'Water Vapor Processes',
#   'Wind Dynamics',
#   'Surface Thermal Properties',
#   'Water Vapor Indicators',
#   'Atmospheric Radiation',
#   'Atmosphere',
#   'Earth Science',
#   'Atmospheric Water Vapor',
#   'Atmospheric Winds',
#   'Atmospheric Pressure',
#   'Liquid Precipitation',
#   'Land Surface',
#   'Precipitation',
#   'Atmospheric Temperature'],
#  'GPM VIRS on TRMM Radiance L1B 1.5 hours 2 km V05 (GPM_1BVIRS) at GES DISC': ['Radiance @ 1.6Um',
#   'Radiance @ 3.75Um',
#   'Infrared Radiance',
#   'Sensor Counts',
#   'Radiance @ 10.8Um',
#   'Radiance @ 12.0Um',
#   'Attitude Characteristics',
#   'Satellite Local Zenith Angle',
#   'Sensor Counts',
#   'Radiance @ 0.63Um',
#   'Visible Radiance',
#   'Infrared Imagery',
#   'Earth Science',
#   'Infrared Wavelengths',
#   'Viewing Geometry',
#   'Thermal Infrared',
#   'Sensor Characteristics',
#   'Visible Imagery',
#   'Visible Wavelengths',
#   'Platform Characteristics',
#   'Spectral/Engineering'],
#  'GPM AMSR-2 on GCOM-W1 (GPROF) Radiometer Precipitation Profiling L3 1 month 0.25 degree x 0.25 degree V05 (GPM_3GPROFGCOMW1AMSR2) at GES DISC': ['Atmospheric Water Vapor',
#   'Precipitation',
#   'Earth Science',
#   'Atmosphere'],
#  'GPM SSMIS on F19 (GPROF) Climate-based Radiometer Precipitation Profiling L3 1 month 0.25 degree x 0.25 degree V05 (GPM_3GPROFF19SSMIS_CLIM) at GES DISC': ['Atmospheric Water Vapor',
#   'Precipitation',
#   'Earth Science',
#   'Atmosphere'],
#  'Aqua/AIRS L2 Cloud-Cleared Infrared Radiances (AIRS+AMSU+HSB) V7.0 at GES DISC': ['Cloud-Cleared Infrared Radiance',
#   'Earth Science',
#   'Infrared Radiance',
#   'Spectral/Engineering',
#   'Infrared Wavelengths'],
#  'GPCP Precipitation Level 3 Daily 0.5-Degree V3.1 (GPCPDAY) at GES DISC': ['Precipitation',
#   'Precipitation Rate',
#   'Atmosphere',
#   'Precipitation',
#   'Earth Science'],
#  'Sounder SIPS: Suomi NPP CrIMSS Level 3 Comprehensive Quality Control Gridded Daily CLIMCAPS Normal Spectral Resolution V2 at GES DISC': ['Tropospheric Ozone',
#   'Tropopause',
#   'Methane',
#   'Atmospheric Ozone',
#   'Surface Pressure',
#   'Outgoing Longwave Radiation',
#   'Surface Temperature',
#   'Air Temperature',
#   'Upper Air Temperature',
#   'Layered Precipitable Water',
#   'Total Precipitable Water',
#   'Water Vapor Profiles',
#   'Cloud Fraction',
#   'Cloud Top Pressure',
#   'Cloud Top Temperature',
#   'Cloud Vertical Distribution',
#   'Precipitation Rate',
#   'Emissivity',
#   'Skin Temperature',
#   'Sea Surface Temperature',
#   'Oceans',
#   'Surface Thermal Properties',
#   'Oxygen Compounds',
#   'Cloud Properties',
#   'Atmospheric Water Vapor',
#   'Land Surface',
#   'Ocean Temperature',
#   'Precipitation',
#   'Surface Radiative Properties',
#   'Altitude',
#   'Atmospheric Chemistry',
#   'Air Quality',
#   'Atmosphere',
#   'Atmospheric Radiation',
#   'Water Vapor Indicators',
#   'Earth Science',
#   'Surface Temperature',
#   'Atmospheric Pressure',
#   'Carbon And Hydrocarbon Compounds',
#   'Clouds',
#   'Atmospheric Temperature'],
#  'ATMOS L2 Trace Gases on Potential Temperature Grid, Tab Delimited Format V3 (ATMOSL2TT) at GES DISC': ['Water Vapor',
#   'Atmospheric Carbon Dioxide',
#   'Atmospheric Ozone',
#   'Nitrous Oxide',
#   'Atmospheric Carbon Monoxide',
#   'Methane',
#   'Nitric Oxide',
#   'Nitrogen Dioxide',
#   'Atmospheric Nitric Acid',
#   'Hydrogen Fluoride',
#   'Hydrogen Chloride',
#   'Carbonyl Sulfide',
#   'Formaldehyde',
#   'Hypochlorous Acid',
#   'Dinitrogen Pentoxide',
#   'Chlorine Nitrate',
#   'Hydrogen Cyanide',
#   'Methyl Chloride',
#   'Cfc-12',
#   'Cfc-11',
#   'Carbon Tetrachloride',
#   'Hcfc-22',
#   'Formic Acid',
#   'Hydrogen-Deuterium Oxide',
#   'Sulfur Hexafluoride',
#   'Water Vapor Indicators',
#   'Atmospheric Chemistry',
#   'Atmosphere',
#   'Oxygen Compounds',
#   'Nitrogen Compounds',
#   'Halocarbons And Halogens',
#   'Earth Science',
#   'Atmospheric Water Vapor',
#   'Hydrogen Compounds',
#   'Sulfur Compounds',
#   'Chlorofluorocarbons',
#   'Carbon And Hydrocarbon Compounds',
#   'Hydrochlorofluorocarbons'],
#  'GLDAS CLM Land Surface Model L4 3 hourly 1.0 x 1.0 degree Subsetted V001 (GLDAS_CLM10SUBP_3H) at GES DISC': ['Surface Pressure',
#   'Heat Flux',
#   'Longwave Radiation',
#   'Shortwave Radiation',
#   'Surface Temperature',
#   'Humidity',
#   'Evapotranspiration',
#   'Surface Winds',
#   'Rain',
#   'Precipitation Rate',
#   'Snow',
#   'Soil Moisture/Water Content',
#   'Soil Temperature',
#   'Land Surface Temperature',
#   'Snow Water Equivalent',
#   'Runoff',
#   'Surface Thermal Properties',
#   'Atmospheric Water Vapor',
#   'Atmospheric Winds',
#   'Surface Water',
#   'Terrestrial Hydrosphere',
#   'Liquid Precipitation',
#   'Land Surface',
#   'Precipitation',
#   'Water Vapor Processes',
#   'Water Vapor Indicators',
#   'Atmospheric Radiation',
#   'Atmosphere',
#   'Surface Water Processes/Measurements',
#   'Solid Precipitation',
#   'Earth Science',
#   'Atmospheric Pressure',
#   'Snow/Ice',
#   'Atmospheric Temperature',
#   'Soils'],
#  'OCO-3 Level 1B calibrated, geolocated calibration spectra, Retrospective Processing EarlyR (OCO3_L1B_Calibration) at GES DISC': ['Atmospheric Carbon Dioxide',
#   'Infrared Radiance',
#   'Infrared Wavelengths',
#   'Atmospheric Chemistry',
#   'Atmosphere',
#   'Carbon And Hydrocarbon Compounds',
#   'Earth Science',
#   'Spectral/Engineering'],
#  'TOMS Nimbus-7 UV Reflectivity Daily L3 Global 1 deg x 1.25 deg Lat/Lon Grid V008 (TOMSN7L3dref) at GES DISC': ['Reflectivity',
#   'Reflectance',
#   'Earth Science',
#   'Atmospheric Radiation',
#   'Atmosphere'],
#  'MERRA-2 inst1_2d_int_Nx: 2d,1-Hourly,Instantaneous,Single-Level,Assimilation,Vertically Integrated Diagnostics 0.625 x 0.5 degree V5.12.4 (M2I1NXINT) at GES DISC': ['Total Precipitable Water',
#   'Cloud Liquid Water/Ice',
#   'Atmospheric Water Vapor',
#   'Oxygen Compounds',
#   'Potential Temperature',
#   'Potential Temperature',
#   'Air Mass/Density',
#   'Water Vapor Indicators',
#   'Atmospheric Chemistry',
#   'Atmosphere',
#   'Earth Science',
#   'Atmospheric Water Vapor',
#   'Surface Temperature',
#   'Atmospheric Pressure',
#   'Clouds',
#   'Cloud Microphysics',
#   'Atmospheric Temperature'],
#  'Sentinel-5P TROPOMI Tropospheric Ozone Profile 1-Orbit L2 5.5km x 3.5km V1 (S5P_L2__O3_TPR_HiR) at GES DISC': ['Oxygen Compounds',
#   'Atmospheric Ozone',
#   'Atmospheric Chemistry',
#   'Oxygen Compounds',
#   'Atmosphere',
#   'Earth Science'],
#  'SBUV2/NOAA-16 Level 2 Daily Ozone Profile and Total Column from CD-ROM V008 (SBUV2N16O3) at GES DISC': ['Ozone Profiles And Total Column',
#   'Uv Reflectivity',
#   'Uv Aerosol Index',
#   'Atmospheric Chemistry',
#   'Oxygen Compounds',
#   'Atmosphere',
#   'Atmospheric Radiation',
#   'Dust/Ash/Smoke',
#   'Earth Science',
#   'Aerosols',
#   'Atmospheric Ozone',
#   'Reflectance'],
#  'NLDAS Mosaic Land Surface Model L4 Hourly 0.125 x 0.125 degree V002 (NLDAS_MOS0125_H) at GES DISC': ['Heat Flux',
#   'Longwave Radiation',
#   'Shortwave Radiation',
#   'Surface Temperature',
#   'Evaporation',
#   'Evapotranspiration',
#   'Rain',
#   'Snow',
#   'Canopy Characteristics',
#   'Leaf Characteristics',
#   'Vegetation Cover',
#   'Soil Moisture/Water Content',
#   'Soil Temperature',
#   'Albedo',
#   'Land Surface Temperature',
#   'Snow Water Equivalent',
#   'Runoff',
#   'Surface Thermal Properties',
#   'Atmospheric Water Vapor',
#   'Surface Water',
#   'Terrestrial Hydrosphere',
#   'Liquid Precipitation',
#   'Land Surface',
#   'Precipitation',
#   'Surface Radiative Properties',
#   'Water Vapor Processes',
#   'Biosphere',
#   'Atmospheric Radiation',
#   'Atmosphere',
#   'Vegetation',
#   'Surface Water Processes/Measurements',
#   'Solid Precipitation',
#   'Earth Science',
#   'Snow/Ice',
#   'Atmospheric Temperature',
#   'Soils'],
#  'TROPESS CrIS-SNPP and TROPOMI-S5P L2 Carbon Monoxide for Forward Stream, Standard Product V1 (TRPSDL2COCRSTRPOMIFS) at GES DISC': ['Carbon Monoxide',
#   'Earth Science',
#   'Air Quality',
#   'Atmosphere'],
#  'OMI/Aura NO2 Tropospheric, Stratospheric & Total Columns MINDS 1-Orbit L2 Swath 13 km x 24 km V1 (OMI_MINDS_NO2) at GES DISC': ['Atmospheric Nitric Acid',
#   'Nitric Oxide',
#   'Nitrogen Dioxide',
#   'Nitrogen Oxides',
#   'Nitrous Oxide',
#   'Atmospheric Chemistry',
#   'Nitrogen Compounds',
#   'Atmosphere',
#   'Earth Science'],
#  'MERRA-2 tavgM_2d_glc_Nx: 2d,Monthly mean,Time-Averaged,Single-Level,Assimilation,Land Ice Surface Diagnostics 0.625 x 0.5 degree V5.12.4 (M2TMNXGLC) at GES DISC': ['Albedo',
#   'Snow Depth',
#   'Snow Depth',
#   'Glacier Runoff',
#   'Glacier Runoff',
#   'Snow Cover',
#   'Earth Science',
#   'Cryosphere',
#   'Terrestrial Hydrosphere',
#   'Glaciers/Ice Sheets',
#   'Land Surface',
#   'Snow/Ice',
#   'Glaciers',
#   'Surface Radiative Properties'],
#  'GPM SSMIS on F17 (GPROF) Radiometer Precipitation Profiling L3 1 day 0.25 degree x 0.25 degree V05 (GPM_3GPROFF17SSMIS_DAY) at GES DISC': ['Atmospheric Water Vapor',
#   'Precipitation',
#   'Earth Science',
#   'Atmosphere'],
#  'Sentinel-5P TROPOMI Carbon Monoxide CO Column 1-Orbit L2 5.5km x 7km V1 (S5P_L2__CO_____HiR) at GES DISC': ['Air Quality',
#   'Carbon Monoxide',
#   'Carbon And Hydrocarbon Compounds',
#   'Atmospheric Carbon Monoxide',
#   'Atmospheric Chemistry',
#   'Air Quality',
#   'Atmosphere',
#   'Carbon And Hydrocarbon Compounds',
#   'Earth Science'],
#  'GPM PR and TMI on TRMM Combined Convective-Stratiform Latent Heating Profiles L3 1 month 0.25x0.25 degree V06 (GPM_3HCSH_TRMM) at GES DISC': ['Heat Flux',
#   'Earth Science',
#   'Atmospheric Radiation',
#   'Atmosphere'],
#  'TRMM Attitude and VIRS Packets and Header Record L1A V7 (TRMM_1A01) at GES DISC': ['Radiance @ 1.6Um',
#   'Radiance @ 3.75Um',
#   'Infrared Radiance',
#   'Sensor Counts',
#   'Radiance @ 10.8Um',
#   'Radiance @ 12.0Um',
#   'Attitude Characteristics',
#   'Satellite Local Zenith Angle',
#   'Sensor Counts',
#   'Radiance @ 0.63Um',
#   'Visible Radiance',
#   'Infrared Imagery',
#   'Earth Science',
#   'Infrared Wavelengths',
#   'Viewing Geometry',
#   'Thermal Infrared',
#   'Sensor Characteristics',
#   'Visible Imagery',
#   'Visible Wavelengths',
#   'Platform Characteristics',
#   'Spectral/Engineering'],
#  'Sentinel-5P TROPOMI Ozone Profile 1-Orbit L2 30km x 30km V2 (S5P_L2__O3__PR_HiR) at GES DISC': ['Oxygen Compounds',
#   'Ozone',
#   'Atmospheric Chemistry',
#   'Oxygen Compounds',
#   'Atmosphere',
#   'Earth Science'],
#  'MLS/Aura Level 3 Monthly Binned Carbon Monoxide (CO) Mixing Ratio on Assorted Grids V005 (ML3MBCO) at GES DISC': ['Atmospheric Carbon Monoxide',
#   'Carbon And Hydrocarbon Compounds',
#   'Earth Science',
#   'Atmospheric Chemistry',
#   'Atmosphere'],
#  'NCEP/DOE Reanalysis II in HDF-EOS5, for GSSTF2c, 1x1 deg Daily grid V2c (GSSTF_NCEP) at GES DISC': ['Sea Level Pressure',
#   'Air Temperature',
#   'Skin Temperature',
#   'Surface Temperature',
#   'Evaporation',
#   'Humidity',
#   'Total Precipitable Water',
#   'Water Vapor',
#   'Surface Winds',
#   'Turbulence',
#   'Wind Stress',
#   'Atmospheric Heating',
#   'Heat Flux',
#   'Radiative Flux',
#   'Conduction',
#   'Evaporation',
#   'Heat Flux',
#   'Sea Level Pressure',
#   'Sea Surface Temperature',
#   'Surface Winds',
#   'Turbulence',
#   'Wind Stress',
#   'Wind Dynamics',
#   'Oceans',
#   'Surface Thermal Properties',
#   'Atmospheric Water Vapor',
#   'Atmospheric Winds',
#   'Land Surface',
#   'Ocean Pressure',
#   'Ocean Temperature',
#   'Water Vapor Processes',
#   'Water Vapor Indicators',
#   'Atmospheric Radiation',
#   'Atmosphere',
#   'Earth Science',
#   'Surface Temperature',
#   'Ocean Heat Budget',
#   'Atmospheric Temperature'],
#  'MLS/Aura Level 3 Daily Binned Water Vapor (H2O) Mixing Ratio on Zonal and Similar Grids V005 (ML3DZH2O) at GES DISC': ['Water Vapor Mixing Ratio Profiles',
#   'Earth Science',
#   'Atmospheric Water Vapor',
#   'Water Vapor Profiles',
#   'Atmosphere'],
#  'TROPESS TROPOMI-S5P L2 Ozone for Forward Stream, Standard Product V1 (TRPSDL2O3TRPOMIFS) at GES DISC': ['Ozone',
#   'Atmospheric Chemistry',
#   'Earth Science',
#   'Oxygen Compounds',
#   'Atmosphere'],
#  'tavgM_2d_chm_Fx: MERRA Chem 2D IAU Diagnostics, Fluxes and Meteorology, Monthly Mean  1.25 x 1 degree V5.2.0 (MATMFXCHM) at GES DISC': ['Cloud Properties',
#   'Heat Flux',
#   'Longwave Radiation',
#   'Humidity',
#   'Total Precipitable Water',
#   'Water Vapor',
#   'Precipitation Rate',
#   'Surface Temperature',
#   'Water Vapor Indicators',
#   'Atmospheric Radiation',
#   'Atmosphere',
#   'Atmospheric Water Vapor',
#   'Earth Science',
#   'Clouds',
#   'Precipitation',
#   'Atmospheric Temperature'],
#  'Sentinel-5P TROPOMI Sulphur Dioxide SO2 1-Orbit L2 5.5km x 3.5km V1 (S5P_L2__SO2____HiR) at GES DISC': ['Chemical Composition',
#   'Sulfate Particles',
#   'Sulfur Oxides',
#   'Sulfur Compounds',
#   'Sulfur Dioxide',
#   'Atmospheric Chemistry',
#   'Air Quality',
#   'Atmosphere',
#   'Earth Science',
#   'Sulfur Compounds',
#   'Aerosols'],
#  'HIRDLS-MLS/Aura Level 3 Monthly 10 x 20 deg Ice Water Content V002 (HIRMLS3IWC) at GES DISC': ['Cloud Liquid Water/Ice',
#   'Clouds',
#   'Cloud Microphysics',
#   'Earth Science',
#   'Atmosphere'],
#  'MLS/Aura Level 3 Daily Binned Geopotential Height (GPH) on Zonal and Similar Grids V005 (ML3DZGPH) at GES DISC': ['Geopotential Height',
#   'Altitude',
#   'Earth Science',
#   'Atmosphere'],
#  'TRMM Ground Validation Radar Site Rain Rate Map L2 1 hour 2 km V7 (TRMM_2A53) at GES DISC': ['Precipitation Rate',
#   'Rain',
#   'Radar Reflectivity',
#   'Liquid Precipitation',
#   'Radar',
#   'Atmosphere',
#   'Precipitation',
#   'Earth Science',
#   'Spectral/Engineering'],
#  'MLS/Aura Level 3 Daily Binned Ozone (O3) Mixing Ratio on Zonal and Similar Grids V004 (ML3DZO3) at GES DISC': ['Atmospheric Ozone',
#   'Atmospheric Chemistry',
#   'Earth Science',
#   'Oxygen Compounds',
#   'Atmosphere'],
#  'AIRS/Aqua L3 Monthly Support Product (AIRS+AMSU) 1 degree x 1 degree V006 (AIRX3SPM) at GES DISC': ['Tropopause',
#   'Surface Pressure',
#   'Air Temperature',
#   'Upper Air Temperature',
#   'Total Precipitable Water',
#   'Water Vapor',
#   'Cloud Height',
#   'Cloud Top Pressure',
#   'Cloud Top Temperature',
#   'Cloud Vertical Distribution',
#   'Emissivity',
#   'Sea Surface Temperature',
#   'Skin Temperature',
#   'Carbon Monoxide',
#   'Geopotential Height',
#   'Humidity',
#   'Water Vapor Profiles',
#   'Cloud Liquid Water/Ice',
#   'Outgoing Longwave Radiation',
#   'Methane',
#   'Atmospheric Ozone',
#   'Cloud Droplet Concentration/Size',
#   'Cloud Optical Depth/Thickness',
#   'Cloud Types',
#   'Precipitation Rate',
#   'Oceans',
#   'Surface Thermal Properties',
#   'Oxygen Compounds',
#   'Cloud Properties',
#   'Atmospheric Water Vapor',
#   'Land Surface',
#   'Ocean Temperature',
#   'Cloud Microphysics',
#   'Precipitation',
#   'Surface Radiative Properties',
#   'Altitude',
#   'Water Vapor Indicators',
#   'Air Quality',
#   'Atmosphere',
#   'Atmospheric Radiation',
#   'Atmospheric Chemistry',
#   'Earth Science',
#   'Surface Temperature',
#   'Atmospheric Pressure',
#   'Carbon And Hydrocarbon Compounds',
#   'Clouds',
#   'Atmospheric Temperature'],
#  'Sentinel-5P TROPOMI Irradiance product SWIR module L1B V2 (S5P_L1B_IR_SIR) at GES DISC': ['Atmospheric Emitted Radiation',
#   'Incoming Solar Radiation',
#   'Net Radiation',
#   'Radiative Forcing',
#   'Scattering',
#   'Shortwave Radiation',
#   'Solar Irradiance',
#   'Solar Radiation',
#   'Flight Data Logs',
#   'Orbital Characteristics',
#   'Viewing Geometry',
#   'Geolocation',
#   'Viewing Geometry',
#   'Atmospheric Radiation',
#   'Atmosphere',
#   'Earth Science',
#   'Sensor Characteristics',
#   'Platform Characteristics',
#   'Spectral/Engineering'],
#  'Sentinel-5P TROPOMI Radiance product band 7 (SWIR detector) L1B V2 (S5P_L1B_RA_BD7) at GES DISC': ['Atmospheric Emitted Radiation',
#   'Net Radiation',
#   'Radiative Forcing',
#   'Scattering',
#   'Shortwave Radiation',
#   'Platform Characteristics',
#   'Flight Data Logs',
#   'Orbital Characteristics',
#   'Viewing Geometry',
#   'Geolocation',
#   'Viewing Geometry',
#   'Atmospheric Radiation',
#   'Atmosphere',
#   'Earth Science',
#   'Sensor Characteristics',
#   'Platform Characteristics',
#   'Spectral/Engineering'],
#  'WindSat/Coriolis surface soil moisture (LPRM) L2 V001 (LPRM_WINDSAT_SOILM2) at GES DISC': ['Vegetation Water Content',
#   'Soil Moisture/Water Content',
#   'Skin Temperature',
#   'Biosphere',
#   'Surface Thermal Properties',
#   'Vegetation',
#   'Earth Science',
#   'Land Surface',
#   'Soils',
#   'Plant Characteristics'],
#  'FLDAS Noah Land Surface Model L4 Global Monthly 0.1 x 0.1 degree (GDAS and CHIRPS-PRELIM) V001 (FLDAS_NOAH01_CP_GL_M) at GES DISC': ['Surface Pressure',
#   'Heat Flux',
#   'Longwave Radiation',
#   'Shortwave Radiation',
#   'Air Temperature',
#   'Specific Humidity',
#   'Evapotranspiration',
#   'Wind Speed',
#   'Rain',
#   'Snow',
#   'Soil Moisture/Water Content',
#   'Soil Temperature',
#   'Land Surface Temperature',
#   'Snow Cover',
#   'Snow Depth',
#   'Snow Water Equivalent',
#   'Runoff',
#   'Surface Thermal Properties',
#   'Atmospheric Water Vapor',
#   'Atmospheric Winds',
#   'Cryosphere',
#   'Terrestrial Hydrosphere',
#   'Surface Water',
#   'Liquid Precipitation',
#   'Land Surface',
#   'Precipitation',
#   'Humidity',
#   'Water Vapor Processes',
#   'Water Vapor Indicators',
#   'Atmospheric Radiation',
#   'Atmosphere',
#   'Surface Water Processes/Measurements',
#   'Solid Precipitation',
#   'Earth Science',
#   'Surface Winds',
#   'Surface Temperature',
#   'Atmospheric Pressure',
#   'Snow/Ice',
#   'Atmospheric Temperature',
#   'Soils'],
#  'Carbon Monitoring System Flux for Prior Total Carbon L4 V1 (CMSFluxTotalprior) at GES DISC': ['Atmospheric Carbon Dioxide',
#   'Carbon Dioxide',
#   'Oceans',
#   'Atmospheric Chemistry',
#   'Atmosphere',
#   'Carbon And Hydrocarbon Compounds',
#   'Earth Science',
#   'Ocean Chemistry'],
#  'TOMS EP Total Column Ozone Daily and Monthly Zonal Means V008 (TOMSEPL3ztoz) at GES DISC': ['Total Ozone',
#   'Atmospheric Chemistry',
#   'Oxygen Compounds',
#   'Atmosphere',
#   'Atmospheric Ozone',
#   'Earth Science'],
#  'Sentinel-5P TROPOMI Carbon Monoxide CO Column 1-Orbit L2 7km x 7km V1 (S5P_L2__CO____) at GES DISC': ['Air Quality',
#   'Carbon Monoxide',
#   'Carbon And Hydrocarbon Compounds',
#   'Atmospheric Carbon Monoxide',
#   'Atmospheric Chemistry',
#   'Air Quality',
#   'Atmosphere',
#   'Carbon And Hydrocarbon Compounds',
#   'Earth Science'],
#  'GEOS-Carb CASA-GFED Monthly Fire Fuel NPP Rh NEE Fluxes 0.5 degree x 0.5 degree V3 (GEOS_CASAGFED_M_FLUX) at GES DISC': ['Atmospheric Carbon Dioxide',
#   'Carbon Dioxide',
#   'Oceans',
#   'Atmospheric Chemistry',
#   'Atmosphere',
#   'Carbon And Hydrocarbon Compounds',
#   'Earth Science',
#   'Ocean Chemistry'],
#  'MERRA-2 tavgU_3d_tdt_Np: 3d,diurnal,Time-Averaged,Pressure-Level,Assimilation,Temperature Tendencies 0.625 x 0.5 degree V5.12.4 (M2TUNPTDT) at GES DISC': ['Upper Air Temperature',
#   'Air Temperature',
#   'Temperature Tendency',
#   'Atmosphere',
#   'Earth Science',
#   'Atmospheric Temperature',
#   'Surface Temperature'],
#  'OCO-2 Level 0 spacecraft attitude data V10 (OCO2_Att) at GES DISC': ['Attitude Characteristics',
#   'Earth Science',
#   'Platform Characteristics',
#   'Spectral/Engineering'],
#  'MERRA-2 tavg3_3d_mst_Np: 3d,3-Hourly,Time-Averaged,Pressure-Level,Assimilation,Moist Processes Diagnostics 0.625 x 0.5 degree V5.12.4 (M2T3NPMST) at GES DISC': ['Precipitation Rate',
#   'Water Vapor Flux',
#   'Water Vapor Processes',
#   'Atmospheric Water Vapor',
#   'Atmosphere',
#   'Precipitation',
#   'Earth Science'],
#  'TROPESS CrIS-SNPP L2 Ozone for West Coast Fires, Standard Product V1 (TRPSDL2O3CRSWCF) at GES DISC': ['Ozone',
#   'Atmospheric Chemistry',
#   'Earth Science',
#   'Oxygen Compounds',
#   'Atmosphere'],
#  'Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_MSU_NOAA06_OBS) at GES DISC': ['Barometric Altitude',
#   'Terrain Elevation',
#   'Land Use/Land Cover Classification',
#   'Altitude',
#   'Topography',
#   'Land Surface',
#   'Atmosphere',
#   'Land Use/Land Cover',
#   'Earth Science'],
#  'MRIR/Nimbus-3 Level 1 Meteorological Radiation Data V001 (MRIRN3L1) at GES DISC': ['Brightness Temperature',
#   'Earth Science',
#   'Infrared Wavelengths',
#   'Spectral/Engineering'],
#  'OMI/Aura Level 1B UV Global Geolocated Earthshine Radiances 1-orbit L2 Swath 13x24 km V003 (OML1BRUG) at GES DISC': ['Ultraviolet Radiance',
#   'Ultraviolet Wavelengths',
#   'Earth Science',
#   'Spectral/Engineering'],
#  'GPM PR on TRMM Echo Power L1B 1.5 hours 5 km V05 (GPM_1BPR) at GES DISC': ['Radar Backscatter',
#   'Radar Reflectivity',
#   'Radar',
#   'Earth Science',
#   'Spectral/Engineering'],
#  'tavg3_3d_chm_Ne: MERRA Chem 3D IAU C-Grid Edge Mass Flux, Time Average 3-Hourly  0.667 x 0.5 degree V5.2.0 (MAT3NECHM) at GES DISC': ['Cloud Properties',
#   'Heat Flux',
#   'Longwave Radiation',
#   'Humidity',
#   'Total Precipitable Water',
#   'Water Vapor',
#   'Precipitation Rate',
#   'Surface Temperature',
#   'Water Vapor Indicators',
#   'Atmospheric Radiation',
#   'Atmosphere',
#   'Atmospheric Water Vapor',
#   'Earth Science',
#   'Clouds',
#   'Precipitation',
#   'Atmospheric Temperature'],
#  'SBUV2/NOAA-19 Ozone (O3) Profile and Total Column Ozone 1 Month Zonal Mean L3 Global 5.0 degree Latitude Zones V1 (SBUV2N19L3zm) at GES DISC': ['Atmospheric Ozone',
#   'Atmospheric Chemistry',
#   'Earth Science',
#   'Oxygen Compounds',
#   'Atmosphere'],
#  'TIROS-4 Medium-Resolution Scanning Radiometer Level 1 Final Meteorological Radiation Data V001 (TIROS4L1FMRT) at GES DISC': ['Brightness Temperature',
#   'Visible Radiance',
#   'Infrared Wavelengths',
#   'Visible Wavelengths',
#   'Earth Science',
#   'Spectral/Engineering'],
#  'TROPESS AIRS-Aqua L2 Ozone for Forward Stream, Standard Product V1 (TRPSDL2O3AIRSFS) at GES DISC': ['Ozone',
#   'Atmospheric Chemistry',
#   'Earth Science',
#   'Oxygen Compounds',
#   'Atmosphere'],
#  'NLDAS Mosaic Land Surface Model L4 Monthly Climatology 0.125 x 0.125 degree V2.0 (NLDAS_MOS0125_MC) at GES DISC': ['Heat Flux',
#   'Longwave Radiation',
#   'Shortwave Radiation',
#   'Surface Temperature',
#   'Evaporation',
#   'Evapotranspiration',
#   'Rain',
#   'Snow',
#   'Canopy Characteristics',
#   'Leaf Characteristics',
#   'Vegetation Cover',
#   'Soil Moisture/Water Content',
#   'Soil Temperature',
#   'Albedo',
#   'Land Surface Temperature',
#   'Snow Water Equivalent',
#   'Runoff',
#   'Surface Thermal Properties',
#   'Atmospheric Water Vapor',
#   'Surface Water',
#   'Terrestrial Hydrosphere',
#   'Liquid Precipitation',
#   'Land Surface',
#   'Precipitation',
#   'Surface Radiative Properties',
#   'Water Vapor Processes',
#   'Biosphere',
#   'Atmospheric Radiation',
#   'Atmosphere',
#   'Vegetation',
#   'Surface Water Processes/Measurements',
#   'Solid Precipitation',
#   'Earth Science',
#   'Snow/Ice',
#   'Atmospheric Temperature',
#   'Soils'],
#  'OMPS-NPP L2 NM Cloud Pressure and Fraction swath orbital V2 (OMPS_NPP_NMCLDRR_L2) at GES DISC': ['Cloud Fraction',
#   'Cloud Top Pressure',
#   'Cloud Properties',
#   'Atmosphere',
#   'Earth Science',
#   'Clouds'],
#  'SBUV2/NOAA-16 Ozone (O3) Nadir Profile and Total Column 1 Day L2 V1 (SBUV2N16L2) at GES DISC': ['Atmospheric Ozone',
#   'Atmospheric Chemistry',
#   'Earth Science',
#   'Oxygen Compounds',
#   'Atmosphere'],
#  'SAMS/Nimbus-7 Level 3 Zonal Means Composition Data V001 (SAMSN7L3ZMTG) at GES DISC': ['Nitrous Oxide',
#   'Methane',
#   'Atmospheric Chemistry',
#   'Nitrogen Compounds',
#   'Atmosphere',
#   'Earth Science',
#   'Carbon And Hydrocarbon Compounds'],
#  'SBUV2/NOAA-17 Ozone (O3) Nadir Profile and Total Column 1 Day L2 V1 (SBUV2N17L2) at GES DISC': ['Atmospheric Ozone',
#   'Atmospheric Chemistry',
#   'Earth Science',
#   'Oxygen Compounds',
#   'Atmosphere'],
#  'CAR Safari South African Biogeophysics and Biogeochemistry L1 V1 (CAR_SAFARI_L1C) at GES DISC': ['Aerosol Radiance',
#   'Cloud Properties',
#   'Reflectance',
#   'Reflectance',
#   'Atmospheric Radiation',
#   'Atmosphere',
#   'Aerosols',
#   'Earth Science',
#   'Clouds'],
#  'Sentinel-5P TROPOMI Radiance product band 2 (UV detector) L1B V1 (S5P_L1B_RA_BD2) at GES DISC': ['Atmospheric Emitted Radiation',
#   'Net Radiation',
#   'Radiative Forcing',
#   'Scattering',
#   'Ultraviolet Radiation',
#   'Platform Characteristics',
#   'Flight Data Logs',
#   'Orbital Characteristics',
#   'Viewing Geometry',
#   'Geolocation',
#   'Viewing Geometry',
#   'Ultraviolet Wavelengths',
#   'Ultraviolet Radiance',
#   'Atmospheric Radiation',
#   'Atmosphere',
#   'Earth Science',
#   'Sensor Characteristics',
#   'Ultraviolet Wavelengths',
#   'Platform Characteristics',
#   'Spectral/Engineering'],
#  'Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_AMSUB_NOAA17_OBS) at GES DISC': ['Barometric Altitude',
#   'Terrain Elevation',
#   'Land Use/Land Cover Classification',
#   'Altitude',
#   'Topography',
#   'Land Surface',
#   'Atmosphere',
#   'Land Use/Land Cover',
#   'Earth Science'],
#  'OCO-2 Level 1A collated, parsed, calibration data, Retrospective Processing V10r (OCO2_L1aIn_Pixel) at GES DISC': ['Atmospheric Carbon Dioxide',
#   'Infrared Radiance',
#   'Infrared Wavelengths',
#   'Atmospheric Chemistry',
#   'Atmosphere',
#   'Carbon And Hydrocarbon Compounds',
#   'Earth Science',
#   'Spectral/Engineering'],
#  'GPM SSMI on F15 (GPROF) Climate-based Radiometer Precipitation Profiling L3 1 day 0.25 degree x 0.25 degree V05 (GPM_3GPROFF15SSMI_DAY_CLIM) at GES DISC': ['Atmospheric Water Vapor',
#   'Precipitation',
#   'Earth Science',
#   'Atmosphere'],
#  'Carbon Monitoring System Lake Michigan Primary Production Yearly V1 (CMSLakeMichiganPPY) at GES DISC': ['Primary Production',
#   'Biosphere',
#   'Earth Science',
#   'Ecological Dynamics',
#   'Ecosystem Functions'],
#  'NLDAS Secondary Forcing Data L4 Monthly 0.125 x 0.125 degree V002 (NLDAS_FORB0125_M) at GES DISC': ['Geopotential Height',
#   'Surface Pressure',
#   'Shortwave Radiation',
#   'Surface Temperature',
#   'Humidity',
#   'Convection',
#   'Surface Winds',
#   'Rain',
#   'Land Surface Temperature',
#   'Altitude',
#   'Wind Dynamics',
#   'Surface Thermal Properties',
#   'Water Vapor Indicators',
#   'Atmospheric Radiation',
#   'Atmosphere',
#   'Earth Science',
#   'Atmospheric Water Vapor',
#   'Atmospheric Winds',
#   'Atmospheric Pressure',
#   'Liquid Precipitation',
#   'Land Surface',
#   'Precipitation',
#   'Atmospheric Temperature'],
#  'MERRA-2 inst3_3d_aer_Nv: 3d,3-Hourly,Instantaneous,Model-Level,Assimilation,Aerosol Mixing Ratio 0.625 x 0.5 degree V5.12.4 (M2I3NVAER) at GES DISC': ['Dust/Ash/Smoke',
#   'Carbonaceous Aerosols',
#   'Organic Particles',
#   'Sulfate Particles',
#   'Sulfur Oxides',
#   'Sulfur Compounds',
#   'Sulfate',
#   'Sulfur Dioxide',
#   'Sulfur Oxides',
#   'Dimethyl Sulfide',
#   'Aerosol Particle Properties',
#   'Particulate Matter',
#   'Aerosols',
#   'Surface Pressure',
#   'Pressure Thickness',
#   'Relative Humidity',
#   'Sea Salt',
#   'Black Carbon',
#   'Air Mass/Density',
#   'Atmospheric Chemistry',
#   'Air Quality',
#   'Atmosphere',
#   'Water Vapor Indicators',
#   'Earth Science',
#   'Atmospheric Water Vapor',
#   'Atmospheric Pressure',
#   'Sulfur Compounds',
#   'Aerosols',
#   'Humidity'],
#  'Sounder SIPS: AQUA AIRS IR-only Level 3 CLIMCAPS: Comprehensive Quality Control Gridded Monthly V2 at GES DISC': ['Tropospheric Ozone',
#   'Tropopause',
#   'Methane',
#   'Atmospheric Ozone',
#   'Surface Pressure',
#   'Outgoing Longwave Radiation',
#   'Surface Temperature',
#   'Air Temperature',
#   'Upper Air Temperature',
#   'Layered Precipitable Water',
#   'Total Precipitable Water',
#   'Water Vapor Profiles',
#   'Cloud Fraction',
#   'Cloud Top Pressure',
#   'Cloud Top Temperature',
#   'Cloud Vertical Distribution',
#   'Precipitation Rate',
#   'Emissivity',
#   'Skin Temperature',
#   'Sea Surface Temperature',
#   'Oceans',
#   'Surface Thermal Properties',
#   'Oxygen Compounds',
#   'Cloud Properties',
#   'Atmospheric Water Vapor',
#   'Land Surface',
#   'Ocean Temperature',
#   'Precipitation',
#   'Surface Radiative Properties',
#   'Altitude',
#   'Atmospheric Chemistry',
#   'Air Quality',
#   'Atmosphere',
#   'Atmospheric Radiation',
#   'Water Vapor Indicators',
#   'Earth Science',
#   'Surface Temperature',
#   'Atmospheric Pressure',
#   'Carbon And Hydrocarbon Compounds',
#   'Clouds',
#   'Atmospheric Temperature'],
#  'AIRS/Aqua L3 Daily Standard Physical Retrieval (AIRS+AMSU) 1 degree x 1 degree V006 (AIRX3STD) at GES DISC': ['Tropopause',
#   'Surface Pressure',
#   'Air Temperature',
#   'Upper Air Temperature',
#   'Total Precipitable Water',
#   'Water Vapor',
#   'Cloud Height',
#   'Cloud Top Pressure',
#   'Cloud Top Temperature',
#   'Cloud Vertical Distribution',
#   'Emissivity',
#   'Sea Surface Temperature',
#   'Skin Temperature',
#   'Carbon Monoxide',
#   'Geopotential Height',
#   'Humidity',
#   'Water Vapor Profiles',
#   'Cloud Liquid Water/Ice',
#   'Outgoing Longwave Radiation',
#   'Methane',
#   'Atmospheric Ozone',
#   'Oceans',
#   'Surface Thermal Properties',
#   'Oxygen Compounds',
#   'Cloud Properties',
#   'Atmospheric Water Vapor',
#   'Land Surface',
#   'Ocean Temperature',
#   'Cloud Microphysics',
#   'Surface Radiative Properties',
#   'Altitude',
#   'Water Vapor Indicators',
#   'Air Quality',
#   'Atmosphere',
#   'Atmospheric Radiation',
#   'Atmospheric Chemistry',
#   'Earth Science',
#   'Surface Temperature',
#   'Atmospheric Pressure',
#   'Carbon And Hydrocarbon Compounds',
#   'Clouds',
#   'Atmospheric Temperature'],
#  'Carbon Monitoring System Carbon Flux for Ocean Prior L4 V2 (CMSFluxOceanPrior) at GES DISC': ['Atmospheric Carbon Dioxide',
#   'Carbon Dioxide',
#   'Oceans',
#   'Atmospheric Chemistry',
#   'Atmosphere',
#   'Carbon And Hydrocarbon Compounds',
#   'Earth Science',
#   'Ocean Chemistry'],
#  'MLS/Aura Near-Real-Time L2 Water Vapor (H2O) Mixing Ratio V004 (ML2H2O_NRT) at GES DISC': ['Water Vapor Mixing Ratio Profiles',
#   'Earth Science',
#   'Atmospheric Water Vapor',
#   'Water Vapor Profiles',
#   'Atmosphere'],
#  'Gridded Monthly Time-Mean Observation minus Forecast (omf) Values 0.5 x 0.667 degree V001 (MA_MSU_NOAA08_OMF) at GES DISC': ['Barometric Altitude',
#   'Terrain Elevation',
#   'Land Use/Land Cover Classification',
#   'Altitude',
#   'Topography',
#   'Land Surface',
#   'Atmosphere',
#   'Land Use/Land Cover',
#   'Earth Science'],
#  'MLS/Aura Level 3 Monthly Binned Chlorine Monoxide (ClO) Mixing Ratio on Assorted Grids V005 (ML3MBCLO) at GES DISC': ['Chlorine Monoxide',
#   'Halocarbons And Halogens',
#   'Earth Science',
#   'Atmospheric Chemistry',
#   'Atmosphere'],
#  'GLDAS Noah Land Surface Model L4 3 hourly 0.25 x 0.25 degree Early Product V2.1 (GLDAS_NOAH025_3H_EP) at GES DISC': ['Surface Pressure',
#   'Heat Flux',
#   'Longwave Radiation',
#   'Shortwave Radiation',
#   'Surface Temperature',
#   'Humidity',
#   'Evapotranspiration',
#   'Surface Winds',
#   'Rain',
#   'Precipitation Rate',
#   'Snow',
#   'Soil Moisture/Water Content',
#   'Soil Temperature',
#   'Land Surface Temperature',
#   'Snow Water Equivalent',
#   'Runoff',
#   'Surface Thermal Properties',
#   'Atmospheric Water Vapor',
#   'Atmospheric Winds',
#   'Surface Water',
#   'Terrestrial Hydrosphere',
#   'Liquid Precipitation',
#   'Land Surface',
#   'Precipitation',
#   'Water Vapor Processes',
#   'Water Vapor Indicators',
#   'Atmospheric Radiation',
#   'Atmosphere',
#   'Surface Water Processes/Measurements',
#   'Solid Precipitation',
#   'Earth Science',
#   'Atmospheric Pressure',
#   'Snow/Ice',
#   'Atmospheric Temperature',
#   'Soils'],
#  'Goddard Satellite-Based Surface Turbulent Fluxes, 1x1 deg Daily Grid, Satellite F14 V2c (GSSTF_F14) at GES DISC': ['Sea Level Pressure',
#   'Air Temperature',
#   'Skin Temperature',
# ...
#   'Oxygen Compounds',
#   'Cloud Properties',
#   'Atmospheric Water Vapor',
#   'Land Surface',
#   'Ocean Pressure',
#   'Ocean Temperature',
#   'Precipitation',
#   'Upper Air Temperature',
#   'Atmospheric Chemistry',
#   'Atmospheric Radiation',
#   'Atmosphere',
#   'Water Vapor Indicators',
#   'Sea Surface Topography',
#   'Earth Science',
#   'Infrared Wavelengths',
#   'Surface Temperature',
#   'Atmospheric Pressure',
#   'Clouds',
#   'Atmospheric Temperature',
#   'Spectral/Engineering'],
#  'MERRA-2 tavgM_2d_lnd_Nx: 2d,Monthly mean,Time-Averaged,Single-Level,Assimilation,Land Surface Diagnostics 0.625 x 0.5 degree V5.12.4 (M2TMNXLND) at GES DISC': ['Longwave Radiation',
#   'Shortwave Radiation',
#   'Soil Heat Budget',
#   'Soil Heat Budget',
#   'Soil Temperature',
#   'Soil Temperature',
#   'Soil Infiltration',
#   'Soil Infiltration',
#   'Soil Moisture/Water Content',
#   'Surface Soil Moisture',
#   'Root Zone Soil Moisture',
#   'Soil Moisture/Water Content',
#   'Evaporation',
#   'Surface Water',
#   'Runoff Rate',
#   'Average Flow',
#   'Average Flow',
#   'Precipitation',
#   'Snow/Ice',
#   'Snow Depth',
#   'Snow Melt',
#   'Snow/Ice Temperature',
#   'Leaf Area Index (Lai)',
#   'Leaf Area Index (Lai)',
#   'Runoff',
#   'Vegetation Index',
#   'Atmospheric Water Vapor',
#   'Surface Water',
#   'Subsurface Flow',
#   'Terrestrial Hydrosphere',
#   'Cryosphere',
#   'Land Surface',
#   'Water Vapor Processes',
#   'Biosphere',
#   'Atmospheric Radiation',
#   'Atmosphere',
#   'Surface Water Processes/Measurements',
#   'Vegetation',
#   'Earth Science',
#   'Soil Moisture/Water Content',
#   'Snow/Ice',
#   'Ground Water Processes/Measurements',
#   'Ground Water',
#   'Soils'],
#  'AIRS/Aqua L3 8-day Support Multiday Product (AIRS+AMSU+HSB) 1 degree x 1 degree V006 (AIRH3SP8) at GES DISC': ['Tropopause',
#   'Surface Pressure',
#   'Air Temperature',
#   'Upper Air Temperature',
#   'Total Precipitable Water',
#   'Water Vapor',
#   'Cloud Height',
#   'Cloud Top Pressure',
#   'Cloud Top Temperature',
#   'Cloud Vertical Distribution',
#   'Emissivity',
#   'Sea Surface Temperature',
#   'Skin Temperature',
#   'Carbon Monoxide',
#   'Geopotential Height',
#   'Humidity',
#   'Water Vapor Profiles',
#   'Cloud Liquid Water/Ice',
#   'Outgoing Longwave Radiation',
#   'Methane',
#   'Atmospheric Ozone',
#   'Cloud Droplet Concentration/Size',
#   'Cloud Optical Depth/Thickness',
#   'Cloud Types',
#   'Precipitation Rate',
#   'Oceans',
#   'Surface Thermal Properties',
#   'Oxygen Compounds',
#   'Cloud Properties',
#   'Atmospheric Water Vapor',
#   'Land Surface',
#   'Ocean Temperature',
#   'Cloud Microphysics',
#   'Precipitation',
#   'Surface Radiative Properties',
#   'Altitude',
#   'Water Vapor Indicators',
#   'Air Quality',
#   'Atmosphere',
#   'Atmospheric Radiation',
#   'Atmospheric Chemistry',
#   'Earth Science',
#   'Surface Temperature',
#   'Atmospheric Pressure',
#   'Carbon And Hydrocarbon Compounds',
#   'Clouds',
#   'Atmospheric Temperature'],
#  'CAR SCAR-B Smoke, Clouds, and Radiation-Brazil L1 V1 (CAR_SCARB_L1C) at GES DISC': ['Aerosol Radiance',
#   'Cloud Properties',
#   'Reflectance',
#   'Reflectance',
#   'Reflectance',
#   'Atmospheric Radiation',
#   'Atmosphere',
#   'Aerosols',
#   'Earth Science',
#   'Clouds'],
#  'CAR ECO3D BRDF Measurements V2 (CAR_ECO3D_BRDF) at GES DISC': ['Reflectance',
#   'Reflectance',
#   'Reflectance',
#   'Atmospheric Radiation',
#   'Atmosphere',
#   'Earth Science'],
#  'GPM PR on TRMM Spectral Latent Heating Profiles L2 1.5 hours 5 km V06 (GPM_2HSLH_TRMM) at GES DISC': ['Heat Flux',
#   'Earth Science',
#   'Atmospheric Radiation',
#   'Atmosphere'],
#  'SCR/Nimbus-4 Level 1 Radiance Data from CD-ROM V001 (SCRN4L1RAD_CDROM) at GES DISC': ['Infrared Radiance',
#   'Earth Science',
#   'Infrared Wavelengths',
#   'Spectral/Engineering'],
#  'TROPESS CrIS-SNPP L2 Carbon Monoxide for West Coast Fires HiRes, Standard Product V1 (TRPSDL2COCRSWCFHI) at GES DISC': ['Carbon Monoxide',
#   'Earth Science',
#   'Air Quality',
#   'Atmosphere'],
#  'MLS/Aura Level 2 Hypochlorous Acid (HOCl) Mixing Ratio V004 (ML2HOCL) at GES DISC': ['Hypochlorous Acid',
#   'Halocarbons And Halogens',
#   'Earth Science',
#   'Atmospheric Chemistry',
#   'Atmosphere'],
#  'GPM AMSU-B on NOAA15 (GPROF) Climate-based Radiometer Precipitation Profiling L2 1.5 hours 16 km V05 (GPM_2AGPROFNOAA15AMSUB) at GES DISC': ['Atmospheric Water Vapor',
#   'Precipitation',
#   'Brightness Temperature',
#   'Infrared Wavelengths',
#   'Atmosphere',
#   'Earth Science',
#   'Spectral/Engineering'],
#  'SBUV2/NOAA-9 Ozone (O3) Nadir Profile and Total Column 1 Day L2 V1 (SBUV2N09L2) at GES DISC': ['Atmospheric Ozone',
#   'Atmospheric Chemistry',
#   'Earth Science',
#   'Oxygen Compounds',
#   'Atmosphere'],
#  'NCEP/DOE Reanalysis II, for GSSTF, 0.25 x 0.25 deg, Daily Grid V3 (GSSTF_NCEP) at GES DISC': ['Sea Level Pressure',
#   'Air Temperature',
#   'Skin Temperature',
#   'Surface Temperature',
#   'Evaporation',
#   'Humidity',
#   'Total Precipitable Water',
#   'Water Vapor',
#   'Surface Winds',
#   'Turbulence',
#   'Wind Stress',
#   'Atmospheric Heating',
#   'Heat Flux',
#   'Radiative Flux',
#   'Conduction',
#   'Evaporation',
#   'Heat Flux',
#   'Sea Level Pressure',
#   'Sea Surface Temperature',
#   'Surface Winds',
#   'Turbulence',
#   'Wind Stress',
#   'Wind Dynamics',
#   'Oceans',
#   'Surface Thermal Properties',
#   'Atmospheric Water Vapor',
#   'Atmospheric Winds',
#   'Land Surface',
#   'Ocean Pressure',
#   'Ocean Temperature',
#   'Water Vapor Processes',
#   'Water Vapor Indicators',
#   'Atmospheric Radiation',
#   'Atmosphere',
#   'Earth Science',
#   'Surface Temperature',
#   'Ocean Heat Budget',
#   'Atmospheric Temperature'],
#  'Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_AMSUA_NOAA18_OBS) at GES DISC': ['Barometric Altitude',
#   'Terrain Elevation',
#   'Land Use/Land Cover Classification',
#   'Altitude',
#   'Topography',
#   'Land Surface',
#   'Atmosphere',
#   'Land Use/Land Cover',
#   'Earth Science'],
#  'tavgU_2d_mld_Nx: MERRA Simulated 2D Incremental Analysis Update (IAU) MERRA-Land reanalysis, GEOSldas-MERRALand, Time Average Diurnal  0.667 x 0.5 degree V5.2.0 (MSTUNXMLD) at GES DISC': ['Cloud Properties',
#   'Heat Flux',
#   'Longwave Radiation',
#   'Humidity',
#   'Total Precipitable Water',
#   'Water Vapor',
#   'Precipitation Rate',
#   'Surface Temperature',
#   'Water Vapor Indicators',
#   'Atmospheric Radiation',
#   'Atmosphere',
#   'Atmospheric Water Vapor',
#   'Earth Science',
#   'Clouds',
#   'Precipitation',
#   'Atmospheric Temperature'],
#  'GOZCARDS Source Hydrogen Chloride 1 month L3 10 degree Zonal Means on a Vertical Pressure Grid V1 (GozSmlpHCl) at GES DISC': ['Hydrogen Chloride',
#   'Halocarbons And Halogens',
#   'Earth Science',
#   'Atmospheric Chemistry',
#   'Atmosphere'],
#  'Ocean Biogeochemistry in the California Current System 2007-2010 L4 Monthly': ['Ocean Chemistry',
#   'Alkalinity',
#   'Biogeochemical Cycles',
#   'Carbon',
#   'Carbon Dioxide',
#   'Dissolved Gases',
#   'Nitrate',
#   'Oxygen',
#   'Ph',
#   'Phosphate',
#   'Oceans',
#   'Earth Science',
#   'Ocean Chemistry'],
#  'Gridded Monthly Time-Mean Observation minus Forecast (omf) Values 0.5 x 0.667 degree V001 (MA_AMSUA_NOAA16_OMF) at GES DISC': ['Barometric Altitude',
#   'Terrain Elevation',
#   'Land Use/Land Cover Classification',
#   'Altitude',
#   'Topography',
#   'Land Surface',
#   'Atmosphere',
#   'Land Use/Land Cover',
#   'Earth Science'],
#  'MERRA-2 inst3_3d_asm_Np: 3d,3-Hourly,Instantaneous,Pressure-Level,Assimilation,Assimilated Meteorological Fields 0.625 x 0.5 degree V5.12.4 (M2I3NPASM) at GES DISC': ['Atmospheric Ozone',
#   'Sea Level Pressure',
#   'Surface Pressure',
#   'U/V Wind Components',
#   'U/V Wind Components',
#   'Potential Vorticity',
#   'Vertical Wind Velocity/Speed',
#   'Vertical Profiles',
#   'Upper Air Temperature',
#   'Air Temperature',
#   'Relative Humidity',
#   'Specific Humidity',
#   'Atmospheric Water Vapor',
#   'Cloud Liquid Water/Ice',
#   'Altitude',
#   'Geopotential Height',
#   'Wind Dynamics',
#   'Oceans',
#   'Oxygen Compounds',
#   'Atmospheric Winds',
#   'Atmospheric Water Vapor',
#   'Vorticity',
#   'Upper Level Winds',
#   'Ocean Pressure',
#   'Cloud Microphysics',
#   'Upper Air Temperature',
#   'Humidity',
#   'Altitude',
#   'Atmospheric Chemistry',
#   'Water Vapor Indicators',
#   'Atmosphere',
#   'Earth Science',
#   'Surface Temperature',
#   'Atmospheric Pressure',
#   'Clouds',
#   'Atmospheric Temperature'],
#  'NLDAS Secondary Forcing Data L4 Monthly Climatology 0.125 x 0.125 degree V2.0 (NLDAS_FORB0125_MC) at GES DISC': ['Geopotential Height',
#   'Surface Pressure',
#   'Shortwave Radiation',
#   'Surface Temperature',
#   'Humidity',
#   'Convection',
#   'Surface Winds',
#   'Rain',
#   'Land Surface Temperature',
#   'Altitude',
#   'Wind Dynamics',
#   'Surface Thermal Properties',
#   'Water Vapor Indicators',
#   'Atmospheric Radiation',
#   'Atmosphere',
#   'Earth Science',
#   'Atmospheric Water Vapor',
#   'Atmospheric Winds',
#   'Atmospheric Pressure',
#   'Liquid Precipitation',
#   'Land Surface',
#   'Precipitation',
#   'Atmospheric Temperature'],
#  'AIRS/Aqua L2 Support Retrieval (AIRS-only) V006 (AIRS2SUP) at GES DISC': ['Air Temperature',
#   'Carbon Monoxide',
#   'Cloud Fraction',
#   'Cloud Height',
#   'Cloud Top Pressure',
#   'Cloud Top Temperature',
#   'Cloud Vertical Distribution',
#   'Emissivity',
#   'Geopotential Height',
#   'Methane',
#   'Outgoing Longwave Radiation',
#   'Atmospheric Ozone',
#   'Total Precipitable Water',
#   'Sea Surface Temperature',
#   'Surface Pressure',
#   'Skin Temperature',
#   'Surface Temperature',
#   'Sulfur Dioxide',
#   'Tropopause',
#   'Tropospheric Ozone',
#   'Upper Air Temperature',
#   'Water Vapor Profiles',
#   'Cloud Liquid Water/Ice',
#   'Cloud Droplet Concentration/Size',
#   'Cloud Optical Depth/Thickness',
#   'Cloud Types',
#   'Precipitation Rate',
#   'Oceans',
#   'Surface Thermal Properties',
#   'Oxygen Compounds',
#   'Cloud Properties',
#   'Atmospheric Water Vapor',
#   'Sulfur Compounds',
#   'Land Surface',
#   'Ocean Temperature',
#   'Cloud Microphysics',
#   'Precipitation',
#   'Surface Radiative Properties',
#   'Altitude',
#   'Atmospheric Chemistry',
#   'Air Quality',
#   'Atmosphere',
#   'Atmospheric Radiation',
#   'Water Vapor Indicators',
#   'Earth Science',
#   'Surface Temperature',
#   'Atmospheric Pressure',
#   'Carbon And Hydrocarbon Compounds',
#   'Clouds',
#   'Atmospheric Temperature'],
#  'OMI/Aura TOMS-Like Ozone and Radiative Cloud Fraction L3 1 day 0.25 degree x 0.25 degree V3 (OMTO3e) at GES DISC': ['Atmospheric Ozone',
#   'Reflectance',
#   'Atmospheric Chemistry',
#   'Oxygen Compounds',
#   'Atmosphere',
#   'Atmospheric Radiation',
#   'Earth Science'],
#  'GPM ATMS on SUOMI-NPP (GPROF) Radiometer Precipitation Profiling L3 1 day 0.25 degree x 0.25 degree V05 (GPM_3GPROFNPPATMS_DAY) at GES DISC': ['Atmospheric Water Vapor',
#   'Precipitation',
#   'Earth Science',
#   'Atmosphere'],
#  'TRMM Ground Validation Radar Site Rain Type Totals Map L3 1 month 2 km V7 (TRMM_3A54) at GES DISC': ['Precipitation Rate',
#   'Rain',
#   'Radar Reflectivity',
#   'Liquid Precipitation',
#   'Radar',
#   'Atmosphere',
#   'Precipitation',
#   'Earth Science',
#   'Spectral/Engineering'],
#  'OMI/Aura TOMS-Like Ozone, Aerosol Index, Cloud Radiance Fraction L3 1 day 1 degree x 1 degree V3 (OMTO3d) at GES DISC': ['Uv Aerosol Index',
#   'Column Amount Ozone',
#   'Reflectance',
#   'Atmospheric Chemistry',
#   'Oxygen Compounds',
#   'Atmosphere',
#   'Dust/Ash/Smoke',
#   'Atmospheric Radiation',
#   'Earth Science',
#   'Aerosols',
#   'Atmospheric Ozone'],
#  'Gridded Monthly Time-Mean Observation minus Forecast (omf) Values 0.5 x 0.667 degree V001 (MA_AIRS_AQUA_OMF) at GES DISC': ['Barometric Altitude',
#   'Terrain Elevation',
#   'Land Use/Land Cover Classification',
#   'Altitude',
#   'Topography',
#   'Land Surface',
#   'Atmosphere',
#   'Land Use/Land Cover',
#   'Earth Science'],
#  'MLS/Aura L1 Radiances from Filter Banks for THz V005 (ML1RADT) at GES DISC': ['Microwave Radiance',
#   'Microwave',
#   'Earth Science',
#   'Spectral/Engineering'],
#  'inst3_3d_asm_Cp: MERRA 3D IAU State, Meteorology Instantaneous 3-hourly  1.25 x 1.25 degree V5.2.0 (MAI3CPASM) at GES DISC': ['Cloud Properties',
#   'Heat Flux',
#   'Longwave Radiation',
#   'Humidity',
#   'Total Precipitable Water',
#   'Water Vapor',
#   'Precipitation Rate',
#   'Surface Temperature',
#   'Water Vapor Indicators',
#   'Atmospheric Radiation',
#   'Atmosphere',
#   'Atmospheric Water Vapor',
#   'Earth Science',
#   'Clouds',
#   'Precipitation',
#   'Atmospheric Temperature'],
#  'Sentinel-5P TROPOMI Radiance product band 6 (NIR detector) L1B V2 (S5P_L1B_RA_BD6) at GES DISC': ['Atmospheric Emitted Radiation',
#   'Net Radiation',
#   'Radiative Forcing',
#   'Scattering',
#   'Ultraviolet Radiation',
#   'Platform Characteristics',
#   'Flight Data Logs',
#   'Orbital Characteristics',
#   'Viewing Geometry',
#   'Geolocation',
#   'Viewing Geometry',
#   'Ultraviolet Wavelengths',
#   'Ultraviolet Radiance',
#   'Atmospheric Radiation',
#   'Atmosphere',
#   'Earth Science',
#   'Sensor Characteristics',
#   'Ultraviolet Wavelengths',
#   'Platform Characteristics',
#   'Spectral/Engineering'],
#  'OMI/Aura Surface UV Irradiance 1-orbit L2 Swath 13x24 km V003 (OMUVB) at GES DISC': ['Ultraviolet Radiation',
#   'Sun-Earth Interactions',
#   'Solar Irradiance',
#   'Climate Indicators',
#   'Atmospheric Radiation',
#   'Atmosphere',
#   'Earth Science'],
#  'TRMM Ground Validation Rain Existence L2 1 month V7 (TRMM_2A52) at GES DISC': ['Precipitation Rate',
#   'Rain',
#   'Radar Reflectivity',
#   'Liquid Precipitation',
#   'Radar',
#   'Atmosphere',
#   'Precipitation',
#   'Earth Science',
#   'Spectral/Engineering'],
#  'GPM IMERG Late Precipitation L3 1 day 0.1 degree x 0.1 degree V06 (GPM_3IMERGDL) at GES DISC': ['Precipitation',
#   'Precipitation Amount',
#   'Precipitation Rate',
#   'Snow',
#   'Rain',
#   'Solid Precipitation',
#   'Liquid Precipitation',
#   'Atmosphere',
#   'Precipitation',
#   'Earth Science'],
#  'TMI/TRMM surface soil moisture (LPRM) L3 1 day 25 km x 25 km nighttime V001 (LPRM_TMI_NT_SOILM3) at GES DISC': ['Skin Temperature',
#   'Soil Moisture/Water Content',
#   'Vegetation Water Content',
#   'Biosphere',
#   'Surface Thermal Properties',
#   'Land Surface',
#   'Vegetation',
#   'Earth Science',
#   'Soils',
#   'Plant Characteristics'],
#  'SORCE SOLSTICE FUV Level 3 Solar Spectral Irradiance Daily Means V016 (SOR3SOLFUVD) at GES DISC': ['Solar Spectral Irradiance',
#   'Solar Irradiance',
#   'Sun-Earth Interactions',
#   'Solar Activity',
#   'Earth Science'],
#  'BUV/Nimbus-4 Ozone (O3) Nadir Profile and Total Column 1 Day L2 V1 (BUVN04L2) at GES DISC': ['Atmospheric Ozone',
#   'Atmospheric Chemistry',
#   'Earth Science',
#   'Oxygen Compounds',
#   'Atmosphere'],
#  'NLDAS Primary Forcing Data L4 Hourly 0.125 x 0.125 degree V002 (NLDAS_FORA0125_H) at GES DISC': ['Surface Pressure',
#   'Longwave Radiation',
#   'Shortwave Radiation',
#   'Surface Temperature',
#   'Evaporation',
#   'Humidity',
#   'Convection',
#   'Surface Winds',
#   'Rain',
#   'Land Surface Temperature',
#   'Water Vapor Processes',
#   'Wind Dynamics',
#   'Surface Thermal Properties',
#   'Water Vapor Indicators',
#   'Atmospheric Radiation',
#   'Atmosphere',
#   'Earth Science',
#   'Atmospheric Water Vapor',
#   'Atmospheric Winds',
#   'Atmospheric Pressure',
#   'Liquid Precipitation',
#   'Land Surface',
#   'Precipitation',
#   'Atmospheric Temperature'],
#  'OMI/Aura Formaldehyde (HCHO) Total Column Daily L2 Global Gridded 0.25 degree x 0.25 degree V3 (OMHCHOG) at GES DISC': ['Formaldehyde',
#   'Carbon And Hydrocarbon Compounds',
#   'Earth Science',
#   'Atmospheric Chemistry',
#   'Atmosphere'],
#  'Sounder SIPS: Suomi NPP CrIMSS Level 2 CHART Normal Spectral Resolution: Cloud Cleared Radiances V1': ['Brightness Temperature',
#   'Infrared Radiance',
#   'Brightness Temperature',
#   'Microwave Radiance',
#   'Infrared Wavelengths',
#   'Microwave',
#   'Earth Science',
#   'Spectral/Engineering'],
#  'TOMS/N7 Near UV Aerosol Index and LER 1-Orbit L2 50x50 km': ['Aerosols',
#   'Aerosol Backscatter',
#   'Aerosol Extinction',
#   'Aerosol Radiance',
#   'Air Quality',
#   'Atmosphere',
#   'Aerosols',
#   'Earth Science'],
#  'Gridded Monthly Time-Mean Observation minus Forecast (omf) Values 0.5 x 0.667 degree V001 (MA_MSU_NOAA07_OMF) at GES DISC': ['Barometric Altitude',
#   'Terrain Elevation',
#   'Land Use/Land Cover Classification',
#   'Altitude',
#   'Topography',
#   'Land Surface',
#   'Atmosphere',
#   'Land Use/Land Cover',
#   'Earth Science'],
#  ...}

# %%
kywrd2titles = dict(zip(all_keywords, [None]*len(all_keywords)))
for keyword in kywrd2titles.keys():
    titles = set()
    for title in title2allkw.keys():
        if keyword in title2allkw[title]:
            titles.add(title)
    kywrd2titles[keyword] = list(titles)

# %%
kywrd2titles['Atmosphere']
# Out:
# ['tavgM_3d_trb_Cp: MERRA 3D IAU Diagnostic, Turbulence, Monthly Mean  1.25 x 1.25 degree V5.2.0 (MATMCPTRB) at GES DISC',
#  'CAR INTEXB BRDF Measurements L1 V2 (CAR_INTEXB_BRDF) at GES DISC',
#  'GPM MHS on NOAA19 (GPROF) Radiometer Precipitation Profiling L3 1 month 0.25 degree x 0.25 degree V05 (GPM_3GPROFNOAA19MHS) at GES DISC',
#  'MERRA-2 tavgU_2d_aer_Nx: 2d,diurnal,Time-averaged,Single-Level,Assimilation,Aerosol Diagnostics 0.625 x 0.5 degree V5.12.4 (M2TUNXAER) at GES DISC',
#  'GPM SSMIS on F18 (GPROF) Climate-based Radiometer Precipitation Profiling L3 1 day 0.25 degree x 0.25 degree V05 (GPM_3GPROFF18SSMIS_DAY_CLIM) at GES DISC',
#  'tavgU_3d_mst_Cp: MERRA 3D IAU Diagnostic, Moist Physics, Diurnal  1.25 x 1.25 degree V5.2.0 (MATUCPMST) at GES DISC',
#  'OMI/Aura Formaldehyde (HCHO) Total Column 1-orbit L2 Swath 13x24 km V003 (OMHCHO) at GES DISC',
#  'Sentinel-5P TROPOMI SNPP cloud product band 7 (SWIR detector) 1-Orbit L2 5.5km x 7km V1 (S5P_L2__NP_BD7_HiR) at GES DISC',
#  'TOMS Nimbus-7 UV Aerosol Index Daily and Monthly Zonal Means V008 (TOMSN7L3zaer) at GES DISC',
#  'GPM DPR Spectral Latent Heating Profiles L2 1.5 hours 5 km V07 (GPM_2HSLH) at GES DISC',
#  'ACOS GOSAT/TANSO-FTS Level 2 bias-corrected XCO2 and other select fields from the full-physics retrieval aggregated as daily files V9r (ACOS_L2_Lite_FP) at GES DISC',
#  'Gridded Monthly Time-Mean Observation minus Forecast (omf) Values 0.5 x 0.667 degree V001 (MA_HIRS3_NOAA17_OMF) at GES DISC',
#  'Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_MHS_NOAA18_OBS) at GES DISC',
#  'MLS/Aura Level 2 Water Vapor (H2O) Mixing Ratio V004 (ML2H2O) at GES DISC',
#  'MLS/Aura Level 3 Daily Binned Hydrogen Chloride (HCl) Mixing Ratio on Zonal and Similar Grids V004 (ML3DZHCL) at GES DISC',
#  'MLS/Aura Level 2 Methanol (CH3OH) Mixing Ratio V005 (ML2CH3OH) at GES DISC',
#  'GPM AMSU-B on NOAA 16 Common Calibrated Brightness Temperatures L1C 1.5 hours 16 km V05 (GPM_1CNOAA16AMSUB) at GES DISC',
#  'GPM SSMIS on F17 (GPROF) Radiometer Precipitation Profiling L2 1.5 hours 12 km V05 (GPM_2AGPROFF17SSMIS) at GES DISC',
#  'OCO-3 Level 2 meteorological parameters interpolated from global assimilation model for each sounding, Retrospective Processing V10r (OCO3_L2_Met) at GES DISC',
#  'CAR CLASIC Cloud and Land Surface Measurements L1 V1 (CAR_CLASIC_L1C) at GES DISC',
#  'Gridded Monthly Time-Mean Observation minus Forecast (omf) Values 0.5 x 0.667 degree V001 (MA_HIRS2_NOAA10_OMF) at GES DISC',
#  'TOMS Meteor-3 UV-Reflectivity Daily L3 Global 1 deg x 1.25 deg Lat/Lon Grid V008 (TOMSM3L3dref) at GES DISC',
#  'OMI/Aura Level 2 Nitrogen Dioxide (NO2) Trace Gas Column Data 1-Orbit subset Swath along CloudSat track 1-Orbit Swath 13x24 km',
#  'TOVS LMD MONTHLY GRIDS from NOAA-10 V01 (TOVSBMNG) at GES DISC',
#  'Aqua/AIRS L2 Standard Physical Retrieval (AIRS+AMSU+HSB) V7.0 at GES DISC',
#  'instU_3d_asm_Cp: MERRA 3D IAU State, Meteorology Diurnal  1.25 x 1.25 degree V5.2.0 (MAIUCPASM) at GES DISC',
#  'TROPESS CrIS-SNPP L2 Ammonia for Australian Fires, Standard Product V1 (TRPSDL2NH3CRSAUS) at GES DISC',
#  'High-resolution mean North American methane fluxes for 2010-2015 optimized with GOSAT satellite data V1 (CMS_HR_MNA_CH4_FLUX)',
#  'const_2d_chm_Fx: MERRA 2-D invariants on chemistry grid 1.25 x 1 degree V5.2.0 (MAC0FXCHM) at GES DISC',
#  'TOMS Nimbus-7 UV Aerosol Index Daily L3 Global 1 deg x 1.25 deg Lat/Lon Grid V008 (TOMSN7L3daer) at GES DISC',
#  'Gridded Monthly Time-Mean Observation minus Analysis (oma) Values 0.5 x 0.667 degree V001 (MA_MSU_NOAA08_OMA) at GES DISC',
#  'MERRA-2 tavgU_2d_chm_Nx: 2d,diurnal,Time-Averaged,Single-Level,Assimilation,Carbon Monoxide and Ozone Diagnostics 0.625 x 0.5 degree V5.12.4 (M2TUNXCHM) at GES DISC',
#  'TOMS Nimbus-7 Total Column Ozone Daily and Monthly Zonal Means V008 (TOMSN7L3ztoz) at GES DISC',
#  'RM-OBS/PU Potential Evapotranspiration and Supporting Forcing L4 3-hourly 0.25x0.25 degree V001 (PET_PU_3H025) at GES DISC',
#  'MUSTARD-EMLS Level 2 Standard Products V1 (MUSEMLSL2DGG) at GES DISC',
#  'Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_AMSUA_NOAA17_OBS) at GES DISC',
#  'Aqua/AIRS L3 Daily Standard Physical Retrieval (AIRS+AMSU+HSB) 1 degree x 1 degree V7.0 at GES DISC',
#  'TRMM Ground Validation Radar Reflectivity Single Level Cartesian Grid 1 hour V7 (TRMM_baseUW) at GES DISC',
#  'MLS/Aura Level 3 Monthly Binned Carbon Monoxide (CO) Mixing Ratio on Assorted Grids V004 (ML3MBCO) at GES DISC',
#  'Sounder SIPS: Suomi NPP CrIMSS Level 3 Specific Quality Control Gridded Daily CLIMCAPS Normal Spectral Resolution V2 at GES DISC',
#  'MLS/Aura Level 3 Daily Binned Hypochlorous Acid (HOCl) Mixing Ratio on Zonal and Similar Grids V005 (ML3DZHOCL) at GES DISC',
#  'AIRS/Aqua L3 daily CO2 in the free troposphere (AIRS-only) 2.5 degrees x 2 degrees V005 (AIRS3C2D) at GES DISC',
#  'TROPESS CrIS-SNPP L2 Ozone for West Coast Fires HiRes, Standard Product V1 (TRPSDL2O3CRSWCFHI) at GES DISC',
#  'GPCP Precipitation Level 3 Monthly 0.5-Degree V3.1 (GPCPMON) at GES DISC',
#  'ACOS GOSAT/TANSO-FTS Level 2 bias-corrected XCO2 and other select fields from the full-physics retrieval aggregated as daily files V7.3 (ACOS_L2_Lite_FP) at GES DISC',
#  'AIRS/Aqua L3 Monthly Standard Physical Retrieval (AIRS-only) 1 degree x 1 degree V006 (AIRS3STM) at GES DISC',
#  'TROPESS CrIS-SNPP L2 Water for Australian Fires, Standard Product V1 (TRPSDL2H2OCRSAUS) at GES DISC',
#  'Gridded Monthly Time-Mean Observation minus Forecast (omf) Values 0.5 x 0.667 degree V001 (MA_HIRS3_AM_OMF) at GES DISC',
#  'SBUV/Nimbus-7 Level 2 Daily Ozone Profile and Total Column from CD-ROM V008 (SBUVN7O3) at GES DISC',
#  'Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_HIRS3_NOAA16_OBS) at GES DISC',
#  'tavg3_3d_chm_Fe: MERRA Chem 3D IAU, Precip Mass Flux, Time average 3-hourly  1.25 x 1 degree V5.2.0 (MAT3FECHM) at GES DISC',
#  'Sentinel-5P TROPOMI Tropospheric Ozone Column V2 (S5P_L2__O3_TCL) at GES DISC',
#  'Sentinel-5P TROPOMI Radiance product band 2 (UV detector) L1B V2 (S5P_L1B_RA_BD2) at GES DISC',
#  'MERRA-2 tavg3_3d_cld_Np: 3d,3-Hourly,Time-Averaged,Pressure-Level,Assimilation,Cloud Diagnostics 0.625 x 0.5 degree V5.12.4 (M2T3NPCLD) at GES DISC',
#  'Gridded Monthly Time-Mean Observation minus Analysis (oma) Values 0.5 x 0.667 degree V001 (MA_HIRS2_NOAA07_OMA) at GES DISC',
#  'AIRS/Aqua L1C Infrared (IR) resampled and corrected radiances V6.7 (AIRICRAD) at GES DISC',
#  'GPM SSMIS on F16 (GPROF) Radiometer Precipitation Profiling L3 1 month 0.25 degree x 0.25 degree V05 (GPM_3GPROFF16SSMIS) at GES DISC',
#  'OCO-2 Level 2 geolocated XCO2 retrievals results, physical model V10 (OCO2_L2_Standard) at GES DISC',
#  'HIRDLS/Aura Level 3 Ozone (O3) 1deg Lat Zonal Fourier Coefficients V007 (H3ZFCO3) at GES DISC',
#  'Sentinel-5P TROPOMI Irradiance product SWIR module L1B V1 (S5P_L1B_IR_SIR) at GES DISC',
#  'NLDAS Primary Forcing Data L4 Monthly Climatology 0.125 x 0.125 degree V2.0 (NLDAS_FORA0125_MC) at GES DISC',
#  'GPM DPR Spectral Latent Heating Profiles L2 1.5 hours 5 km V06 (GPM_2HSLH) at GES DISC',
#  'OMI/Aura Near UV Aerosol Optical Depth and Single Scattering Albedo Daily L2 Global Gridded 0.25 degree x 0.25 degree V3 (OMAERUVG) at GES DISC',
#  'TRMM (TMPA/3B43) Rainfall Estimate L3 1 month 0.25 degree x 0.25 degree V7 (TRMM_3B43) at GES DISC',
#  'TOVS GLA 5 DAY GRIDS from NOAA-12 V01 (TOVSA5ND) at GES DISC',
#  'MLS/Aura Level 2 Hydrogen Chloride (HCl) Mixing Ratio V004 (ML2HCL) at GES DISC',
#  'Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_SSU_NOAA07_OBS) at GES DISC',
#  'GPM AMSUB on NOAA16 (GPROF) Climate-based Radiometer Precipitation Profiling L3 1 month 0.25 degree x 0.25 degree  V05 (GPM_3GPROFNOAA16AMSUB_CLIM) at GES DISC',
#  'OMI/Aura Near UV Aerosol Index, Optical Depth and Single Scattering Albedo 1-Orbit L2 13x24km',
#  'TRMM PR Gridded Orbital Spectral Latent Heating Profiles L3 1.5 hours 0.5 degree x 0.5 degree V7 (TRMM_3G25) at GES DISC',
#  'MLS/Aura Level 3 Monthly Binned Geopotential Height (GPH) on Assorted Grids V004 (ML3MBGPH) at GES DISC',
#  'GPM AMSR-2 on GCOM-W1 (GPROF) Radiometer Precipitation Profiling L2A 1.5 hours 10 km V05 (GPM_2AGPROFGCOMW1AMSR2) at GES DISC',
#  'MLS/Aura Level 3 Daily Binned Cloud Ice (IWC) on Assorted Grids V005 (ML3DBIWC) at GES DISC',
#  'ATMOS L2 Trace Gases on Potential Temperature Grid, Tab Delimited Format V3 (ATMOSL2TT) at GES DISC',
#  'MLS/Aura Level 2 Ozone (O3) Mixing Ratio V004 (ML2O3) at GES DISC',
#  'Carbon Monitoring System Flux for Ocean Carbon L4 V1 (CMSFluxOcean) at GES DISC',
#  'MLS/Aura Level 3 Daily Binned Ozone (O3) Mixing Ratio on Zonal and Similar Grids V005 (ML3DZO3) at GES DISC',
#  'MLS/Aura Level 3 Daily Binned Water Vapor (H2O) Mixing Ratio on Zonal and Similar Grids V004 (ML3DZH2O) at GES DISC',
#  'Gridded Monthly Time-Mean Observation minus Forecast (omf) Values 0.5 x 0.667 degree V001 (MA_HIRS2_NOAA11_OMF) at GES DISC',
#  'HIRDLS/Aura Level 3 Extinction at 12.1 Microns 1deg Lat Zonal Fourier Coefficients V007 (H3ZFC12MEXT) at GES DISC',
#  'Sentinel-5P TROPOMI Radiance product band 7 (SWIR detector) L1B 5.5km x 7km V1 (S5P_L1B_RA_BD7_HiR) at GES DISC',
#  'Goddard Satellite-Based Surface Turbulent Fluxes, 0.25 x 0.25 deg, Daily Grid F11 V3 (GSSTF_F11) at GES DISC',
#  'Goddard Satellite-Based Surface Turbulent Fluxes, 0.25 x 0.25 deg, Daily Grid V3 (GSSTF) at GES DISC',
#  'Gridded Monthly Time-Mean Observation minus Forecast (omf) Values 0.5 x 0.667 degree V001 (MA_SSU_NOAA09_OMF) at GES DISC',
#  'Sentinel-5P TROPOMI Tropospheric NO2 1-Orbit L2 7km x 3.5km V1 (S5P_L2__NO2___) at GES DISC',
#  'GPCP Precipitation Level 3 Daily 0.5-Degree V3.1 (GPCPDAY) at GES DISC',
#  'TOMS Earth Probe Ground Station Overpass Data V008 (TOMSEPOVP) at GES DISC',
#  'TROPESS CrIS-SNPP and TROPOMI-S5P L2 Deuterated Water Vapor for Forward Stream, Standard Product V1 (TRPSDL2HDOCRSTRPOMIFS) at GES DISC',
#  'MLS/Aura Level 3 Daily Binned Cloud Ice (IWC) on Zonal and Similar Grids V004 (ML3DZIWC) at GES DISC',
#  'OMI/Aura Nitrogen Dioxide (NO2) Total and Tropospheric Column 1-orbit L2 Swath 13x24 km V003 (OMNO2) at GES DISC',
#  'NLDAS Mosaic Land Surface Model L4 Hourly 0.125 x 0.125 degree V002 (NLDAS_MOS0125_H) at GES DISC',
#  'GPM GMI (GPROF) Climate-based Radiometer Precipitation Profiling L3 1 day 0.25 degree x 0.25 degree  V05 (GPM_3GPROFGPMGMI_DAY_CLIM) at GES DISC',
#  'MERRA-2 tavgC_3d_ltm_Np: 3d, Long Term Mean 3-Dimensional Meteorological Fields V1 (M2TCNPLTM) at GES DISC',
#  'TOMS Earth Probe UV-B Erythemal Local Noon Irradiance Monthly L3 Global 1 deg x 1.25 deg Lat/Lon Grid V008 (TOMSEPL3mery) at GES DISC',
#  'MODIS Aqua L2 chopped blocks',
#  'CAR SCAR-A Sulfates, Clouds, and Radiation-Atlantic BRDF Measurements BRDF V2 (CAR_SCARA_BRDF) at GES DISC',
#  'GPM GMI XCAL Common Calibrated Brightness Temperatures L1BASE 1.5 hours 13 km V05 (GPM_BASEGPMGMI_XCAL) at GES DISC',
#  'GPM TMI on TRMM Common Calibrated Brightness Temperatures L1C 1.5 hours 13 km V05 (GPM_1CTRMMTMI) at GES DISC',
#  'Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_HIRS2_NOAA09_OBS) at GES DISC',
#  'inst3_3d_chm_Ne: MERRA Chem 3D IAU Edge Pressure, Instantaneous 3-Hourly  0.667 x 0.5 degree V5.2.0 (MAI3NECHM) at GES DISC',
#  'CAR CLAMS BRDF Measurements V2 (CAR_CLAMS_BRDF) at GES DISC',
#  'Sentinel-5P TROPOMI Tropospheric Ozone Column V1 (S5P_L2__O3_TCL) at GES DISC',
#  'Explorer-7 Thermal Radiation Experiment Temperature Values from All Sensors V001 (EXP7L1TRTALL) at GES DISC',
#  'Gridded Monthly Time-Mean Observation minus Analysis (oma) Values 0.5 x 0.667 degree V001 (MA_AMSUA_NOAA15_OMA) at GES DISC',
#  'GPM DPR Ka-band Received Power L1B 1.5 hours 5 km V07 (GPM_PRL1KA) at GES DISC',
#  'Sounder SIPS: Suomi NPP CrIMSS Level 3 Comprehensive Quality Control Gridded Monthly CLIMCAPS Normal Spectral Resolution V2 at GES DISC',
#  'TROPESS CrIS-SNPP L2 Carbon Monoxide for Forward Stream, Standard Product V1 (TRPSDL2COCRSFS) at GES DISC',
#  'GPM AMSR-2 on GCOM-W1 (GPROF) Climate-based Radiometer Precipitation Profiling L3 1 month 0.25 degree x 0.25 degree V05 (GPM_3GPROFGCOMW1AMSR2_CLIM) at GES DISC',
#  'Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_HIRS2_NOAA07_OBS) at GES DISC',
#  'Sounder SIPS: AQUA AIRS IR-only Level 2 CLIMCAPS : Atmosphere, cloud and surface geophysical state V2 at GES DISC',
#  'tavgM_3d_cld_Cp: MERRA 3D IAU Diagnostic, Cloud Properties, Monthly Mean  1.25 x 1.25 degree V5.2.0 (MATMCPCLD) at GES DISC',
#  'AIRS/Aqua L3 5-day Quantization in Physical Units (AIRS+AMSU+HSB) 5 degrees x 5 degrees V006 (AIRH3QP5) at GES DISC',
#  'MERRA-2 instU_2d_asm_Nx: 2d,diurnal,Instantaneous,Single-Level,Assimilation,Single-Level Diagnostics 0.625 x 0.5 degree V5.12.4 (M2IUNXASM) at GES DISC',
#  'Gridded Monthly Time-Mean Observation minus Analysis (oma) Values 0.5 x 0.667 degree V001 (MA_AMSUB_NOAA16_OMA) at GES DISC',
#  'MLS/Aura Level 3 Monthly Binned Hypochlorous Acid (HOCl) Mixing Ratio on Assorted Grids V004 (ML3MBHOCL) at GES DISC',
#  'GPM ATMS on SUOMI-NPP (GPROF) Radiometer Precipitation Profiling L3 1 day 0.25 degree x 0.25 degree V05 (GPM_3GPROFNPPATMS_DAY) at GES DISC',
#  'Goddard Satellite-Based Surface Turbulent Fluxes, 1x1 deg Daily Grid, Satellite F15 V2c (GSSTF_F15) at GES DISC',
#  'SBUV2/NOAA-18 Ozone (O3) Nadir Profile and Total Column 1 Day L2 V1 (SBUV2N18L2) at GES DISC',
#  'GPM PR on TRMM Gridded Orbital Spectral Latent Heating Profiles L3 1.5 hours 0.5x0.5 degree V06 (GPM_3GSLH_TRMM) at GES DISC',
#  'MLS/Aura Level 3 Daily Binned Methyl Chloride (CH3Cl) Mixing Ratio on Zonal and Similar Grids V005 (ML3DZCH3CL) at GES DISC',
#  'MLS/Aura Level 3 Monthly Binned Relative Humidity With Respect To Ice (RHI) on Assorted Grids V005 (ML3MBRHI) at GES DISC',
#  'GPM SSMIS on F18 (GPROF) Radiometer Precipitation Profiling L3 1 month 0.25 degree x 0.25 degree V05 (GPM_3GPROFF18SSMIS) at GES DISC',
#  'Multi-Instrument Fused bias-corrected XCO2 and other select fields aggregated as Level 4 daily files V1 (MultiInstrumentFusedXCO2) at GES DISC',
#  'GLDAS VIC Land Surface Model L4 3 hourly 1.0 x 1.0 degree V2.1 (GLDAS_VIC10_3H) at GES DISC',
#  'OCO-2 Level 1A collated, parsed, calibration data V10 (OCO2_L1aIn_Pixel) at GES DISC',
#  'TROPESS OMI-Aura L2 Ozone for Forward Stream, Standard Product V1 (TRPSDL2O3OMIFS) at GES DISC',
#  'OMPS/NPP PCA SO2 Total Column 1-Orbit L2 Swath 50x50km V1 (OMPS_NPP_NMSO2_PCA_L2) at GES DISC',
#  'GLDAS Catchment Land Surface Model L4 daily 0.25 x 0.25 degree GRACE-DA1 V2.2 (GLDAS_CLSM025_DA1_D_EP) at GES DISC',
#  'Gridded Monthly Time-Mean Observation minus Analysis (oma) Values 0.5 x 0.667 degree V001 (MA_AMSUA_NOAA17_OMA) at GES DISC',
#  'GLDAS CLM Land Surface Model L4 3 hourly 1.0 x 1.0 degree Subsetted V001 (GLDAS_CLM10SUBP_3H) at GES DISC',
#  'GLDAS Catchment Land Surface Model L4 monthly 1.0 x 1.0 degree Early Product V2.1 (GLDAS_CLSM10_M_EP) at GES DISC',
#  'Sentinel-5P TROPOMI Aerosol Index 1-Orbit L2 5.5km x 3.5km V1 (S5P_L2__AER_AI_HiR) at GES DISC',
#  'GPM DPR Precipitation Profile 1 Day 0.25 degree x 0.25 degree V06 (GPM_3DPRD) at GES DISC',
#  'AIRS-CloudSat cloud mask and radar reflectivities collocation indexes V4.0 (AIRS_CPR_IND) at GES_DISC',
#  'MERRA-2 instU_2d_lfo_Nx: 2d,diurnal,Instantaneous,Single-Level,Assimilation,Land Surface Forcings 0.625 x 0.5 degree V5.12.4 (M2IUNXLFO) at GES DISC',
#  'NEMS/Nimbus-5 Level 2 Output Data V001 (NEMSN5L2) at GES DISC',
#  'TROPOMI/Sentinel-5P Near UV Aerosol Optical Depth and Single Scattering Albedo L2 1-Orbit Snapshot 7.5 km x 3 km',
#  'TOVS GLA 5 DAY GRIDS from TIROSN V01 (TOVSA5TN ) at GES DISC',
#  'MERRA-2 inst1_2d_lfo_Nx: 2d,1-Hourly,Instantaneous,Single-Level,Assimilation,Land Surface Forcings 0.625 x 0.5 degree V5.12.4 (M2I1NXLFO) at GES DISC',
#  'Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_HIRS2_AM_OBS) at GES DISC',
#  'GPM MHS on METOP-B (GPROF) Radiometer Precipitation Profiling L3 1 day 0.25 degree x 0.25 degree V05 (GPM_3GPROFMETOPBMHS_DAY) at GES DISC',
#  'Gridded Monthly Time-Mean Observation minus Forecast (omf) Values 0.5 x 0.667 degree V001 (MA_SSMI_DMSP15_OMF) at GES DISC',
#  'TOMS EP UV Reflectivity Daily and Monthly Zonal Means V008 (TOMSEPL3zref) at GES DISC',
#  'AIRS/Aqua L3 Monthly Support Product (AIRS+AMSU+HSB) 1 degree x 1 degree V006 (AIRH3SPM) at GES DISC',
#  'Sentinel-5P TROPOMI Radiance product band 6 (NIR detector) L1B 5.5km x 3.5km V1 (S5P_L1B_RA_BD6_HiR) at GES DISC',
#  'Sentinel-5P TROPOMI Radiance product band 6 (NIR detector) L1B V1 (S5P_L1B_RA_BD6) at GES DISC',
#  'MERRA-2 tavgM_2d_ocn_Nx: 2d,Monthly mean,Time-Averaged,Single-Level,Assimilation,Ocean Surface Diagnostics 0.625 x 0.5 degree V5.12.4 (M2TMNXOCN) at GES DISC',
#  'Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_MSU_NOAA07_OBS) at GES DISC',
#  'OCO-2 Level 2 spatially ordered geolocated retrievals screened using the A-band Preprocessor V10 (OCO2_L2_ABand) at GES DISC',
#  'MLS/Aura Level 3 Daily Binned Hypochlorous Acid (HOCl) Mixing Ratio on Zonal and Similar Grids V004 (ML3DZHOCL) at GES DISC',
#  'UARS Cryogenic Limb Array Etalon Spectrometer (CLAES) Level 3AT V009 (UARCL3AT) at GES DISC',
#  'Sounder SIPS: Suomi NPP CrIMSS Level 3 Comprehensive Quality Control Gridded Monthly CLIMCAPS Normal Spectral Resolution V1',
#  'GPM SAPHIR on MT1 (PRPS) Climate-based Radiometer Precipitation Profiling L2 1.5 hours 10 km V06 (GPM_2APRPSMT1SAPHIR_CLIM) at GES DISC',
#  'LIMS/Nimbus-7 Level 2 Vertical Profiles of O3, NO2, H2O, HNO3, Geopotential Height, and Temperature V006 (LIMSN7L2) at GES DISC',
#  'CAR SCAR-A Sulfates, Clouds, and Radiation-Atlantic L1 V1 (CAR_SCARA_L1C) at GES DISC',
#  'Gridded Monthly Time-Mean Observation minus Analysis (oma) Values 0.5 x 0.667 degree V001 (MA_HIRS2_NOAA12_OMA) at GES DISC',
#  'UARS Microwave Limb Sounder (MLS) Level 3AL V005 (UARML3AL) at GES DISC',
#  'CAR TARFOX Tropospheric Aerosol Experiment BRDF V2 (CAR_TARFOX_BRDF) at GES DISC',
#  'TRMM Ground Validation Radar Site Rain Totals Map L3 5 days 2 km V7 (TRMM_3A53) at GES DISC',
#  'Carbon Monitoring System Carbon Flux for Ocean Prior L4 V2 (CMSFluxOceanPrior) at GES DISC',
#  'CAR Clams Chesapeake Lighthouse Aircraft Ocean Measurements L1 V1 (CAR_CLAMS_L1C) at GES DISC',
#  'Gridded Monthly Time-Mean Observation minus Forecast (omf) Values 0.5 x 0.667 degree V001 (MA_SSMI_DMSP08_OMF) at GES DISC',
#  'GPM DPR Ku-band Received Power L1B 1.5 hours 5 km V07 (GPM_PRL1KU) at GES DISC',
#  'MERRA-2 tavg1_2d_rad_Nx: 2d,1-Hourly,Time-Averaged,Single-Level,Assimilation,Radiation Diagnostics 0.625 x 0.5 degree V5.12.4 (M2T1NXRAD) at GES DISC',
#  'GLDAS Mosaic Land Surface Model L4 3 Hourly 1.0 x 1.0 degree Subsetted V001 (GLDAS_MOS10SUBP_3H) at GES DISC',
#  'MLS/Aura Level 3 Daily Binned Chlorine Monoxide (ClO) Mixing Ratio on Zonal and Similar Grids V005 (ML3DZCLO) at GES DISC',
#  'GPM DPR and GMI (Combined Precipitation) L3 1 month 0.25 degree x 0.25 degree V07 (GPM_3CMB) at GES DISC',
#  'TROPESS AIRS-Aqua L2 Methane for Forward Stream, Standard Product V1 (TRPSDL2CH4AIRSFS) at GES DISC',
#  'UARS Correlative NMC Daily Gridded Stratospheric Assimilated Data V001 (UARZCNMC) at GES DISC',
#  'Aqua/AIRS L3 Monthly Support Product (AIRS-only) 1 degree x 1 degree V7.0 at GES DISC',
#  'OMI/Aura Cloud Pressure and Fraction (O2-O2 Absorption) 1-Orbit L2 Swath 13x24km V003 (OMCLDO2) at GES DISC',
#  'MERRA-2 instM_2d_asm_Nx: 2d,Monthly mean,Single-Level,Assimilation,Single-Level Diagnostics 0.625 x 0.5 degree V5.12.4 (M2IMNXASM) at GES DISC',
#  'GLDAS VIC Land Surface Model L4 monthly 1.0 x 1.0 degree V2.1 (GLDAS_VIC10_M) at GES DISC',
#  'Sentinel-5P TROPOMI Radiance product band 3 (UVIS detector) L1B V1 (S5P_L1B_RA_BD3) at GES DISC',
#  'Gridded Monthly Time-Mean Observation minus Analysis (oma) Values 0.5 x 0.667 degree V001 (MA_SSU_NOAA09_OMA) at GES DISC',
#  'Gridded Monthly Time-Mean Observation minus Forecast (omf) Values 0.5 x 0.667 degree V001 (MA_MSU_TIROSN_OMF) at GES DISC',
#  'MERRA-2 tavg1_2d_ocn_Nx: 2d,1-Hourly,Time-Averaged,Single-Level,Assimilation,Ocean Surface Diagnostics 0.625 x 0.5 degree V5.12.4 (M2T1NXOCN) at GES DISC',
#  'GPM MHS on METOP-B (GPROF) Climate-based Radiometer Precipitation Profiling L3 1 day 0.25 degree x 0.25 degree V05 (GPM_3GPROFMETOPBMHS_DAY_CLIM) at GES DISC',
#  'MLS/Aura Level 3 Monthly Binned Relative Humidity With Respect To Ice (RHI) on Assorted Grids V004 (ML3MBRHI) at GES DISC',
#  'Sentinel-5P TROPOMI Radiance product band 2 (UV detector) L1B 5.5km x 3.5km V2 (S5P_L1B_RA_BD2_HiR) at GES DISC',
#  'GLDAS VIC Land Surface Model L4 3 hourly 1.0 x 1.0 degree V2.0 (GLDAS_VIC10_3H) at GES DISC',
#  'MLS/Aura Level 2 Hydrogen Cyanide (HCN) Mixing Ratio V004 (ML2HCN) at GES DISC',
#  'MLS/Aura Level 3 Daily Binned Hydrogen Cyanide (HCN) Mixing Ratio on Zonal and Similar Grids V004 (ML3DZHCN) at GES DISC',
#  'Shuttle SBUV (SSBUV) Level 2 Ozone Profile and Total Column, Aerosol Index, and UV-Reflectivity V008 (SSBUVO3) at GES DISC',
#  'OMI/Aura Formaldehyde (HCHO) Total Column Daily L3 Weighted Mean Global 0.1deg Lat/Lon Grid V003 (OMHCHOd) at GES DISC',
#  'MERRA-2 tavg3_3d_rad_Np: 3d,3-Hourly,Time-Averaged,Pressure-Level,Assimilation,Radiation Diagnostics 0.625 x 0.5 degree V5.12.4 (M2T3NPRAD) at GES DISC',
#  'MLS/Aura Near-Real-Time L2 Nitric Acid (HNO3) Mixing Ratio V004 (ML2HNO3_NRT) at GES DISC',
#  'GPM MHS on NOAA-18 Common Calibrated Brightness Temperature L1C 1.5 hours 17 km V05 (GPM_1CNOAA18MHS) at GES DISC',
#  'NLDAS Primary Forcing Data L4 Hourly 0.125 x 0.125 degree V2.0 (NLDAS_FORA0125_H) at GES DISC',
#  'Sounder SIPS: Suomi NPP CrIMSS Level 2 CHART Normal Spectral Resolution: Atmosphere, cloud and surface geophysical state V1',
#  'Sentinel-5P TROPOMI Radiance product band 4 (UVIS detector) L1B 5.5km x 3.5km V1 (S5P_L1B_RA_BD4_HiR) at GES DISC',
#  'TRMM Ground Validation Calibrated QC Radar Reflectivity Full Volume Scan L1C 1 hour V7 (TRMM_1C51UW) at GES DISC',
#  'LIMS/Nimbus-7 Level 3 Daily 2 deg Latitude Zonal Fourier Coefficients of O3, NO2, H2O, HNO3, Geopotential Height, and Temperature V006 (LIMSN7L3) at GES DISC',
#  'TOVS GLA DAILY GRIDS from TIROSN V01 (TOVSADTN) at GES DISC',
#  'tavgM_2d_flx_Nx: MERRA 2D IAU Diagnostic, Surface Fluxes, Monthly Mean  0.667 x 0.5 degree V5.2.0 (MATMNXFLX) at GES DISC',
#  'GPM MHS on METOP-A (GPROF) Radiometer Precipitation Profiling L3 1 day 0.25 degree x 0.25 degree V05 (GPM_3GPROFMETOPAMHS_DAY_CLIM) at GES DISC',
#  'GPM ATMS on NOAA-20 (GPROF) Radiometer Precipitation Profiling L2A 1.5 hours 17 km V05 (GPM_2AGPROFNOAA20ATMS) at GES DISC',
#  'Gridded Monthly Time-Mean Observation minus Analysis (oma) Values 0.5 x 0.667 degree V001 (MA_SSU_NOAA06_OMA) at GES DISC',
#  'tavgM_2d_int_Nx: MERRA 2D IAU Diagnostic, Vertical Integrals and Budget Terms, Monthly Mean  0.667 x 0.5 degree V5.2.0 (MATMNXINT) at GES DISC',
#  'Gridded Monthly Time-Mean Observation minus Analysis (oma) Values 0.5 x 0.667 degree V001 (MA_SSU_TIROSN_OMA) at GES DISC',
#  'AIRS/Aqua L3 Monthly Support Product (AIRS-only) 1 degree x 1 degree V006 (AIRS3SPM) at GES DISC',
#  'Carbon Monitoring System Flux for Prior Total Carbon L4 V1 (CMSFluxTotalprior) at GES DISC',
#  'HIRDLS/Aura Level 3 Chlorofluorocarbon-12 (CFC-12) 1deg Lat Zonal Fourier Coefficients V007 (H3ZFCCFC11) at GES DISC',
#  'MERRA-2 tavgU_2d_lnd_Nx: 2d,diurnal,Time-Averaged,Single-Level,Assimilation,Land Surface Diagnostics 0.625 x 0.5 degree V5.12.4 (M2TUNXLND) at GES DISC',
#  'MLS/Aura Level 3 Daily Binned Hydrogen Chloride (HCl) Mixing Ratio on Assorted Grids V005 (ML3DBHCL) at GES DISC',
#  'TROPESS CrIS-SNPP L2 Ammonia for West Coast Fires HiRes, Standard Product V1 (TRPSDL2NH3CRSWCFHI) at GES DISC',
#  'Gridded Monthly Time-Mean Observation minus Forecast (omf) Values 0.5 x 0.667 degree V001 (MA_AMSUA_NOAA18_OMF) at GES DISC',
#  'Shuttle SBUV (SSBUV) Solar Spectral Irradiance V008 (SSBUVIRR) at GES DISC',
#  'OCO-3 Level 2 CO2 prior based on CO2 monthly flask record, global meteorology, and age of air VEarlyR (OCO3_L2_CO2Prior) at GES DISC',
#  'AMSR-MODIS Boundary Layer Water Vapor L3 Daily 1 degree x 1 degree V2 (AMDBLWV) at GES DISC',
#  'MLS/Aura Level 3 Monthly Binned Ozone (O3) Mixing Ratio on Assorted Grids V004 (ML3MBO3) at GES DISC',
#  'NLDAS VIC Land Surface Model L4 Hourly 0.125 x 0.125 degree V2.0 (NLDAS_VIC0125_H) at GES DISC',
#  'GPM MHS on METOP-A Common Calibrated Brightness Temperature L1C 1.5 hours 17 km V05 (GPM_1CMETOPAMHS) at GES DISC',
#  'TOVS LMD MONTHLY GRIDS from NOAA-12 V01 (TOVSBMND) at GES DISC',
#  'Sentinel-5P TROPOMI Carbon Monoxide CO Column 1-Orbit L2 5.5km x 7km V1 (S5P_L2__CO_____HiR) at GES DISC',
#  'AIRS/Aqua L3 daily CO2 in the free troposphere (AIRS-only) 1 degree x 1 degree V006 (AIRS3C2D) at GES DISC',
#  'MERRA-2 instM_2d_gas_Nx: 2d,Monthly mean,Instantaneous,Single-Level,Assimilation,Aerosol Optical Depth Analysis 0.625 x 0.5 degree V5.12.4 (M2IMNXGAS) at GES DISC',
#  'MERRA-2 tavgU_3d_cld_Np: 3d,diurnal,Time-Averaged,Pressure-Level,Assimilation,Cloud Diagnostics 0.625 x 0.5 degree V5.12.4 (M2TUNPCLD) at GES DISC',
#  'Sounder SIPS: Suomi NPP CrIMSS Level 3 Comprehensive Quality Control Gridded Daily CHART Normal Spectral Resolution V1',
#  'MERRA-2 statM_2d_slv_Nx: 2d,Monthly,Aggregated Statistics,Single-Level,Assimilation,Single-Level Diagnostics 0.625 x 0.5 degree V5.12.4 (M2SMNXSLV) at GES DISC',
#  'GOZCARDS Merged Water Vapor 1 month L3 10 degree Zonal Means on a Vertical Pressure Grid V1 (GozMmlpH2O) at GES DISC',
#  'OCO-3 Level 2 CO2 prior based on CO2 monthly flask record, global meteorology, and age of air VEarly (OCO3_L2_CO2Prior) at GES DISC',
#  'TOMS Nimbus-7 Total Column Ozone Daily L3 Global 1 deg x 1.25 deg Lat/Lon Grid V008 (TOMSN7L3dtoz) at GES DISC',
#  'TOVS GLA DAILY GRIDS from NOAA-12 V01 (TOVSADND) at GES DISC',
#  'Sentinel-5P TROPOMI Cloud 1-Orbit L2 5.5km x 3.5km V2 (S5P_L2__CLOUD__HiR) at GES DISC',
#  'Gridded Monthly Time-Mean Observation minus Forecast (omf) Values 0.5 x 0.667 degree V001 (MA_SSU_NOAA14_OMF) at GES DISC',
#  'Aqua/AIRS L3 Monthly Standard Physical Retrieval (AIRS-only) 1 degree x 1 degree V7.0 at GES DISC',
#  'GPM PR on TRMM Reflectivity, Precipitation Statistics, Histograms, at Surface and Fixed Heights, Ascending, 1 day 5x5 and 0.25x0.25 degree V06 (GPM_3PR_ASC) at GES DISC',
#  'GLDAS Noah Land Surface Model L4 monthly 0.25 x 0.25 degree V2.0 (GLDAS_NOAH025_M) at GES DISC',
#  'MERRA-2 statM_2d_edi_Nx: 2d, Single-Level, Monthly Extremes Detection Indices V1 (M2SMNXEDI) at GES DISC',
#  'MLS/Aura Level 3 Daily Binned Hydrogen Chloride (HCl) Mixing Ratio on Zonal and Similar Grids V005 (ML3DZHCL) at GES DISC',
#  'TROPESS TROPOMI-S5P L2 Ozone for Forward Stream, Standard Product V1 (TRPSDL2O3TRPOMIFS) at GES DISC',
#  'instU_3d_ana_Np: MERRA 3D Analyzed State, Meteorology Diurnal  0.667 x 0.5 degree V5.2.0 (MAIUNPANA) at GES DISC',
#  'MERRA-2 instU_2d_int_Nx: 2d,diurnal,Instantaneous,Single-Level,Assimilation,Vertically Integrated Diagnostics 0.625 x 0.5 degree V5.12.4 (M2IUNXINT) at GES DISC',
#  'OCO-3 Level 2 meteorological parameters interpolated from global assimilation model for each sounding VEarly (OCO3_L2_Met) at GES DISC',
#  'MERRA-2 tavgM_2d_csp_Nx: 2d,Monthly mean,Time-averaged,Single-Level,Assimilation,COSP Satellite Simulator 0.625 x 0.5 degree V5.12.4 (M2TMNXCSP) at GES DISC',
#  'GPM DPR and GMI Combined Stratiform Heating L2 1.5 hours 5 km V07 (GPM_2HCSH) at GES DISC',
#  'tavg3_3d_chm_Nv: MERRA Chem 3D IAU C-Grid Edge Mass Flux, Time Average 3-Hourly  1.25 x 1.25 degree V5.2.0 (MAT3NVCHM) at GES DISC',
#  'Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_AMSUA_NOAA15_OBS) at GES DISC',
#  'Sentinel-5P TROPOMI Radiance product band 8 (SWIR detector) L1B V2 (S5P_L1B_RA_BD8) at GES DISC',
#  'Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_MSU_NOAA11_OBS) at GES DISC',
#  'TROPESS CrIS-JPSS1 L2 Peroxyacetyl Nitrate for Forward Stream, Standard Product V1 (TRPSDL2PANCRS1FS) at GES DISC',
#  'OMI/Aura NO2 Tropospheric, Stratospheric & Total Columns MINDS 1-Orbit L2 Swath 13 km x 24 km V1.1 (OMI_MINDS_NO2) at GES DISC',
#  'GOZCARDS Source Water Vapor 1 month L3 10 degree Zonal Means on a Vertical Pressure Grid V1 (GozSmlpH2O) at GES DISC',
#  'Gridded Monthly Time-Mean Observation minus Forecast (omf) Values 0.5 x 0.667 degree V001 (MA_HIRS2_NOAA14_OMF) at GES DISC',
#  'Gridded Monthly Time-Mean Observation minus Forecast (omf) Values 0.5 x 0.667 degree V001 (MA_HIRS3_NOAA16_OMF) at GES DISC',
#  'OMI/Aura and MODIS/Aqua Aerosol Geo-colocation Product 1-Orbit L2 Swath 13x24 km V003 (OMMYDAGEO) at GES DISC',
#  'GPM DPR and GMI Combined Convective Stratiform Heating L3 1 month 0.5 degree x 0.5 degree V06 (GPM_3HCSH) at GES DISC',
#  'TOVS GLA MONTHLY GRIDS from NOAA-10 V01 (TOVSAMNG) at GES DISC',
#  'Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_SSU_NOAA08_OBS) at GES DISC',
#  'tavgM_3d_tdt_Cp: MERRA 3D IAU Tendency, Temperature, Monthly Mean  1.25 x 1.25 degree V5.2.0 (MATMCPTDT) at GES DISC',
#  'SBUV2/NOAA-14 Ozone (O3) Profile and Total Column Ozone 1 Month Zonal Mean L3 Global 5.0 degree Latitude Zones V1 (SBUV2N14L3zm) at GES DISC',
#  'OMI/Aura DOAS Total Column Ozone Zoomed 1-Orbit L2 Swath 13x12km V003 (OMDOAO3Z) at GES DISC',
#  'Gridded Monthly Time-Mean Observation minus Analysis (oma) Values 0.5 x 0.667 degree V001 (MA_AMSUA_AQUA_OMA) at GES DISC',
#  'Sentinel-5P TROPOMI Radiance product band 2 (UV detector) L1B V1 (S5P_L1B_RA_BD2) at GES DISC',
#  'MLS/Aura Level 3 Monthly Binned Hydrogen Cyanide (HCN) Mixing Ratio on Assorted Grids V005 (ML3MBHCN) at GES DISC',
#  'MLS/Aura Level 3 Monthly Binned Hydrogen Chloride (HCl) Mixing Ratio on Assorted Grids V004 (ML3MBHCL) at GES DISC',
#  'Aqua/AIRS L3 Daily Standard Physical Retrieval (AIRS-only) 1 degree x 1 degree V7.0 at GES DISC',
#  'SAMS/Nimbus-7 Level 3 Zonal Means Composition Data V001 (SAMSN7L3ZMTG) at GES DISC',
#  'OCO-3 Level 2 bias-corrected solar-induced fluorescence and other select fields from the IMAP-DOAS algorithm aggregated as daily files, Retrospective processing V10r (OCO3_L2_Lite_SIF) at GES DISC',
#  'Goddard Satellite-Based Surface Turbulent Fluxes, 1x1 deg Seasonal Climatology, Set1 and NCEP V2c (GSSTFSC) at GES DISC',
#  'AIRS/Aqua L2 Support Retrieval (AIRS+AMSU) V006 (AIRX2SUP) at GES DISC',
#  'Goddard Satellite-Based Surface Turbulent Fluxes, 1x1 deg Yearly Climatology, Set1 and NCEP V2c (GSSTFYC) at GES DISC',
#  'BUV/Nimbus-4 Ozone (O3) Profile and Total Column Ozone 1 Month Zonal Mean L3 Global 5.0 degree Latitude Zones V1 (BUVN04L3zm) at GES DISC',
#  'TOVS GLA MONTHLY GRIDS from TIROSN V01 (TOVSAMTN) at GES DISC',
#  'GPM SSMIS on F16 (GPROF) Climate-based Radiometer Precipitation Profiling L3 1 month 0.25 degree x 0.25 degree V05 (GPM_3GPROFF16SSMIS_CLIM) at GES DISC',
#  'Gridded Monthly Time-Mean Observation minus Forecast (omf) Values 0.5 x 0.667 degree V001 (MA_AMSUA_NOAA17_OMF) at GES DISC',
#  'SeaWiFS Deep Blue Aerosol Optical Depth and Angstrom Exponent Daily Level 3 Data Gridded at 0.5 Degrees V004 (SWDB_L305) at GES DISC',
#  'tavg3_3d_chm_Ne: MERRA Chem 3D IAU C-Grid Edge Mass Flux, Time Average 3-Hourly  0.667 x 0.5 degree V5.2.0 (MAT3NECHM) at GES DISC',
#  'CAR Eco-3D Vegetation Response to Changing Forcing Factors L1 V1 (CAR_ECO3D_L1C) at GES DISC',
#  'Sentinel-5P TROPOMI SNPP cloud product band 7 (SWIR detector) 1-Orbit L2 7km x 7km V1 (S5P_L2__NP_BD7) at GES DISC',
#  'AIRS/Aqua L3 Monthly CO2 in the free troposphere (AIRS-only) 1 degree x 1 degree V006 (AIRS3C2M) at GES DISC',
#  'Sentinel-5P TROPOMI Radiance product band 3 (UVIS detector) L1B 5.5km x 3.5km V2 (S5P_L1B_RA_BD3_HiR) at GES DISC',
#  'MODIS/Aqua Total Precip Water Vapor 1km and 5km 5-Min L2 Narrow Swath Subset along CloudSat V002 (MAC05S0) at GES DISC',
#  'MLS/Aura Level 2 Nitrous Oxide (N2O) Mixing Ratio V005 (ML2N2O) at GES DISC',
#  'MLS/Aura Near-Real-Time L2 Nitric Acid (HNO3) Mixing Ratio V005 (ML2HNO3_NRT) at GES DISC',
#  'TRMM Ground Validation Rain Gauge Rain Rate L2 1 month V7 (TRMM_2A56) at GES DISC',
#  'Methane (CH4) Flux for Canadian Oil/Gas Systems L4 V1 (CMS_CH4_FLX_CA) at GES DISC',
#  'Multi-Satellite Lambertian Equivalent Reflectivity (Local Satellite Time) 10-Day L3 Global 2.0x5.0deg Lat/Lon Grid V1 (MSLERLSTL3d10) at GES DISC',
#  'Gridded Monthly Time-Mean Observation minus Forecast (omf) Values 0.5 x 0.667 degree V001 (MA_AMSUA_NOAA16_OMF) at GES DISC',
#  'OCO-3 Level 2 spatially ordered geolocated retrievals screened using the A-band Preprocessor, Retrospective Processing V10r (OCO3_L2_ABand) at GES DISC',
#  'SMMR/Nimbus-7 Color Images V001 (SMMRN7IM) at GES DISC',
#  'OCO-3 Level 2 spatially ordered geolocated retrievals screened using the A-band Preprocessor VEarlyR (OCO3_L2_ABand) at GES DISC',
#  'AMSR-MODIS Boundary Layer Water Vapor L3 Monthly 1 degree x 1 degree V1 (AMMBLWV) at GES DISC',
#  'MERRA-2 tavgM_3d_tdt_Np: 3d,Monthly mean,Time-Averaged,Pressure-Level,Assimilation,Temperature Tendencies 0.625 x 0.5 degree V5.12.4 (M2TMNPTDT) at GES DISC',
#  'Sentinel-5P TROPOMI Ozone Profile 1-Orbit L2 21km x 28km V1 (S5P_L2__O3__PR) at GES DISC',
#  'Sounder SIPS: AQUA AIRS IR-only Level 3 CLIMCAPS : Comprehensive Quality Control Gridded Daily V2 at GES DISC',
#  'MLS/Aura Level 2 Ozone (O3) Mixing Ratio V005 (ML2O3) at GES DISC',
#  'OMI/Aura Multi-wavelength Aerosol Optical Depth and Single Scattering Albedo 1-orbit L2 Swath 13x24 km V003 (OMAERO) at GES DISC',
#  'Gridded Monthly Time-Mean Observation minus Forecast (omf) Values 0.5 x 0.667 degree V001 (MA_SSU_NOAA08_OMF) at GES DISC',
#  'OMPS-NPP L2 NP Ozone (O3) Vertical Profile swath orbital',
#  'Gridded Monthly Time-Mean Observation minus Analysis (oma) Values 0.5 x 0.667 degree V001 (MA_MSU_NOAA06_OMA) at GES DISC',
#  'AIRS/Aqua L2 CO2 support retrieval (AIRS-only) V005 (AIRS2SPC) at GES DISC',
#  'Gridded 6 hours Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_CONV_OMA) at GES DISC',
#  'TOVS GLA DAILY GRIDS from NOAA-9 V01 (TOVSADNF) at GES DISC',
#  'Goddard Satellite-Based Surface Turbulent Fluxes, 0.25 x 0.25 deg, Monthly Grid V3 (GSSTFM) at GES DISC',
#  'GPM ATMS on NOAA-20 (GPROF) Radiometer Precipitation Profiling L3 1 month 0.25 degree x 0.25 degree V05 (GPM_3GPROFNOAA20ATMS) at GES DISC',
#  'tavg1_2d_flx_Nx: MERRA 2D IAU Diagnostic, Surface Fluxes, Time Average 1-hourly  0.667 x 0.5 degree V5.2.0 (MAT1NXFLX) at GES DISC',
#  'Gridded Monthly Time-Mean Observation minus Analysis (oma) Values 0.5 x 0.667 degree V001 (MA_HIRS3_NOAA17_OMA) at GES DISC',
#  'MLS/Aura Level 2 Chlorine Monoxide (ClO) Mixing Ratio V005 (ML2CLO) at GES DISC',
#  'GPM DPR Precipitation Profile 1 Day Ascending 0.25 degree x 0.25 degree V06 (GPM_3DPR_ASC) at GES DISC',
#  'MERRA-2 tavgU_2d_rad_Nx: 2d,diurnal,Time-Averaged,Single-Level,Assimilation,Radiation Diagnostics 0.625 x 0.5 degree V5.12.4 (M2TUNXRAD) at GES DISC',
#  'BUV/Nimbus-4 Level 2 Compressed Ozone Profile Data V005 (BUVN4L2CPOZ) at GES DISC',
#  'MLS/Aura Level 3 Monthly Binned Nitrous Oxide (N2O) Mixing Ratio on Assorted Grids V005 (ML3MBN2O) at GES DISC',
#  'tavgM_3d_qdt_Cp: MERRA 3D IAU Tendency, Specific Humidity, Monthly Mean  1.25 x 1.25 degree V5.2.0 (MATMCPQDT) at GES DISC',
#  'tavgU_3d_rad_Cp: MERRA 3D IAU Diagnostic, Radiation, Diurnal  1.25 x 1.25 degree V5.2.0 (MATUCPRAD) at GES DISC',
#  'GPM MHS on NOAA-19 Common Calibrated Brightness Temperatures L1C 1.5 hours 17 km V05 (GPM_1CNOAA19MHS) at GES DISC',
#  'OCO-3 Level 2 bias-corrected solar-induced fluorescence and other select fields from the IMAP-DOAS algorithm aggregated as daily files, Retrospective processing VEarlyR (OCO3_L2_Lite_SIF) at GES DISC',
#  'OMI/Aura TOMS-Like Ozone and Radiative Cloud Fraction L3 1 day 0.25 degree x 0.25 degree V3 (OMTO3e) at GES DISC',
#  'HIRDLS/Aura Level 3 Nitrogen Dioxide (NO2) 1deg Lat Zonal Fourier Coefficients V007 (H3ZFCNO2) at GES DISC',
#  'OCO-2 Level 2 preprocessor using Generic Algorithm for Single Band Acquisition of Gases (GASBAG), Retrospective Processing V10r (OCO2_L2_GASBAG) at GES DISC',
#  'inst3_3d_asm_Cp: MERRA 3D IAU State, Meteorology Instantaneous 3-hourly  1.25 x 1.25 degree V5.2.0 (MAI3CPASM) at GES DISC',
#  'TROPESS CrIS-JPSS1 L2 Ozone for Forward Stream, Standard Product V1 (TRPSDL2O3CRS1FS) at GES DISC',
#  'Gridded Monthly Time-Mean Observation minus Forecast (omf) Values 0.5 x 0.667 degree V001 (MA_AMSUB_NOAA15_OMF) at GES DISC',
#  'NLDAS Primary Forcing Data L4 Monthly 0.125 x 0.125 degree V002 (NLDAS_FORA0125_M) at GES DISC',
#  'GPM PR on TRMM Precipitation Statistics, at Surface and Fixed Heights 1 day 0.25x0.25 degree V06 (GPM_3PRD) at GES DISC',
#  'MERRA-2 tavgM_2d_aer_Nx: 2d,Monthly mean,Time-averaged,Single-Level,Assimilation,Aerosol Diagnostics 0.625 x 0.5 degree V5.12.4 (M2TMNXAER) at GES DISC',
#  'SBUV2/NOAA-16 Level 2 Daily Ozone Profile and Total Column from CD-ROM V008 (SBUV2N16O3) at GES DISC',
#  'Aqua AIRS-MLS Matchup Indexes V1.0 (AIRS_MLS_IND) at GES_DISC',
#  'TROPESS CrIS-SNPP L2 Peroxyacetyl Nitrate for West Coast Fires HiRes, Standard Product V1 (TRPSDL2PANCRSWCFHI) at GES DISC',
#  'Aqua/AIRS  L2 Support Retrieval (AIRS+AMSU) V7.0 at GES DISC',
#  'Multi-Satellite Volcanic Sulfur Dioxide L4 Long-Term Global Database V3 (MSVOLSO2L4) at GES DISC',
#  'MLS/Aura Level 2 Relative Humidity With Respect To Ice V005 (ML2RHI) at GES DISC',
#  'GOZCARDS Source Nitric Acid 1 month L3 10 degree Zonal Means on a Vertical Pressure Grid V1 (GozSmlpHNO3) at GES DISC',
#  'Gridded Monthly Time-Mean Observation minus Forecast (omf) Values 0.5 x 0.667 degree V001 (MA_MSU_NOAA09_OMF) at GES DISC',
#  'inst6_3d_ana_Nv: MERRA 3D Analyzed State, Meteorology Instantaneous 6-hourly  0.667 x 0.5 degree V5.2.0 (MAI6NVANA) at GES DISC',
#  'GPM SSMIS on F19 (GPROF) Radiometer Precipitation Profiling L2 1.5 hours 12 km V05 (GPM_2AGPROFF19SSMIS) at GES DISC',
#  'Sentinel-5P TROPOMI Tropospheric Formaldehyde HCHO 1-Orbit L2 5.5km x 3.5km V1 (S5P_L2__HCHO___HiR) at GES DISC',
#  'SAMS/Nimbus-7 Level 3 Gridded Retrieval Temperature Data V001 (SAMSN7L3GRIDT) at GES DISC',
#  'tavgU_3d_cld_Cp: MERRA 3D IAU Diagnostic, Cloud Properties, Diurnal  1.25 x 1.25 degree V5.2.0 (MATUCPCLD) at GES DISC',
#  'TROPESS CrIS-JPSS1 L2 Atmospheric Temperature for Forward Stream, Standard Product V1 (TRPSDL2TATMCRS1FS) at GES DISC',
#  'Gridded Monthly Time-Mean Observation minus Forecast (omf) Values 0.5 x 0.667 degree V001 (MA_MSU_NOAA06_OMF) at GES DISC',
#  'MLS/Aura Level 3 Daily Binned Sulfur Dioxide (SO2) Mixing Ratio on Zonal and Similar Grids V004 (ML3DZSO2) at GES DISC',
#  'OCO-3 Level 2 geolocated XCO2 retrieval results and algorithm diagnostic information VEarlyR (OCO3_L2_Diagnostic) at GES DISC',
#  'Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_SSU_NOAA06_OBS) at GES DISC',
#  'MLS/Aura Level 3 Monthly Binned Temperature on Assorted Grids V004 (ML3MBT) at GES DISC',
#  'MERRA-2 inst3_2d_gas_Nx: 2d,3-Hourly,Instantaneous,Single-Level,Assimilation,Aerosol Optical Depth Analysis 0.625 x 0.5 degree V5.12.4 (M2I3NXGAS) at GES DISC',
#  'MERRA-2 tavg1_2d_slv_Nx: 2d,1-Hourly,Time-Averaged,Single-Level,Assimilation,Single-Level Diagnostics 0.625 x 0.5 degree V5.12.4 (M2T1NXSLV) at GES DISC',
#  ' Sounder SIPS: Aqua AIRS Level-1C Calibration Subset: Random full spectra, V2 at GES DISC',
#  'GLDAS Noah Land Surface Model L4 3 hourly 0.25 x 0.25 degree V2.0 (GLDAS_NOAH025_3H) at GES DISC',
#  'GPM PR and TMI on TRMM Combined Precipitation L2B 1.5 hours 5 km V06 (GPM_2BCMB_TRMM) at GES DISC',
#  'Sounder SIPS: JPSS-1 CrIS Level 3 Specific Quality Control Gridded Daily CLIMCAPS V2 at GES DISC',
#  'Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_SSU_NOAA11_OBS) at GES DISC',
#  'TRMM Ground Validation Radar Site 3D Rain Map L3 1 month 2 km V7 (TRMM_3A55) at GES DISC',
#  'CAR ARCTAS Arctic Research of the Composition of the Troposphere from Aircraft and Satellites L1 V1 (CAR_ARCTAS_L1C) at GES DISC',
#  'MLS/Aura Level 2 Hydroperoxy (HO2) Mixing Ratio V004 (ML2HO2) at GES DISC',
#  'tavg3_2d_chm_Fx: MERRA Chem 2D IAU Diagnostics, Fluxes and Meteorology, Time Average 3-hourly  1.25 x 1 degree V5.2.0 (MAT3FXCHM) at GES DISC',
#  'GPM SSMI on F11 (GPROF) Climate-based Radiometer Precipitation Profiling L3 1 day 0.25 degree x 0.25 degree V05 (GPM_3GPROFF11SSMI_DAY_CLIM) at GES DISC',
#  'GPM GMI (GPROF) Radiometer Precipitation Profiling L3 1 month 0.25 degree x 0.25 degree V05 (GPM_3GPROFGPMGMI) at GES DISC',
#  'Gridded Monthly Time-Mean Observation minus Analysis (oma) Values 0.5 x 0.667 degree V001 (MA_SSMI_DMSP08_OMA) at GES DISC',
#  'MLS/Aura Level 3 Daily Binned Hypochlorous Acid (HOCl) Mixing Ratio on Assorted Grids V004 (ML3DBHOCL) at GES DISC',
#  'UARS High Resolution Doppler Imager (HRDI) Level 3AL V011 (UARHR3AL) at GES DISC',
#  'MLS/Aura Level 3 Daily Binned Methyl Chloride (CH3Cl) Mixing Ratio on Assorted Grids V005 (ML3DBCH3CL) at GES DISC',
#  'Sentinel-5P TROPOMI Radiance product band 1 (UV detector) L1B V1 (S5P_L1B_RA_BD1) at GES DISC',
#  'TRMM TMI/PR Combined Precipitation L3 1 month 0.5 degree x 0.5 degree V7 (TRMM_3B31) at GES DISC',
#  'MERRA-2 inst1_2d_asm_Nx: 2d,1-Hourly,Instantaneous,Single-Level,Assimilation,Single-Level Diagnostics 0.625 x 0.5 degree V5.12.4 (M2I1NXASM) at GES DISC',
#  'Gridded Monthly Time-Mean Observation minus Forecast (omf) Values 0.5 x 0.667 degree V001 (MA_HIRS2_NOAA12_OMF) at GES DISC',
#  'SBUV2/NOAA-11 Level 2 Daily Ozone Profile and Total Column from CD-ROM V008 (SBUV2N11O3) at GES DISC',
#  'GPM AMSU-B on NOAA 17 Common Calibrated Brightness Temperatures L1C 1.5 hours 16 km V05 (GPM_1CNOAA17AMSUB) at GES DISC',
#  'GPM DPR Ku Precipitation Profile 2A 1.5 hours 5 km V07 (GPM_2AKu) at GES DISC',
#  'MLS/Aura Level 3 Monthly Binned Hydrogen Cyanide (HCN) Mixing Ratio on Assorted Grids V004 (ML3MBHCN) at GES DISC',
#  'Gridded Monthly Time-Mean Observation minus Analysis (oma) Values 0.5 x 0.667 degree V001 (MA_AMSUA_NOAA18_OMA) at GES DISC',
#  'MLS/Aura Level 3 Daily Binned Cloud Ice (IWC) on Assorted Grids V004 (ML3DBIWC) at GES DISC',
#  'OCO-2 Level 1B calibrated, geolocated science spectra, Retrospective Processing V10r (OCO2_L1B_Science) at GES DISC',
#  'TRMM Radar Rain Distributions L3 1 month 5 degree x 5 degree V7 (TRMM_3A26) at GES DISC',
#  'GPM SSM/I on F14 (GPROF) Climate-based Radiometer Precipitation Profiling L2 1.5 hours 12 km V05 (GPM_2AGPROFF14SSMI_CLIM) at GES DISC',
#  'GPM ATMS on SUOMI-NPP (GPROF) Radiometer Precipitation Profiling L2 1.5 hours 16 km V05 (GPM_2AGPROFNPPATMS) at GES DISC',
#  'GPM DPR Ku Environment L2A 1.5 hours 5 km V07 (GPM_2AKuENV) at GES DISC',
#  'TOMS Earth Probe Total Column Ozone Daily L3 Global 1 deg x 1.25 deg Lat/Lon Grid V008 (TOMSEPL3dtoz) at GES DISC',
#  'GPM DPR Ka Precipitation Profile 2A 1.5 hours 5 km V06 (GPM_2AKa) at GES DISC',
#  'GPM DPR Precipitation Profile 1 Day 0.25 degree x 0.25 degree V07 (GPM_3DPRD) at GES DISC',
#  'TROPESS CrIS-SNPP L2 Methanol for Forward Stream, Standard Product V1 (TRPSDL2CH3OHCRSFS) at GES DISC',
#  'TROPESS AIRS-Aqua L2 Atmospheric Temperature for Forward Stream, Standard Product V1 (TRPSDL2TATMAIRSFS) at GES DISC',
#  'SBUV2/NOAA-18 Ozone (O3) Profile and Total Column Ozone 1 Month Zonal Mean L3 Global 5.0 degree Latitude Zones V1 (SBUV2N18L3zm) at GES DISC',
#  'MLS/Aura Near-Real-Time L2 Temperature V005 (ML2T_NRT) at GES DISC',
#  'MERRA-2 tavg3_3d_cld_Nv: 3d,3-Hourly,Time-Averaged,Model-Level,Assimilation,Cloud Diagnostics 0.625 x 0.5 degree V5.12.4 (M2T3NVCLD) at GES DISC',
#  'Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_HIRS3_AM_OBS) at GES DISC',
#  'Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_SSMI_DMSP11_OBS) at GES DISC',
#  'Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_HIRS2_NOAA14_OBS) at GES DISC',
#  'MERRA-2 avgM_2d_pm25_admin0, 2d, Single-Level, Country-Level Surface PM2.5 Monthly Mean Products V1 (M2_TMAX_PM25) at GES DISC',
#  'GPM IMERG Late Precipitation L3 1 day 0.1 degree x 0.1 degree V06 (GPM_3IMERGDL) at GES DISC',
#  'GPM AMSU-B on NOAA15 (GPROF) Climate-based Radiometer Precipitation Profiling L2 1.5 hours 16 km V05 (GPM_2AGPROFNOAA15AMSUB) at GES DISC',
#  'NCEP/DOE Reanalysis II in HDF-EOS5, for GSSTF2c, 1x1 deg Monthly grid V2c (GSSTFM_NCEP) at GES DISC',
#  'OCO-2 Gridded bias-corrected XCO2 and other select fields aggregated as Level 4 daily files V1 (OCO2GriddedXCO2) at GES DISC',
#  'MLS/Aura Level 3 Daily Binned Geopotential Height (GPH) on Zonal and Similar Grids V005 (ML3DZGPH) at GES DISC',
#  'SBUV2/NOAA-9 Level 2 Daily Ozone Profile and Total Column from CD-ROM V008 (SBUV2N09O3) at GES DISC',
#  'MLS/Aura Level 3 Daily Binned Relative Humidity With Respect To Ice (RHI) on Zonal and Similar Grids V005 (ML3DZRHI) at GES DISC',
#  'AIRS/Aqua L2 Standard Physical Retrieval (AIRS+AMSU+HSB) V006 (AIRH2RET) at GES DISC',
#  'TROPESS CrIS-SNPP L2 Peroxyacetyl Nitrate for West Coast Fires, Standard Product V1 (TRPSDL2PANCRSWCF) at GES DISC',
#  'OCO-3 Level 2 spatially ordered geolocated retrievals screened using the A-band Preprocessor VEarly (OCO3_L2_ABand) at GES DISC',
#  'MERRA-2 tavgU_3d_qdt_Np: 3d,diurnal,Time-Averaged,Pressure-Level,Assimilation,Moist Tendencies 0.625 x 0.5 degree V5.12.4 (M2TUNPQDT) at GES DISC',
#  'MLS/Aura Level 3 Daily Binned Nitrous Oxide (N2O) Mixing Ratio on Assorted Grids V005 (ML3DBN2O) at GES DISC',
#  'Goddard Satellite-Based Surface Turbulent Fluxes Climatology, 0.25 x 0.25 deg, Seasonal Grid V3 (GSSTFSC) at GES DISC',
#  'GPM SSMI on F14 Common Calibrated Brightness Temperatures L1C 1.5 hours 13 km V06 (GPM_1CF14SSMI) at GES DISC',
#  'MERRA-2 tavgU_2d_adg_Nx: 2d,diurnal,Time-averaged,Single-Level,Assimilation,Aerosol Diagnostics (extended) 0.625 x 0.5 degree V5.12.4 (M2TUNXADG) at GES DISC',
#  'Gridded Monthly Time-Mean Observation minus Forecast (omf) Values 0.5 x 0.667 degree V001 (MA_MSU_NOAA12_OMF) at GES DISC',
#  'TRMM Microwave Imager Precipitation Profile L3 1 month 0.5 degree x 0.5 degree V7 (TRMM_3A12) at GES DISC',
#  'GPM SSMIS on F19 (GPROF) Radiometer Precipitation Profiling L3 1 day 0.25 degree x 0.25 degree V05 (GPM_3GPROFF19SSMIS_DAY) at GES DISC',
#  'OMI/Aura Sulfur Dioxide (SO2) Total Column Daily L3 1 day Best Pixel in 0.25 degree x 0.25 degree V3 (OMSO2e) at GES DISC',
#  'Gridded Monthly Time-Mean Observation minus Analysis (oma) Values 0.5 x 0.667 degree V001 (MA_MSU_NOAA09_OMA) at GES DISC',
#  'TROPESS CrIS-SNPP L2 Methane for Australian Fires, Standard Product V1 (TRPSDL2CH4CRSAUS) at GES DISC',
#  'MLS/Aura Level 3 Daily Binned Methyl Chloride (CH3Cl) Mixing Ratio on Assorted Grids V004 (ML3DBCH3CL) at GES DISC',
#  'GPM MHS on NOAA-19 (GPROF) Radiometer Precipitation Profiling L2A 1.5 hours 17 km V05 (GPM_2AGPROFNOAA19MHS) at GES DISC',
#  'Gridded Monthly Time-Mean Observation minus Analysis (oma) Values 0.5 x 0.667 degree V001 (MA_HIRS2_NOAA11_OMA) at GES DISC',
#  'NLDAS Noah Land Surface Model L4 Monthly 0.125 x 0.125 degree V002 (NLDAS_NOAH0125_M) at GES DISC',
#  'AIRS/Aqua L2 Near Real Time (NRT) Standard Physical Retrieval (AIRS-only) V006 (AIRS2RET_NRT) at GES DISC',
#  'TROPESS CrIS-SNPP and TROPOMI-S5P L2 Ozone for Forward Stream, Standard Product V1 (TRPSDL2O3CRSTRPOMIFS) at GES DISC',
#  'GLDAS Noah Land Surface Model L4 3 hourly 0.25 x 0.25 degree Early Product V2.1 (GLDAS_NOAH025_3H_EP) at GES DISC',
#  'HIRDLS/Aura Level 3 Water Vapor (H2O) 1deg Lat Zonal Fourier Coefficients V007 (H3ZFCH2O) at GES DISC',
#  'OMI/Aura Sulphur Dioxide (SO2) Total Column Daily L2 Global Gridded 0.125 degree x 0.125 degree V3 (OMSO2G) at GES DISC',
#  'MLS/Aura Near-Real-Time L2 Nitrous Oxide (N2O) Mixing Ratio V004 (ML2N2O_NRT) at GES DISC',
#  'GLDAS VIC Land Surface Model L4 monthly 1.0 x 1.0 degree Early Product V2.1 (GLDAS_VIC10_M_EP) at GES DISC',
#  'Sentinel-5P TROPOMI Radiance product band 8 (SWIR detector) L1B 5.5km x 7km V2 (S5P_L1B_RA_BD8_HiR) at GES DISC',
#  'OCO-3 Level 1B calibrated, geolocated science spectra,  Early (OCO3_L1B_Science) at GES DISC',
#  'MLS/Aura Level 2 Methyl Chloride (CH3CL) Mixing Ratio V005 (ML2CH3CL) at GES DISC',
# ...
#  'UARS Wind Imaging Interferometer (WINDII) Level 3AL V011 (UARWI3AL) at GES DISC',
#  'GPM PR on TRMM Reflectivity, Precipitation Characteristics and Rate, at Surface and Profile L2 1.5 hours V06 (GPM_2APR) at GES DISC',
#  'OCO-3 Level 2 spatially ordered geolocated retrievals screened using the IMAP-DOAS Preprocessor (IDP), Forward Processing V10 (OCO3_L2_IMAPDOAS) at GES DISC',
#  'Sentinel-5P TROPOMI Sulphur Dioxide SO2 1-Orbit L2 5.5km x 3.5km V1 (S5P_L2__SO2____HiR) at GES DISC',
#  'Multi-Satellite Lambertian Equivalent Reflectivity (Noon Normalized) 10-Day L3 Global 2.0x5.0deg Lat/Lon Grid V1 (MSLERNNL3d10) at GES DISC',
#  'MERRA-2 inst6_3d_ana_Nv: 3d,6-Hourly,Instantaneous,Model-Level,Analysis,Analyzed Meteorological Fields 0.625 x 0.5 degree V5.12.4 (M2I6NVANA) at GES DISC',
#  'MERRA-2 inst6_3d_ana_Np: 3d,6-Hourly,Instantaneous,Pressure-Level,Analysis,Analyzed Meteorological Fields 0.625 x 0.5 degree V5.12.4 (M2I6NPANA) at GES DISC',
#  'MERRA-2 tavg3_3d_asm_Nv: 3d,3-Hourly,Time-Averaged,Model-Level,Assimilation,Assimilated Meteorological Fields 0.625 x 0.5 degree V5.12.4 (M2T3NVASM) at GES DISC',
#  'OCO-2 Level 2 bias-corrected XCO2 and other select fields from the full-physics retrieval aggregated as daily files, Retrospective processing V9r (OCO2_L2_Lite_FP) at GES DISC',
#  'TROPESS CrIS-SNPP and TROPOMI-S5P L2 Methane for Forward Stream, Standard Product V1 (TRPSDL2CH4CRSTRPOMIFS) at GES DISC',
#  'SAMS/Nimbus-7 Level 1 Radiance Data from CD-ROM V001 (SAMSN7L1RAD_CDROM) at GES DISC',
#  'OCO-2 Level 2 bias-corrected XCO2 and other select fields from the full-physics retrieval aggregated as daily files, Retrospective processing V10r (OCO2_L2_Lite_FP) at GES DISC',
#  'GPM MHS on NOAA19 (GPROF) Radiometer Precipitation Profiling L3 1 month 0.25 degree x 0.25 degree V05 (GPM_3GPROFNOAA19MHS_CLIM) at GES DISC',
#  'OMI/Aura Near UV Aerosol Optical Depth and Single Scattering Albedo L3 1 day 1.0 degree x 1.0 degree V3 (OMAERUVd) at GES DISC',
#  'MUSTARD-UMLS Level 2 Standard Products V1 (MUSUMLSL2DGG) at GES DISC',
#  'GPM SSMI on F15 Common Calibrated Brightness Temperatures L1C 1.5 hours 13 km V06 (GPM_1CF15SSMI) at GES DISC',
#  'OCO-3 Level 1B calibrated, geolocated calibration spectra, Retrospective Processing EarlyR (OCO3_L1B_Calibration) at GES DISC',
#  'AIRS/Aqua L3 8-day CO2 in the free troposphere (AIRS-only) 1 degree x 1 degree V006 (AIRS3C28) at GES DISC',
#  'TROPESS CrIS-SNPP L2 Carbon Monoxide for Buchholz2021 TS1, Standard Product V1 (TRPSDL2COCRSTS1) at GES DISC',
#  'Sentinel-5P TROPOMI SNPP VIIRS cloud product band 6 (NIR detector) 1-Orbit L2 7km x 3.5km V1 (S5P_L2__NP_BD6) at GES DISC',
#  'ATMOS L2 Trace Gases on Potential Temperature Grid, Fixed Field Format V3 (ATMOSL2TF) at GES DISC',
#  'OCO-2 Gridded bias-corrected XCO2 and other select fields aggregated as Level 4 daily files V3 (OCO2GriddedXCO2)',
#  'Carbon Monitoring System Carbon Flux Total L4 V2 (CMSFluxTotal) at GES DISC',
#  'MERRA-2 instM_2d_lfo_Nx: 2d,Monthly mean,Instantaneous,Single-Level,Assimilation,Land Surface Forcings 0.625 x 0.5 degree V5.12.4 (M2IMNXLFO) at GES DISC',
#  'TOVS GLA MONTHLY GRIDS from NOAA-9 V01 (TOVSAMNF) at GES DISC',
#  'HIRDLS/Aura Level 3 Daily Gridded 1 x 1 deg Stratospheric Columns of NO2 V007 (HIR3SCOL) at GES DISC',
#  'GPM DPR Ka Environment L2A 1.5 hours 5 km V06 (GPM_2AKaENV) at GES DISC',
#  'GPM ATMS on NOAA-20 (GPROF) Climate-based Radiometer Precipitation Profiling L2A 1.5 hours 17 km V05 (GPM_2AGPROFNOAA20ATMS_CLIM) at GES DISC',
#  'MERRA-2 tavgM_3d_qdt_Np: 3d,Monthly mean,Time-Averaged,Pressure-Level,Assimilation,Moist Tendencies 0.625 x 0.5 degree V5.12.4 (M2TMNPQDT) at GES DISC',
#  'TOMS Nimbus-7 Total Column Ozone Monthly L3 Global 1 deg x 1.25 deg Lat/Lon Grid V008 (TOMSN7L3mtoz) at GES DISC',
#  'tavg3_3d_udt_Cp: MERRA 3D IAU Tendency, Wind Components, Time average 3-hourly  1.25 x 1.25 degree V5.2.0 (MAT3CPUDT) at GES DISC',
#  'HIRDLS-MLS/Aura Level 3 Monthly 10 x 20 deg Ice Water Content V002 (HIRMLS3IWC) at GES DISC',
#  'MERRA-2 inst3_3d_aer_Nv: 3d,3-Hourly,Instantaneous,Model-Level,Assimilation,Aerosol Mixing Ratio 0.625 x 0.5 degree V5.12.4 (M2I3NVAER) at GES DISC',
#  'GPM DPR Spectral Latent Heating Profiles L3 1 month 0.5 degree x 0.5 degree V07 (GPM_3HSLH) at GES DISC',
#  'GPM MHS on METOP-C (GPROF) Climate-based Radiometer Precipitation Profiling L3 1 month 0.25 degree x 0.25 degree V05 (GPM_3GPROFMETOPCMHS_CLIM) at GES DISC',
#  'Sentinel-5P TROPOMI Tropospheric Formaldehyde HCHO 1-Orbit L2 7km x 3.5km V1 (S5P_L2__HCHO__) at GES DISC',
#  'GPM SSMIS on F17 (GPROF) Climate-based Radiometer Precipitation Profiling L3 1 month 0.25 degree x 0.25 degree V05 (GPM_3GPROFF17SSMIS_CLIM) at GES DISC',
#  'Sentinel-5P TROPOMI Radiance product band 5 (NIR detector) L1B V2 (S5P_L1B_RA_BD5) at GES DISC',
#  'MLS/Aura Level 3 Daily Binned Carbon Monoxide (CO) Mixing Ratio on Zonal and Similar Grids V005 (ML3DZCO) at GES DISC',
#  'Multi-Satellite Merged Ozone (O3) Profile and Total Column 1 Month Zonal Mean L3 Global 5.0 degree Latitude Zones V1 (MSO3L3zm5) at GES DISC',
#  'OCO-3 Level 1B calibrated, geolocated science spectra, Retrospective Processing V10r (OCO3_L1B_Science) at GES DISC',
#  'TRMM Ground Validation Calibrated QC Radar Reflectivity Full Volume Scan L1C 1 hour V7 (TRMM_1C51) at GES DISC',
#  'MLS/Aura Level 3 Daily Binned Nitrous Oxide (N2O) Mixing Ratio on Assorted Grids V004 (ML3DBN2O) at GES DISC',
#  'TIROS-3 Low-Resolution Omnidirectional Radiometer Level 1 Temperature Data V001 (TIROS3L1ORT) at GES DISC',
#  'Sentinel-5P TROPOMI Radiance product band 5 (NIR detector) L1B 5.5km x 3.5km V2 (S5P_L1B_RA_BD5_HiR) at GES DISC',
#  'MERRA-2 const_2d_ctm_Nx: Constant Model Parameters for Usage by CTM 0.625 x 0.5 degree V5.12.4 (M2C0NXCTM) at GES DISC',
#  'MLS/Aura Level 3 Daily Binned Chlorine Monoxide (ClO) Mixing Ratio on Assorted Grids V004 (ML3DBCLO) at GES DISC',
#  'CAR Kuwait Oil Fire Spectral Reflectance L1 V1 (CAR_KUWAITOILFIRE_L1C) at GES DISC',
#  'SBUV2/NOAA-19 Ozone (O3) Profile and Total Column Ozone 1 Month Zonal Mean L3 Global 5.0 degree Latitude Zones V1 (SBUV2N19L3zm) at GES DISC',
#  'Carbon Monitoring System Carbon Flux for Fire L4 V1 (CMSFluxFire) at GES DISC',
#  'MERRA-2 tavgM_2d_adg_Nx: 2d,Monthly mean,Time-averaged,Single-Level,Assimilation,Aerosol Diagnostics (extended) 0.625 x 0.5 degree V5.12.4 (M2TMNXADG) at GES DISC',
#  'BUV/Nimbus-4 Level 3 Ozone Zonal Means V005 (BUVN4L3ZMT) at GES DISC',
#  'GPM DPR Spectral Latent Heating Profiles L3 1 month 0.5 degree x 0.5 degree V06 (GPM_3HSLH) at GES DISC',
#  'OCO-2 Level 2 meteorological parameters interpolated from global assimilation model for each sounding, Retrospective Processing V9r (OCO2_L2_Met) at GES DISC',
#  'MLS/Aura Level 3 Monthly Binned Cloud Ice (IWC) on Assorted Grids V004 (ML3MBIWC) at GES DISC',
#  'Gridded Monthly Time-Mean Observation minus Analysis (oma) Values 0.5 x 0.667 degree V001 (MA_AMSUB_NOAA17_OMA) at GES DISC',
#  'GPM TMI on TRMM Antenna Temperatures L1BASE 1.5 hours 13 km V05 (GPM_BASETRMMTMI) at GES DISC',
#  'MLS/Aura Near-Real-Time L2 Carbon Monoxide (CO) Mixing Ratio V005 (ML2CO_NRT) at GES DISC',
#  'MLS/Aura Near-Real-Time L2 Nitrous Oxide (N2O) Mixing Ratio V005 (ML2N2O_NRT) at GES DISC',
#  'MODIS/Aqua Clouds 1km and 5km 5-Min L2 Wide Swath Subset along CloudSat V002 (MAC06S1) at GES DISC',
#  'Carbon Monitoring System Carbon Flux from the Net Biome Exchange Prior L4 V2 (CMSFluxNBEPrior) at GES DISC',
#  'CAR SnowEx17 Snow Mass and Energy Measurements L1 V1 (CAR_SNOWEX17_L1C) at GES DISC',
#  'GEOS-Carb CASA-GFED Daily Fire and Fuel Emissions 0.5 degree x 0.5 degree V2 (GEOS_CASAGFED_D_FIRE) at GES DISC',
#  'MLS/Aura Level 2 Hypochlorous Acid (HOCl) Mixing Ratio V004 (ML2HOCL) at GES DISC',
#  'GPM IMERG Early Precipitation L3 1 day 0.1 degree x 0.1 degree V06 (GPM_3IMERGDE) at GES DISC',
#  'TRMM Precipitation Radar Surface Cross-Section L2 1.5 hours  V7 (TRMM_2A21) at GES DISC',
#  'TRMM (TMPA-RT) Near Real-Time Microwave precipitation estimate L3 3 hour 0.25 degree x 0.25 degree V7 (TRMM_3B40RT) at GES DISC',
#  'GPM SSMIS on F16 (GPROF) Climate-based Radiometer Precipitation Profiling L3 1 day 0.25 degree x 0.25 degree V05 (GPM_3GPROFF16SSMIS_DAY_CLIM) at GES DISC',
#  'OMI/Aura Cloud Pressure and Fraction (Raman Scattering) 200-km swath subset along CloudSat track V003 (OMCLDRR_CPR) at GES DISC',
#  'MLS/Aura Level 2 Methyl Chloride (CH3CL) Mixing Ratio V004 (ML2CH3CL) at GES DISC',
#  'NCEP/DOE Reanalysis II, for GSSTF, 0.25x0.25 deg, Monthly grid V3 (GSSTFM_NCEP) at GES DISC',
#  'tavgM_3d_mst_Cp: MERRA 3D IAU Diagnostic, Moist Physics, Monthly Mean  1.25 x 1.25 degree V5.2.0 (MATMCPMST) at GES DISC',
#  'TRMM Microwave Imager Hydrometeor Profile L2 1.5 hours V7 (TRMM_2A12) at GES DISC',
#  'TROPESS TROPOMI-S5P L2 Carbon Monoxide for Forward Stream, Standard Product V1 (TRPSDL2COTRPOMIFS) at GES DISC',
#  'GPM PR and TMI on TRMM Combined Convective-Stratiform Latent Heating Profiles L2 1.5 hours 5 km V06 (GPM_2HCSH_TRMM) at GES DISC',
#  'MLS/Aura Level 2 Nitric Acid (HNO3) Mixing Ratio V005 (ML2HNO3) at GES DISC',
#  'NLDAS Noah Land Surface Model L4 Monthly Climatology 0.125 x 0.125 degree V002 (NLDAS_NOAH0125_MC) at GES DISC',
#  'CAR SCAR-B Smoke, Clouds, and Radiation-Brazil L1 V1 (CAR_SCARB_L1C) at GES DISC',
#  'NLDAS VIC Land Surface Model L4 Monthly 0.125 x 0.125 degree V002 (NLDAS_VIC0125_M) at GES DISC',
#  'MLS/Aura Level 2 Cloud Ice Product V005 (ML2IWC) at GES DISC',
#  'GPS Radio Occultation Boundary Layer Depth Seasonal L3 V1 (GPSROZPBLS) at GES DISC',
#  'OCO-3 Level 2 geolocated XCO2 retrieval results and algorithm diagnostic information, Forward Processing V10 (OCO3_L2_Diagnostic) at GES DISC',
#  'MERRA-2 tavgU_3d_odt_Np: 3d,diurnal,Time-Averaged,Pressure-Level,Assimilation,Ozone Tendencies 0.625 x 0.5 degree V5.12.4 (M2TUNPODT) at GES DISC',
#  'Gridded Monthly Time-Mean Observation minus Forecast (omf) Values 0.5 x 0.667 degree V001 (MA_MSU_NOAA10_OMF) at GES DISC',
#  'AIRS/Aqua L3 8-day Support Multiday Product (AIRS+AMSU) 1 degree x 1 degree V006 (AIRX3SP8) at GES DISC',
#  'MLS/Aura Level 3 Monthly Binned Hypochlorous Acid (HOCl) Mixing Ratio on Assorted Grids V005 (ML3MBHOCL) at GES DISC',
#  'Sentinel-5P TROPOMI Ozone Profile 1-Orbit L2 30km x 30km V2 (S5P_L2__O3__PR_HiR) at GES DISC',
#  'Carbon Monitoring System Flux for Posterior Fire Carbon L4 V1 (CMSFluxFirepost) at GES DISC',
#  'Sentinel-5P TROPOMI Radiance product band 4 (UVIS detector) L1B V1 (S5P_L1B_RA_BD4) at GES DISC',
#  'GPM MHS on NOAA19 (GPROF) Radiometer Precipitation Profiling L3 1 day 0.25 degree x 0.25 degree  V05 (GPM_3GPROFNOAA19MHS_DAY) at GES DISC',
#  'GPM SSMI on F11 Common Calibrated Brightness Temperatures L1C 1.5 hours 13 km V06 (GPM_1CF11SSMI) at GES DISC',
#  'Gridded Monthly Time-Mean Observation minus Forecast (omf) Values 0.5 x 0.667 degree V001 (MA_AIRS_AQUA_OMF) at GES DISC',
#  'MLS/Aura Level 3 Monthly Binned Cloud Ice (IWC) on Assorted Grids V005 (ML3MBIWC) at GES DISC',
#  'Sentinel-5P TROPOMI Carbon Monoxide CO Column 1-Orbit L2 7km x 7km V1 (S5P_L2__CO____) at GES DISC',
#  'GPM MHS on METOP-C (GPROF) Radiometer Precipitation Profiling L2A 1.5 hours 17 km V05 (GPM_2AGPROFMETOPCMHS) at GES DISC',
#  'GPM DPR and GMI (Combined Precipitation) L3 1 day 0.25 degree x 0.25 degree V06 (GPM_3CMB_DAY) at GES DISC',
#  'SeaWiFS Deep Blue Aerosol Optical Depth and Angstrom Exponent Level 2 Data V004 (SWDB_L2) at GES DISC V004',
#  'MSU Daily Oceanic Precipitation with Limb93 Correction L3 1 day 2.5 degree x 2.5 degree V001 (MSUOP) at GES DISC',
#  'GPM GMI (GPROF) Radiometer Precipitation Profiling L3 1 day 0.25 degree x 0.25 degree V05 (GPM_3GPROFGPMGMI_DAY) at GES DISC',
#  'Carbon Monitoring System Carbon Flux for Fossil Fuel Prior L4 V2 (CMSFluxFossilFuelPrior) at GES DISC',
#  'GPM MHS on METOP-B Common Calibrated Brightness Temperature L1C 1.5 hours 17 km V05 (GPM_1CMETOPBMHS) at GES DISC',
#  'GPM IMERG Final Precipitation L3 1 day 0.1 degree x 0.1 degree V06 (GPM_3IMERGDF) at GES DISC',
#  'TRMM Combined Precipitation Radar and Microwave Imager Rainfall Profile L2 1.5 hours V7 (TRMM_2B31) at GES DISC',
#  'NLDAS Secondary Forcing Data L4 Monthly 0.125 x 0.125 degree V002 (NLDAS_FORB0125_M) at GES DISC',
#  'Sentinel-5P TROPOMI SNPP VIIRS cloud product band 3 (UVIS detector) 1-Orbit L2 5.5km x 3.5km V1 (S5P_L2__NP_BD3_HiR) at GES DISC',
#  'GPM AMSUB on NOAA17 (GPROF) Climate-based Radiometer Precipitation Profiling L3 1 month 0.25 degree x 0.25 degree  V05 (GPM_3GPROFNOAA17AMSUB_CLIM) at GES DISC',
#  'Aqua/AIRS L2 Support Retrieval (AIRS-only) V7.0 at GES DISC',
#  'Gridded Monthly Time-Mean Observation (obs) Values 0.5 x 0.667 degree V001 (MA_MSU_NOAA08_OBS) at GES DISC',
#  'SBUV2/NOAA-11 Ozone (O3) Nadir Profile and Total Column 1 Day L2 V1 (SBUV2N11L2) at GES DISC',
#  'OMI/Aura Sulphur Dioxide (SO2) Total Column 1-orbit L2 Swath 13x24 km V003 (OMSO2) at GES DISC',
#  'Sentinel-5P TROPOMI Radiance product band 8 (SWIR detector) L1B 5.5km x 7km V1 (S5P_L1B_RA_BD8_HiR) at GES DISC',
#  'OCO-3 Level 2 meteorological parameters interpolated from global assimilation model for each sounding VEarlyR (OCO3_L2_Met) at GES DISC',
#  'MLS/Aura Near-Real-Time L2 Sulfur Dioxide (SO2) Mixing Ratio V005 (ML2SO2_NRT) at GES DISC',
#  'Aqua/AIRS L2 Near Real Time (NRT) Support Retrieval (AIRS-only) V7.0 at GES DISC',
#  'TOVS GLA DAILY GRIDS from NOAA-10 V01 (TOVSADNG) at GES DISC',
#  'MLS/Aura Level 2 Relative Humidity With Respect To Ice V004 (ML2RHI) at GES DISC',
#  'GPM MHS on NOAA18 (GPROF) Radiometer Precipitation Profiling L3 1 month 0.25 degree x 0.25 degree V05 (GPM_3GPROFNOAA18MHS) at GES DISC',
#  'TOMS Earth Probe UV Aerosol Index Monthly L3 Global 1 deg x 1.25 deg Lat/Lon Grid V008 (TOMSEPL3maer) at GES DISC',
#  'TRMM (TMPA-RT) Near Real-Time Precipitation L3 3 hour 0.25 degree x 0.25 degree V7 (TRMM_3B42RT) at GES DISC',
#  'Sentinel-5P TROPOMI Methane CH4 1-Orbit L2 5.5km x 7km V1 (S5P_L2__CH4____HiR) at GES DISC',
#  'MLS/Aura Level 3 Monthly Binned Methyl Chloride (CH3Cl) Mixing Ratio on Assorted Grids V005 (ML3MBCH3CL) at GES DISC',
#  'NLDAS Noah Land Surface Model L4 Hourly 0.125 x 0.125 degree V2.0 (NLDAS_NOAH0125_H) at GES DISC',
#  'GPM SSMIS on F18 (GPROF) Climate-based Radiometer Precipitation Profiling 1.5 hours 12 km V05 (GPM_2AGPROFF18SSMIS_CLIM) at GES DISC',
#  'OMPS-NPP L2 NM Ozone (O3) Total Column swath orbital',
#  'TOVS GLA MONTHLY GRIDS from NOAA-8 02 (TOVSAMNE) at GES DISC',
#  'TROPESS CrIS-SNPP L2 Peroxyacetyl Nitrate for Forward Stream, Standard Product V1 (TRPSDL2PANCRSFS) at GES DISC',
#  'TROPESS CrIS-SNPP L2 Carbon Monoxide for West Coast Fires HiRes, Standard Product V1 (TRPSDL2COCRSWCFHI) at GES DISC',
#  'MERRA-2 inst3_3d_chm_Nv: 3d,3-Hourly,Instantaneous,Model-Level,Assimilation,Carbon Monoxide and Ozone Mixing Ratio 0.625 x 0.5 degree V5.12.4 (M2I3NVCHM) at GES DISC',
#  'MLS/Aura Level 3 Monthly Binned Sulfur Dioxide (SO2) Mixing Ratio on Assorted Grids V005 (ML3MBSO2) at GES DISC',
#  'TOVS LMD DAILY GRIDS from NOAA-10 V01 (TOVSBDNG) at GES DISC',
#  'MLS/Aura Level 3 Daily Binned Sulfur Dioxide (SO2) Mixing Ratio on Assorted Grids V004 (ML3DBSO2) at GES DISC',
#  'OMPS-NPP L2 NM Nitrogen Dioxide (NO2) Total and Tropospheric Column swath orbital V2 (OMPS_NPP_NMNO2_L2) at GES DISC',
#  'tavg3_3d_odt_Cp: MERRA 3D IAU Tendency, Ozone, Time average 3-hourly  1.25 x 1.25 degree V5.2.0 (MAT3CPODT) at GES DISC',
#  'Gridded Monthly Time-Mean Observation minus Analysis (oma) Values 0.5 x 0.667 degree V001 (MA_SSMI_DMSP13_OMA) at GES DISC',
#  'TROPESS CrIS-JPSS1 L2 Methane for Forward Stream, Standard Product V1 (TRPSDL2CH4CRS1FS) at GES DISC',
#  'MLS/Aura Level 3 Daily Binned Relative Humidity With Respect To Ice (RHI) on Assorted Grids V005 (ML3DBRHI) at GES DISC',
#  'Sounder SIPS: JPSS-1 CrIS Level 3 Comprehensive Quality Control Gridded Monthly CLIMCAPS V2 at GES DISC',
#  'HIRDLS/Aura Level 3 Nitrous Oxide (N2O) 1deg Lat Zonal Fourier Coefficients V007 (H3ZFCN2O) at GES DISC',
#  'UARS Wind Imaging Interferometer (WINDII) Level 3AT V011 (UARWI3AT) at GES DISC',
#  ...]

# %%
kywrd2titles['12.1 Micron Extinction']

# %%
kywrd2ndftr = {}
for keyword in kywrd2titles.keys():
    sum = np.zeros(df_tfidf.shape[1])
    titles = kywrd2titles[keyword]
    for title in titles:
        tfidf_score = df_tfidf.iloc[title2index[title]].tolist()
        sum += tfidf_score
    keyword_node_features = sum / len(titles)
    kywrd2ndftr[keyword] = list(keyword_node_features)

# %%
keyword_node_features = np.array(list(kywrd2ndftr.values()))
keyword_tfidf_tensor = torch.tensor(keyword_node_features, dtype=torch.float)

# %%
keyword_tfidf_tensor
# Out:
# tensor([[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         ...,
#         [0.0000, 0.0000, 0.0000,  ..., 0.0016, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000,  ..., 0.0060, 0.0000, 0.0000]])

# %%
x = torch.cat((tfidf_tensor, keyword_tfidf_tensor))

# %%
data = Data(x=x, edge_index=edge_index, y=y, train_mask=train_mask, val_mask=val_mask, test_mask=test_mask)
